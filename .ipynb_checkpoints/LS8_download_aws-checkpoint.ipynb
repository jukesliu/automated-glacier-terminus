# %% [markdown]
# # Code to download LS8 images for Greenland peripheral glaciers using Amazon Web Services (aws)
#
# ### Jukes Liu
#
# The following code automatically downloads Landsat 8 scenes available through Amazon Web Services that have less than a threshold % of cloud cover. The Landsat 8 scenes over each glacier are identified using their pre-determined path and row, stored in a .csv file. The scenes are filtered for cloud cover using their metadata files.

# %% [markdown]
# ## 1) Set up:

# %% [markdown]
# #### Install AWS using pip or pip3
#
# Must have Amazon Web Services installed on your terminal. Follow instructions at https://docs.aws.amazon.com/cli/latest/userguide/install-linux-al2017.html to get aws commands onto your shell terminal.

# %% [markdown]
# #### Import packages

# %%
import pandas as pd
import numpy as np
import os
import subprocess
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy.ma as ma

# %% [markdown]
# #### Read in LS path and row for each peripheral glacier by BoxID into a DataFrame

# %% [markdown]
# The LS Path and Row information for each peripheral glacier is stored in a .csv file.
#
# Note: Many glaciers exist in the same Landsat scene, so some Paths and Rows are repeated. Therefore, the subsequent code will not repeat download for a path and row combination that already exists in the output directory.

# %%
# #set basepath
# basepath = '/home/jukes/Documents/Sample_glaciers/'
# #basepath = '/home/automated-glacier-terminus/'
# outputpath = '/media/jukes/jukes1/'

# #read the path row csv file into a dataframe
# pathrows_df = pd.read_csv(basepath+'LS_pathrows.csv', sep=',', usecols =[0,1,2], dtype=str, nrows =10)
# pathrows_df = pathrows_df.set_index('BoxID')
# pathrows_df

# %%
#set basepath
basepath = '/home/jukes/Documents/Sample_glaciers/'
#basepath = '/home/automated-glacier-terminus/'
outputpath = '/media/jukes/jukes1/'

#read the path row csv file into a dataframe
pathrows_df_mult = pd.read_csv(basepath+'LS_pathrows_multiple.csv', sep=',', usecols =[1,2,3], dtype=str)
# pathrows_df = pathrows_df.set_index('BoxID')
pathrows_df_mult
# Out:
#    BoxID Path  Row
# 0    001  036  004
# 1    001  037  004
# 2    001  035  005
# 3    001  033  005
# 4    001  034  005
# 5    001  031  005
# 6    001  032  005
# 7    002  033  005
# 8    002  035  005
# 9    002  034  005
# 10   002  031  005
# 11   002  030  005
# 12   002  032  005
# 13   004  032  005
# 14   004  031  005
# 15   004  034  005
# 16   004  029  006
# 17   004  028  006
# 18   004  030  005
# 19   004  033  005
# 20   033  009  014
# 21   033  008  014
# 22   033  007  014
# 23   033  009  013
# 24   120  232  018
# 25   120  233  017
# 26   120  232  017
# 27   174  232  017
# 28   174  233  017
# 29   235  232  015
# 30   235  233  015
# 31   235  001  015
# 32   259  232  015
# 33   259  233  015
# 34   259  001  015
# 35   277  001  014
# 36   277  232  015
# 37   277  233  015
# 38   531  017  001
# 39   531  016  001
# 40   531  119  001
# 41   531  120  001
# 42   531  121  001
# 43   531  007  002
# 44   531  008  002
# 45   531  006  003
# 46   531  010  002
# 47   531  011  002
# 48   531  012  002
# 49   531  013  002
# 50   531  115  002
# 51   531  007  003
# 52   531  015  001
# 53   531  009  002
# 54   531  014  001

# %%
#check the df dimensions
pathrows_df_mult.shape

# %% [markdown]
# #### Create output directory: LS8aws

# %%
#create LS8aws folder
if os.path.exists(outputpath+'LS8aws')==True:
    print("Path exists already")
else:
    os.mkdir(outputpath+'LS8aws')
    print("LS8aws directory made")
# Out:
# Path exists already

# %% [markdown]
# ## 2) Download B8 (panchromatic band) and MTL.txt (metadata) files for all available images over the path/row of the glaciers

# %% [markdown]
# The Landsat8 scenes stored in AWS can be accessed using the landsat-pds bucket and the path and row information. Each of the bands and a metadata file can be accessed separately.
#
# We are interested in the panchromatic band (B8.TIF) and the metadata file to filter for cloud cover (MTL.txt). The download commands will use the following syntax:
#
#
#     aws --no-sign-request s3 cp s3://landsat-pds/L8/path/row/LC8pathrowyear001LGN00/LC8pathrowyear001LGN00_MTL.txt /path_to/output/
#
#     aws --no-sign-request s3 cp s3://landsat-pds/L8/path/row/LC8pathrowyear001LGN00/LC8pathrowyear001LGN00_B8.TIF /path_to/output/
#
# Access https://docs.opendata.aws/landsat-pds/readme.html to learn more.

# %% [markdown]
# ### 2A) For one BoxID (one glacier) at a time

# %%
#choose a glacier: Box001
BoxID = pathrows_df.index[0]
path = pathrows_df['Path'][0]
row = pathrows_df['Row'][0] 
print('BoxID ', BoxID, 'path', path, 'row', row)

#set path row folder name
folder_name = 'Path'+path+'_Row'+row
print(folder_name)

#set input path
bp_in = 's3://landsat-pds/L8/'
totalp_in = bp_in+path+'/'+row+'/'
print(totalp_in)

#set output path
bp_out = outputpath+'LS8aws/'+folder_name+'/'
print(bp_out)
# Out:
# BoxID  001 path 034 row 005
# Path034_Row005
# s3://landsat-pds/L8/034/005/
# /media/jukes/jukes1/LS8aws/Path034_Row005/

# %% [markdown]
# #### Create the Path_Row folder

# %%
#create Path_row folder and write path names to txt files
if os.path.exists(bp_out):
    print(folder_name, " EXISTS ALREADY. SKIP.")
else:
    os.mkdir(bp_out)
    print(folder_name+" directory made")
# Out:
# Path034_Row005  EXISTS ALREADY. SKIP.

# %% [markdown]
# #### Download all the metadata text files using os.system aws commands

# %% [markdown]
# Use the following syntax:
#
#     aws --no-sign-request s3 cp s3://landsat-pds/L8/031/005/ Output/path/LS8aws/Path031_Row005/ --recursive --exclude "*" --include "*.txt"

# %%
# #Check command syntax:
# command = 'aws --no-sign-request s3 cp '+totalp_in+' '+bp_out+' --recursive --exclude "*" --include "*.txt"'
# print(command)

# %%
# #call the command line that downloads the metadata files using aws
# subprocess.call(command, shell=True)

# %% [markdown]
# #### Download BQA band to get cloud mask using os.system aws commands

# %% [markdown]
# Use the following syntax:
#
#     aws --no-sign-request s3 cp s3://landsat-pds/L8/031/005/ Output/path/LS8aws/Path031_Row005/ --recursive --exclude "*" --include "*BQA.TIF"

# %%
#Check command syntax:
command2 = 'aws --no-sign-request s3 cp '+totalp_in+' '+bp_out+' --recursive --exclude "*" --include "*BQA.TIF"'
print(command2)
# Out:
# aws --no-sign-request s3 cp s3://landsat-pds/L8/034/005/ /media/jukes/jukes1/LS8aws/Path034_Row005/ --recursive --exclude "*" --include "*BQA.TIF"

# %%
#call the command line that downloads the BQA files using aws
subprocess.call(command2, shell=True)
# Out:
# 0

# %% [markdown]
# ### Cloud filtering

# %% [markdown]
# #### Option 1) Filter for cloud cover using metadata cloud cover percentage
#
# If the metadata files indicate land cloud cover is less than the threshold, then download the B8, otherwise, delete the folder. Not all metadata files contain the land cloud cover, some only contain the overall cloud cover. If land cloud cover is not found, use the cloud cover value to determine whether the image should be downloaded .Use the following metadata attributes:
#
#   GROUP = IMAGE_ATTRIBUTES
#
#     CLOUD_COVER = 23.58
#     CLOUD_COVER_LAND = 20.41

# %% [markdown]
# Set cloud cover % thresholds and paths:

# %%
# #set cloud cover % thresholds
# ccland_thresh = 30.0
# cc_thresh = 50.0

# #set paths:
# #set path row folder name
# folder_name = 'Path'+path+'_Row'+row
# print(folder_name)

# #set input path
# bp_in = 's3://landsat-pds/L8/'
# totalp_in = bp_in+path+'/'+row+'/'
# print(totalp_in)

# #set output path
# bp_out = outputpath+'LS8aws/'+folder_name+'/'
# print(bp_out)

# %% [markdown]
# Loop, filter, download all images:

# %%
# #loop through all the metadata files in the path_row folder:
# for image in os.listdir(bp_out):
#     if image.startswith("LC"):
#         #list the name of the image folder
#         print(image)
        
#         #open the metadata file within that folder
#         mdata = open(bp_out+image+"/"+image+"_MTL.txt", "r")
        
#         #set a detection variable for whether or not the metadata contains land cloud cover
#         ccl_detected = False
        
#         #loop through each line in metadata to find Land Cloud Cover
#         for line in mdata:
#             cc_variable = line.split("=")[0]
            
#             #if there is land cloud cover:
#             if ("CLOUD_COVER_LAND" in cc_variable):
#                 #save it:
#                 ccl = np.float(line.split("=")[1])
                         
#                 #switch the ccl_detected variable to True!
#                 ccl_detected = True
                    
#                 #if the ccl is less than the threshold, delete the file
#                 if ccl > ccland_thresh:
#                     #remove the image directory
#                     subprocess.call('rm -r '+bp_out+image, shell=True)
#                     print(ccl, ' > ', ccland_thresh, ", ", image, "removed")
#                 #otherwise: 
#                 else:
#                     #DOWNLOAD THE B8 FILE
#                     subprocess.call('source activate aws; aws --no-sign-request s3 cp '+totalp_in+' '+bp_out+' --recursive --exclude "*" --include "*B8.TIF"', shell=True)
#                     print(image, "B8 downloaded -ccl ")
        
#         #Was the ccl detected?
#         print("CCL detected = ", ccl_detected)
                        
#         #if False,use the overall cloud cover:
#         if ccl_detected == False:   
#             print("CCL not detected, use CC.")
            
#             #open the metadata file again
#             mdata = open(bp_out+image+"/"+image+"_MTL.txt", "r")
#             for line in mdata:
#                 variable = line.split("=")[0]
                
#                 #now there should only be one line starting with cloud_cover
#                 if ("CLOUD_COVER" in variable):       
#                     #save the cloud cover:
#                     cc = np.float(line.split("=")[1])

#                     #if the cc is less than the threshold, delete the file:
#                     if cc > cc_thresh:
#                         #remove the image directory
#                         subprocess.call('rm -r '+bp_out+image, shell=True)
#                         print(cc, ' > ', cc_thresh, ", ", image, "removed")

#                     #otherwise: 
#                     else:
#                         #DOWNLOAD THE B8 FILE
#                         subprocess.call('source activate aws; aws --no-sign-request s3 cp '+totalp_in+' '+bp_out+' --recursive --exclude "*" --include "*B8.TIF"', shell=True)
#                         print(image, "B8 downloaded -cc")
# print('Done.')

# %% [markdown]
# #### Option 2) Filter for cloud cover using BQA cloud info
#
# The Landsat-8 BQA band includes a basic classification of surface types. These classes include water, snow/ice, and cloud. The values for cloud pixels are higher than others, > 50,000 in the 16-bit images. Therefore, we calculate the percentage of cloud pixels in each glacier's terminus box. If the percentage is above the threshold, we remove the directory and do not download the image. If the percentage is lower than the threshold, then we download the panchromatic image.
#
# Set cloud percentage threshold:

# %%
cpercent_thresh = 20.0

# %% [markdown]
# Load terminus box shapefile for subsetting and load the raster to count total number of pixels within the box:

# %%
#set path to terminus box shp
boxpath = basepath+'Box'+BoxID+'/Box'+BoxID+'.shp'
print(boxpath)

#set path to terminus box raster
boxrasterpath = basepath+'Box'+BoxID+'/Box'+BoxID+'_raster_cut.png'
print(boxrasterpath)
# Out:
# /home/jukes/Documents/Sample_glaciers/Box001/Box001.shp
# /home/jukes/Documents/Sample_glaciers/Box001/Box001_raster_cut.png

# %%
#load in box raster and count where raster == 1 using np.count_nonzero
#read the raster into an ndarray
termbox = mpimg.imread(boxrasterpath)
termplot = plt.imshow(termbox)
plt.show()

totalpixels = np.count_nonzero(termbox)
#print(termbox.shape[0]*termbox.shape[1])
print('Total number of pixels in the raster:',totalpixels)
# Out:
# Total number of pixels in the raster: 3023

# %% [markdown]
# Re-project and subset the BQA band to the glacier BOI terminus box using GDAL commands with syntax:
#
# 1) Reproject into Greenland Polar Stereographic projection
#
#     gdalwarp -t_srs ‘+proj=stere +lat_ts=70 +lat_0=90 +lon_0=-45 +y=0 +x=0 +k=1 +datum=WGS84 +units=m’ path_to_input_BQA.TIF path_to_renamed_output_BQA.TIF
#
# 2) Subset
#
#     gdalwarp -cutline path_to_Box###.shp -crop_to_cutline path_to_BQA.TIF path_to_result_BQA.TIF
#
# Then calculate the number of cloud pixels

# %%
#export GDAL path command:
export_GDALpath = 'export PATH=/Library/Frameworks/GDAL.framework/Programs:$PATH ; '

#loop through all the metadata files in the path_row folder:
for image in os.listdir(bp_out):
    if image.startswith("LC"):
        #list the name of the image folder
#         print(image)

        #set the path to the BQA band
        bandpath = bp_out+image+'/'
        
        for band in os.listdir(bandpath):
            if band.endswith("BQA.TIF"):
                print(band)
                
                bandpath = bandpath+band
                rp_bandpath = bandpath[:-4]+"_PS.TIF"
                cut_rp_bandpath = rp_bandpath[:-4]+"_Box"+BoxID+".TIF"
#                 print(bandpath)
#                 print(rp_bandpath)
#                 print(cut_rp_bandpath)
                
#                 #reproject the band:
#                 reproject_cmd = "gdalwarp -t_srs '+proj=stere +lat_ts=70 +lat_0=90 +lon_0=-45 +y=0 +x=0 +k=1 +datum=WGS84 +units=m' "+bandpath+" "+rp_bandpath
# #                 print(export_GDALpath+reproject_cmd)
#                 subprocess.call(export_GDALpath+reproject_cmd, shell=True)
                print('BQA reprojected')

#                 #subset the reprojected BQA band to terminus box:
#                 subsetBQA_cmd = 'gdalwarp -cutline '+boxpath+' -crop_to_cutline '+rp_bandpath+" "+cut_rp_bandpath
# #                 print(export_GDALpath+subsetBQA_cmd)
#                 subprocess.call(export_GDALpath+subsetBQA_cmd, shell=True)
                print('BQA subset')
        
                #load the subset BQA band and mask out any values that are less than 50000 (clouds)
                subsetBQA = mpimg.imread(cut_rp_bandpath)
                cloudBQA = subsetBQA[subsetBQA >= 50000]
#                 print(cloudBQA)
                
                #count the number of cloud pixels
                cloudpixels = len(cloudBQA)
#                 print(cloudpixels)
                
                #calculate divided by the total
                cloudpercent = cloudpixels/totalpixels*100
                print('Cloud % in box:', cloudpercent)
                
                #if statement cloud percent is greater than the threshold, delete the folder:
            if cloudpercent > cpercent_thresh:
                #remove the image directory
                subprocess.call('rm -r '+bp_out+image, shell=True)
                print(cloudpercent, ' > ', cpercent_thresh, ", ", image, "removed")
            #otherwise: 
            else:
                #DOWNLOAD THE B8 FILE
#                 subprocess.call('source activate aws; aws --no-sign-request s3 cp '+totalp_in+' '+bp_out+' --recursive --exclude "*" --include "*B8.TIF"', shell=True)
                print(image, "B8 downloaded")
# Out:
# LC80340052014215LGN00_BQA.TIF
# Cloud % in box: 6.45054581541515
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-108-c86da8f39fc8> in <module>
#      55                 else:
#      56                     #DOWNLOAD THE B8 FILE
# ---> 57                     subprocess.call('source activate aws; aws --no-sign-request s3 cp '+totalp_in+' '+bp_out+' --recursive --exclude "*" --include "*B8.TIF"', shell=True)
#      58                     print(image, "B8 downloaded")
#      59
#
# ~/anaconda3/lib/python3.7/subprocess.py in call(timeout, *popenargs, **kwargs)
#     323     with Popen(*popenargs, **kwargs) as p:
#     324         try:
# --> 325             return p.wait(timeout=timeout)
#     326         except:  # Including KeyboardInterrupt, wait handled that.
#     327             p.kill()
#
# ~/anaconda3/lib/python3.7/subprocess.py in wait(self, timeout)
#     988             endtime = _time() + timeout
#     989         try:
# --> 990             return self._wait(timeout=timeout)
#     991         except KeyboardInterrupt:
#     992             # https://bugs.python.org/issue25942
#
# ~/anaconda3/lib/python3.7/subprocess.py in _wait(self, timeout)
#    1622                         if self.returncode is not None:
#    1623                             break  # Another thread waited.
# -> 1624                         (pid, sts) = self._try_wait(0)
#    1625                         # Check the pid and loop as waitpid has been known to
#    1626                         # return 0 even without WNOHANG in odd situations.
#
# ~/anaconda3/lib/python3.7/subprocess.py in _try_wait(self, wait_flags)
#    1580             """All callers to this function MUST hold self._waitpid_lock."""
#    1581             try:
# -> 1582                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1583             except ChildProcessError:
#    1584                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %% [markdown]
# ### 2B) For ALL glaciers:

# %% [markdown]
# #### Option 1: Metadata cloud cover % threshold

# %%
# #SET cloud cover thresholds for filtering
# ccland_thresh = 30.0
# cc_thresh = 50.0



# #LOOP through each of the glaciers in the DataFrame and download for each path and row
# for i in range(0, len(pathrows_df.index)):
#     #SET path and row variables to the LS path and rows of the box
#     path = pathrows_df['Path'][i]
#     row = pathrows_df['Row'][i]
#     #print(path, row)
    
#     #1) CREATE path and row folders to download into and set input output paths
#     #SET path row folder name
#     folder_name = 'Path'+path+'_Row'+row
#     print(folder_name)
    
#     #SET input path
#     bp_in = 's3://landsat-pds/L8/'
#     totalp_in = bp_in+path+'/'+row+'/'
#     #print(totalp_in)

#     #SET output path
#     bp_out = outputpath+'LS8aws/'+folder_name+'/'
    
    
    
#     #IF the folder exists, it's already been downloaded, do not attempt download.
#     if os.path.exists(bp_out):
#         print(folder_name, " EXISTS ALREADY. SKIP.")
#     #2) OTHERWISE, create the folder and download into it
#     else:
#         os.mkdir(bp_out)
#         print(folder_name+" directory made")

        
#         #3) DOWNLOAD metadata files into the new path-row folder
#         #CHECK COMMAND SYNTAX
#         command = 'source activate aws; aws --no-sign-request s3 cp '+totalp_in+' '+bp_out+' --recursive --exclude "*" --include "*.txt"'
#         #print(command)
#         subprocess.call(command, shell=True)
        
        
        
#         #4) LOOP through all the files in the path_row folder to download based on cloud cover
#         # in the metadata files
#         for image in os.listdir(bp_out):
#             if image.startswith("LC"):
#                 #list the name of the image folder
#                 print(image)

#                 #open the metadata file within that folder
#                 mdata = open(bp_out+image+"/"+image+"_MTL.txt", "r")

#                 #set a detection variable for whether or not the metadata contains land cloud cover
#                 ccl_detected = False

#                 #loop through each line in metadata to find the land cloud cover
#                 for line in mdata:
#                     cc_variable = line.split("=")[0]

#                     #if there is land cloud cover:
#                     if ("CLOUD_COVER_LAND" in cc_variable):
#                         #save it:
#                         ccl = np.float(line.split("=")[1])

#                         #switch the ccl detected variable to True
#                         ccl_detected = True

#                         #if the ccl is less than the threshold, delete the file
#                         if ccl > ccland_thresh:
#                             #remove the image directory
#                             #subprocess.call('rm -r '+bp_out+image, shell=True)
#                             print(ccl, ' > ', ccland_thresh, ", ", image, "removed")
#                         #otherwise: 
#                         else:
#                             #download the B8 file
#                             subprocess.call('source activate aws; aws --no-sign-request s3 cp '+totalp_in+' '+bp_out+' --recursive --exclude "*" --include "*B8.TIF"', shell=True)
#                             print(image, "B8 downloaded -ccl ")

#                 print("CCL detected = ", ccl_detected)

#                 #if False,use the overall cloud cover:
#                 if ccl_detected == False:   
#                     print("CCL not detected, use CC.")

#                     #open the metadata file again
#                     mdata = open(bp_out+image+"/"+image+"_MTL.txt", "r")
#                     for line in mdata:
#                         variable = line.split("=")[0]

#                         #now there should only be one line starting with cloud_cover
#                         if ("CLOUD_COVER" in variable):       
#                             #save the cloud cover:
#                             cc = np.float(line.split("=")[1])

#                             #if the cc is less than the threshold, delete the file:
#                             if cc > cc_thresh:
#                                 #remove the image directory
#                                 #subprocess.call('rm -r '+bp_out+image, shell=True)
#                                 print(cc, ' > ', cc_thresh, ", ", image, "removed")

#                             #otherwise: 
#                             else:
#                                 #DOWNLOAD THE B8 FILE
#                                 subprocess.call('source activate aws; aws --no-sign-request s3 cp '+totalp_in+' '+bp_out+' --recursive --exclude "*" --include "*B8.TIF"', shell=True)
#                                 print(image, "B8 downloaded -cc")

# %% [markdown]
# #### Option 2: BQA cloud cover threshold. Might be best to split this into 3 separate parts

# %%
#SET cloud cover threshold
cpercent_thresh = 20.0

#LOOP through each of the glaciers in the DataFrame and download for each path and row
for i in range(0, len(pathrows_df_mult)):
    #SET path and row variables to the LS path and rows of the box
    path = pathrows_df_mult['Path'][i]
    row = pathrows_df_mult['Row'][i]
    BoxID = pathrows_df_mult['BoxID'][i]
#     print(path, row, BoxID)
    
    #SET path and row and set input output paths and create BoxID folder if it doesn't already exists
    #set path row folder name
    folder_name = 'Path'+path+'_Row'+row
#     print(folder_name)
    folder_path = outputpath+'LS8aws/'+folder_name+'/'
   
    #SET input path
    bp_in = 's3://landsat-pds/L8/'
    totalp_in = bp_in+path+'/'+row+'/'    
    #print(totalp_in)

    #SET output path
    bp_out = outputpath+'LS8aws/Box'+BoxID+'/'    
    
    #1) CREATE BOXID FOLDER AND PATHROW FOLDERS
    if os.path.exists(bp_out):
        print("Box"+BoxID+" exists already.")
    # OTHERWISE, create the folder and download into it
    else:
        os.mkdir(bp_out)
        print("Box"+BoxID+" folder made")
     
    #IF the path_row folder exists, it's already been downloaded, do not attempt download.
    if os.path.exists(folder_path):
        print(folder_name, " ALREADY DOWNLOADED. SKIP.")
#     #OTHERWISE, create the folder and download into it
#     else:
#         os.mkdir(folder_path)
#         print(folder_name+" directory made")
            
    
#         2) DOWNLOAD METADATAFILES INTO PATHROW FOLDERS FOR STORAGE
#         # #Check command syntax:
#         dwn_command = 'aws --no-sign-request s3 cp '+totalp_in+' '+folder_path+' --recursive --exclude "*" --include "*.txt"'
#         print(dwn_command)
#         subprocess.call(dwn_command, shell=True)
    
    
#         #3) DOWNLOAD BQA files into the BoxID folder
#         #CHECK COMMAND SYNTAX
#         command2 = 'aws --no-sign-request s3 cp '+totalp_in+' '+bp_out+' --recursive --exclude "*" --include "*BQA.TIF"'
# #         print(command2)
#         subprocess.call(command2, shell=True)
        

        #set path to terminus box raster for calculation of cloud cover percentage
        boxrasterpath = basepath+'Box'+BoxID+'/Box'+BoxID+'_raster_cut.png'
#         print(boxrasterpath)
                
        #load in box raster and count where raster == 1 using np.count_nonzero
        #read the raster into an ndarray
        termbox = mpimg.imread(boxrasterpath)
        termplot = plt.imshow(termbox)
        plt.show()

        totalpixels = np.count_nonzero(termbox)
        #print(termbox.shape[0]*termbox.shape[1])
        print('Total number of pixels in the raster:',totalpixels)
        
        
        
        #set path to terminus box shp for subsetting
        boxpath = basepath+'Box'+BoxID+'/Box'+BoxID+'.shp'
#         print(boxpath)

        #export GDAL path command:
        export_GDALpath = 'export PATH=/Library/Frameworks/GDAL.framework/Programs:$PATH ; '

        #loop through all the BQA files in the path_row folder:
        for image in os.listdir(bp_out):
            if image.endswith("LGN", -5, -2):
                #list the name of the image folder
        #         print(image)
                #set the path to the BQA band
                bandpath = bp_out+image+'/'
#                 print(bandpath)
                
                img_name = image
                #default downloaded flag is False
                downloaded = False
                        
                for band in os.listdir(bandpath):

                    if band.endswith("BQA.TIF"):
#                         print(band)
                        
                        cloudpercent = 9999

                        bandpath = bandpath+band
                        rp_bandpath = bandpath[:-4]+"_PS.TIF"
                        cut_rp_bandpath = rp_bandpath[:-4]+"_Box"+BoxID+".TIF"
                        
                        
#                         #4) REPROJECT AND SUBSET THE BQA BAND FOR CLOUD COVER % CALCULATION FOR EACH GLACIER
#         #                 #reproject the band:
#                         reproject_cmd = "gdalwarp -t_srs '+proj=stere +lat_ts=70 +lat_0=90 +lon_0=-45 +y=0 +x=0 +k=1 +datum=WGS84 +units=m' "+bandpath+" "+rp_bandpath
#         #                 print(export_GDALpath+reproject_cmd)
#                         subprocess.call(export_GDALpath+reproject_cmd, shell=True)
#                         print('BQA reprojected')

#                         #subset the reprojected BQA band to terminus box:
#                         subsetBQA_cmd = 'gdalwarp -cutline '+boxpath+' -crop_to_cutline '+rp_bandpath+" "+cut_rp_bandpath
#         #                 print(export_GDALpath+subsetBQA_cmd)
#                         subprocess.call(export_GDALpath+subsetBQA_cmd, shell=True)
#                         print('BQA subset')
                        
                        #if the scene is in the folder_path, continue with download!
                        if os.path.exists(folder_path+img_name):
                            print(img_name)
                            #5) CALCULATE % CLOUD COVER IN EACH GLACIER'S TERMINUS BOX
                            #load the subset BQA band and mask out any values that are less than 50000 (clouds)
                            subsetBQA = mpimg.imread(cut_rp_bandpath)
                            cloudBQA = subsetBQA[subsetBQA >= 50000]
            #                 print(cloudBQA)

                            #count the number of cloud pixels
                            cloudpixels = len(cloudBQA)
            #                 print(cloudpixels)

                            #calculate divided by the total
                            cloudpercent = cloudpixels/totalpixels*100
                            print('Cloud % in box:', cloudpercent)

                            #5) IF cloud percent is greater than the threshold, delete the folder:
                            if cloudpercent > cpercent_thresh:
                                #remove the image directory from the BoxID folder
                                subprocess.call('rm -r '+bp_out+image, shell=True)
                                print(cloudpercent, ' > ', cpercent_thresh, ", ", image, "removed")
                            #otherwise: 
                            else:
                                #then go into the folder and try to find a B8 file:
                                for file in os.listdir(folder_path+img_name+'/'):
                                    if file == img_name+"_B8.TIF":
                                        #if B8 is found, do not download again, flip downloaded tag
                                        print(img_name, "B8 already downloaded.")
                                        downloaded = True
                                if downloaded == False:
                                    print(img_name, "B8 downloading")
    #                                 subprocess.call('source activate aws; aws --no-sign-request s3 cp '+totalp_in+' '+folder_path+' --recursive --exclude "*" --include "*B8.TIF"', shell=True)
# Out:
# Box001 exists already.
# Path036_Row004  ALREADY DOWNLOADED. SKIP.
# Total number of pixels in the raster: 3023
# LC80360042017077LGN00
# Cloud % in box: 2.3817399933840555
# LC80360042017077LGN00 B8 already downloaded.
# LC80360042016107LGN00
# Cloud % in box: 17.036056897122066
# LC80360042016107LGN00 B8 already downloaded.
# LC80360042015232LGN00
# Cloud % in box: 0.03307972213033411
# LC80360042015232LGN00 B8 already downloaded.
# LC80360042015072LGN00
# Cloud % in box: 4.366523321204102
# LC80360042015072LGN00 B8 already downloaded.
# LC80360042015200LGN00
# Cloud % in box: 17.697651339728747
# LC80360042015200LGN00 B8 already downloaded.
# LC80360042013258LGN00
# Cloud % in box: 3.208733046642408
# LC80360042013258LGN00 B8 already downloaded.
# LC80360042016267LGN00
# Cloud % in box: 1.0254713860403573
# LC80360042016267LGN00 B8 already downloaded.
# LC80360042014229LGN00
# Cloud % in box: 18.425405226596098
# LC80360042014229LGN00 B8 already downloaded.
# LC80360042016203LGN00
# Cloud % in box: 0.9923916639100231
# LC80360042016203LGN00 B8 already downloaded.
# LC80360042015280LGN00
# Cloud % in box: 0.03307972213033411
# LC80360042015280LGN00 B8 already downloaded.
# LC80360042014245LGN00
# Cloud % in box: 0.03307972213033411
# LC80360042014245LGN00 B8 already downloaded.
# LC80360042015168LGN00
# Cloud % in box: 0.33079722130334105
# LC80360042015168LGN00 B8 already downloaded.
# LC80360042016219LGN00
# Cloud % in box: 0.16539861065167052
# LC80360042016219LGN00 B8 already downloaded.
# LC80360042014181LGN00
# Cloud % in box: 0.0
# LC80360042014181LGN00 B8 already downloaded.
# LC80360042016139LGN00
# Cloud % in box: 0.0
# LC80360042016139LGN00 B8 already downloaded.
# LC80360042016251LGN00
# Cloud % in box: 0.0
# LC80360042016251LGN00 B8 already downloaded.
# LC80360042017109LGN00
# Cloud % in box: 0.03307972213033411
# LC80360042017109LGN00 B8 already downloaded.
# LC80360042015216LGN00
# Cloud % in box: 11.313264968574265
# LC80360042015216LGN00 B8 already downloaded.
# LC80360042014261LGN00
# Cloud % in box: 0.0
# LC80360042014261LGN00 B8 already downloaded.
# LC80360042015104LGN00
# Cloud % in box: 0.03307972213033411
# LC80360042015104LGN00 B8 already downloaded.
# LC80360042013146LGN00
# Cloud % in box: 0.0
# LC80360042013146LGN00 B8 already downloaded.
# LC80360042016123LGN00
# Cloud % in box: 4.168044988422097
# LC80360042016123LGN00 B8 already downloaded.
# LC80360042015136LGN00
# Cloud % in box: 7.839894144889183
# LC80360042015136LGN00 B8 already downloaded.
# LC80360042016091LGN00
# Cloud % in box: 0.5954349983460139
# LC80360042016091LGN00 B8 already downloaded.
# LC80360042017093LGN00
# Cloud % in box: 1.6209063843863711
# LC80360042017093LGN00 B8 already downloaded.
# LC80360042015264LGN00
# Cloud % in box: 0.29771749917300694
# LC80360042015264LGN00 B8 already downloaded.
# LC80360042014101LGN00
# Cloud % in box: 0.06615944426066822
# LC80360042014101LGN00 B8 already downloaded.
# LC80360042015088LGN00
# Cloud % in box: 0.5292755540853458
# LC80360042015088LGN00 B8 already downloaded.
# LC80360042015120LGN00
# Cloud % in box: 0.29771749917300694
# LC80360042015120LGN00 B8 already downloaded.
# Box001 exists already.
# Path037_Row004  ALREADY DOWNLOADED. SKIP.
# Total number of pixels in the raster: 3023
# LC80370042015079LGN00
# Cloud % in box: 0.0
# LC80370042015079LGN00 B8 downloading
# LC80370042014172LGN00
# Cloud % in box: 0.0
# LC80370042014172LGN00 B8 downloading
# LC80370042015223LGN00
# Cloud % in box: 0.0
# LC80370042015223LGN00 B8 downloading
# LC80370042016210LGN00
# Cloud % in box: 0.0
# LC80370042016210LGN00 B8 downloading
# LC80370042016162LGN00
# Cloud % in box: 0.0
# LC80370042016162LGN00 B8 downloading
# LC80370042016098LGN00
# Cloud % in box: 0.0
# LC80370042016098LGN00 B8 downloading
# LC80370042015191LGN00
# Cloud % in box: 0.0
# LC80370042015191LGN00 B8 downloading
# LC80370042015271LGN00
# Cloud % in box: 0.0
# LC80370042015271LGN00 B8 downloading
# LC80370042014252LGN00
# Cloud % in box: 0.0
# LC80370042014252LGN00 B8 downloading
# LC80370042015255LGN00
# Cloud % in box: 0.0
# LC80370042015255LGN00 B8 downloading
# LC80370042014156LGN01
# Cloud % in box: 0.0
# LC80370042014156LGN01 B8 downloading
# LC80370042016226LGN00
# Cloud % in box: 0.0
# LC80370042016226LGN00 B8 downloading
# LC80370042017084LGN00
# Cloud % in box: 0.0
# LC80370042017084LGN00 B8 downloading
# LC80370042017100LGN00
# Cloud % in box: 0.0
# LC80370042017100LGN00 B8 downloading
# LC80370042015127LGN00
# Cloud % in box: 0.0
# LC80370042015127LGN00 B8 downloading
# LC80370042016194LGN00
# Cloud % in box: 0.0
# LC80370042016194LGN00 B8 downloading
# LC80370042016146LGN00
# Cloud % in box: 0.0
# LC80370042016146LGN00 B8 downloading
# LC80370042014268LGN00
# Cloud % in box: 0.0
# LC80370042014268LGN00 B8 downloading
# LC80370042013265LGN00
# Cloud % in box: 0.0
# LC80370042013265LGN00 B8 downloading
# LC80370042017068LGN00
# Cloud % in box: 0.0
# LC80370042017068LGN00 B8 downloading
# LC80370042013249LGN00
# Cloud % in box: 0.0
# LC80370042013249LGN00 B8 downloading
# LC80370042015111LGN00
# Cloud % in box: 0.0
# LC80370042015111LGN00 B8 downloading
# LC80370042015143LGN00
# Cloud % in box: 0.0
# LC80370042015143LGN00 B8 downloading
# LC80370042016242LGN00
# Cloud % in box: 0.0
# LC80370042016242LGN00 B8 downloading
# LC80370042014236LGN00
# Cloud % in box: 0.0
# LC80370042014236LGN00 B8 downloading
# LC80370042016130LGN00
# Cloud % in box: 0.0
# LC80370042016130LGN00 B8 downloading
# LC80370042015159LGN00
# Cloud % in box: 0.0
# LC80370042015159LGN00 B8 downloading
# LC80370042016274LGN00
# Cloud % in box: 0.0
# LC80370042016274LGN00 B8 downloading
# LC80370042017116LGN00
# Cloud % in box: 0.0
# LC80370042017116LGN00 B8 downloading
# LC80370042016082LGN00
# Cloud % in box: 0.0
# LC80370042016082LGN00 B8 downloading
# LC80370042015095LGN00
# Cloud % in box: 0.0
# LC80370042015095LGN00 B8 downloading
# LC80370042016114LGN00
# Cloud % in box: 0.0
# LC80370042016114LGN00 B8 downloading
# LC80370042015239LGN00
# Cloud % in box: 0.0
# LC80370042015239LGN00 B8 downloading
# LC80370042014220LGN00
# Cloud % in box: 0.0
# LC80370042014220LGN00 B8 downloading
# LC80370042014124LGN00
# Cloud % in box: 0.0
# LC80370042014124LGN00 B8 downloading
# LC80370042016178LGN00
# Cloud % in box: 0.0
# LC80370042016178LGN00 B8 downloading
# LC80370042014188LGN00
# Cloud % in box: 0.0
# LC80370042014188LGN00 B8 downloading
# LC80370042013233LGN00
# Cloud % in box: 0.0
# LC80370042013233LGN00 B8 downloading
# LC80370042013137LGN01
# Cloud % in box: 0.0
# LC80370042013137LGN01 B8 downloading
# LC80370042016258LGN00
# Cloud % in box: 0.0
# LC80370042016258LGN00 B8 downloading
# LC80370042015175LGN00
# Cloud % in box: 0.0
# LC80370042015175LGN00 B8 downloading
# LC80370042015207LGN00
# Cloud % in box: 0.0
# LC80370042015207LGN00 B8 downloading
# LC80370042014140LGN00
# Cloud % in box: 0.0
# LC80370042014140LGN00 B8 downloading
# LC80370042014204LGN00
# Cloud % in box: 0.0
# LC80370042014204LGN00 B8 downloading
# Box001 exists already.
# Path035_Row005  ALREADY DOWNLOADED. SKIP.
# Total number of pixels in the raster: 3023
# LC80350052013123LGN01
# Cloud % in box: 1.6209063843863711
# LC80350052013123LGN01 B8 downloading
# LC80350052015273LGN00
# Cloud % in box: 0.0
# LC80350052015273LGN00 B8 downloading
# LC80350052015225LGN00
# Cloud % in box: 0.33079722130334105
# LC80350052015225LGN00 B8 downloading
# LC80350052016244LGN00
# Cloud % in box: 7.74065497849818
# LC80350052016244LGN00 B8 downloading
# LC80350052015129LGN00
# Cloud % in box: 0.0
# LC80350052015129LGN00 B8 downloading
# LC80350052014078LGN00
# Cloud % in box: 0.03307972213033411
# LC80350052014078LGN00 B8 downloading
# LC80350052016196LGN00
# Cloud % in box: 17.829970228250083
# LC80350052016196LGN00 B8 downloading
# LC80350052014142LGN00
# Cloud % in box: 0.5292755540853458
# LC80350052014142LGN00 B8 downloading
# LC80350052013235LGN00
# Cloud % in box: 0.19847833278200464
# LC80350052013235LGN00 B8 downloading
# LC80350052017118LGN00
# Cloud % in box: 0.09923916639100232
# LC80350052017118LGN00 B8 downloading
# LC80350052014270LGN00
# Cloud % in box: 11.28018524644393
# LC80350052014270LGN00 B8 downloading
# LC80350052015145LGN00
# Cloud % in box: 0.03307972213033411
# LC80350052015145LGN00 B8 downloading
# LC80350052015177LGN00
# Cloud % in box: 0.0
# LC80350052015177LGN00 B8 downloading
# LC80350052014190LGN00
# Cloud % in box: 0.23155805491233872
# LC80350052014190LGN00 B8 downloading
# LC80350052013251LGN00
# Cloud % in box: 0.0
# LC80350052013251LGN00 B8 downloading
# LC80350052015209LGN00
# Cloud % in box: 0.5292755540853458
# LC80350052015209LGN00 B8 downloading
# LC80350052016084LGN00
# Cloud % in box: 1.3893483294740323
# LC80350052016084LGN00 B8 downloading
# LC80350052014126LGN00
# Cloud % in box: 0.0
# LC80350052014126LGN00 B8 downloading
# LC80350052015241LGN00
# Cloud % in box: 15.48130995699636
# LC80350052015241LGN00 B8 downloading
# LC80350052014222LGN00
# Cloud % in box: 0.0
# LC80350052014222LGN00 B8 downloading
# LC80350052013267LGN00
# Cloud % in box: 6.185908038372478
# LC80350052013267LGN00 B8 downloading
# LC80350052016212LGN00
# Cloud % in box: 0.2646377770426729
# LC80350052016212LGN00 B8 downloading
# LC80350052017070LGN00
# Cloud % in box: 0.0
# LC80350052017070LGN00 B8 downloading
# LC80350052015193LGN00
# Cloud % in box: 0.03307972213033411
# LC80350052015193LGN00 B8 downloading
# LC80350052017102LGN00
# Cloud % in box: 0.0
# LC80350052017102LGN00 B8 downloading
# LC80350052016116LGN00
# Cloud % in box: 0.0
# LC80350052016116LGN00 B8 downloading
# LC80350052016276LGN00
# Cloud % in box: 0.0
# LC80350052016276LGN00 B8 downloading
# LC80350052016228LGN00
# Cloud % in box: 0.19847833278200464
# LC80350052016228LGN00 B8 downloading
# LC80350052015113LGN00
# Cloud % in box: 0.0
# LC80350052015113LGN00 B8 downloading
# LC80350052014206LGN00
# Cloud % in box: 18.954680780681443
# LC80350052014206LGN00 B8 downloading
# LC80350052015065LGN00
# Cloud % in box: 0.03307972213033411
# LC80350052015065LGN00 B8 downloading
# LC80350052016132LGN00
# Cloud % in box: 0.0
# LC80350052016132LGN00 B8 downloading
# LC80350052016180LGN00
# Cloud % in box: 0.16539861065167052
# LC80350052016180LGN00 B8 downloading
# Box001 exists already.
# Path033_Row005  ALREADY DOWNLOADED. SKIP.
# Total number of pixels in the raster: 3023
# LC80330052015147LGN00
# Cloud % in box: 0.06615944426066822
# LC80330052015147LGN00 B8 downloading
# LC80330052014176LGN00
# Cloud % in box: 0.06615944426066822
# LC80330052014176LGN00 B8 downloading
# LC80330052015243LGN00
# Cloud % in box: 13.264968574263976
# LC80330052015243LGN00 B8 downloading
# LC80330052016134LGN00
# Cloud % in box: 3.407211379424413
# LC80330052016134LGN00 B8 downloading
# LC80330052015115LGN00
# Cloud % in box: 0.03307972213033411
# LC80330052015115LGN00 B8 downloading
# LC80330052014144LGN00
# Cloud % in box: 0.33079722130334105
# LC80330052014144LGN00 B8 downloading
# LC80330052017072LGN00
# Cloud % in box: 0.23155805491233872
# LC80330052017072LGN00 B8 downloading
# LC80330052015067LGN00
# Cloud % in box: 0.0
# LC80330052015067LGN00 B8 downloading
# LC80330052014160LGN00
# Cloud % in box: 0.09923916639100232
# LC80330052014160LGN00 B8 downloading
# LC80330052013269LGN00
# Cloud % in box: 0.0
# LC80330052013269LGN00 B8 downloading
# LC80330052016070LGN00
# Cloud % in box: 0.13231888852133644
# LC80330052016070LGN00 B8 downloading
# LC80330052015083LGN00
# Cloud % in box: 0.09923916639100232
# LC80330052015083LGN00 B8 downloading
# LC80330052016166LGN00
# Cloud % in box: 0.06615944426066822
# LC80330052016166LGN00 B8 downloading
# LC80330052017120LGN00
# Cloud % in box: 0.0
# LC80330052017120LGN00 B8 downloading
# LC80330052013141LGN01
# Cloud % in box: 0.16539861065167052
# LC80330052013141LGN01 B8 downloading
# LC80330052017104LGN00
# Cloud % in box: 0.0
# LC80330052017104LGN00 B8 downloading
# LC80330052014272LGN00
# Cloud % in box: 0.0
# LC80330052014272LGN00 B8 downloading
# LC80330052013253LGN00
# Cloud % in box: 0.06615944426066822
# LC80330052013253LGN00 B8 downloading
# LC80330052016150LGN00
# Cloud % in box: 0.33079722130334105
# LC80330052016150LGN00 B8 downloading
# LC80330052015131LGN00
# Cloud % in box: 6.582864703936487
# LC80330052015131LGN00 B8 downloading
# LC80330052014224LGN00
# Cloud % in box: 0.13231888852133644
# LC80330052014224LGN00 B8 downloading
# LC80330052013125LGN01
# Cloud % in box: 0.0
# LC80330052013125LGN01 B8 downloading
# LC80330052014256LGN00
# Cloud % in box: 0.06615944426066822
# LC80330052014256LGN00 B8 downloading
# LC80330052015179LGN00
# Cloud % in box: 0.09923916639100232
# LC80330052015179LGN00 B8 downloading
# LC80330052016198LGN00
# Cloud % in box: 0.13231888852133644
# LC80330052016198LGN00 B8 downloading
# LC80330052016262LGN00
# Cloud % in box: 0.13231888852133644
# LC80330052016262LGN00 B8 downloading
# LC80330052015227LGN00
# Cloud % in box: 6.781343036718492
# LC80330052015227LGN00 B8 downloading
# Box001 exists already.
# Path034_Row005  ALREADY DOWNLOADED. SKIP.
# Total number of pixels in the raster: 3023
# LC80340052014215LGN00
# Cloud % in box: 6.45054581541515
# LC80340052014215LGN00 B8 downloading
# LC80340052013148LGN00
# Cloud % in box: 0.09923916639100232
# LC80340052013148LGN00 B8 downloading
# LC80340052016125LGN00
# Cloud % in box: 0.06615944426066822
# LC80340052016125LGN00 B8 downloading
# LC80340052016157LGN00
# Cloud % in box: 0.29771749917300694
# LC80340052016157LGN00 B8 downloading
# LC80340052015106LGN00
# Cloud % in box: 19.120079391333114
# LC80340052015106LGN00 B8 downloading
# LC80340052016093LGN00
# Cloud % in box: 0.5623552762156798
# LC80340052016093LGN00 B8 downloading
# LC80340052014247LGN00
# Cloud % in box: 0.03307972213033411
# LC80340052014247LGN00 B8 downloading
# LC80340052015202LGN00
# Cloud % in box: 0.16539861065167052
# LC80340052015202LGN00 B8 downloading
# LC80340052015266LGN00
# Cloud % in box: 0.09923916639100232
# LC80340052015266LGN00 B8 downloading
# LC80340052017079LGN00
# Cloud % in box: 0.0
# LC80340052017079LGN00 B8 downloading
# LC80340052014087LGN00
# Cloud % in box: 0.7277538868673503
# LC80340052014087LGN00 B8 downloading
# LC80340052017095LGN00
# Cloud % in box: 0.23155805491233872
# LC80340052017095LGN00 B8 downloading
# LC80340052014151LGN00
# Cloud % in box: 7.310618590803837
# LC80340052014151LGN00 B8 downloading
# LC80340052016205LGN00
# Cloud % in box: 0.03307972213033411
# LC80340052016205LGN00 B8 downloading
# LC80340052014263LGN00
# LC80310052017090LGN00
# Cloud % in box: 0.9593119417796889
# LC80310052017090LGN00 B8 downloading
# LC80310052015069LGN00
# Cloud % in box: 0.5954349983460139
# LC80310052015069LGN00 B8 downloading
# LC80310052013239LGN00
# Cloud % in box: 0.16539861065167052
# LC80310052013239LGN00 B8 downloading
# LC80310052014178LGN00
# Cloud % in box: 0.13231888852133644
# LC80310052014178LGN00 B8 downloading
# LC80310052015229LGN00
# Cloud % in box: 0.39695666556400927
# LC80310052015229LGN00 B8 downloading
# LC80310052016152LGN00
# Cloud % in box: 3.5726099900760833
# LC80310052016152LGN00 B8 downloading
# LC80310052015117LGN00
# Cloud % in box: 0.13231888852133644
# LC80310052015117LGN00 B8 downloading
# LC80310052015181LGN00
# Cloud % in box: 0.46311610982467744
# LC80310052015181LGN00 B8 downloading
# LC80310052016248LGN00
# Cloud % in box: 17.598412173337742
# LC80310052016248LGN00 B8 downloading
# LC80310052016088LGN00
# Cloud % in box: 2.6132980482963943
# LC80310052016088LGN00 B8 downloading
# LC80310052014258LGN00
# Cloud % in box: 0.0
# LC80310052014258LGN00 B8 downloading
# LC80310052015245LGN00
# Cloud % in box: 0.2646377770426729
# LC80310052015245LGN00 B8 downloading
# LC80310052016072LGN00
# Cloud % in box: 0.0
# LC80310052016072LGN00 B8 downloading
# LC80310052015213LGN00
# Cloud % in box: 0.06615944426066822
# LC80310052015213LGN00 B8 downloading
# LC80310052016104LGN00
# Cloud % in box: 8.071452199801522
# LC80310052016104LGN00 B8 downloading
# LC80310052016200LGN00
# Cloud % in box: 16.83757856434006
# LC80310052016200LGN00 B8 downloading
# LC80310052014082LGN00
# Cloud % in box: 0.06615944426066822
# LC80310052014082LGN00 B8 downloading
# LC80310052015261LGN00
# Cloud % in box: 0.16539861065167052
# LC80310052015261LGN00 B8 downloading
# LC80310052016136LGN00
# Cloud % in box: 15.54746940125703
# LC80310052016136LGN00 B8 downloading
# LC80310052014226LGN00
# Cloud % in box: 0.23155805491233872
# LC80310052014226LGN00 B8 downloading
# LC80310052014274LGN00
# Cloud % in box: 0.0
# LC80310052014274LGN00 B8 downloading
# LC80310052014242LGN00
# Cloud % in box: 0.13231888852133644
# LC80310052014242LGN00 B8 downloading
# LC80310052014194LGN00
# Cloud % in box: 0.03307972213033411
# LC80310052014194LGN00 B8 downloading
# Box001 exists already.
# Path032_Row005  ALREADY DOWNLOADED. SKIP.
# Total number of pixels in the raster: 3023
# LC80320052016255LGN00
# Cloud % in box: 0.0
# LC80320052016255LGN00 B8 downloading
# LC80320052015284LGN00
# Cloud % in box: 3.5726099900760833
# LC80320052015284LGN00 B8 downloading
# LC80320052014201LGN00
# Cloud % in box: 0.23155805491233872
# LC80320052014201LGN00 B8 downloading
# LC80320052014265LGN00
# Cloud % in box: 0.09923916639100232
# LC80320052014265LGN00 B8 downloading
# LC80320052013134LGN03
# Cloud % in box: 0.0
# LC80320052013134LGN03 B8 downloading
# LC80320052014185LGN00
# Cloud % in box: 0.09923916639100232
# LC80320052014185LGN00 B8 downloading
# LC80320052015252LGN00
# Cloud % in box: 13.36420774065498
# LC80320052015252LGN00 B8 downloading
# LC80310052015149LGN00 B8 downloading
# LC80310052014098LGN00
# Cloud % in box: 0.07185743484925908
# LC80310052014098LGN00 B8 downloading
# LC80310052017090LGN00
# Cloud % in box: 0.12135922330097086
# LC80310052017090LGN00 B8 downloading
# LC80310052013239LGN00
# Cloud % in box: 0.003193663771078181
# LC80310052013239LGN00 B8 downloading
# LC80310052014178LGN00
# Cloud % in box: 0.09261624936126725
# LC80310052014178LGN00 B8 downloading
# LC80310052015197LGN00
# Cloud % in box: 0.0015968318855390906
# LC80310052015197LGN00 B8 downloading
# LC80310052015229LGN00
# Cloud % in box: 0.0
# LC80310052015229LGN00 B8 downloading
# LC80310052013143LGN01
# Cloud % in box: 0.5205671946857435
# LC80310052013143LGN01 B8 downloading
# LC80310052015117LGN00
# Cloud % in box: 0.26507409299948903
# LC80310052015117LGN00 B8 downloading
# LC80310052015181LGN00
# Cloud % in box: 0.0
# LC80310052015181LGN00 B8 downloading
# LC80310052016088LGN00
# Cloud % in box: 0.02395247828308636
# LC80310052016088LGN00 B8 downloading
# LC80310052014258LGN00
# Cloud % in box: 1.3157894736842104
# LC80310052014258LGN00 B8 downloading
# LC80310052015245LGN00
# Cloud % in box: 0.0
# LC80310052015245LGN00 B8 downloading
# LC80310052016072LGN00
# Cloud % in box: 0.5461165048543689
# LC80310052016072LGN00 B8 downloading
# LC80310052015213LGN00
# Cloud % in box: 1.4706821665815024
# LC80310052015213LGN00 B8 downloading
# LC80310052014082LGN00
# Cloud % in box: 1.6543178334184976
# LC80310052014082LGN00 B8 downloading
# LC80310052016136LGN00
# Cloud % in box: 0.1453117015840572
# LC80310052016136LGN00 B8 downloading
# LC80310052014226LGN00
# Cloud % in box: 0.014371486969851814
# LC80310052014226LGN00 B8 downloading
# LC80310052014242LGN00
# Cloud % in box: 0.6147802759325498
# LC80310052014242LGN00 B8 downloading
# LC80310052014194LGN00
# Cloud % in box: 0.0
# LC80310052014194LGN00 B8 downloading
# Box004 exists already.
# Path034_Row005  ALREADY DOWNLOADED. SKIP.
# Total number of pixels in the raster: 62624
# Box004 exists already.
# Path029_Row006  ALREADY DOWNLOADED. SKIP.
# Total number of pixels in the raster: 62624
# LC80290062016282LGN00
# Cloud % in box: 0.11497189575881452
# LC80290062016282LGN00 B8 downloading
# LC80290062013161LGN00
# Cloud % in box: 4.081502299437916
# LC80290062013161LGN00 B8 downloading
# LC80290062015151LGN00
# Cloud % in box: 1.5457332652018394
# LC80290062015151LGN00 B8 downloading
# LC80290062014068LGN00
# Cloud % in box: 1.1193791517629024
# LC80290062014068LGN00 B8 downloading
# LC80290062016170LGN00
# Cloud % in box: 0.0
# LC80290062016170LGN00 B8 downloading
# LC80290062015199LGN00
# Cloud % in box: 0.0
# LC80290062015199LGN00 B8 downloading
# LC80290062015167LGN00
# Cloud % in box: 2.63317577925396
# LC80290062015167LGN00 B8 downloading
# LC80290062015119LGN00
# Cloud % in box: 0.07824476239141544
# LC80290062015119LGN00 B8 downloading
# LC80290062014244LGN00
# Cloud % in box: 0.035130301481859985
# LC80290062014244LGN00 B8 downloading
# LC80290062016186LGN00
# Cloud % in box: 0.0
# LC80290062016186LGN00 B8 downloading
# LC80290062015231LGN00
# Cloud % in box: 0.0
# LC80290062015231LGN00 B8 downloading
# LC80290062016090LGN00
# Cloud % in box: 0.42635411343893714
# LC80290062016090LGN00 B8 downloading
# LC80290062015247LGN00
# Cloud % in box: 0.653104241185488
# LC80290062015247LGN00 B8 downloading
# LC80290062014164LGN00
# Cloud % in box: 0.030339805825242715
# LC80290062014164LGN00 B8 downloading
# LC80290062016058LGN00
# Cloud % in box: 0.24431527848748086
# LC80290062016058LGN00 B8 downloading
# LC80290062017108LGN00
# Cloud % in box: 3.8946729688298416
# LC80290062017108LGN00 B8 downloading
# LC80290062013241LGN00
# Cloud % in box: 0.006387327542156362
# LC80290062013241LGN00 B8 downloading
# LC80290062014100LGN00
# Cloud % in box: 0.014371486969851814
# LC80290062014100LGN00 B8 downloading
# LC80290062014180LGN00
# Cloud % in box: 1.5489269289729177
# LC80290062014180LGN00 B8 downloading
# LC80290062015135LGN00
# Cloud % in box: 2.610820132856413
# LC80290062015135LGN00 B8 downloading
# LC80290062013257LGN00
# Cloud % in box: 0.07505109862033725
# LC80290062013257LGN00 B8 downloading
# LC80290062016074LGN00
# Cloud % in box: 0.0
# LC80290062016074LGN00 B8 downloading
# LC80290062016138LGN00
# Cloud % in box: 0.19481349003576903
# LC80290062016138LGN00 B8 downloading
# Box004 exists already.
# Path028_Row006  ALREADY DOWNLOADED. SKIP.
# Total number of pixels in the raster: 62624
# LC80280062015080LGN00
# Cloud % in box: 1.9672968829841593
# LC80280062015080LGN00 B8 downloading
# LC80280062015128LGN00
# Cloud % in box: 0.1309402146142054
# LC80280062015128LGN00 B8 downloading
# LC80280062016211LGN00
# Cloud % in box: 0.006387327542156362
# LC80280062016211LGN00 B8 downloading
# LC80280062017117LGN00
# Cloud % in box: 3.0627235564639754
# LC80280062017117LGN00 B8 downloading
# LC80280062015144LGN00
# Cloud % in box: 0.035130301481859985
# LC80280062015144LGN00 B8 downloading
# LC80280062013138LGN01
# Cloud % in box: 2.5804803270311703
# LC80280062013138LGN01 B8 downloading
# LC80280062015160LGN00
# Cloud % in box: 0.6275549310168625
# LC80280062015160LGN00 B8 downloading
# LC80280062016275LGN00
# Cloud % in box: 1.574476239141543
# LC80280062016275LGN00 B8 downloading
# LC80280062014141LGN00
# Cloud % in box: 4.664345937659683
# LC80280062014141LGN00 B8 downloading
# LC80280062017101LGN00
# Cloud % in box: 0.42475728155339804
# LC80280062017101LGN00 B8 downloading
# LC80280062016179LGN00
# Cloud % in box: 0.0335334695963209
# LC80280062016179LGN00 B8 downloading
# LC80280062015224LGN00
# Cloud % in box: 0.0
# LC80280062015224LGN00 B8 downloading
# LC80280062016115LGN00
# Cloud % in box: 0.17086101175268267
# LC80280062016115LGN00 B8 downloading
# LC80280062016163LGN00
# Cloud % in box: 0.0
# LC80280062016163LGN00 B8 downloading
# LC80280062016083LGN00
# Cloud % in box: 0.05748594787940726
# LC80280062016083LGN00 B8 downloading
# LC80280062015096LGN00
# Cloud % in box: 0.1836356668369954
# LC80280062015096LGN00 B8 downloading
# LC80280062017085LGN00
# Cloud % in box: 1.128960143076137
# LC80280062017085LGN00 B8 downloading
# LC80280062016131LGN00
# Cloud % in box: 0.27944557996934083
# LC80280062016131LGN00 B8 downloading
# LC80280062014189LGN00
# Cloud % in box: 0.27944557996934083
# LC80280062014189LGN00 B8 downloading
# LC80280062015112LGN00
# Cloud % in box: 0.17405467552376086
# LC80280062015112LGN00 B8 downloading
# LC80280062014173LGN00
# Cloud % in box: 3.4028487480838017
# LC80280062014173LGN00 B8 downloading
# LC80280062015288LGN00
# Cloud % in box: 0.0
# LC80280062015288LGN00 B8 downloading
# LC80280062016243LGN00
# Cloud % in box: 2.899846704138988
# LC80280062016243LGN00 B8 downloading
# LC80280062015192LGN00
# Cloud % in box: 0.0015968318855390906
# LC80280062015192LGN00 B8 downloading
# LC80280062013250LGN00
# Cloud % in box: 0.6020056208482372
# LC80280062013250LGN00 B8 downloading
# LC80280062015272LGN00
# Cloud % in box: 3.281489524782831
# LC80280062015272LGN00 B8 downloading
# LC80280062015208LGN00
# Cloud % in box: 0.0047904956566172715
# LC80280062015208LGN00 B8 downloading
# LC80280062016195LGN00
# Cloud % in box: 0.0015968318855390906
# LC80280062016195LGN00 B8 downloading
# Box004 exists already.
# Path030_Row005  ALREADY DOWNLOADED. SKIP.
# Total number of pixels in the raster: 62624
# Box004 exists already.
# Path033_Row005  ALREADY DOWNLOADED. SKIP.
# Total number of pixels in the raster: 62624
# Box033 exists already.
# Path009_Row014  ALREADY DOWNLOADED. SKIP.
# Total number of pixels in the raster: 26787
# LC80090142015203LGN00
# Cloud % in box: 4.382722962631127
# LC80090142015203LGN00 B8 downloading
# LC80090142017032LGN00
# Cloud % in box: 0.022398924851607122
# LC80090142017032LGN00 B8 downloading
# LC80090142016318LGN00
# Cloud % in box: 0.8324933736513982
# LC80090142016318LGN00 B8 downloading
# LC80090142015139LGN00
# Cloud % in box: 0.4853100384514876
# LC80090142015139LGN00 B8 downloading
# LC80090142016030LGN00
# Cloud % in box: 0.08586254526449397
# LC80090142016030LGN00 B8 downloading
# LC80090142014200LGN00
# Cloud % in box: 0.5674394295740471
# LC80090142014200LGN00 B8 downloading
# LC80090142014280LGN00
# Cloud % in box: 0.5711725837159817
# LC80090142014280LGN00 B8 downloading
# LC80090142014072LGN00
# Cloud % in box: 0.2165229402322022
# LC80090142014072LGN00 B8 downloading
# LC80090142016302LGN00
# Cloud % in box: 0.0
# LC80090142016302LGN00 B8 downloading
# LC80090142015283LGN00
# Cloud % in box: 1.2506066375480642
# LC80090142015283LGN00 B8 downloading
# LC80090142014184LGN00
# Cloud % in box: 0.5413073505805055
# LC80090142014184LGN00 B8 downloading
# LC80090142015219LGN00
# Cloud % in box: 0.6047709709933924
# LC80090142015219LGN00 B8 downloading
# LC80090142014312LGN00
# Cloud % in box: 0.2687870982192855
# LC80090142014312LGN00 B8 downloading
# LC80090142017048LGN00
# Cloud % in box: 0.5002426550192257
# LC80090142017048LGN00 B8 downloading
# LC80090142013309LGN00
# Cloud % in box: 0.25012132750961286
# LC80090142013309LGN00 B8 downloading
# LC80090142015155LGN00
# Cloud % in box: 0.6010378168514577
# LC80090142015155LGN00 B8 downloading
# LC80090142013101LGN01
# Cloud % in box: 0.5002426550192257
# LC80090142013101LGN01 B8 downloading
# LC80090142016206LGN00
# Cloud % in box: 0.6458356665546721
# LC80090142016206LGN00 B8 downloading
ALREADY DOWNLOADED. SKIP.
# Total number of pixels in the raster: 26787
# LC80070142015269LGN00
# Cloud % in box: 0.5861052002837197
# LC80070142015269LGN00 B8 downloading
# LC80070142014026LGN00
# Cloud % in box: 0.6458356665546721
# LC80070142014026LGN00 B8 downloading
# LC80070142016032LGN00
# Cloud % in box: 0.1455930115354463
# LC80070142016032LGN00 B8 downloading
# LC80070142016320LGN00
# Cloud % in box: 0.19412401538059507
# LC80070142016320LGN00 B8 downloading
# LC80070142016160LGN00
# Cloud % in box: 1.0863478553029455
# LC80070142016160LGN00 B8 downloading
# LC80070142016096LGN00
# Cloud % in box: 0.925822227199761
# LC80070142016096LGN00 B8 downloading
# LC80070142016256LGN00
# Cloud % in box: 0.39198118490312467
# LC80070142016256LGN00 B8 downloading
# LC80070142014298LGN00
# Cloud % in box: 0.1455930115354463
# LC80070142014298LGN00 B8 downloading
# LC80070142015317LGN01
# Cloud % in box: 0.022398924851607122
# LC80070142015317LGN01 B8 downloading
# LC80070142014042LGN00
# Cloud % in box: 0.23892186508380933
# LC80070142014042LGN00 B8 downloading
# LC80070142014218LGN00
# Cloud % in box: 0.5935715085675888
# LC80070142014218LGN00 B8 downloading
# LC80070142015205LGN01
# Cloud % in box: 0.5301078881547019
# LC80070142015205LGN01 B8 downloading
# LC80070142014106LGN00
# Cloud % in box: 0.10079516183223207
# LC80070142014106LGN00 B8 downloading
# LC80070142015109LGN00
# Cloud % in box: 0.20905663194833315
# LC80070142015109LGN00 B8 downloading
# LC80070142013151LGN00
# Cloud % in box: 0.5413073505805055
# LC80070142013151LGN00 B8 downloading
# LC80070142017114LGN00
# Cloud % in box: 0.0
# LC80070142017114LGN00 B8 downloading
# LC80070142017098LGN00
# Cloud % in box: 0.05226415798708329
# LC80070142017098LGN00 B8 downloading
# LC80070142014314LGN00
# Cloud % in box: 0.05226415798708329
# LC80070142014314LGN00 B8 downloading
# LC80070142015093LGN00
# Cloud % in box: 3.7928846082054726
# LC80070142015093LGN00 B8 downloading
# LC80070142016048LGN00
# Cloud % in box: 2.18016201888976
# LC80070142016048LGN00 B8 downloading
# LC80070142016080LGN00
# Cloud % in box: 0.21278978609026766
# LC80070142016080LGN00 B8 downloading
# LC80070142015237LGN00
# Cloud % in box: 0.49277634673535675
# LC80070142015237LGN00 B8 downloading
# LC80070142015253LGN00
# Cloud % in box: 0.2911860230708926
# LC80070142015253LGN00 B8 downloading
# LC80070142013247LGN00
# Cloud % in box: 0.05973046627095233
# LC80070142013247LGN00 B8 downloading
# LC80070142015045LGN00
# Cloud % in box: 0.16799193638705343
# LC80070142015045LGN00 B8 downloading
# LC80070142014186LGN00
# Cloud % in box: 9.235823347146004
# LC80070142014186LGN00 B8 downloading
# LC80070142015189LGN00
# Cloud % in box: 0.5711725837159817
# LC80070142015189LGN00 B8 downloading
# LC80070142013119LGN01
# Cloud % in box: 0.5338410422966364
# LC80070142013119LGN01 B8 downloading
# LC80070142016208LGN00
# Cloud % in box: 0.6271698958449995
# LC80070142016208LGN00 B8 downloading
# LC80070142016304LGN00
# Cloud % in box: 11.56157837757121
# LC80070142016304LGN00 B8 downloading
# LC80070142017066LGN00
# Cloud % in box: 1.175943554709374
# LC80070142017066LGN00 B8 downloading
# LC80070142013231LGN00
# Cloud % in box: 1.3626012618061
# LC80070142013231LGN00 B8 downloading
# LC80070142017034LGN00
# Cloud % in box: 0.0
# LC80070142017034LGN00 B8 downloading
# LC80070142014266LGN00
# Cloud % in box: 3.2702430283346398
# LC80070142014266LGN00 B8 downloading
# LC80070142016192LGN00
# Cloud % in box: 0.5151752715869639
# LC80070142016192LGN00 B8 downloading
# LC80070142017050LGN00
# Cloud % in box: 1.075148392877142
# LC80070142017050LGN00 B8 downloading
# LC80070142014058LGN00
# Cloud % in box: 1.743382984283421
# LC80070142014058LGN00 B8 downloading
# LC80070142014234LGN00
# Cloud % in box: 0.7802292156643148
# LC80070142014234LGN00 B8 downloading
# LC80070142015157LGN00
# Cloud % in box: 7.925486243326987
# LC80070142015157LGN00 B8 downloading
# LC80070142014170LGN00
# Cloud % in box: 0.4703774218837496
# LC80070142014170LGN00 B8 downloading
# LC80070142015125LGN00
# Cloud % in box: 0.014932616567738083
# LC80070142015125LGN00 B8 downloading
# LC80070142015029LGN00
# Cloud % in box: 0.0
# LC80070142015029LGN00 B8 downloading
# LC80070142015141LGN00
# Cloud % in box: 0.44797849703214243
# LC80070142015141LGN00 B8 downloading
# LC80070142014122LGN00
# Cloud % in box: 0.4703774218837496
# LC80070142014122LGN00 B8 downloading
# LC80070142015285LGN00
# Cloud % in box: 0.0
# LC80070142015285LGN00 B8 downloading
# LC80070142013311LGN00
# Cloud % in box: 0.3061186396386307
# LC80070142013311LGN00 B8 downloading
# LC80070142015301LGN00
# Cloud % in box: 0.0
# LC80070142015301LGN00 B8 downloading
# Box033 exists already.
# Path009_Row013  ALREADY DOWNLOADED. SKIP.
# Total number of pixels in the raster: 26787
# LC80090132017032LGN00
# Cloud % in box: 3.733154141934521
# LC80090132017032LGN00 B8 downloading
# LC80090132014200LGN00
# Cloud % in box: 0.5823720461417852
# LC80090132014200LGN00 B8 downloading
# LC80090132014152LGN00
# Cloud % in box: 0.7018329786836899
# LC80090132014152LGN00 B8 downloading
# LC80090132016286LGN00
# Cloud % in box: 1.885242841676933
# LC80090132016286LGN00 B8 downloading
# ...
# LC80120022017085LGN00
# Cloud % in box: 1.5163066497246929
# LC80120022017085LGN00 B8 downloading
# LC80120022016179LGN00
# Cloud % in box: 0.0
# LC80120022016179LGN00 B8 downloading
# LC80120022015224LGN00
# Cloud % in box: 0.5167301990681914
# LC80120022015224LGN00 B8 downloading
# LC80120022015240LGN00
# Cloud % in box: 8.352393053790767
# LC80120022015240LGN00 B8 downloading
# LC80120022015096LGN00
# Cloud % in box: 15.730622617534943
# LC80120022015096LGN00 B8 downloading
# LC80120022014269LGN00
# Cloud % in box: 4.150783566285472
# LC80120022014269LGN00 B8 downloading
# LC80120022016083LGN00
# Cloud % in box: 3.4561626429479033
# LC80120022016083LGN00 B8 downloading
# LC80120022015144LGN00
# Cloud % in box: 1.0334603981363828
# LC80120022015144LGN00 B8 downloading
# LC80120022015192LGN00
# Cloud % in box: 13.55357899195256
# LC80120022015192LGN00 B8 downloading
# LC80120022014253LGN00
# Cloud % in box: 2.6175349428208388
# LC80120022014253LGN00 B8 downloading
# LC80120022015176LGN00
# Cloud % in box: 0.0
# LC80120022015176LGN00 B8 downloading
# LC80120022015112LGN00
# Cloud % in box: 0.0677678949597628
# LC80120022015112LGN00 B8 downloading
# LC80120022017101LGN00
# Cloud % in box: 0.17789072426937738
# LC80120022017101LGN00 B8 downloading
# LC80120022016115LGN00
# Cloud % in box: 0.025412960609911054
# LC80120022016115LGN00 B8 downloading
# LC80120022016147LGN00
# Cloud % in box: 0.0
# LC80120022016147LGN00 B8 downloading
# LC80120022015256LGN00
# Cloud % in box: 0.0
# LC80120022015256LGN00 B8 downloading
# LC80120022014221LGN00
# Cloud % in box: 13.689114781872089
# LC80120022014221LGN00 B8 downloading
# LC80120022016259LGN00
# Cloud % in box: 0.2710715798390512
# LC80120022016259LGN00 B8 downloading
# LC80120022014173LGN00
# Cloud % in box: 19.771283354510803
# LC80120022014173LGN00 B8 downloading
# LC80120022013122LGN01
# Cloud % in box: 0.0
# LC80120022013122LGN01 B8 downloading
# LC80120022016131LGN00
# Cloud % in box: 0.05082592121982211
# LC80120022016131LGN00 B8 downloading
# Box531 exists already.
# Path013_Row002  ALREADY DOWNLOADED. SKIP.
# Total number of pixels in the raster: 11805
# LC80130022014180LGN00
# Cloud % in box: 4.438797119864464
# LC80130022014180LGN00 B8 downloading
# LC80130022016106LGN00
# Cloud % in box: 0.05929690808979246
# LC80130022016106LGN00 B8 downloading
# LC80130022016186LGN00
# Cloud % in box: 0.0
# LC80130022016186LGN00 B8 downloading
# LC80130022014212LGN00
# Cloud % in box: 11.605252011859383
# LC80130022014212LGN00 B8 downloading
# LC80130022015135LGN00
# Cloud % in box: 0.4404913172384583
# LC80130022015135LGN00 B8 downloading
# LC80130022017108LGN00
# Cloud % in box: 0.05082592121982211
# LC80130022017108LGN00 B8 downloading
# LC80130022015119LGN00
# Cloud % in box: 17.83989834815756
# LC80130022015119LGN00 B8 downloading
# LC80130022016090LGN00
# Cloud % in box: 0.8216857263871242
# LC80130022016090LGN00 B8 downloading
# LC80130022014100LGN00
# Cloud % in box: 0.15247776365946633
# LC80130022014100LGN00 B8 downloading
# LC80130022015183LGN00
# Cloud % in box: 13.0283778060144
# LC80130022015183LGN00 B8 downloading
# LC80130022015247LGN00
# Cloud % in box: 0.0
# LC80130022015247LGN00 B8 downloading
# LC80130022016266LGN00
# Cloud % in box: 4.371029224904702
# LC80130022016266LGN00 B8 downloading
# LC80130022017076LGN00
# Cloud % in box: 5.387547649301143
# LC80130022017076LGN00 B8 downloading
# LC80130022016154LGN00
# Cloud % in box: 8.759000423549343
# LC80130022016154LGN00 B8 downloading
# LC80130022015087LGN00
# Cloud % in box: 1.5078356628547225
# LC80130022015087LGN00 B8 downloading
# LC80130022015263LGN00
# Cloud % in box: 1.541719610334604
# LC80130022015263LGN00 B8 downloading
# LC80130022014148LGN00
# Cloud % in box: 3.4900465904277844
# LC80130022014148LGN00 B8 downloading
# LC80130022015199LGN00
# Cloud % in box: 13.714527742482
# LC80130022015199LGN00 B8 downloading
# LC80130022016234LGN00
# Cloud % in box: 5.887335874629394
# LC80130022016234LGN00 B8 downloading
# LC80130022016250LGN00
# Cloud % in box: 0.2710715798390512
# LC80130022016250LGN00 B8 downloading
# LC80130022013113LGN01
# Cloud % in box: 0.00847098686997035
# LC80130022013113LGN01 B8 downloading
# LC80130022013273LGN00
# Cloud % in box: 0.0
# LC80130022013273LGN00 B8 downloading
# LC80130022015071LGN00
# Cloud % in box: 0.0
# LC80130022015071LGN00 B8 downloading
# LC80130022016074LGN00
# Cloud % in box: 0.0677678949597628
# LC80130022016074LGN00 B8 downloading
# LC80130022016138LGN00
# Cloud % in box: 1.0249894112664126
# LC80130022016138LGN00 B8 downloading
# LC80130022016170LGN00
# Cloud % in box: 0.0
# LC80130022016170LGN00 B8 downloading
# LC80130022014196LGN00
# Cloud % in box: 2.473528166031343
# LC80130022014196LGN00 B8 downloading
# LC80130022016202LGN00
# Cloud % in box: 0.22024565861922915
# LC80130022016202LGN00 B8 downloading
# LC80130022013145LGN00
# Cloud % in box: 0.05929690808979246
# LC80130022013145LGN00 B8 downloading
# Box531 exists already.
# Path115_Row002  ALREADY DOWNLOADED. SKIP.
# Total number of pixels in the raster: 11805
# Box531 exists already.
# Path007_Row003  ALREADY DOWNLOADED. SKIP.
# Total number of pixels in the raster: 11805
# LC80070032015173LGN00
# Cloud % in box: 0.05929690808979246
# LC80070032015173LGN00 B8 downloading
# LC80070032015109LGN00
# Cloud % in box: 0.00847098686997035
# LC80070032015109LGN00 B8 downloading
# LC80070032014170LGN00
# Cloud % in box: 15.340957221516307
# LC80070032014170LGN00 B8 downloading
# LC80070032015189LGN00
# Cloud % in box: 7.835662854722575
# LC80070032015189LGN00 B8 downloading
# LC80070032015221LGN00
# Cloud % in box: 8.462515883100382
# LC80070032015221LGN00 B8 downloading
# LC80070032016096LGN00
# Cloud % in box: 0.35578144853875476
# LC80070032016096LGN00 B8 downloading
# LC80070032014234LGN00
# Cloud % in box: 1.7450232952138922
# LC80070032014234LGN00 B8 downloading
# LC80070032015269LGN00
# Cloud % in box: 3.5408725116476067
# LC80070032015269LGN00 B8 downloading
# LC80070032016160LGN00
# Cloud % in box: 0.0
# LC80070032016160LGN00 B8 downloading
# LC80070032017114LGN00
# Cloud % in box: 0.0
# LC80070032017114LGN00 B8 downloading
# LC80070032016192LGN00
# Cloud % in box: 0.3218975010588734
# LC80070032016192LGN00 B8 downloading
# LC80070032015253LGN00
# Cloud % in box: 0.05929690808979246
# LC80070032015253LGN00 B8 downloading
# LC80070032015205LGN01
# Cloud % in box: 15.781448538754764
# LC80070032015205LGN01 B8 downloading
# LC80070032016256LGN00
# Cloud % in box: 10.139771283354511
# LC80070032016256LGN00 B8 downloading
# LC80070032014202LGN00
# Cloud % in box: 0.35578144853875476
# LC80070032014202LGN00 B8 downloading
# LC80070032016176LGN00
# Cloud % in box: 19.093604404913172
# LC80070032016176LGN00 B8 downloading
# LC80070032017098LGN00
# Cloud % in box: 0.0
# LC80070032017098LGN00 B8 downloading
# LC80070032014250LGN00
# Cloud % in box: 0.6099110546378653
# LC80070032014250LGN00 B8 downloading
# LC80070032014218LGN00
# Cloud % in box: 0.7539178314273612
# LC80070032014218LGN00 B8 downloading
# LC80070032016208LGN00
# Cloud % in box: 0.28801355357899194
# LC80070032016208LGN00 B8 downloading
# LC80070032017082LGN00
# Cloud % in box: 0.0
# LC80070032017082LGN00 B8 downloading
# LC80070032015077LGN00
# Cloud % in box: 3.8034731046166876
# LC80070032015077LGN00 B8 downloading
# LC80070032015093LGN00
# Cloud % in box: 0.2626005929690809
# LC80070032015093LGN00 B8 downloading
# LC80070032014106LGN00
# Cloud % in box: 0.042354934349851756
# LC80070032014106LGN00 B8 downloading
# LC80070032015157LGN00
# Cloud % in box: 5.760271071579838
# LC80070032015157LGN00 B8 downloading
# LC80070032016112LGN00
# Cloud % in box: 0.0
# LC80070032016112LGN00 B8 downloading
# Box531 exists already.
# Path015_Row001  ALREADY DOWNLOADED. SKIP.
# Total number of pixels in the raster: 11805
# LC80150012016088LGN00
# Cloud % in box: 6.77678949597628
# LC80150012016088LGN00 B8 downloading
# LC80150012016184LGN00
# Cloud % in box: 0.22871664548919948
# LC80150012016184LGN00 B8 downloading
# LC80150012014210LGN00
# Cloud % in box: 2.0160948750529437
# LC80150012014210LGN00 B8 downloading
# LC80150012014242LGN00
# Cloud % in box: 0.6183820415078357
# LC80150012014242LGN00 B8 downloading
# LC80150012015149LGN00
# Cloud % in box: 18.475222363405337
# LC80150012015149LGN00 B8 downloading
# LC80150012013143LGN01
# Cloud % in box: 6.98856416772554
# LC80150012013143LGN01 B8 downloading
# LC80150012013255LGN00
# Cloud % in box: 3.9135959339263025
# LC80150012013255LGN00 B8 downloading
# LC80150012016216LGN00
# Cloud % in box: 0.6946209233375689
# LC80150012016216LGN00 B8 downloading
# LC80150012015181LGN00
# Cloud % in box: 0.0
# LC80150012015181LGN00 B8 downloading
# LC80150012015197LGN00
# Cloud % in box: 0.07623888182973317
# LC80150012015197LGN00 B8 downloading
# LC80150012014226LGN00
# Cloud % in box: 0.9572215163066498
# LC80150012014226LGN00 B8 downloading
# LC80150012015133LGN00
# Cloud % in box: 0.025412960609911054
# LC80150012015133LGN00 B8 downloading
# LC80150012015117LGN00
# Cloud % in box: 0.0
# LC80150012015117LGN00 B8 downloading
# LC80150012015213LGN00
# Cloud % in box: 0.14400677678949597
# LC80150012015213LGN00 B8 downloading
# LC80150012015261LGN00
# Cloud % in box: 0.0
# LC80150012015261LGN00 B8 downloading
# LC80150012014082LGN00
# Cloud % in box: 0.2710715798390512
# LC80150012014082LGN00 B8 downloading
# LC80150012015085LGN00
# Cloud % in box: 3.532401524777637
# LC80150012015085LGN00 B8 downloading
# LC80150012017074LGN00
# Cloud % in box: 13.841592545531553
# LC80150012017074LGN00 B8 downloading
# LC80150012015101LGN00
# Cloud % in box: 0.00847098686997035
# LC80150012015101LGN00 B8 downloading
# LC80150012016232LGN00
# Cloud % in box: 0.5252011859381618
# LC80150012016232LGN00 B8 downloading
# LC80150012016136LGN00
# Cloud % in box: 0.08470986869970351
# LC80150012016136LGN00 B8 downloading
# LC80150012014258LGN00
# Cloud % in box: 3.0919102075391782
# LC80150012014258LGN00 B8 downloading
# LC80150012016264LGN00
# Cloud % in box: 0.652265988987717
# LC80150012016264LGN00 B8 downloading
# LC80150012014194LGN00
# Cloud % in box: 1.3553578991952562
# LC80150012014194LGN00 B8 downloading
# LC80150012016120LGN00
# Cloud % in box: 0.042354934349851756
# LC80150012016120LGN00 B8 downloading
# LC80150012014162LGN00
# Cloud % in box: 0.025412960609911054
# LC80150012014162LGN00 B8 downloading
# LC80150012016248LGN00
# Cloud % in box: 12.232105040237187
# LC80150012016248LGN00 B8 downloading
# LC80150012017090LGN00
# Cloud % in box: 0.24565861922914017
# LC80150012017090LGN00 B8 downloading
# Box531 exists already.
# Path009_Row002  ALREADY DOWNLOADED. SKIP.
# Total number of pixels in the raster: 11805
# LC80090022015171LGN00
# Cloud % in box: 0.30495552731893266
# LC80090022015171LGN00 B8 downloading
# LC80090022017096LGN00
# Cloud % in box: 0.48284625158831007
# LC80090022017096LGN00 B8 downloading
# LC80090022015107LGN00
# Cloud % in box: 0.042354934349851756
# LC80090022015107LGN00 B8 downloading
# LC80090022015091LGN00
# Cloud % in box: 0.5506141465480728
# LC80090022015091LGN00 B8 downloading
# LC80090022015267LGN00
# Cloud % in box: 6.77678949597628
# LC80090022015267LGN00 B8 downloading
# LC80090022014264LGN00
# Cloud % in box: 9.495976281236764
# LC80090022014264LGN00 B8 downloading
# LC80090022016110LGN00
# Cloud % in box: 0.0169419737399407
# LC80090022016110LGN00 B8 downloading
# LC80090022016174LGN00
# Cloud % in box: 3.6509953409572216
# LC80090022016174LGN00 B8 downloading
# LC80090022013261LGN00
# Cloud % in box: 3.3121558661584074
# LC80090022013261LGN00 B8 downloading
# LC80090022016158LGN00
# Cloud % in box: 0.0
# LC80090022016158LGN00 B8 downloading
# LC80090022014104LGN00
# Cloud % in box: 0.14400677678949597
# LC80090022014104LGN00 B8 downloading
# LC80090022016190LGN00
# Cloud % in box: 17.56035578144854
# LC80090022016190LGN00 B8 downloading
# LC80090022015123LGN00
# Cloud % in box: 1.6687844133841592
# LC80090022015123LGN00 B8 downloading
# LC80090022016254LGN00
# Cloud % in box: 0.0
# LC80090022016254LGN00 B8 downloading
# LC80090022013117LGN01
# Cloud % in box: 0.0169419737399407
# LC80090022013117LGN01 B8 downloading
# LC80090022015219LGN00
# Cloud % in box: 0.7962727657772131
# LC80090022015219LGN00 B8 downloading
# LC80090022014216LGN00
# Cloud % in box: 0.5675561202880135
# LC80090022014216LGN00 B8 downloading
# LC80090022017112LGN00
# Cloud % in box: 0.0169419737399407
# LC80090022017112LGN00 B8 downloading
# LC80090022016206LGN00
# Cloud % in box: 0.28801355357899194
# LC80090022016206LGN00 B8 downloading
# LC80090022015139LGN00
# Cloud % in box: 3.8458280389665394
# LC80090022015139LGN00 B8 downloading
# LC80090022014232LGN00
# Cloud % in box: 0.9572215163066498
# LC80090022014232LGN00 B8 downloading
# LC80090022016238LGN00
# Cloud % in box: 2.88860652265989
# LC80090022016238LGN00 B8 downloading
# LC80090022016222LGN00
# Cloud % in box: 3.6933502753070733
# LC80090022016222LGN00 B8 downloading
# LC80090022016094LGN00
# Cloud % in box: 0.6692079627276578
# LC80090022016094LGN00 B8 downloading
# LC80090022017080LGN00
# Cloud % in box: 7.064803049555274
# LC80090022017080LGN00 B8 downloading
# LC80090022014088LGN00
# Cloud % in box: 0.9911054637865312
# LC80090022014088LGN00 B8 downloading
# LC80090022015187LGN00
# Cloud % in box: 0.0
# LC80090022015187LGN00 B8 downloading
# LC80090022016270LGN00
# Cloud % in box: 7.920372723422278
# LC80090022016270LGN00 B8 downloading
# LC80090022014200LGN00
# Cloud % in box: 13.03684879288437
# LC80090022014200LGN00 B8 downloading
# LC80090022015203LGN00
# Cloud % in box: 1.279119017365523
# LC80090022015203LGN00 B8 downloading
# Box531 exists already.
# Path014_Row001  ALREADY DOWNLOADED. SKIP.
# Total number of pixels in the raster: 11805
# LC80140012017115LGN00
# Cloud % in box: 0.0169419737399407
# LC80140012017115LGN00 B8 downloading
# LC80140012016177LGN00
# Cloud % in box: 11.605252011859383
# LC80140012016177LGN00 B8 downloading
# LC80140012014171LGN00
# Cloud % in box: 0.025412960609911054
# LC80140012014171LGN00 B8 downloading
# LC80140012015270LGN00
# Cloud % in box: 19.178314273612877
# LC80140012015270LGN00 B8 downloading
# LC80140012013120LGN01
# Cloud % in box: 0.0
# LC80140012013120LGN01 B8 downloading
# LC80140012013248LGN00
# Cloud % in box: 18.839474798814063
# LC80140012013248LGN00 B8 downloading
# LC80140012015206LGN00
# Cloud % in box: 2.9733163913595937
# LC80140012015206LGN00 B8 downloading
# LC80140012014251LGN00
# Cloud % in box: 2.600592969080898
# LC80140012014251LGN00 B8 downloading
# LC80140012016113LGN00
# Cloud % in box: 0.05082592121982211
# LC80140012016113LGN00 B8 downloading
# LC80140012013232LGN00
# Cloud % in box: 0.6437950021177468
# LC80140012013232LGN00 B8 downloading
# LC80140012015158LGN00
# Cloud % in box: 0.1948326980093181
# LC80140012015158LGN00 B8 downloading
# LC80140012015126LGN00
# Cloud % in box: 0.8047437526471835
# LC80140012015126LGN00 B8 downloading
# LC80140012014187LGN00
# Cloud % in box: 19.407030919102077
# LC80140012014187LGN00 B8 downloading
# LC80140012015094LGN00
# Cloud % in box: 6.166878441338416
# LC80140012015094LGN00 B8 downloading
# LC80140012014267LGN00
# Cloud % in box: 0.0
# LC80140012014267LGN00 B8 downloading
# LC80140012015174LGN00
# Cloud % in box: 0.0
# LC80140012015174LGN00 B8 downloading
# LC80140012013264LGN00
# Cloud % in box: 0.11859381617958492
# LC80140012013264LGN00 B8 downloading
# LC80140012014123LGN00
# Cloud % in box: 0.05929690808979246
# LC80140012014123LGN00 B8 downloading
# LC80140012017099LGN00
# Cloud % in box: 0.4404913172384583
# LC80140012017099LGN00 B8 downloading
# LC80140012016129LGN00
# Cloud % in box: 0.042354934349851756
# LC80140012016129LGN00 B8 downloading
# LC80140012015078LGN00
# Cloud % in box: 6.920796272765776
# LC80140012015078LGN00 B8 downloading
# LC80140012015190LGN00
# Cloud % in box: 0.00847098686997035
# LC80140012015190LGN00 B8 downloading
# LC80140012016257LGN00
# Cloud % in box: 2.117746717492588
# LC80140012016257LGN00 B8 downloading
# LC80140012015254LGN00
# Cloud % in box: 2.100804743752647
# LC80140012015254LGN00 B8 downloading
# LC80140012014203LGN00
# Cloud % in box: 0.48284625158831007
# LC80140012014203LGN00 B8 downloading
# LC80140012016193LGN00
# Cloud % in box: 0.30495552731893266
# LC80140012016193LGN00 B8 downloading
# LC80140012015238LGN00
# Cloud % in box: 16.37441761965269
# LC80140012015238LGN00 B8 downloading
# LC80140012015142LGN00
# Cloud % in box: 0.33883947479881404
# LC80140012015142LGN00 B8 downloading
# LC80140012015110LGN00
# Cloud % in box: 0.05929690808979246
# LC80140012015110LGN00 B8 downloading
# LC80140012016097LGN00
# Cloud % in box: 0.7539178314273612
# LC80140012016097LGN00 B8 downloading
# LC80140012017083LGN00
# Cloud % in box: 8.276154171961034
# LC80140012017083LGN00 B8 downloading
# LC80140012014139LGN00
# Cloud % in box: 0.9318085556967387
# LC80140012014139LGN00 B8 downloading
# LC80140012016081LGN00
# Cloud % in box: 0.0
# LC80140012016081LGN00 B8 downloading

# %% [markdown]
# ## 3) Grab image dates from the metadata

# %%
import datetime

#create dictionary of datetime objects for the images:
datetime_objs = {}

#LOOP through each of the glaciers in the DataFrame and download for each path and row
for i in range(0, len(pathrows_df.index)):
    #SET path and row variables to the LS path and rows of the box
    path = pathrows_df['Path'][i]
    row = pathrows_df['Row'][i]
    BoxID = pathrows_df.index[i]
    #print(path, row)
    
    #SET path row folder name
    folder_name = 'Path'+path+'_Row'+row
#     print(folder_name)
    
    #SET path to the folder names
    folder_path = outputpath+'LS8aws/'+folder_name+'/'
        
    # LOOP through all the metadata files to grab the image dates
    # in the metadata files
    for scene in os.listdir(folder_path):
        if folder_name.startswith("Path") and scene.endswith("LGN", -5, -2):
            #list the name of the image folder
#             print(scene)
            scenetag = scene[8:19]
#             print(scenetag)
            scenecount = scenecount+1

            #open the metadata file within that folder
            for file in os.listdir(folder_path+scene+"/"):                
                if ("MTL.txt" in file):
                    
                    mdata = open(folder_path+scene+"/"+scene+"_MTL.txt", "r")

                    #loop through each line in metadata to find the date and time of acquisition
                    for line in mdata:
                        variable = line.split("=")[0]

                        if ("DATE_ACQUIRED" in variable):
                            #save it:
                            date = line.split("=")[1][1:-1]
#                             print(date)

                        #if ("SCENE_CENTER_TIME" in variable): 
                            #save it:
                            #time = line.split("=")[1][2:-2]
                            #print(time)
                
                    #combine them into a datetime object
                    datetime_obj = datetime.datetime.strptime(date, '%Y-%m-%d')
                    datetime_objs.update( {scene[4:-5]: datetime_obj} )
                         
datetime_df = pd.DataFrame.from_dict(datetime_objs, orient='index')
datetime_df

# %% [markdown]
# Export image dates to .csv

# %%
datetime_df.to_csv(path_or_buf = basepath+'datetags.csv', sep=',')

# %% [markdown]
# ## For download using Google instead, follow these instructions:

# %% [markdown]
# Use gsutil: https://krstn.eu/landsat-batch-download-from-google/
#
# To access a scene for Path 124, Row 053, use this syntax:
#
# gsutil cp -n gs://earthengine-public/landsat/L8/124/053/LC81240532013107LGN01.tar.bz /landsat/
