# %% [markdown]
# # Greenland peripherial glacier pre-image download processing
#
# #### Jukes Liu
# __Last modified 10-15-2019.__

# %% [markdown]
# ## 1) Import packages, set base path, set glaciers of interest by BoxID

# %%
import subprocess
import numpy as np
import os
import pandas as pd
import rasterio
import fiona
from shapely.geometry import Polygon, Point
import shapely
import math
import shutil
from PIL import Image
import matplotlib.image as mpimg
import scipy.misc

#SET basepath to your own folder
basepath='/home/jukes/Documents/Sample_glaciers/'
downloadpath = '/media/jukes/jukes1/LS8aws/'

#ENTER list of glaciers of interest by BoxID
#make this into a widget where you can enter them in?
BOXIDS = ['001', '002', '004', '033', '120', '174', '235', '259', '277', '531'];
# BOXIDS = ['Alison', 'Helheim']
# BOXIDS = ['147', '148', '149', '150', '152', '190', '191', '192', '193', '194', '195', '195', '196', '213', '214', '215']

# %%
def distance(x1, y1, x2, y2):
    dist = math.sqrt(((x2-x1)**2) + ((y2-y1)**2))
    return dist

# %%
#define a function that uses trigonometry to calculate the slope angle
#that each pair of box vertices make
def slope_angle(x1, y1, x2, y2):
    return np.arctan2(y2-y1, x2-x1)*180/np.pi

# %% [markdown]
# ## 2) Create buffer zone around terminus boxes and rasterize/subset terminus boxes

# %% [markdown]
# The following code pulls the buffer distances around the terminus boxes from an existing .csv file with the exported attributes tables for the peripheral glacier terminus boxes. These buffer distances will be used to create a buffer zone to subset the Landsat scenes.

# %%
buffers = []

#Calculate a buffer distance around the terminus box using the UTM projected boxes
for BoxID in BOXIDS:
    buff_distances = []

    for file in os.listdir(basepath+'Box'+BoxID+'/'):
        if 'UTM' in file and '.shp' in file:
            print(file)
            boxpath = basepath+"Box"+BoxID+"/"+file
#             print(boxpath)
            
            termbox = fiona.open(boxpath)
            #grab the box feature:
            box = termbox.next()
            box_geom= box.get('geometry')
            box_coords = box_geom.get('coordinates')[0]
#             print(box_geom)
            
            points = []
            for coord_pair in box_coords:
                lat = coord_pair[0]
                lon = coord_pair[1]
                
                points.append([lat, lon])
            
            #Calculate distance between 1 and 2 and distance between 2 and 3
            #pick the longer one (length)
            coord1 = points[0]
            coord2 = points[1]
            coord3 = points[2]
            
            #1 and 2
            dist1 = distance(coord1[0], coord1[1], coord2[0], coord2[1])       
            #2 and 3
            dist2 = distance(coord2[0], coord2[1], coord3[0], coord3[1])
            
            buff_dist = int(np.max([dist1, dist2]))
#             print(buff_dist)
            buff_distances.append(buff_dist)
    
    buffer = buff_distances[0]
    buffers.append(buffer)

buff_df = pd.DataFrame(list(zip(BOXIDS, buffers)), columns=['BoxID', 'Buff_dist_m'])
buff_df
# Out:
# Box147_UTM_23.shp
# Box147_UTM_24.shp
# Buffer147_UTM_23.shp
# Buffer147_UTM_24.shp
# Box148_UTM_23.shp
# Box148_UTM_24.shp
# Buffer148_UTM_24.shp
# Buffer148_UTM_23.shp
# Box149_UTM_24.shp
# Box149_UTM_23.shp
# Buffer149_UTM_23.shp
# Buffer149_UTM_24.shp
# Buffer150_UTM_24.shp
# Box150_UTM_24.shp
# Box150_UTM_23.shp
# Buffer150_UTM_23.shp
# Box152_UTM_23.shp
# Buffer152_UTM_24.shp
# Box152_UTM_24.shp
# Buffer152_UTM_23.shp
# Box190_UTM_24.shp
# Buffer190_UTM_24.shp
# Box190_UTM_23.shp
# Buffer190_UTM_23.shp
# Box191_UTM_24.shp
# Box191_UTM_23.shp
# Buffer191_UTM_23.shp
# Buffer191_UTM_24.shp
# Buffer192_UTM_23.shp
# Buffer192_UTM_24.shp
# Box192_UTM_23.shp
# Box192_UTM_24.shp
# Box193_UTM_23.shp
# Buffer193_UTM_23.shp
# Buffer193_UTM_24.shp
# Box193_UTM_24.shp
# Buffer194_UTM_24.shp
# Box194_UTM_23.shp
# Box194_UTM_24.shp
# Buffer194_UTM_23.shp
# Buffer195_UTM_23.shp
# Buffer195_UTM_24.shp
# Box195_UTM_24.shp
# Box195_UTM_23.shp
# Buffer195_UTM_23.shp
# Buffer195_UTM_24.shp
# Box195_UTM_24.shp
# Box195_UTM_23.shp
# Buffer196_UTM_24.shp
# Buffer196_UTM_23.shp
# Box196_UTM_23.shp
# Box196_UTM_24.shp
# Box213_UTM_24.shp
# Buffer213_UTM_24.shp
# Box213_UTM_23.shp
# Buffer213_UTM_23.shp
# Box214_UTM_24.shp
# Buffer214_UTM_23.shp
# Buffer214_UTM_24.shp
# Box214_UTM_23.shp
# Buffer215_UTM_23.shp
# Box215_UTM_24.shp
# Box215_UTM_23.shp
# Buffer215_UTM_24.shp
# /home/jukes/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: FionaDeprecationWarning: Collection.__next__() is buggy and will be removed in Fiona 2.0. Switch to `next(iter(collection))`.
#   from ipykernel import kernelapp as app
#    BoxID  Buff_dist_m
# 0    147         1083
# 1    148          861
# 2    149          662
# 3    150           34
# 4    152          934
# 5    190         1946
# 6    191         1685
# 7    192           33
# 8    193         1509
# 9    194           87
# 10   195           61
# 11   195           61
# 12   196           34
# 13   213         2478
# 14   214         2777
# 15   215          131

# %% [markdown]
# The next section creates a buffer zone using GDAL command **ogr2ogr** with the following syntax:
#
#     ogr2ogr Buffer###.shp path_to_terminusbox###.shp  -dialect sqlite -sql "SELECT ST_Buffer(geometry, buffer_distance) AS geometry,*FROM 'Box###'" -f "ESRI Shapefile"

# %%
for index, row in buff_df.iterrows():
    BoxID = row['BoxID']
    buff_dist = str(row['Buff_dist_m'])
    
    #SET path to the terminus box shapefiles
    terminusbox_path = basepath+"Box"+BoxID+"/Box"+BoxID+".shp"
    outputbuffer_path = basepath+"Box"+BoxID+"/Buffer"+BoxID+".shp"
    
    #SET buffer command and print to check it
    buffer_cmd = 'ogr2ogr '+outputbuffer_path+" "+terminusbox_path+' -dialect sqlite -sql "SELECT ST_Buffer(geometry, '+buff_dist+") AS geometry,*FROM 'Box"+BoxID+"'"+'" -f "ESRI Shapefile"'
    print(buffer_cmd)
    
    subprocess.call(buffer_cmd, shell=True)
    
    print("Box"+BoxID)
# Out:
# ogr2ogr /home/jukes/Documents/Sample_glaciers/Box147/Buffer147.shp /home/jukes/Documents/Sample_glaciers/Box147/Box147.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 1083) AS geometry,*FROM 'Box147'" -f "ESRI Shapefile"
# Box147
# ogr2ogr /home/jukes/Documents/Sample_glaciers/Box148/Buffer148.shp /home/jukes/Documents/Sample_glaciers/Box148/Box148.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 861) AS geometry,*FROM 'Box148'" -f "ESRI Shapefile"
# Box148
# ogr2ogr /home/jukes/Documents/Sample_glaciers/Box149/Buffer149.shp /home/jukes/Documents/Sample_glaciers/Box149/Box149.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 662) AS geometry,*FROM 'Box149'" -f "ESRI Shapefile"
# Box149
# ogr2ogr /home/jukes/Documents/Sample_glaciers/Box150/Buffer150.shp /home/jukes/Documents/Sample_glaciers/Box150/Box150.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 34) AS geometry,*FROM 'Box150'" -f "ESRI Shapefile"
# Box150
# ogr2ogr /home/jukes/Documents/Sample_glaciers/Box152/Buffer152.shp /home/jukes/Documents/Sample_glaciers/Box152/Box152.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 934) AS geometry,*FROM 'Box152'" -f "ESRI Shapefile"
# Box152
# ogr2ogr /home/jukes/Documents/Sample_glaciers/Box190/Buffer190.shp /home/jukes/Documents/Sample_glaciers/Box190/Box190.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 1946) AS geometry,*FROM 'Box190'" -f "ESRI Shapefile"
# Box190
# ogr2ogr /home/jukes/Documents/Sample_glaciers/Box191/Buffer191.shp /home/jukes/Documents/Sample_glaciers/Box191/Box191.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 1685) AS geometry,*FROM 'Box191'" -f "ESRI Shapefile"
# Box191
# ogr2ogr /home/jukes/Documents/Sample_glaciers/Box192/Buffer192.shp /home/jukes/Documents/Sample_glaciers/Box192/Box192.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 33) AS geometry,*FROM 'Box192'" -f "ESRI Shapefile"
# Box192
# ogr2ogr /home/jukes/Documents/Sample_glaciers/Box193/Buffer193.shp /home/jukes/Documents/Sample_glaciers/Box193/Box193.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 1509) AS geometry,*FROM 'Box193'" -f "ESRI Shapefile"
# Box193
# ogr2ogr /home/jukes/Documents/Sample_glaciers/Box194/Buffer194.shp /home/jukes/Documents/Sample_glaciers/Box194/Box194.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 87) AS geometry,*FROM 'Box194'" -f "ESRI Shapefile"
# Box194
# ogr2ogr /home/jukes/Documents/Sample_glaciers/Box195/Buffer195.shp /home/jukes/Documents/Sample_glaciers/Box195/Box195.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 61) AS geometry,*FROM 'Box195'" -f "ESRI Shapefile"
# Box195
# ogr2ogr /home/jukes/Documents/Sample_glaciers/Box195/Buffer195.shp /home/jukes/Documents/Sample_glaciers/Box195/Box195.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 61) AS geometry,*FROM 'Box195'" -f "ESRI Shapefile"
# Box195
# ogr2ogr /home/jukes/Documents/Sample_glaciers/Box196/Buffer196.shp /home/jukes/Documents/Sample_glaciers/Box196/Box196.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 34) AS geometry,*FROM 'Box196'" -f "ESRI Shapefile"
# Box196
# ogr2ogr /home/jukes/Documents/Sample_glaciers/Box213/Buffer213.shp /home/jukes/Documents/Sample_glaciers/Box213/Box213.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 2478) AS geometry,*FROM 'Box213'" -f "ESRI Shapefile"
# Box213
# ogr2ogr /home/jukes/Documents/Sample_glaciers/Box214/Buffer214.shp /home/jukes/Documents/Sample_glaciers/Box214/Box214.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 2777) AS geometry,*FROM 'Box214'" -f "ESRI Shapefile"
# Box214
# ogr2ogr /home/jukes/Documents/Sample_glaciers/Box215/Buffer215.shp /home/jukes/Documents/Sample_glaciers/Box215/Box215.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 131) AS geometry,*FROM 'Box215'" -f "ESRI Shapefile"
# Box215

# %% [markdown]
# The terminus box shapefiles are then rasterized (to be used as a mask during the WTMM filering) using the GDAL **gdal_rasterize** command and subset to the buffer zone using the GDAL **gdalwarp** command using the following syntax:
#
# 1) Rasterize
#
#     gdal_rasterize -burn 1.0 -tr x_resolution y_resolution -a_nodata 0.0 path_to_terminusbox.shp path_to_terminusbox_raster.TIF
#
# The x_resolution and y_resolution are set to be 15.0 (meters) to match the Landsat B8 resolution.
#
# 2) Subset
#
#     gdalwarp -cutline path_to_Buffer###.shp -crop_to_cutline path_to_terminusbox_raster.TIF path_to_subset_raster_cut.TIF

# %%
for index, row in buff_df.iterrows():
    BoxID = row['BoxID']
    #SET path to the terminus box shapefiles
    terminusbox_path = basepath+"Box"+BoxID+"/Box"+BoxID+".shp"
    buffer_path = basepath+"Box"+BoxID+"/Buffer"+BoxID+".shp"
    
    #output raster path:
    terminusraster_path = basepath+"Box"+BoxID+"/Box"+BoxID+".TIF"
    cutraster_path = basepath+"Box"+BoxID+"/Box"+BoxID+"_cut.TIF"
    
    #SET commands and print to check
    rasterize_cmd = 'gdal_rasterize -burn 1.0 -tr 15.0 15.0 -a_nodata 0.0 '+terminusbox_path+' '+terminusraster_path
    subsetbuffer_cmd = 'gdalwarp -cutline '+buffer_path+' -crop_to_cutline '+terminusraster_path+" "+cutraster_path
    #print(export_GDALpath+rasterize_cmd)
    #print(export_GDALpath+subsetbuffer_cmd)
    
    #RASTERIZE & SUBSET
    subprocess.call(rasterize_cmd, shell=True)
    subprocess.call(subsetbuffer_cmd, shell=True)
    
    print("Box"+BoxID)
# Out:
# Box147
# Box148
# Box149
# Box150
# Box152
# Box190
# Box191
# Box192
# Box193
# Box194
# Box195
# Box195
# Box196
# Box213
# Box214
# Box215

# %% [markdown]
# ## 3) Calculate average flow direction (weighted by magnitude) for each glacier

# %% [markdown]
# The following code processes 2016-2017 ice velocity data from the ESA Cryoportal to determine each glacier of interest's weighted average flow direction. The ice velocity direction (calculated from yx velocity) and the velocity magnitude at each glacier's terminus  is subset using the terminus box shapefile using a GDAL command (**gdalwarp**) with the following syntax:
#
#     gdalwarp -cutline path_to_terminusbox.shp -crop_to_cutline path_to_input_velocity.TIF path_to_output_velocity_at_term###.TIF

# %%
for BoxID in BOXIDS:
    #SET paths to the terminus box shapefiles and velocity data
    terminusbox_path = basepath+"Box"+BoxID+"/Box"+BoxID+".shp"

    for vdate in ['2014_15', '2015_16', '2016_17']:
        vdir = vdate+'_velocity_dir_degree_yx.tif'
        vmag = vdate+'_velocity_mag.tif'
        
        #set input paths
        vdir_in = basepath+vdir
        vmag_in = basepath+vmag
    
        #SET output paths
        vdir_out = basepath+"Box"+BoxID+"/"+vdir
        vmag_out = basepath+"Box"+BoxID+"/"+vmag

        #SET velocity subset commands and print to check it
        v_subset_dir_cmd = 'gdalwarp -cutline '+terminusbox_path+' -crop_to_cutline '+vdir_in+" "+vdir_out
        v_subset_mag_cmd = 'gdalwarp -cutline '+terminusbox_path+' -crop_to_cutline '+vmag_in+" "+vmag_out
        print(v_subset_dir_cmd)
        print(v_subset_mag_cmd)

        #SUBSET velocity rasters
        subprocess.call(v_subset_dir_cmd, shell=True)
        subprocess.call(v_subset_mag_cmd, shell=True)
    
    print("Box"+BoxID)
# Out:
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Box001.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2014_15_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box001/2014_15_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Box001.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2014_15_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box001/2014_15_velocity_mag.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Box001.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2015_16_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box001/2015_16_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Box001.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2015_16_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box001/2015_16_velocity_mag.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Box001.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2016_17_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box001/2016_17_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Box001.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2016_17_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box001/2016_17_velocity_mag.tif
# Box001
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box002/Box002.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2014_15_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box002/2014_15_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box002/Box002.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2014_15_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box002/2014_15_velocity_mag.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box002/Box002.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2015_16_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box002/2015_16_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box002/Box002.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2015_16_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box002/2015_16_velocity_mag.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box002/Box002.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2016_17_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box002/2016_17_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box002/Box002.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2016_17_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box002/2016_17_velocity_mag.tif
# Box002
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box004/Box004.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2014_15_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box004/2014_15_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box004/Box004.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2014_15_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box004/2014_15_velocity_mag.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box004/Box004.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2015_16_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box004/2015_16_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box004/Box004.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2015_16_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box004/2015_16_velocity_mag.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box004/Box004.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2016_17_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box004/2016_17_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box004/Box004.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2016_17_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box004/2016_17_velocity_mag.tif
# Box004
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box033/Box033.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2014_15_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box033/2014_15_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box033/Box033.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2014_15_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box033/2014_15_velocity_mag.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box033/Box033.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2015_16_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box033/2015_16_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box033/Box033.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2015_16_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box033/2015_16_velocity_mag.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box033/Box033.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2016_17_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box033/2016_17_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box033/Box033.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2016_17_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box033/2016_17_velocity_mag.tif
# Box033
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box120/Box120.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2014_15_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box120/2014_15_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box120/Box120.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2014_15_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box120/2014_15_velocity_mag.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box120/Box120.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2015_16_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box120/2015_16_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box120/Box120.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2015_16_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box120/2015_16_velocity_mag.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box120/Box120.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2016_17_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box120/2016_17_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box120/Box120.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2016_17_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box120/2016_17_velocity_mag.tif
# Box120
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box174/Box174.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2014_15_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box174/2014_15_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box174/Box174.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2014_15_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box174/2014_15_velocity_mag.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box174/Box174.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2015_16_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box174/2015_16_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box174/Box174.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2015_16_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box174/2015_16_velocity_mag.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box174/Box174.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2016_17_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box174/2016_17_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box174/Box174.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2016_17_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box174/2016_17_velocity_mag.tif
# Box174
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box235/Box235.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2014_15_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box235/2014_15_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box235/Box235.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2014_15_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box235/2014_15_velocity_mag.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box235/Box235.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2015_16_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box235/2015_16_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box235/Box235.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2015_16_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box235/2015_16_velocity_mag.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box235/Box235.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2016_17_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box235/2016_17_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box235/Box235.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2016_17_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box235/2016_17_velocity_mag.tif
# Box235
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box259/Box259.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2014_15_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box259/2014_15_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box259/Box259.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2014_15_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box259/2014_15_velocity_mag.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box259/Box259.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2015_16_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box259/2015_16_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box259/Box259.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2015_16_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box259/2015_16_velocity_mag.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box259/Box259.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2016_17_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box259/2016_17_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box259/Box259.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2016_17_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box259/2016_17_velocity_mag.tif
# Box259
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box277/Box277.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2014_15_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box277/2014_15_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box277/Box277.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2014_15_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box277/2014_15_velocity_mag.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box277/Box277.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2015_16_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box277/2015_16_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box277/Box277.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2015_16_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box277/2015_16_velocity_mag.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box277/Box277.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2016_17_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box277/2016_17_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box277/Box277.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2016_17_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box277/2016_17_velocity_mag.tif
# Box277
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Box531.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2014_15_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box531/2014_15_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Box531.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2014_15_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box531/2014_15_velocity_mag.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Box531.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2015_16_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box531/2015_16_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Box531.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2015_16_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box531/2015_16_velocity_mag.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Box531.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2016_17_velocity_dir_degree_yx.tif /home/jukes/Documents/Sample_glaciers/Box531/2016_17_velocity_dir_degree_yx.tif
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Box531.shp -crop_to_cutline /home/jukes/Documents/Sample_glaciers/2016_17_velocity_mag.tif /home/jukes/Documents/Sample_glaciers/Box531/2016_17_velocity_mag.tif
# Box531

# %% [markdown]
# Next, these subset velocity rasters are opened using the **rasterio** package and read into arrays. They are filtered for anomalous values and the velocity magnitudes are converted into weights. Then the **numpy.average()** function is used to calculated the weighted average flow directions where the flow directions of the pixels where the highest velocities are found are weighted more.
#
# The resulting average flow direction will be representative of the glacier's main flow. These directions will be used to rotate the images of the glaciers so that their flow is due right.

# %%
# #CREATE list of glacier average flow directions:
# boxes = []
# avg_rot = []
# max_mag = []
# years = []

# avg_rot_3 = []

# for BoxID in BOXIDS :
#     rot_angles = []
#     max_magnitudes = []
    
#     for vdate in ['2014_15', '2015_16', '2016_17']:
#         #READ velocity direction and magnitude data at terminus for each glacier into an array
#         vdir = vdate+'_velocity_dir_degree_yx.tif'
#         vmag = vdate+'_velocity_mag.tif'  
                
#         direction = rasterio.open(basepath+"Box"+BoxID+"/"+vdir, "r")
#         dir_array = direction.read()
#         #convert from radians to degree for 2016_17
#         if vdate == '2016_17':
#             dir_array = dir_array*180.0/np.pi

#         magnitude = rasterio.open(basepath+"Box"+BoxID+"/"+vmag, "r")
#         mag_array = magnitude.read()
       
#         #REMOVE anomalous values
#         #direction must be between 180 and -180 degrees
#         mask_dir = (dir_array < 180) & (dir_array > -180)
#         masked_dir = dir_array[mask_dir]
# #         print(dir_array.shape)
# #         print(masked_dir.shape)
# #         print(masked_dir.min(), masked_dir.max())

#         #magnitude must be between 0 and 10 m/d
#         mask_mag = (mag_array < 100) & (mag_array > 0)
#         masked_mag = mag_array[mask_mag]
# #         print(mag_array.shape)
# #         print(masked_mag.shape)
# #         print(masked_mag.min(), masked_mag.max())

#         #MAKE sure the two arrays are the same length
#         diff = np.diff([len(masked_dir), len(masked_mag)])[0]
# #         print(diff)   
#         if diff > 0:
#             masked_mag = masked_mag[:-diff]
# #             print(len(masked_mag))
# #             print(masked_dir)
#         if diff < 0:
#             masked_dir = masked_dir[:-diff]

#         #CALCULATE weights (0 - 1) from magnitudes
#         mag_range = masked_mag.max() - masked_mag.min()
#         stretch = 1/mag_range
#         weights = stretch*(masked_mag - masked_mag.min())
# #         print(weights.min(), weights.max()) #should be between 0 and 1
# #         print(weights.shape, masked_dir.shape)
        
#         #CALCULATE the weighted average rotation angle
#         avg_dir = np.average(masked_dir, weights=weights)

            
#         #APPEND the rotation angles to the dictionary
#         if masked_dir.min() == masked_dir.max():
#             rot_angles.append(masked_dir.min())
#         else:
#             rot_angles.append(avg_dir)
        
#         #APPEND the maximum flow magnitude
#         max_magnitudes.append(masked_mag.max())
        
#         #for all three years
#         years.append(vdate)
#         avg_rot_3.append(avg_dir)
#         boxes.append(BoxID)
#         max_mag.append(masked_mag.max())
#         print(vdate, avg_dir)
        
#     rot_angles = rot_angles[:-1]
#     max_magnitudes = max_magnitudes[:-1]
        
#     #APPEND the final values
# #     boxes.append(BoxID)
#     #grab maximum magnitude of all three years
# #     max_mag.append(np.max(max_magnitudes))
#     #grab the avg flow dir closest to the a box angle out of the three years
#     #load in box shape and grab coordinates using fiona
#     boxshp = fiona.open(basepath+'Box'+BoxID+'/Box'+BoxID+'.shp')
#     coordinates = boxshp[0]['geometry']['coordinates'][0]
#     coords = [xy[0:2] for xy in coordinates]
#     vertices = coords[:-1]
#     print(BoxID)
#     #grab vertex angles:
#     for i in range(0, len(vertices)):
#         #for the last vertex in the loop, use the original vertex as x2, y2
#         if i == 3:
#             x1, y1 = vertices[i]
#             x2, y2 = vertices[0]
#         else:
#             x1, y1 = vertices[i]
#             x2, y2 = vertices[i+1]
#         print(slope_angle(x1, y1, x2, y2))  
#     print('---------------')
# #create dataframe with the calculations
# velocities_df = pd.DataFrame(list(zip(boxes,years, avg_rot_3, max_mag)), 
#                              columns=['BoxID','Year','Flow_dir', 'Max_speed'])
# # velocities_df = pd.DataFrame(list(zip(boxes,avg_rot, max_mag)), columns=['BoxID','Flow_dir', 'Max_speed'])
# velocities_df = velocities_df.sort_values(by='BoxID')
# velocities_df = velocities_df.drop_duplicates()
# velocities_df

# %%
# #EXPORT MAX VELOCITY AND AVERAGE FLOW DIRECTION TO A .CSV FILE
# #write the data frame to csv file
# velocities_df.to_csv(path_or_buf = basepath+'Glacier_vel_3yrs_sample10.csv', sep=',', index=False)

# %%
# print(list(velocities_df.Flow_dir))
# Out:
# [24.437496185302734, 154.302001953125, 51.870487213134766, 119.75666809082031, -78.63849639892578, 18.988548278808594, -152.5367431640625, 114.55601501464844, -24.19788360595703, 21.693702697753906]

# %% [markdown]
# ## 4) Rotate all images by flow direction
#
# Read in the glacier velocity file as velocities_df if not already loaded:

# %%
velocities_df = pd.read_csv(basepath+'Glacier_velocities.csv', sep=',', dtype=str, usecols=[1,2,3])
velocities_df = velocities_df.set_index('BoxID')
velocities_df
# Out:
#                   Flow_dir             Max_speed
# BoxID
# 001      56.28428268432617  0.043774381279945374
# 002      155.9872283935547     3.583226442337036
# 004     -3.483433723449707    0.6230824589729309
# 033         142.1181640625    0.7716577649116516
# 120     -77.38639831542969   0.27788856625556946
# 174     12.677642822265625    0.9145031571388245
# 235    -145.85076904296875   0.15709678828716278
# 259      98.99927520751953    3.0749008655548096
# 277     -65.12018585205078   0.28601959347724915
# 531      78.83521270751953   0.04078477621078491

# %%
#make rotated images directory in BoxID folders if it doesn't already exist
for BoxID in BOXIDS:
    if os.path.exists(downloadpath+"Box"+BoxID+'/rotated/'):
        print("Already exists.")
        #OTHERWISE, create the folder and download into it
    else:
        os.mkdir(downloadpath+"Box"+BoxID+'/rotated/')
        print("Folder made for Box"+BoxID)
# Out:
# Already exists.
# Already exists.
# Already exists.
# Already exists.
# Already exists.
# Already exists.
# Already exists.
# Already exists.
# Already exists.
# Already exists.

# %%
#convert all files in reprojected folder to png from TIF
for BoxID in BOXIDS:
    command = 'cd '+downloadpath+'Box'+BoxID+'/reprojected/; '+'mogrify -format png *.TIF'
#     print(command)
    subprocess.call(command, shell=True)

# %%
#move box raster into reprojected folder:
for BoxID in BOXIDS:
    boxfile = 'Box'+BoxID+'_raster_cut.png'
    boxrasterpath = basepath+'Box'+BoxID+'/'+boxfile
    newpath = downloadpath+'Box'+BoxID+'/reprojected/'+boxfile
    
    shutil.copyfile(boxrasterpath, newpath)

# %%
#ROTATE THE IMAGES
for BoxID in BOXIDS:
    #for each file in the reprojected folder:
    for file in os.listdir(downloadpath+"Box"+BoxID+'/reprojected/'):
        if file.endswith('.png'):
            print(file)
            img  = Image.open(downloadpath+"Box"+BoxID+'/reprojected/'+file)
            #rotate the image by the flow direction from flowspeed_df
            rotated = img.rotate(-float(velocities_df.loc[BoxID, 'Flow_dir']))
            rotated.save(downloadpath+"Box"+BoxID+'/rotated/R_'+file)
# Out:
# LC80360042015104LGN00_B8_PS_Buffer001.png
# LC80320052014153LGN00_B8_PS_Buffer001.png
# LC80310052014242LGN00_B8_PS_Buffer001.png
# LC80350052013267LGN00_B8_PS_Buffer001.png
# LC80350052016180LGN00_B8_PS_Buffer001.png
# LC80350052014126LGN00_B8_PS_Buffer001.png
# LC80310052016280LGN00_B8_PS_Buffer001.png
# LC80320052014249LGN00_B8_PS_Buffer001.png
# LC80350052015145LGN00_B8_PS_Buffer001.png
# LC80360042015264LGN00_B8_PS_Buffer001.png
# LC80350052015225LGN00_B8_PS_Buffer001.png
# LC80330052014176LGN00_B8_PS_Buffer001.png
# LC80320052015092LGN00_B8_PS_Buffer001.png
# LC80320052015284LGN00_B8_PS_Buffer001.png
# LC80350052013123LGN01_B8_PS_Buffer001.png
# LC80360042015168LGN00_B8_PS_Buffer001.png
# Box001_raster_cut.png
# LC80330052016070LGN00_B8_PS_Buffer001.png
# LC80310052015229LGN00_B8_PS_Buffer001.png
# LC80330052014160LGN00_B8_PS_Buffer001.png
# LC80330052017072LGN00_B8_PS_Buffer001.png
# LC80310052015277LGN00_B8_PS_Buffer001.png
# LC80350052015177LGN00_B8_PS_Buffer001.png
# LC80320052013246LGN00_B8_PS_Buffer001.png
# LC80320052014265LGN00_B8_PS_Buffer001.png
# LC80320052014201LGN00_B8_PS_Buffer001.png
# LC80360042017077LGN00_B8_PS_Buffer001.png
# LC80310052014178LGN00_B8_PS_Buffer001.png
# LC80360042016219LGN00_B8_PS_Buffer001.png
# LC80340052014103LGN00_B8_PS_Buffer001.png
# LC80350052015209LGN00_B8_PS_Buffer001.png
# LC80340052016221LGN00_B8_PS_Buffer001.png
# LC80340052017079LGN00_B8_PS_Buffer001.png
# LC80350052015113LGN00_B8_PS_Buffer001.png
# LC80310052014194LGN00_B8_PS_Buffer001.png
# LC80350052016228LGN00_B8_PS_Buffer001.png
# LC80340052017095LGN00_B8_PS_Buffer001.png
# LC80320052015108LGN00_B8_PS_Buffer001.png
# LC80330052016150LGN00_B8_PS_Buffer001.png
# LC80360042015120LGN00_B8_PS_Buffer001.png
# LC80330052017120LGN00_B8_PS_Buffer001.png
# LC80340052015202LGN00_B8_PS_Buffer001.png
# LC80350052013235LGN00_B8_PS_Buffer001.png
# LC80360042016123LGN00_B8_PS_Buffer001.png
# LC80310052015213LGN00_B8_PS_Buffer001.png
# LC80330052014144LGN00_B8_PS_Buffer001.png
# LC80310052016072LGN00_B8_PS_Buffer001.png
# LC80330052015179LGN00_B8_PS_Buffer001.png
# LC80310052015117LGN00_B8_PS_Buffer001.png
# LC80360042014261LGN00_B8_PS_Buffer001.png
# LC80340052017111LGN00_B8_PS_Buffer001.png
# LC80350052015129LGN00_B8_PS_Buffer001.png
# LC80310052014146LGN00_B8_PS_Buffer001.png
# LC80360042014245LGN00_B8_PS_Buffer001.png
# LC80340052015138LGN00_B8_PS_Buffer001.png
# LC80310052014098LGN00_B8_PS_Buffer001.png
# LC80330052015147LGN00_B8_PS_Buffer001.png
# LC80360042014181LGN00_B8_PS_Buffer001.png
# LC80350052017118LGN00_B8_PS_Buffer001.png
# LC80340052015266LGN00_B8_PS_Buffer001.png
# LC80320052016063LGN00_B8_PS_Buffer001.png
# LC80320052015140LGN00_B8_PS_Buffer001.png
# LC80340052015090LGN00_B8_PS_Buffer001.png
# LC80320052016223LGN00_B8_PS_Buffer001.png
# LC80310052015181LGN00_B8_PS_Buffer001.png
# LC80310052015069LGN00_B8_PS_Buffer001.png
# LC80360042015072LGN00_B8_PS_Buffer001.png
# LC80340052016125LGN00_B8_PS_Buffer001.png
# LC80350052014142LGN00_B8_PS_Buffer001.png
# LC80320052015124LGN00_B8_PS_Buffer001.png
# LC80360042016251LGN00_B8_PS_Buffer001.png
# LC80310052014258LGN00_B8_PS_Buffer001.png
# LC80350052016212LGN00_B8_PS_Buffer001.png
# LC80330052014224LGN00_B8_PS_Buffer001.png
# LC80360042015232LGN00_B8_PS_Buffer001.png
# LC80310052014274LGN00_B8_PS_Buffer001.png
# LC80310052015149LGN00_B8_PS_Buffer001.png
# LC80330052013253LGN00_B8_PS_Buffer001.png
# LC80320052015268LGN00_B8_PS_Buffer001.png
# LC80310052017090LGN00_B8_PS_Buffer001.png
# LC80360042016139LGN00_B8_PS_Buffer001.png
# LC80340052016189LGN00_B8_PS_Buffer001.png
# LC80350052016084LGN00_B8_PS_Buffer001.png
# LC80350052014190LGN00_B8_PS_Buffer001.png
# LC80360042017109LGN00_B8_PS_Buffer001.png
# LC80330052014256LGN00_B8_PS_Buffer001.png
# LC80330052014272LGN00_B8_PS_Buffer001.png
# LC80340052016061LGN00_B8_PS_Buffer001.png
# LC80340052016205LGN00_B8_PS_Buffer001.png
# LC80330052015083LGN00_B8_PS_Buffer001.png
# LC80340052016157LGN00_B8_PS_Buffer001.png
# LC80330052017104LGN00_B8_PS_Buffer001.png
# LC80330052016198LGN00_B8_PS_Buffer001.png
# LC80340052014247LGN00_B8_PS_Buffer001.png
# LC80340052015074LGN00_B8_PS_Buffer001.png
# LC80360042017093LGN00_B8_PS_Buffer001.png
# LC80350052017102LGN00_B8_PS_Buffer001.png
# LC80340052015154LGN00_B8_PS_Buffer001.png
# LC80320052015236LGN00_B8_PS_Buffer001.png
# LC80360042013258LGN00_B8_PS_Buffer001.png
# LC80310052017074LGN00_B8_PS_Buffer001.png
# LC80360042016267LGN00_B8_PS_Buffer001.png
# LC80360042015280LGN00_B8_PS_Buffer001.png
# LC80320052016079LGN00_B8_PS_Buffer001.png
# LC80350052015193LGN00_B8_PS_Buffer001.png
# LC80330052013269LGN00_B8_PS_Buffer001.png
# LC80330052016262LGN00_B8_PS_Buffer001.png
# LC80310052015261LGN00_B8_PS_Buffer001.png
# LC80330052016166LGN00_B8_PS_Buffer001.png
# LC80310052016088LGN00_B8_PS_Buffer001.png
# LC80330052015115LGN00_B8_PS_Buffer001.png
# LC80320052014073LGN00_B8_PS_Buffer001.png
# LC80360042015088LGN00_B8_PS_Buffer001.png
# LC80340052016077LGN00_B8_PS_Buffer001.png
# LC80320052016255LGN00_B8_PS_Buffer001.png
# LC80340052014087LGN00_B8_PS_Buffer001.png
# LC80310052013239LGN00_B8_PS_Buffer001.png
# LC80310052014226LGN00_B8_PS_Buffer001.png
# LC80350052016276LGN00_B8_PS_Buffer001.png
# LC80340052016093LGN00_B8_PS_Buffer001.png
# LC80310052016184LGN00_B8_PS_Buffer001.png
# LC80340052013260LGN00_B8_PS_Buffer001.png
# LC80320052013134LGN03_B8_PS_Buffer001.png
# LC80330052013125LGN01_B8_PS_Buffer001.png
# LC80320052015188LGN00_B8_PS_Buffer001.png
# LC80310052014082LGN00_B8_PS_Buffer001.png
# LC80320052015204LGN00_B8_PS_Buffer001.png
# LC80350052014078LGN00_B8_PS_Buffer001.png
# LC80350052015065LGN00_B8_PS_Buffer001.png
# LC80310052013271LGN00_B8_PS_Buffer001.png
# LC80320052014185LGN00_B8_PS_Buffer001.png
# LC80340052016109LGN00_B8_PS_Buffer001.png
# LC80320052015188LGN00_B8_PS_Buffer002.png
# LC80340052015090LGN00_B8_PS_Buffer002.png
# LC80350052015209LGN00_B8_PS_Buffer002.png
# LC80300052016273LGN00_B8_PS_Buffer002.png
# LC80330052016198LGN00_B8_PS_Buffer002.png
# LC80330052015147LGN00_B8_PS_Buffer002.png
# LC80350052015145LGN00_B8_PS_Buffer002.png
# Box002_raster_cut.png
# LC80330052017072LGN00_B8_PS_Buffer002.png
# LC80300052017083LGN00_B8_PS_Buffer002.png
# LC80340052015154LGN00_B8_PS_Buffer002.png
# LC80330052013253LGN00_B8_PS_Buffer002.png
# LC80320052014153LGN00_B8_PS_Buffer002.png
# LC80300052014267LGN00_B8_PS_Buffer002.png
# LC80320052014265LGN00_B8_PS_Buffer002.png
# LC80310052016184LGN00_B8_PS_Buffer002.png
# LC80340052014263LGN00_B8_PS_Buffer002.png
# LC80320052015156LGN00_B8_PS_Buffer002.png
# LC80300052015142LGN00_B8_PS_Buffer002.png
# LC80320052015220LGN00_B8_PS_Buffer002.png
# LC80300052015126LGN00_B8_PS_Buffer002.png
# LC80330052013269LGN00_B8_PS_Buffer002.png
# LC80310052015149LGN00_B8_PS_Buffer002.png
# LC80310052015117LGN00_B8_PS_Buffer002.png
# LC80310052014274LGN00_B8_PS_Buffer002.png
# LC80300052016097LGN00_B8_PS_Buffer002.png
# LC80300052015078LGN00_B8_PS_Buffer002.png
# LC80310052016072LGN00_B8_PS_Buffer002.png
# LC80320052016079LGN00_B8_PS_Buffer002.png
# LC80330052017104LGN00_B8_PS_Buffer002.png
# LC80330052016150LGN00_B8_PS_Buffer002.png
# LC80330052014224LGN00_B8_PS_Buffer002.png
# LC80330052015179LGN00_B8_PS_Buffer002.png
# LC80310052017090LGN00_B8_PS_Buffer002.png
# LC80320052015268LGN00_B8_PS_Buffer002.png
# LC80300052015206LGN00_B8_PS_Buffer002.png
# LC80340052015266LGN00_B8_PS_Buffer002.png
# LC80310052015213LGN00_B8_PS_Buffer002.png
# LC80310052015261LGN00_B8_PS_Buffer002.png
# LC80320052016255LGN00_B8_PS_Buffer002.png
# LC80340052015138LGN00_B8_PS_Buffer002.png
# LC80340052015186LGN00_B8_PS_Buffer002.png
# LC80330052014144LGN00_B8_PS_Buffer002.png
# LC80320052015140LGN00_B8_PS_Buffer002.png
# LC80350052016196LGN00_B8_PS_Buffer002.png
# LC80350052015193LGN00_B8_PS_Buffer002.png
# LC80320052014185LGN00_B8_PS_Buffer002.png
# LC80300052017099LGN00_B8_PS_Buffer002.png
# LC80320052015284LGN00_B8_PS_Buffer002.png
# LC80320052016223LGN00_B8_PS_Buffer002.png
# LC80300052016129LGN00_B8_PS_Buffer002.png
# LC80350052014190LGN00_B8_PS_Buffer002.png
# LC80340052016093LGN00_B8_PS_Buffer002.png
# LC80340052014103LGN00_B8_PS_Buffer002.png
# LC80310052015069LGN00_B8_PS_Buffer002.png
# LC80310052014178LGN00_B8_PS_Buffer002.png
# LC80300052016145LGN01_B8_PS_Buffer002.png
# LC80330052014256LGN00_B8_PS_Buffer002.png
# LC80340052016189LGN00_B8_PS_Buffer002.png
# LC80340052015122LGN00_B8_PS_Buffer002.png
# LC80300052014155LGN00_B8_PS_Buffer002.png
# LC80330052016070LGN00_B8_PS_Buffer002.png
# LC80350052016164LGN00_B8_PS_Buffer002.png
# LC80340052016205LGN00_B8_PS_Buffer002.png
# LC80310052017074LGN00_B8_PS_Buffer002.png
# LC80320052015204LGN00_B8_PS_Buffer002.png
# LC80350052015225LGN00_B8_PS_Buffer002.png
# LC80330052014192LGN00_B8_PS_Buffer002.png
# LC80330052014272LGN00_B8_PS_Buffer002.png
# LC80330052014176LGN00_B8_PS_Buffer002.png
# LC80350052016276LGN00_B8_PS_Buffer002.png
# LC80340052013260LGN00_B8_PS_Buffer002.png
# LC80320052014249LGN00_B8_PS_Buffer002.png
# LC80330052015211LGN00_B8_PS_Buffer002.png
# LC80330052016262LGN00_B8_PS_Buffer002.png
# LC80340052015202LGN00_B8_PS_Buffer002.png
# LC80320052015236LGN00_B8_PS_Buffer002.png
# LC80300052014251LGN00_B8_PS_Buffer002.png
# LC80350052014078LGN00_B8_PS_Buffer002.png
# LC80310052014082LGN00_B8_PS_Buffer002.png
# LC80310052016280LGN00_B8_PS_Buffer002.png
# LC80310052015245LGN00_B8_PS_Buffer002.png
# LC80350052016260LGN00_B8_PS_Buffer002.png
# LC80350052016212LGN00_B8_PS_Buffer002.png
# LC80350052017086LGN00_B8_PS_Buffer002.png
# LC80300052016081LGN00_B8_PS_Buffer002.png
# LC80340052016237LGN00_B8_PS_Buffer002.png
# LC80350052016084LGN00_B8_PS_Buffer002.png
# LC80340052013148LGN00_B8_PS_Buffer002.png
# LC80310052015181LGN00_B8_PS_Buffer002.png
# LC80310052013239LGN00_B8_PS_Buffer002.png
# LC80340052016221LGN00_B8_PS_Buffer002.png
# LC80340052014247LGN00_B8_PS_Buffer002.png
# LC80310052015197LGN00_B8_PS_Buffer002.png
# LC80310052014194LGN00_B8_PS_Buffer002.png
# LC80300052014187LGN00_B8_PS_Buffer002.png
# LC80310052013271LGN00_B8_PS_Buffer002.png
# LC80310052014226LGN00_B8_PS_Buffer002.png
# LC80310052015229LGN00_B8_PS_Buffer002.png
# LC80310052014098LGN00_B8_PS_Buffer002.png
# LC80320052015124LGN00_B8_PS_Buffer002.png
# LC80340052014087LGN00_B8_PS_Buffer002.png
# LC80340052017095LGN00_B8_PS_Buffer002.png
# LC80310052015277LGN00_B8_PS_Buffer002.png
# LC80330052015115LGN00_B8_PS_Buffer002.png
# LC80330052014208LGN00_B8_PS_Buffer002.png
# LC80300052014235LGN00_B8_PS_Buffer002.png
# LC80300052015222LGN00_B8_PS_Buffer002.png
# LC80350052016180LGN00_B8_PS_Buffer002.png
# LC80300052016257LGN00_B8_PS_Buffer002.png
# LC80350052015065LGN00_B8_PS_Buffer002.png
# LC80310052016088LGN00_B8_PS_Buffer002.png
# LC80320052016159LGN00_B8_PS_Buffer002.png
# LC80320052014073LGN00_B8_PS_Buffer002.png
# LC80320052015092LGN00_B8_PS_Buffer002.png
# LC80350052016228LGN00_B8_PS_Buffer002.png
# LC80340052016077LGN00_B8_PS_Buffer002.png
# LC80310052014242LGN00_B8_PS_Buffer002.png
# LC80300052014107LGN00_B8_PS_Buffer002.png
# LC80330052013269LGN00_B8_PS_Buffer004.png
# LC80310052015117LGN00_B8_PS_Buffer004.png
# LC80290062015071LGN00_B8_PS_Buffer004.png
# LC80310052015149LGN00_B8_PS_Buffer004.png
# LC80330052014192LGN00_B8_PS_Buffer004.png
# LC80300052016145LGN01_B8_PS_Buffer004.png
# LC80320052015124LGN00_B8_PS_Buffer004.png
# LC80330052016262LGN00_B8_PS_Buffer004.png
# LC80300052017083LGN00_B8_PS_Buffer004.png
# LC80310052013239LGN00_B8_PS_Buffer004.png
# LC80290062013257LGN00_B8_PS_Buffer004.png
# LC80300052016273LGN00_B8_PS_Buffer004.png
# LC80290062016122LGN00_B8_PS_Buffer004.png
# LC80310052014226LGN00_B8_PS_Buffer004.png
# LC80330052017104LGN00_B8_PS_Buffer004.png
# LC80280062015080LGN00_B8_PS_Buffer004.png
# LC80290062015231LGN00_B8_PS_Buffer004.png
# LC80310052016184LGN00_B8_PS_Buffer004.png
# LC80280062015208LGN00_B8_PS_Buffer004.png
# LC80330052016070LGN00_B8_PS_Buffer004.png
# LC80340052016221LGN00_B8_PS_Buffer004.png
# LO80300052015062LGN00_B8_PS_Buffer004.png
# LC80330052014144LGN00_B8_PS_Buffer004.png
# LC80310052014098LGN00_B8_PS_Buffer004.png
# LC80330052013125LGN01_B8_PS_Buffer004.png
# LC80280062015064LGN00_B8_PS_Buffer004.png
# LC80310052015213LGN00_B8_PS_Buffer004.png
# LC80280062016243LGN00_B8_PS_Buffer004.png
# LC80300052014107LGN00_B8_PS_Buffer004.png
# LC80280062014189LGN00_B8_PS_Buffer004.png
# LC80340052016109LGN00_B8_PS_Buffer004.png
# LC80280062015192LGN00_B8_PS_Buffer004.png
# LC80300052014059LGN00_B8_PS_Buffer004.png
# LC80280062015272LGN00_B8_PS_Buffer004.png
# LC80330052015115LGN00_B8_PS_Buffer004.png
# LC80320052015236LGN00_B8_PS_Buffer004.png
# LC80320052016255LGN00_B8_PS_Buffer004.png
# LC80290062016058LGN00_B8_PS_Buffer004.png
# LC80300052016257LGN00_B8_PS_Buffer004.png
# LC80300052015190LGN00_B8_PS_Buffer004.png
# LC80330052015131LGN00_B8_PS_Buffer004.png
# LC80320052017081LGN00_B8_PS_Buffer004.png
# LC80300052016097LGN00_B8_PS_Buffer004.png
# LC80330052017072LGN00_B8_PS_Buffer004.png
# LC80310052015277LGN00_B8_PS_Buffer004.png
# LC80300052017115LGN00_B8_PS_Buffer004.png
# LC80310052014082LGN00_B8_PS_Buffer004.png
# LC80290062014244LGN00_B8_PS_Buffer004.png
# LC80290062015279LGN00_B8_PS_Buffer004.png
# LC80340052016157LGN00_B8_PS_Buffer004.png
# LC80290062015199LGN00_B8_PS_Buffer004.png
# LC80290062014180LGN00_B8_PS_Buffer004.png
# Box004_raster_cut.png
# LC80340052015250LGN00_B8_PS_Buffer004.png
# LC80320052016127LGN00_B8_PS_Buffer004.png
# LC80320052014073LGN00_B8_PS_Buffer004.png
# LC80340052014247LGN00_B8_PS_Buffer004.png
# LC80310052015245LGN00_B8_PS_Buffer004.png
# LC80290062014196LGN00_B8_PS_Buffer004.png
# LC80290062017060LGN00_B8_PS_Buffer004.png
# LC80300052016161LGN00_B8_PS_Buffer004.png
# LC80280062013138LGN01_B8_PS_Buffer004.png
# LC80320052015140LGN00_B8_PS_Buffer004.png
# LC80300052015078LGN00_B8_PS_Buffer004.png
# LC80280062015160LGN00_B8_PS_Buffer004.png
# LC80280062017085LGN00_B8_PS_Buffer004.png
# LC80320052016223LGN00_B8_PS_Buffer004.png
# LC80340052015138LGN00_B8_PS_Buffer004.png
# LC80300052014139LGN00_B8_PS_Buffer004.png
# LC80280062016115LGN00_B8_PS_Buffer004.png
# LC80290062015151LGN00_B8_PS_Buffer004.png
# LC80310052015069LGN00_B8_PS_Buffer004.png
# LC80280062014077LGN00_B8_PS_Buffer004.png
# LC80310052015197LGN00_B8_PS_Buffer004.png
# LC80320052014265LGN00_B8_PS_Buffer004.png
# LC80290062015135LGN00_B8_PS_Buffer004.png
# LC80290062016090LGN00_B8_PS_Buffer004.png
# LC80320052016191LGN00_B8_PS_Buffer004.png
# LC80290062016170LGN00_B8_PS_Buffer004.png
# LC80340052015234LGN00_B8_PS_Buffer004.png
# LC80320052015092LGN00_B8_PS_Buffer004.png
# LC80280062015112LGN00_B8_PS_Buffer004.png
# LC80310052014242LGN00_B8_PS_Buffer004.png
# LC80340052016189LGN00_B8_PS_Buffer004.png
# LC80310052015181LGN00_B8_PS_Buffer004.png
# LC80300052016081LGN00_B8_PS_Buffer004.png
# LC80310052017074LGN00_B8_PS_Buffer004.png
# LC80320052015252LGN00_B8_PS_Buffer004.png
# LC80310052013271LGN00_B8_PS_Buffer004.png
# LC80340052016125LGN00_B8_PS_Buffer004.png
# LC80280062015144LGN00_B8_PS_Buffer004.png
# LC80330052015211LGN00_B8_PS_Buffer004.png
# LC80290062014100LGN00_B8_PS_Buffer004.png
# LC80320052015268LGN00_B8_PS_Buffer004.png
# LC80330052015147LGN00_B8_PS_Buffer004.png
# LC80290062016282LGN00_B8_PS_Buffer004.png
# LC80310052015261LGN00_B8_PS_Buffer004.png
# LC80310052016072LGN00_B8_PS_Buffer004.png
# LC80320052015204LGN00_B8_PS_Buffer004.png
# LC80290062016138LGN00_B8_PS_Buffer004.png
# LC80320052015284LGN00_B8_PS_Buffer004.png
# LC80330052016198LGN00_B8_PS_Buffer004.png
# LC80280062016083LGN00_B8_PS_Buffer004.png
# LC80290062014276LGN00_B8_PS_Buffer004.png
# LC80300052015158LGN00_B8_PS_Buffer004.png
# LC80340052014263LGN00_B8_PS_Buffer004.png
# LC80310052017090LGN00_B8_PS_Buffer004.png
# LC80340052015154LGN00_B8_PS_Buffer004.png
# LC80300052016129LGN00_B8_PS_Buffer004.png
# LC80310052014194LGN00_B8_PS_Buffer004.png
# LC80300052015110LGN00_B8_PS_Buffer004.png
# LC80330052014272LGN00_B8_PS_Buffer004.png
# LC80300052015206LGN00_B8_PS_Buffer004.png
# LC80330052013253LGN00_B8_PS_Buffer004.png
# LC80310052014146LGN00_B8_PS_Buffer004.png
# LC80330052014224LGN00_B8_PS_Buffer004.png
# LC80300052015222LGN00_B8_PS_Buffer004.png
# LC80320052016079LGN00_B8_PS_Buffer004.png
# LC80340052015202LGN00_B8_PS_Buffer004.png
# LC80330052015179LGN00_B8_PS_Buffer004.png
# LC80290062014164LGN00_B8_PS_Buffer004.png
# LC80320052013262LGN00_B8_PS_Buffer004.png
# LC80320052014153LGN00_B8_PS_Buffer004.png
# LC80310052015229LGN00_B8_PS_Buffer004.png
# LC80340052015186LGN00_B8_PS_Buffer004.png
# LC80280062014173LGN00_B8_PS_Buffer004.png
# LC80290062016186LGN00_B8_PS_Buffer004.png
# LC80290062015119LGN00_B8_PS_Buffer004.png
# LC80330052016086LGN00_B8_PS_Buffer004.png
# LC80280062014061LGN00_B8_PS_Buffer004.png
# LC80280062013250LGN00_B8_PS_Buffer004.png
# LC80290062013273LGN00_B8_PS_Buffer004.png
# LC80290062013241LGN00_B8_PS_Buffer004.png
# LC80300052015142LGN00_B8_PS_Buffer004.png
# LC80310052016088LGN00_B8_PS_Buffer004.png
# LC80310052016280LGN00_B8_PS_Buffer004.png
# LC80300052014187LGN00_B8_PS_Buffer004.png
# LC80340052016061LGN00_B8_PS_Buffer004.png
# LC80340052016093LGN00_B8_PS_Buffer004.png
# LC80280062015224LGN00_B8_PS_Buffer004.png
# LC80310052016136LGN00_B8_PS_Buffer004.png
# LC80330052014176LGN00_B8_PS_Buffer004.png
# LC80300052014219LGN00_B8_PS_Buffer004.png
# LC80340052016237LGN00_B8_PS_Buffer004.png
# LC80330052016150LGN00_B8_PS_Buffer004.png
# LC80310052014178LGN00_B8_PS_Buffer004.png
# LC80290062015247LGN00_B8_PS_Buffer004.png
# LC80290062014068LGN00_B8_PS_Buffer004.png
# LC80320052014185LGN00_B8_PS_Buffer004.png
# LC80320052014249LGN00_B8_PS_Buffer004.png
# LC80310052015165LGN00_B8_PS_Buffer004.png
# LC80340052014167LGN00_B8_PS_Buffer004.png
# LC80070142015045LGN00_B8_PS_Buffer033.png
# LC80080142014161LGN00_B8_PS_Buffer033.png
# LC80080142015212LGN00_B8_PS_Buffer033.png
# LC80080142014273LGN00_B8_PS_Buffer033.png
# LC80090142016206LGN00_B8_PS_Buffer033.png
# LC80090132014184LGN00_B8_PS_Buffer033.png
# LC80080142015196LGN00_B8_PS_Buffer033.png
# LC80080142016231LGN00_B8_PS_Buffer033.png
# LC80090132014216LGN00_B8_PS_Buffer033.png
# LC80080142016183LGN00_B8_PS_Buffer033.png
# LC80070142014122LGN00_B8_PS_Buffer033.png
# LC80070142015141LGN00_B8_PS_Buffer033.png
# LC80070142015269LGN00_B8_PS_Buffer033.png
# LC80090142014312LGN00_B8_PS_Buffer033.png
# LC80080142017057LGN00_B8_PS_Buffer033.png
# LC80070142015317LGN01_B8_PS_Buffer033.png
# LC80090142016078LGN00_B8_PS_Buffer033.png
# LC80090132015219LGN00_B8_PS_Buffer033.png
# LC80070142013119LGN01_B8_PS_Buffer033.png
# LC80090132015187LGN00_B8_PS_Buffer033.png
# LC80090132017064LGN00_B8_PS_Buffer033.png
# LC80080142016247LGN00_B8_PS_Buffer033.png
# LC80090132017048LGN00_B8_PS_Buffer033.png
# LC80070142015189LGN00_B8_PS_Buffer033.png
# LC80070142016160LGN00_B8_PS_Buffer033.png
# LC80070142017098LGN00_B8_PS_Buffer033.png
# LC80090142016254LGN00_B8_PS_Buffer033.png
# LC80090142014104LGN00_B8_PS_Buffer033.png
# LC80090142016142LGN00_B8_PS_Buffer033.png
# LC80090142016302LGN00_B8_PS_Buffer033.png
# LC80080142015148LGN00_B8_PS_Buffer033.png
# LC80090142017032LGN00_B8_PS_Buffer033.png
# LC80070142013311LGN00_B8_PS_Buffer033.png
# LC80070142016320LGN00_B8_PS_Buffer033.png
# LC80090142014152LGN00_B8_PS_Buffer033.png
# LC80090142015235LGN00_B8_PS_Buffer033.png
# LC80090142015155LGN00_B8_PS_Buffer033.png
# LC80090142014200LGN00_B8_PS_Buffer033.png
# LC80070142013151LGN00_B8_PS_Buffer033.png
# LC80070142016192LGN00_B8_PS_Buffer033.png
# LC80090132015091LGN00_B8_PS_Buffer033.png
# LC80070142015253LGN00_B8_PS_Buffer033.png
# LC80090132016238LGN00_B8_PS_Buffer033.png
# LC80090142015123LGN00_B8_PS_Buffer033.png
# LC80090142013101LGN01_B8_PS_Buffer033.png
# LC80090132013309LGN00_B8_PS_Buffer033.png
# Box033_raster_cut.png
# LC80070142017066LGN00_B8_PS_Buffer033.png
# LC80090142014072LGN00_B8_PS_Buffer033.png
# LC80090132016206LGN00_B8_PS_Buffer033.png
# LC80070142014218LGN00_B8_PS_Buffer033.png
# LC80090142016270LGN00_B8_PS_Buffer033.png
# LC80090142015187LGN00_B8_PS_Buffer033.png
# LC80090132015107LGN00_B8_PS_Buffer033.png
# LC80080142015180LGN00_B8_PS_Buffer033.png
# LC80070142015301LGN00_B8_PS_Buffer033.png
# LC80080142017089LGN00_B8_PS_Buffer033.png
# LC80090142016126LGN00_B8_PS_Buffer033.png
# LC80090142016030LGN00_B8_PS_Buffer033.png
# LC80090142015091LGN00_B8_PS_Buffer033.png
# LC80080142016167LGN00_B8_PS_Buffer033.png
# LC80070142014186LGN00_B8_PS_Buffer033.png
# LC80090132016030LGN00_B8_PS_Buffer033.png
# LC80090132015075LGN00_B8_PS_Buffer033.png
# LC80090142017064LGN00_B8_PS_Buffer033.png
# LC80090132015235LGN00_B8_PS_Buffer033.png
# LC80090132015139LGN00_B8_PS_Buffer033.png
# LC80090132016126LGN00_B8_PS_Buffer033.png
# LC80090132014312LGN00_B8_PS_Buffer033.png
# LC80090142014184LGN00_B8_PS_Buffer033.png
# LC80070142014170LGN00_B8_PS_Buffer033.png
# LC80080142014129LGN00_B8_PS_Buffer033.png
# LC80080142016263LGN00_B8_PS_Buffer033.png
# LC80090142015315LGN00_B8_PS_Buffer033.png
# LC80090132016142LGN00_B8_PS_Buffer033.png
# LC80090132013101LGN01_B8_PS_Buffer033.png
# LC80070142014314LGN00_B8_PS_Buffer033.png
# LC80090142015075LGN00_B8_PS_Buffer033.png
# LC80070142015285LGN00_B8_PS_Buffer033.png
# LC80090132016078LGN00_B8_PS_Buffer033.png
# LC80070142015237LGN00_B8_PS_Buffer033.png
# LC80080142015308LGN00_B8_PS_Buffer033.png
# LC80070142016208LGN00_B8_PS_Buffer033.png
# LC80090142014216LGN00_B8_PS_Buffer033.png
# LC80090142014056LGN01_B8_PS_Buffer033.png
# LC80090132015123LGN00_B8_PS_Buffer033.png
# LC80080142013110LGN01_B8_PS_Buffer033.png
# LC80080142015244LGN00_B8_PS_Buffer033.png
# LC80090132014200LGN00_B8_PS_Buffer033.png
# LC80090132014072LGN00_B8_PS_Buffer033.png
# LC80090132014104LGN00_B8_PS_Buffer033.png
# LC80070142016096LGN00_B8_PS_Buffer033.png
# LC80080142015164LGN00_B8_PS_Buffer033.png
# LC80080142014097LGN00_B8_PS_Buffer033.png
# LC80070142016032LGN00_B8_PS_Buffer033.png
# LC80090142017048LGN00_B8_PS_Buffer033.png
# LC80070142014026LGN00_B8_PS_Buffer033.png
# LC80070142015205LGN01_B8_PS_Buffer033.png
# LC80080142014081LGN00_B8_PS_Buffer033.png
# LC80080142017025LGN00_B8_PS_Buffer033.png
# LC80080142013302LGN00_B8_PS_Buffer033.png
# LC80070142015093LGN00_B8_PS_Buffer033.png
# LC80080142016215LGN00_B8_PS_Buffer033.png
# LC80090132014152LGN00_B8_PS_Buffer033.png
# LC80090142016318LGN00_B8_PS_Buffer033.png
# LC80090142015107LGN00_B8_PS_Buffer033.png
# LC80090132016270LGN00_B8_PS_Buffer033.png
# LC80070142014298LGN00_B8_PS_Buffer033.png
# LC80090142015219LGN00_B8_PS_Buffer033.png
# LC80090132015155LGN00_B8_PS_Buffer033.png
# LC80070142015125LGN00_B8_PS_Buffer033.png
# LC80090142014280LGN00_B8_PS_Buffer033.png
# LC80090142015203LGN00_B8_PS_Buffer033.png
# LC80080142016135LGN00_B8_PS_Buffer033.png
# LC80080142015292LGN00_B8_PS_Buffer033.png
# LC80080142014193LGN01_B8_PS_Buffer033.png
# LC80090142013309LGN00_B8_PS_Buffer033.png
# LC80080142014305LGN00_B8_PS_Buffer033.png
# LC80070142016048LGN00_B8_PS_Buffer033.png
# LC80080142017105LGN00_B8_PS_Buffer033.png
# LC80090132014280LGN00_B8_PS_Buffer033.png
# LC80070142016080LGN00_B8_PS_Buffer033.png
# LC80090132015203LGN00_B8_PS_Buffer033.png
# LC80080142014145LGN00_B8_PS_Buffer033.png
# LC80070142016256LGN00_B8_PS_Buffer033.png
# LC80070142013231LGN00_B8_PS_Buffer033.png
# LC80080142016151LGN00_B8_PS_Buffer033.png
# LC80070142015109LGN00_B8_PS_Buffer033.png
# LC80080142016295LGN00_B8_PS_Buffer033.png
# LC80090132016254LGN00_B8_PS_Buffer033.png
# LC80090142015139LGN00_B8_PS_Buffer033.png
# LC80090142016238LGN00_B8_PS_Buffer033.png
# LC82320182016200LGN00_B8_PS_Buffer120.png
# LC82330172017065LGN00_B8_PS_Buffer120.png
# LC82320182014322LGN00_B8_PS_Buffer120.png
# LC82320182016312LGN00_B8_PS_Buffer120.png
# LC82330172016287LGN00_B8_PS_Buffer120.png
# LC82320182014098LGN00_B8_PS_Buffer120.png
# LC82330172015204LGN00_B8_PS_Buffer120.png
# LC82330172014265LGN00_B8_PS_Buffer120.png
# LC82320172016072LGN00_B8_PS_Buffer120.png
# LC82330172015172LGN00_B8_PS_Buffer120.png
# LC82320172015277LGN00_B8_PS_Buffer120.png
# LC82330172015268LGN00_B8_PS_Buffer120.png
# LC82330172016303LGN00_B8_PS_Buffer120.png
# LC82320172014066LGN00_B8_PS_Buffer120.png
# LC82320182014178LGN00_B8_PS_Buffer120.png
# LC82320182014146LGN00_B8_PS_Buffer120.png
# LC82320172014018LGN00_B8_PS_Buffer120.png
# LC82320172016200LGN00_B8_PS_Buffer120.png
# LC82320172014258LGN00_B8_PS_Buffer120.png
# LC82320182015005LGN00_B8_PS_Buffer120.png
# LC82320182014354LGN00_B8_PS_Buffer120.png
# LC82320172014210LGN00_B8_PS_Buffer120.png
# LC82320182013255LGN00_B8_PS_Buffer120.png
# LC82320172014322LGN00_B8_PS_Buffer120.png
# LC82320182016104LGN00_B8_PS_Buffer120.png
# LC82320172017090LGN00_B8_PS_Buffer120.png
# LC82320182013271LGN00_B8_PS_Buffer120.png
# LC82330172013102LGN01_B8_PS_Buffer120.png
# LC82320182013335LGN00_B8_PS_Buffer120.png
# LC82320172014146LGN00_B8_PS_Buffer120.png
# LC82320182015357LGN00_B8_PS_Buffer120.png
# LC82320182016360LGN00_B8_PS_Buffer120.png
# LC82320182015149LGN00_B8_PS_Buffer120.png
# LC82330172014233LGN00_B8_PS_Buffer120.png
# LC82330172014153LGN00_B8_PS_Buffer120.png
# LC82320182014130LGN00_B8_PS_Buffer120.png
# LC82320182015181LGN00_B8_PS_Buffer120.png
# LC82320182016072LGN00_B8_PS_Buffer120.png
# LC82330172013294LGN00_B8_PS_Buffer120.png
# LC82320182014210LGN00_B8_PS_Buffer120.png
# LC82330172015220LGN00_B8_PS_Buffer120.png
# LC82330172013310LGN00_B8_PS_Buffer120.png
# LC82330172013246LGN00_B8_PS_Buffer120.png
# LC82330172014345LGN00_B8_PS_Buffer120.png
# LC82320182014194LGN00_B8_PS_Buffer120.png
# LC82320172017026LGN00_B8_PS_Buffer120.png
# LC82320172015197LGN00_B8_PS_Buffer120.png
# LC82330172016047LGN00_B8_PS_Buffer120.png
# LC82330172017001LGN00_B8_PS_Buffer120.png
# LC82320172014130LGN00_B8_PS_Buffer120.png
# LC82320182016328LGN00_B8_PS_Buffer120.png
# LC82320182015197LGN00_B8_PS_Buffer120.png
# LC82320172015181LGN00_B8_PS_Buffer120.png
# LC82320182014066LGN00_B8_PS_Buffer120.png
# LC82320172014306LGN00_B8_PS_Buffer120.png
# LC82330172014329LGN00_B8_PS_Buffer120.png
# LC82320172013255LGN00_B8_PS_Buffer120.png
# LC82320172014194LGN00_B8_PS_Buffer120.png
# LC82330172016015LGN00_B8_PS_Buffer120.png
# LC82330172013150LGN00_B8_PS_Buffer120.png
# LC82320172014098LGN00_B8_PS_Buffer120.png
# LC82320172016312LGN00_B8_PS_Buffer120.png
# LC82320172015341LGN00_B8_PS_Buffer120.png
# LC82320172015021LGN00_B8_PS_Buffer120.png
# LC82320182013351LGN00_B8_PS_Buffer120.png
# LC82320172016104LGN00_B8_PS_Buffer120.png
# LC82320172014178LGN00_B8_PS_Buffer120.png
# LC82330172015300LGN00_B8_PS_Buffer120.png
# Box120_raster_cut.png
# LC82330172016175LGN00_B8_PS_Buffer120.png
# LC82320182015341LGN00_B8_PS_Buffer120.png
# LC82330172013230LGN00_B8_PS_Buffer120.png
# LC82330172014009LGN00_B8_PS_Buffer120.png
# LC82320172016328LGN00_B8_PS_Buffer120.png
# LC82330172015140LGN00_B8_PS_Buffer120.png
# LC82320182017026LGN00_B8_PS_Buffer120.png
# LC82330172017017LGN00_B8_PS_Buffer120.png
# LC82320182017074LGN00_B8_PS_Buffer120.png
# LC82330172014297LGN00_B8_PS_Buffer120.png
# LC82330172016127LGN00_B8_PS_Buffer120.png
# LC82330172016255LGN00_B8_PS_Buffer120.png
# LC82330172015252LGN00_B8_PS_Buffer120.png
# LC82330172014249LGN00_B8_PS_Buffer120.png
# LC82320182014018LGN00_B8_PS_Buffer120.png
# LC82330172014041LGN00_B8_PS_Buffer120.png
# LC82330172016271LGN00_B8_PS_Buffer120.png
# LC82320182014306LGN00_B8_PS_Buffer120.png
# LC82330172016319LGN00_B8_PS_Buffer120.png
# LC82320182015213LGN00_B8_PS_Buffer120.png
# LC82320182015021LGN00_B8_PS_Buffer120.png
# LC82330172015028LGN00_B8_PS_Buffer120.png
# LC82330172016335LGN00_B8_PS_Buffer120.png
# LC82320172013271LGN00_B8_PS_Buffer120.png
# LC82320182015277LGN00_B8_PS_Buffer120.png
# LC82320182014258LGN00_B8_PS_Buffer120.png
# LC82320172015149LGN00_B8_PS_Buffer120.png
# LC82320182017090LGN00_B8_PS_Buffer120.png
# LC82320172017074LGN00_B8_PS_Buffer120.png
# LC82330172015236LGN00_B8_PS_Buffer120.png
# LC82320172015005LGN00_B8_PS_Buffer120.png
# LC82320172015213LGN00_B8_PS_Buffer120.png
# LC82330172014137LGN00_B8_PS_Buffer120.png
# LC82330172014009LGN00_B8_PS_Buffer174.png
# LC82320172014290LGN00_B8_PS_Buffer174.png
# LC82320172014306LGN00_B8_PS_Buffer174.png
# LC82330172016127LGN00_B8_PS_Buffer174.png
# LC82320172013319LGN00_B8_PS_Buffer174.png
# LC82330172016319LGN00_B8_PS_Buffer174.png
# LC82320172014066LGN00_B8_PS_Buffer174.png
# LC82320172015197LGN00_B8_PS_Buffer174.png
# LC82330172017113LGN00_B8_PS_Buffer174.png
# LC82320172014002LGN00_B8_PS_Buffer174.png
# LC82330172013294LGN00_B8_PS_Buffer174.png
# LC82330172014105LGN00_B8_PS_Buffer174.png
# LC82320172016264LGN00_B8_PS_Buffer174.png
# LC82330172017001LGN00_B8_PS_Buffer174.png
# LC82320172016312LGN00_B8_PS_Buffer174.png
# LC82330172017017LGN00_B8_PS_Buffer174.png
# LC82330172015028LGN00_B8_PS_Buffer174.png
# LC82330172016207LGN00_B8_PS_Buffer174.png
# LC82320172014338LGN00_B8_PS_Buffer174.png
# LC82320172016168LGN00_B8_PS_Buffer174.png
# LC82330172017065LGN00_B8_PS_Buffer174.png
# LC82330172015252LGN00_B8_PS_Buffer174.png
# LC82320172016104LGN00_B8_PS_Buffer174.png
# LC82320172017074LGN00_B8_PS_Buffer174.png
# LC82320172015277LGN00_B8_PS_Buffer174.png
# LC82320172014258LGN00_B8_PS_Buffer174.png
# LC82330172014297LGN00_B8_PS_Buffer174.png
# LC82330172016047LGN00_B8_PS_Buffer174.png
# LC82330172014265LGN00_B8_PS_Buffer174.png
# LC82330172014185LGN00_B8_PS_Buffer174.png
# LC82320172015181LGN00_B8_PS_Buffer174.png
# LC82320172014194LGN00_B8_PS_Buffer174.png
# LC82320172014146LGN00_B8_PS_Buffer174.png
# LC82330172014233LGN00_B8_PS_Buffer174.png
# LC82320172016280LGN00_B8_PS_Buffer174.png
# LC82320172014130LGN00_B8_PS_Buffer174.png
# LC82330172015268LGN00_B8_PS_Buffer174.png
# LC82320172016200LGN00_B8_PS_Buffer174.png
# LC82320172016296LGN00_B8_PS_Buffer174.png
# LC82330172013310LGN00_B8_PS_Buffer174.png
# LC82330172014137LGN00_B8_PS_Buffer174.png
# LC82330172016255LGN00_B8_PS_Buffer174.png
# LC82330172015140LGN00_B8_PS_Buffer174.png
# LC82320172016120LGN00_B8_PS_Buffer174.png
# LC82330172013246LGN00_B8_PS_Buffer174.png
# LC82330172016111LGN00_B8_PS_Buffer174.png
# Box174_raster_cut.png
# LC82320172014210LGN00_B8_PS_Buffer174.png
# LC82320172014018LGN00_B8_PS_Buffer174.png
# LC82320172014322LGN00_B8_PS_Buffer174.png
# LC82330172016271LGN00_B8_PS_Buffer174.png
# LC82320172015005LGN00_B8_PS_Buffer174.png
# LC82330172015236LGN00_B8_PS_Buffer174.png
# LC82330172014329LGN00_B8_PS_Buffer174.png
# LC82320172017090LGN00_B8_PS_Buffer174.png
# LC82320172015213LGN00_B8_PS_Buffer174.png
# LC82330172013230LGN00_B8_PS_Buffer174.png
# LC82330172015332LGN00_B8_PS_Buffer174.png
# LC82320172017026LGN00_B8_PS_Buffer174.png
# LC82330172016303LGN00_B8_PS_Buffer174.png
# LC82330172017097LGN00_B8_PS_Buffer174.png
# LC82330172016287LGN00_B8_PS_Buffer174.png
# LC82320172016328LGN00_B8_PS_Buffer174.png
# LC82330172015220LGN00_B8_PS_Buffer174.png
# LC82330172014249LGN00_B8_PS_Buffer174.png
# LC82320172013271LGN00_B8_PS_Buffer174.png
# LC82330172013342LGN00_B8_PS_Buffer174.png
# LC82320172015085LGN00_B8_PS_Buffer174.png
# LC80010152013141LGN01_B8_PS_Buffer235.png
# LC82330152015028LGN00_B8_PS_Buffer235.png
# LC82320152016136LGN00_B8_PS_Buffer235.png
# LC80010152016230LGN00_B8_PS_Buffer235.png
# LC80010152016294LGN00_B8_PS_Buffer235.png
# LC82320152016056LGN00_B8_PS_Buffer235.png
# LC82330152013294LGN00_B8_PS_Buffer235.png
# LC80010152017040LGN00_B8_PS_Buffer235.png
# LC80010152013237LGN00_B8_PS_Buffer235.png
# LC80010152016070LGN00_B8_PS_Buffer235.png
# LC80010152016246LGN00_B8_PS_Buffer235.png
# LC82320152016296LGN00_B8_PS_Buffer235.png
# LC82320152014098LGN00_B8_PS_Buffer235.png
# LC82330152016063LGN00_B8_PS_Buffer235.png
# LC82320152017074LGN00_B8_PS_Buffer235.png
# LC82320152015101LGN00_B8_PS_Buffer235.png
# LC82330152014233LGN00_B8_PS_Buffer235.png
# LC82320152014130LGN00_B8_PS_Buffer235.png
# LC82320152013271LGN00_B8_PS_Buffer235.png
# LC82320152013319LGN00_B8_PS_Buffer235.png
# LC80010152015163LGN00_B8_PS_Buffer235.png
# LC82320152015165LGN00_B8_PS_Buffer235.png
# LC80010152015147LGN00_B8_PS_Buffer235.png
# LC82330152013230LGN00_B8_PS_Buffer235.png
# LC82330152016303LGN00_B8_PS_Buffer235.png
# LC82320152015277LGN00_B8_PS_Buffer235.png
# LC80010152015211LGN00_B8_PS_Buffer235.png
# LC80010152014160LGN00_B8_PS_Buffer235.png
# LC80010152017104LGN00_B8_PS_Buffer235.png
# LC82320152014194LGN00_B8_PS_Buffer235.png
# LC80010152016086LGN00_B8_PS_Buffer235.png
# LC82330152013246LGN00_B8_PS_Buffer235.png
# LC82320152014178LGN00_B8_PS_Buffer235.png
# LC82330152016047LGN00_B8_PS_Buffer235.png
# LC80010152015291LGN00_B8_PS_Buffer235.png
# LC82320152016184LGN00_B8_PS_Buffer235.png
# LC80010152014192LGN00_B8_PS_Buffer235.png
# LC80010152013317LGN00_B8_PS_Buffer235.png
# LC82320152015053LGN00_B8_PS_Buffer235.png
# LC80010152014224LGN00_B8_PS_Buffer235.png
# LC82330152016287LGN00_B8_PS_Buffer235.png
# LC80010152015195LGN00_B8_PS_Buffer235.png
# LC80010152015115LGN00_B8_PS_Buffer235.png
# LC82330152014105LGN00_B8_PS_Buffer235.png
# LC80010152016182LGN00_B8_PS_Buffer235.png
# LC82320152015117LGN00_B8_PS_Buffer235.png
# LC82320152017026LGN00_B8_PS_Buffer235.png
# LC82320152016264LGN00_B8_PS_Buffer235.png
# LC82330152013118LGN01_B8_PS_Buffer235.png
# LC80010152015051LGN00_B8_PS_Buffer235.png
# LC82320152015021LGN00_B8_PS_Buffer235.png
# LC82330152016191LGN00_B8_PS_Buffer235.png
# LC80010152016150LGN00_B8_PS_Buffer235.png
# LC82330152013310LGN00_B8_PS_Buffer235.png
# LC80010152013269LGN00_B8_PS_Buffer235.png
# LC82330152017065LGN00_B8_PS_Buffer235.png
# LC82320152015229LGN00_B8_PS_Buffer235.png
# LC82320152015197LGN00_B8_PS_Buffer235.png
# LC82330152016111LGN00_B8_PS_Buffer235.png
# LC82320152014306LGN00_B8_PS_Buffer235.png
# LC82320152013255LGN00_B8_PS_Buffer235.png
# LC82330152015316LGN00_B8_PS_Buffer235.png
# LC80010152014288LGN00_B8_PS_Buffer235.png
# LC80010152016214LGN00_B8_PS_Buffer235.png
# LC80010152017088LGN00_B8_PS_Buffer235.png
# LC80010152015275LGN00_B8_PS_Buffer235.png
# LC80010152015227LGN00_B8_PS_Buffer235.png
# LC82330152017033LGN00_B8_PS_Buffer235.png
# LC82330152014185LGN00_B8_PS_Buffer235.png
# LC82330152016255LGN00_B8_PS_Buffer235.png
# LC82330152016271LGN00_B8_PS_Buffer235.png
# LC82320152016104LGN00_B8_PS_Buffer235.png
# LC82320152014146LGN00_B8_PS_Buffer235.png
# LC82320152016216LGN00_B8_PS_Buffer235.png
# LC82330152016207LGN00_B8_PS_Buffer235.png
# LC80010152016198LGN00_B8_PS_Buffer235.png
# LC80010152015019LGN00_B8_PS_Buffer235.png
# LC82330152014137LGN00_B8_PS_Buffer235.png
# LC82330152013278LGN00_B8_PS_Buffer235.png
# LC82320152017090LGN00_B8_PS_Buffer235.png
# LC80010152016102LGN00_B8_PS_Buffer235.png
# Box235_raster_cut.png
# LC80010152016166LGN00_B8_PS_Buffer235.png
# LC80010152014144LGN00_B8_PS_Buffer235.png
# LC82330152015204LGN00_B8_PS_Buffer235.png
# LC82320152015245LGN00_B8_PS_Buffer235.png
# LC82320152015213LGN00_B8_PS_Buffer235.png
# LC82320152015181LGN00_B8_PS_Buffer235.png
# LC82320152016200LGN00_B8_PS_Buffer235.png
# LC82330152015140LGN00_B8_PS_Buffer235.png
# LC82330152015220LGN00_B8_PS_Buffer235.png
# LC82330152016127LGN00_B8_PS_Buffer235.png
# LC80010152016182LGN00_B8_PS_Buffer259.png
# LC80010152016278LGN00_B8_PS_Buffer259.png
# LC82320152016200LGN00_B8_PS_Buffer259.png
# LC80010152016198LGN00_B8_PS_Buffer259.png
# LC80010152015291LGN00_B8_PS_Buffer259.png
# LC80010152013317LGN00_B8_PS_Buffer259.png
# LC82320152015197LGN00_B8_PS_Buffer259.png
# LC82330152016127LGN00_B8_PS_Buffer259.png
# LC80010152017040LGN00_B8_PS_Buffer259.png
# LC82330152015188LGN00_B8_PS_Buffer259.png
# LC82320152017026LGN00_B8_PS_Buffer259.png
# LC82320152015245LGN00_B8_PS_Buffer259.png
# LC80010152016150LGN00_B8_PS_Buffer259.png
# LC80010152015051LGN00_B8_PS_Buffer259.png
# LC82330152015028LGN00_B8_PS_Buffer259.png
# LC82330152013246LGN00_B8_PS_Buffer259.png
# LC80010152015211LGN00_B8_PS_Buffer259.png
# LC80010152016294LGN00_B8_PS_Buffer259.png
# Box259_raster_cut.png
# LC80010152015227LGN00_B8_PS_Buffer259.png
# LC80010152015195LGN00_B8_PS_Buffer259.png
# LC82330152014137LGN00_B8_PS_Buffer259.png
# LC80010152017104LGN00_B8_PS_Buffer259.png
# LC80010152016086LGN00_B8_PS_Buffer259.png
# LC82320152014130LGN00_B8_PS_Buffer259.png
# LC82320152017090LGN00_B8_PS_Buffer259.png
# LC82320152015021LGN00_B8_PS_Buffer259.png
# LC80010152015147LGN00_B8_PS_Buffer259.png
# LC82320152015229LGN00_B8_PS_Buffer259.png
# LC80010152016102LGN00_B8_PS_Buffer259.png
# LC80010152014288LGN00_B8_PS_Buffer259.png
# LC82330152016271LGN00_B8_PS_Buffer259.png
# LC82330152016255LGN00_B8_PS_Buffer259.png
# LC82320152015213LGN00_B8_PS_Buffer259.png
# LC80010152015179LGN00_B8_PS_Buffer259.png
# LC80010152016134LGN00_B8_PS_Buffer259.png
# LC80010152014160LGN00_B8_PS_Buffer259.png
# LC80010152014224LGN00_B8_PS_Buffer259.png
# LC82320152015101LGN00_B8_PS_Buffer259.png
# LC82330152014185LGN00_B8_PS_Buffer259.png
# LC82320152013271LGN00_B8_PS_Buffer259.png
# LC82320152014274LGN00_B8_PS_Buffer259.png
# LC80010152014192LGN00_B8_PS_Buffer259.png
# LC82320152017074LGN00_B8_PS_Buffer259.png
# LC80010152013269LGN00_B8_PS_Buffer259.png
# LC82320152016136LGN00_B8_PS_Buffer259.png
# LC82320152016216LGN00_B8_PS_Buffer259.png
# LC80010152013237LGN00_B8_PS_Buffer259.png
# LC82320152014210LGN00_B8_PS_Buffer259.png
# LC80010152016246LGN00_B8_PS_Buffer259.png
# LC82320152014194LGN00_B8_PS_Buffer259.png
# LC82330152014105LGN00_B8_PS_Buffer259.png
# LC80010152017088LGN00_B8_PS_Buffer259.png
# LC82330152016207LGN00_B8_PS_Buffer259.png
# LC82320152014146LGN00_B8_PS_Buffer259.png
# LC80010152013141LGN01_B8_PS_Buffer259.png
# LC80010152016310LGN00_B8_PS_Buffer259.png
# LC80010152016166LGN00_B8_PS_Buffer259.png
# LC82320152015165LGN00_B8_PS_Buffer259.png
# LC82320152016184LGN00_B8_PS_Buffer259.png
# LC80010152015275LGN00_B8_PS_Buffer259.png
# LC82320152015053LGN00_B8_PS_Buffer259.png
# LC82330152016191LGN00_B8_PS_Buffer259.png
# LC82330152015316LGN00_B8_PS_Buffer259.png
# LC82320152016104LGN00_B8_PS_Buffer259.png
# LC82330152014233LGN00_B8_PS_Buffer259.png
# LC82320152014098LGN00_B8_PS_Buffer259.png
# LC82330152017113LGN00_B8_PS_Buffer259.png
# LC80010152017120LGN00_B8_PS_Buffer259.png
# LC82330152013230LGN00_B8_PS_Buffer259.png
# LC82330152015220LGN00_B8_PS_Buffer259.png
# LC82330152016303LGN00_B8_PS_Buffer277.png
# LC82330152016255LGN00_B8_PS_Buffer277.png
# LC82320152016136LGN00_B8_PS_Buffer277.png
# LC80010142013237LGN00_B8_PS_Buffer277.png
# LC82320152016120LGN00_B8_PS_Buffer277.png
# LC80010142015179LGN00_B8_PS_Buffer277.png
# LC82330152014233LGN00_B8_PS_Buffer277.png
# LC80010142016102LGN00_B8_PS_Buffer277.png
# LC82320152017074LGN00_B8_PS_Buffer277.png
# LC82320152015213LGN00_B8_PS_Buffer277.png
# Box277_raster_cut.png
# LC80010142016166LGN00_B8_PS_Buffer277.png
# LC82330152015156LGN00_B8_PS_Buffer277.png
# LC80010142014192LGN00_B8_PS_Buffer277.png
# LC82320152017090LGN00_B8_PS_Buffer277.png
# LC82320152014098LGN00_B8_PS_Buffer277.png
# LC82330152016127LGN00_B8_PS_Buffer277.png
# LC80010142015227LGN00_B8_PS_Buffer277.png
# LC82320152014066LGN00_B8_PS_Buffer277.png
# LC80010142015195LGN00_B8_PS_Buffer277.png
# LC80010142016246LGN00_B8_PS_Buffer277.png
# LC82320152015053LGN00_B8_PS_Buffer277.png
# LC82320152016312LGN00_B8_PS_Buffer277.png
# LC82330152013118LGN01_B8_PS_Buffer277.png
# LC82330152017113LGN00_B8_PS_Buffer277.png
# LC80010142017040LGN00_B8_PS_Buffer277.png
# LC82330152016287LGN00_B8_PS_Buffer277.png
# LC80010142014160LGN00_B8_PS_Buffer277.png
# LC80010142015051LGN00_B8_PS_Buffer277.png
# LC80010142016150LGN00_B8_PS_Buffer277.png
# LC80010142017120LGN00_B8_PS_Buffer277.png
# LC80010142016182LGN00_B8_PS_Buffer277.png
# LC82330152016111LGN00_B8_PS_Buffer277.png
# LC82320152017026LGN00_B8_PS_Buffer277.png
# LC82320152016216LGN00_B8_PS_Buffer277.png
# LC80010142013141LGN01_B8_PS_Buffer277.png
# LC82320152014130LGN00_B8_PS_Buffer277.png
# LC82330152015028LGN00_B8_PS_Buffer277.png
# LC80010142015259LGN00_B8_PS_Buffer277.png
# LC82320152015021LGN00_B8_PS_Buffer277.png
# LC82330152017065LGN00_B8_PS_Buffer277.png
# LC82320152016104LGN00_B8_PS_Buffer277.png
# LC80010142015291LGN00_B8_PS_Buffer277.png
# LC82330152014105LGN00_B8_PS_Buffer277.png
# LC80010142016278LGN00_B8_PS_Buffer277.png
# LC82330152016159LGN00_B8_PS_Buffer277.png
# LC82320152013255LGN00_B8_PS_Buffer277.png
# LC82320152014146LGN00_B8_PS_Buffer277.png
# LC80010142015275LGN00_B8_PS_Buffer277.png
# LC82320152015165LGN00_B8_PS_Buffer277.png
# LC82320152014194LGN00_B8_PS_Buffer277.png
# LC82320152016088LGN00_B8_PS_Buffer277.png
# LC80010142016294LGN00_B8_PS_Buffer277.png
# LC82330152016063LGN00_B8_PS_Buffer277.png
# LC80010142014224LGN00_B8_PS_Buffer277.png
# LC82330152014137LGN00_B8_PS_Buffer277.png
# LC82330152015316LGN00_B8_PS_Buffer277.png
# LC82330152016271LGN00_B8_PS_Buffer277.png
# LC80010142014288LGN00_B8_PS_Buffer277.png
# LC82320152014306LGN00_B8_PS_Buffer277.png
# LC82330152014297LGN00_B8_PS_Buffer277.png
# LC82330152014265LGN00_B8_PS_Buffer277.png
# LC80010142017024LGN00_B8_PS_Buffer277.png
# LC82330152014185LGN00_B8_PS_Buffer277.png
# LC82330152016207LGN00_B8_PS_Buffer277.png
# LC82320152013271LGN00_B8_PS_Buffer277.png
# LC80010142013317LGN00_B8_PS_Buffer277.png
# LC82330152014249LGN00_B8_PS_Buffer277.png
# LC80010142015163LGN00_B8_PS_Buffer277.png
# LC82320152015197LGN00_B8_PS_Buffer277.png
# LC82320152016200LGN00_B8_PS_Buffer277.png
# LC82330152015124LGN00_B8_PS_Buffer277.png
# LC82330152015188LGN00_B8_PS_Buffer277.png
# LC82330152013246LGN00_B8_PS_Buffer277.png
# LC80010142017088LGN00_B8_PS_Buffer277.png
# LC82330152013102LGN01_B8_PS_Buffer277.png
# LC82320152013319LGN00_B8_PS_Buffer277.png
# LC80010142016198LGN00_B8_PS_Buffer277.png
# LC80010142015211LGN00_B8_PS_Buffer277.png
# LC82330152015172LGN00_B8_PS_Buffer277.png
# LC82330152016191LGN00_B8_PS_Buffer277.png
# LC82320152015277LGN00_B8_PS_Buffer277.png
# LC82320152014322LGN00_B8_PS_Buffer277.png
# LC80110022014150LGN00_B8_PS_Buffer531.png
# LC80080022013142LGN01_B8_PS_Buffer531.png
# LC80140012013264LGN00_B8_PS_Buffer531.png
# LC80070022015173LGN00_B8_PS_Buffer531.png
# LC80060032015182LGN00_B8_PS_Buffer531.png
# LC80160012016175LGN00_B8_PS_Buffer531.png
# LC80080022015100LGN00_B8_PS_Buffer531.png
# LC80150012016184LGN00_B8_PS_Buffer531.png
# LC80060032015262LGN00_B8_PS_Buffer531.png
# LC80110022016204LGN00_B8_PS_Buffer531.png
# LC80090022016110LGN00_B8_PS_Buffer531.png
# LC80090022015139LGN00_B8_PS_Buffer531.png
# LC80090022014232LGN00_B8_PS_Buffer531.png
# LC80130022014100LGN00_B8_PS_Buffer531.png
# LC80070032016192LGN00_B8_PS_Buffer531.png
# LC80060032017107LGN00_B8_PS_Buffer531.png
# LC80150012015213LGN00_B8_PS_Buffer531.png
# LC80150012015085LGN00_B8_PS_Buffer531.png
# LC80060032016201LGN00_B8_PS_Buffer531.png
# LC80150012015101LGN00_B8_PS_Buffer531.png
# LC80100022013236LGN00_B8_PS_Buffer531.png
# LC80110022013259LGN00_B8_PS_Buffer531.png
# LC80130022016090LGN00_B8_PS_Buffer531.png
# LC80110022013243LGN00_B8_PS_Buffer531.png
# LC80080022017105LGN00_B8_PS_Buffer531.png
# LC80130022016202LGN00_B8_PS_Buffer531.png
# LC80060032017091LGN00_B8_PS_Buffer531.png
# LC80070032015077LGN00_B8_PS_Buffer531.png
# LC80060032016233LGN00_B8_PS_Buffer531.png
# LC80150012014082LGN00_B8_PS_Buffer531.png
# LC80140012015078LGN00_B8_PS_Buffer531.png
# LC80130022016074LGN00_B8_PS_Buffer531.png
# LC80120022016083LGN00_B8_PS_Buffer531.png
# LC80080022015212LGN00_B8_PS_Buffer531.png
# LC80110022014214LGN00_B8_PS_Buffer531.png
# LC80120022016163LGN00_B8_PS_Buffer531.png
# LC80110022016172LGN00_B8_PS_Buffer531.png
# LC80160012014137LGN00_B8_PS_Buffer531.png
# LC80060032016265LGN00_B8_PS_Buffer531.png
# LC80130022016170LGN00_B8_PS_Buffer531.png
# LC80120022016131LGN00_B8_PS_Buffer531.png
# LC80070032014106LGN00_B8_PS_Buffer531.png
# LC80060032016105LGN00_B8_PS_Buffer531.png
# LC80070032017082LGN00_B8_PS_Buffer531.png
# LC80120022013122LGN01_B8_PS_Buffer531.png
# LC80100022014095LGN00_B8_PS_Buffer531.png
# LC80160012015124LGN00_B8_PS_Buffer531.png
# LC80130022014196LGN00_B8_PS_Buffer531.png
# LC80100022014191LGN00_B8_PS_Buffer531.png
# LC80100022017087LGN00_B8_PS_Buffer531.png
# LC80070032016096LGN00_B8_PS_Buffer531.png
# LC80110022016268LGN00_B8_PS_Buffer531.png
# LC80130022016138LGN00_B8_PS_Buffer531.png
# LC80120022017101LGN00_B8_PS_Buffer531.png
# LC80070022016160LGN00_B8_PS_Buffer531.png
# LC80130022017108LGN00_B8_PS_Buffer531.png
# LC80140012014251LGN00_B8_PS_Buffer531.png
# LC80160012014233LGN00_B8_PS_Buffer531.png
# LC80070032015221LGN00_B8_PS_Buffer531.png
# LC80090022016238LGN00_B8_PS_Buffer531.png
# LC80100022017119LGN00_B8_PS_Buffer531.png
# LC80130022013113LGN01_B8_PS_Buffer531.png
# LC80100022013124LGN01_B8_PS_Buffer531.png
# LC80060032017075LGN00_B8_PS_Buffer531.png
# LC80120022016115LGN00_B8_PS_Buffer531.png
# LC80070032015173LGN00_B8_PS_Buffer531.png
# LC80130022015135LGN00_B8_PS_Buffer531.png
# LC80100022017103LGN00_B8_PS_Buffer531.png
# LC80130022015263LGN00_B8_PS_Buffer531.png
# LC80090022015091LGN00_B8_PS_Buffer531.png
# LC80090022016270LGN00_B8_PS_Buffer531.png
# LC80130022016250LGN00_B8_PS_Buffer531.png
# LC80100022014271LGN00_B8_PS_Buffer531.png
# LC80140012016097LGN00_B8_PS_Buffer531.png
# LC80150012014162LGN00_B8_PS_Buffer531.png
# LC80140012017083LGN00_B8_PS_Buffer531.png
# LC80110022016092LGN00_B8_PS_Buffer531.png
# LC80150012015197LGN00_B8_PS_Buffer531.png
# LC80070032014234LGN00_B8_PS_Buffer531.png
# LC80160012014217LGN00_B8_PS_Buffer531.png
# LC80150012016120LGN00_B8_PS_Buffer531.png
# LC80140012016113LGN00_B8_PS_Buffer531.png
# LC80060032014211LGN00_B8_PS_Buffer531.png
# LC80060032015118LGN00_B8_PS_Buffer531.png
# LC80110022015185LGN00_B8_PS_Buffer531.png
# LC80060032013272LGN00_B8_PS_Buffer531.png
# LC80090022015107LGN00_B8_PS_Buffer531.png
# LC80150012014226LGN00_B8_PS_Buffer531.png
# LC80070022014202LGN00_B8_PS_Buffer531.png
# LC80080022017089LGN00_B8_PS_Buffer531.png
# LC80130022016186LGN00_B8_PS_Buffer531.png
# LC80150012016216LGN00_B8_PS_Buffer531.png
# LC80070032015253LGN00_B8_PS_Buffer531.png
# LC80140012017099LGN00_B8_PS_Buffer531.png
# LC80130022016106LGN00_B8_PS_Buffer531.png
# LC80090022016206LGN00_B8_PS_Buffer531.png
# LC80100022016197LGN00_B8_PS_Buffer531.png
# LC80070032014250LGN00_B8_PS_Buffer531.png
# LC80080022016199LGN00_B8_PS_Buffer531.png
# LC80150012014210LGN00_B8_PS_Buffer531.png
# LC80140012015142LGN00_B8_PS_Buffer531.png
# LC80100022016101LGN00_B8_PS_Buffer531.png
# LC80080022014257LGN00_B8_PS_Buffer531.png
# LC80070032016112LGN00_B8_PS_Buffer531.png
# LC80160012015108LGN00_B8_PS_Buffer531.png
# LC80130022015087LGN00_B8_PS_Buffer531.png
# LC80080022014241LGN00_B8_PS_Buffer531.png
# LC80070032015109LGN00_B8_PS_Buffer531.png
# LC80110022013147LGN00_B8_PS_Buffer531.png
# LC80110022015201LGN00_B8_PS_Buffer531.png
# LC80080022016183LGN00_B8_PS_Buffer531.png
# LC80060032014227LGN00_B8_PS_Buffer531.png
# LC80100022014143LGN00_B8_PS_Buffer531.png
# LC80160012015252LGN00_B8_PS_Buffer531.png
# LC80100022016149LGN00_B8_PS_Buffer531.png
# LC80110022015217LGN00_B8_PS_Buffer531.png
# LC80140012017115LGN00_B8_PS_Buffer531.png
# LC80070022016256LGN00_B8_PS_Buffer531.png
# LC80120022016179LGN00_B8_PS_Buffer531.png
# LC80150012015117LGN00_B8_PS_Buffer531.png
# LC80070022015109LGN00_B8_PS_Buffer531.png
# LC80090022017096LGN00_B8_PS_Buffer531.png
# LC80150012016232LGN00_B8_PS_Buffer531.png
# LC80070032014218LGN00_B8_PS_Buffer531.png
# LC80120022015176LGN00_B8_PS_Buffer531.png
# LC80100022016133LGN00_B8_PS_Buffer531.png
# LC80140012015110LGN00_B8_PS_Buffer531.png
# LC80160012014089LGN00_B8_PS_Buffer531.png
# LC80100022016085LGN00_B8_PS_Buffer531.png
# LC80140012014123LGN00_B8_PS_Buffer531.png
# LC80110022016076LGN00_B8_PS_Buffer531.png
# LC80140012016129LGN00_B8_PS_Buffer531.png
# LC80160012015156LGN00_B8_PS_Buffer531.png
# LC80120022017085LGN00_B8_PS_Buffer531.png
# LC80080022015260LGN00_B8_PS_Buffer531.png
# LC80090022014264LGN00_B8_PS_Buffer531.png
# LC80080022015196LGN00_B8_PS_Buffer531.png
# LC80090022015267LGN00_B8_PS_Buffer531.png
# LC80090022014088LGN00_B8_PS_Buffer531.png
# LC80060032014243LGN00_B8_PS_Buffer531.png
# LC80090022014104LGN00_B8_PS_Buffer531.png
# LC80110022014262LGN00_B8_PS_Buffer531.png
# LC80060032016185LGN00_B8_PS_Buffer531.png
# LC80160012016111LGN00_B8_PS_Buffer531.png
# Box531_raster_cut.png
# LC80130022013145LGN00_B8_PS_Buffer531.png
# LC80120022013234LGN00_B8_PS_Buffer531.png
# LC80070032014202LGN00_B8_PS_Buffer531.png
# LC80080022016263LGN00_B8_PS_Buffer531.png
# LC80140012015254LGN00_B8_PS_Buffer531.png
# LC80120022015144LGN00_B8_PS_Buffer531.png
# LC80140012014139LGN00_B8_PS_Buffer531.png
# LC80070022015253LGN00_B8_PS_Buffer531.png
# LC80110022014230LGN00_B8_PS_Buffer531.png
# LC80160012016191LGN00_B8_PS_Buffer531.png
# LC80110022017094LGN00_B8_PS_Buffer531.png
# LC80100022015226LGN00_B8_PS_Buffer531.png
# LC80160012015188LGN00_B8_PS_Buffer531.png
# LC80160012017081LGN00_B8_PS_Buffer531.png
# LC80140012015126LGN00_B8_PS_Buffer531.png
# LC80070032016160LGN00_B8_PS_Buffer531.png
# LC80090022016094LGN00_B8_PS_Buffer531.png
# LC80080022015164LGN00_B8_PS_Buffer531.png
# LC80120022015112LGN00_B8_PS_Buffer531.png
# LC80060032015246LGN00_B8_PS_Buffer531.png
# LC80060032016121LGN00_B8_PS_Buffer531.png
# LC80110022013115LGN01_B8_PS_Buffer531.png
# LC80110022016252LGN00_B8_PS_Buffer531.png
# LC80120022015224LGN00_B8_PS_Buffer531.png
# LC80140012014203LGN00_B8_PS_Buffer531.png
# LC80160012016095LGN00_B8_PS_Buffer531.png
# LC80100022016245LGN00_B8_PS_Buffer531.png
# LC80070032015093LGN00_B8_PS_Buffer531.png
# LC80110022017078LGN00_B8_PS_Buffer531.png
# LC80070022016192LGN00_B8_PS_Buffer531.png
# LC80090022016254LGN00_B8_PS_Buffer531.png
# LC80090022015123LGN00_B8_PS_Buffer531.png
# LC80160012015236LGN00_B8_PS_Buffer531.png
# LC80110022014182LGN00_B8_PS_Buffer531.png
# LC80150012016264LGN00_B8_PS_Buffer531.png
# LC80110022016108LGN00_B8_PS_Buffer531.png
# LC80120022014253LGN00_B8_PS_Buffer531.png
# LC80140012016081LGN00_B8_PS_Buffer531.png
# LC80090022013261LGN00_B8_PS_Buffer531.png
# LC80080022016247LGN00_B8_PS_Buffer531.png
# LC80150012015181LGN00_B8_PS_Buffer531.png
# LC80160012014249LGN00_B8_PS_Buffer531.png
# LC80060032014083LGN00_B8_PS_Buffer531.png
# LC80140012016193LGN00_B8_PS_Buffer531.png
# LC80120022013266LGN00_B8_PS_Buffer531.png
# LC80090022015187LGN00_B8_PS_Buffer531.png
# LC80100022015258LGN00_B8_PS_Buffer531.png
# LC80070032016208LGN00_B8_PS_Buffer531.png
# LC80160012013118LGN01_B8_PS_Buffer531.png
# LC80140012015174LGN00_B8_PS_Buffer531.png
# LC80110022015137LGN00_B8_PS_Buffer531.png
# LC80090022016174LGN00_B8_PS_Buffer531.png
# LC80100022015130LGN00_B8_PS_Buffer531.png
# LC80100022016229LGN00_B8_PS_Buffer531.png
# LC80150012015133LGN00_B8_PS_Buffer531.png
# LC80160012015092LGN00_B8_PS_Buffer531.png
# LC80110022015153LGN00_B8_PS_Buffer531.png
# LC80060032016249LGN00_B8_PS_Buffer531.png
# LC80070032017098LGN00_B8_PS_Buffer531.png
# LC80130022015247LGN00_B8_PS_Buffer531.png
# LC80060032015214LGN00_B8_PS_Buffer531.png
# LC80110022016140LGN00_B8_PS_Buffer531.png
# LC80130022016234LGN00_B8_PS_Buffer531.png
# LC80160012013262LGN00_B8_PS_Buffer531.png
# LC80080022013270LGN00_B8_PS_Buffer531.png
# LC80120022016259LGN00_B8_PS_Buffer531.png
# LC80080022014161LGN00_B8_PS_Buffer531.png
# LC80110022017110LGN00_B8_PS_Buffer531.png
# LC80070022016208LGN00_B8_PS_Buffer531.png
# LC80150012015261LGN00_B8_PS_Buffer531.png
# LC80070032017114LGN00_B8_PS_Buffer531.png
# LC80160012014201LGN00_B8_PS_Buffer531.png
# LC80160012016255LGN00_B8_PS_Buffer531.png
# LC80160012015268LGN00_B8_PS_Buffer531.png
# LC80090022014216LGN00_B8_PS_Buffer531.png
# LC80140012013232LGN00_B8_PS_Buffer531.png
# LC80130022017076LGN00_B8_PS_Buffer531.png
# LC80110022014166LGN00_B8_PS_Buffer531.png
# LC80070022015221LGN00_B8_PS_Buffer531.png
# LC80070022016112LGN00_B8_PS_Buffer531.png
# LC80080022016215LGN00_B8_PS_Buffer531.png
# LC80080022016087LGN00_B8_PS_Buffer531.png
# LC80080022016119LGN00_B8_PS_Buffer531.png
# LC80130022014180LGN00_B8_PS_Buffer531.png
# LC80060032014147LGN00_B8_PS_Buffer531.png
# LC80150012014242LGN00_B8_PS_Buffer531.png
# LC80160012017113LGN00_B8_PS_Buffer531.png
# LC80160012016079LGN00_B8_PS_Buffer531.png
# LC80100022016117LGN00_B8_PS_Buffer531.png
# LC80080022017073LGN00_B8_PS_Buffer531.png
# LC80160012015204LGN00_B8_PS_Buffer531.png
# LC80080022016135LGN00_B8_PS_Buffer531.png
# LC80160012014105LGN00_B8_PS_Buffer531.png
# LC80100022014223LGN00_B8_PS_Buffer531.png
# LC80090022017112LGN00_B8_PS_Buffer531.png
# LC80080022015116LGN00_B8_PS_Buffer531.png

# %% [markdown]
# ## 5) Resize images to minimum dimensions

# %%
# #Make sure resized folders are removed
# for BoxID in BOXIDS:
#     if os.path.exists(downloadpath+"Box"+BoxID+'/resized/'):
#         shutil.rmtree(downloadpath+"Box"+BoxID+'/resized/', ignore_errors=False, onerror=None)
#     else:
#         print("Resized folder already removed")

# %%
for BoxID in BOXIDS:
    dimensions_x = []
    dimensions_y = []
    images = os.listdir(downloadpath+"Box"+BoxID+'/rotated/')
    for image in images:
        img = mpimg.imread(downloadpath+"Box"+BoxID+'/rotated/'+image)
        dimensions_x.append(img.shape[1])
        dimensions_y.append(img.shape[0])
    
    #find minimum dimensions
    min_y = np.min(dimensions_y)
    min_x = np.min(dimensions_x)
    index_y = dimensions_y.index(min_y)
    index_x = dimensions_x.index(min_x)
          
    if index_x != index_y:
        print('Something is funky with the image dimesions for Box'+BoxID)
    else:
        crop_y = dimensions_y[index_y]
        crop_x = dimensions_x[index_y]

        #crop each image if the dimensions are larger than the minimum
        for image in images:
            img = mpimg.imread(downloadpath+"Box"+BoxID+'/rotated/'+image)
            if img.shape[1] > crop_x or img.shape[0] > crop_y:
                #calculate difference, and divide by 2 to get amount of rows to remove by
                diffx_half = (img.shape[1] - crop_x)/2
                diffy_half = (img.shape[0] - crop_y)/2
#                 print(diffx_half, diffy_half)
                
                #if the difference is a half pixel, make sure to remove the full value from the first side only
                if int(diffx_half) != diffx_half:
                    #remember for image slicing y is the first dimension, x is the second
                    img_cropx = img[:, int(diffx_half):-int(diffx_half)-1]
                #otherwise remove it from both sides:
                else:
                    img_cropx = img[:, int(diffx_half):-int(diffx_half)]
                
                #same for y
                if int(diffy_half) != diffy_half:   
                    img_cropy = img_cropx[int(diffy_half):-int(diffy_half)-1, :]
                #otherwise remove it from both sides:
                else:
                    img_cropy = img_cropx[int(diffy_half):-int(diffy_half), :]
                
#                 print(BoxID, crop_y, crop_x)
#                 print(BoxID, img_cropy.shape)
                    
                #save over original images
                scipy.misc.imsave(downloadpath+"Box"+BoxID+'/rotated/'+image, img_cropy)
# Out:
# /home/jukes/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:50: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.

# %%
#convert all final files to pgm
for BoxID in BOXIDS:
    command = 'cd '+downloadpath+'Box'+BoxID+'/rotated/; '+'mogrify -format pgm *.png'
#     print(command)
    subprocess.call(command, shell=True)

# %% [markdown]
# ## Now we're ready for 2D WTMM analysis!
#
# ## 6) Run Tcl scripts:
#
# Pull in the input BoxIDs from above.

# %%
inputIDs = " ".join(BOXIDS)
print(inputIDs)
# Out:
# 001 002 004 033 120 174 235 259 277 531

# %% [markdown]
# ### Run scr_gaussian.tcl with BoxIDs as input

# %%
scr_gaussian = '/home/akhalil/src/xsmurf-2.7/main/xsmurf -nodisplay /home/jukes/Documents/Scripts/scr_gaussian.tcl '+inputIDs
print(scr_gaussian)
subprocess.call(scr_gaussian, shell=True)
# Out:
# /home/akhalil/src/xsmurf-2.7/main/xsmurf -nodisplay /home/jukes/Documents/Scripts/scr_gaussian.tcl 001 002 004 033 120 174 235 259 277 531
# 0

# %% [markdown]
# ### Run terminus_pick.tcl with thresholds and BoxIDs as input

# %%
size_thresh = 0.8
mod_thresh = 0.8
terminus_pick = '/home/akhalil/src/xsmurf-2.7/main/xsmurf -nodisplay /home/jukes/Documents/Scripts/terminus_pick.tcl '+str(size_thresh)+' '+str(mod_thresh)+' '+inputIDs
# print(terminus_pick)
subprocess.call(terminus_pick, shell=True)
# Out:
# 0
