# %% [markdown]
# # Post-WTMM analysis of terminus positions
#
# By Jukes Liu
#
# _Last modified 05-07-2020._

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

basepath = '/home/jukes/Documents/Sample_glaciers/'

os.chdir('/home/jukes/automated-glacier-terminus')
from automated_terminus_functions import midpoint

# %% [markdown]
# ### Grab the BoxIDs

# %%
downloaded_df = pd.read_csv(basepath+'Images_downloaded_SE_2.csv', sep=',', dtype=str)
downloaded_df = downloaded_df.set_index('BoxID')
# # pathrows_df = pathrows_df.drop('215')
# pathrows_df
BoxIDs = list(downloaded_df.index)
print(BoxIDs)
# Out:
# ['106', '111', '116', '121', '126', '131', '136', '146', '151', '156', '161', '166', '171', '176', '186', '191', '196', '201', '211', '216', '226', '231', '246', '256', '261', '266', '271', '281', '291', '296']

# %% [markdown]
# # 1) Grab the vertices of the glacier terminus boxes in pixel coordinates
#
# The vertices of the glacier terminus box will be used to calculate a midpoint of the left edge of the terminus box, which will be our reference point for calculating terminus position.

# %%
#create dictionary to store each terminus box ndarray by BoxID
termboxes = {}

#read in the terminus box rasters
for BoxID in BoxIDs:
    #load in the raster
#     boxpath = basepath+"Box"+BoxID+"/rotated_images/final/crop_Box"+BoxID+"_raster_cut.pgm"
    boxpath = "/media/jukes/jukes1/LS8aws/Box"+BoxID+"/rotated/R_Box"+BoxID+"_raster_cut.pgm"
    #read the raster into an ndarray
    termbox = mpimg.imread(boxpath)
    #add the ndarray into a dictionary with the BoxID as the key
    termboxes.update( {BoxID: termbox} )

# %%
#visualize each terminus box rasters by BoxID
termplot = plt.imshow(termboxes['276'])
plt.show()

# %% [markdown]
# #### Find x,y coordinates of box vertices and midpoints of left and right edges to get the centerline

# %%
#create dictionary to store the all coordinates of the box rasters
boxes_xcoords = {}; boxes_ycoords = {}

#create dictionaries for the box vertices
topleft_coords = {}; bottomleft_coords = {}; topright_coords = {} ;bottomright_coords = {}

#create lists to store the left midpoints (1C) and right midpoints (2C)
midpoints_x = []; midpoints_y = []; midpoints_r_x = []; midpoints_r_y = []
mids_l025_x = []; mids_l025_y = []; mids_r025_x = []; mids_r025_y = []
mids_l075_x = []; mids_l075_y = []; mids_r075_x = []; mids_r075_y = []

#create lists to store the slopes and intercepts of the centerline equations
slope_50 = []; intercept_50 = []; slope_25 = []; intercept_25 = []; slope_75 = []; intercept_75 = []; boxes = []

#for all the box rasters
for BoxID in BoxIDs:
    BOI = termboxes[BoxID] #Read in the raster of the BoxID of interest
    yindices, xindices = np.where(BOI > 0) #keep the pixels of where thevalue is nonzero (where the box exists)
    boxes_ycoords.update( {BoxID: yindices}); boxes_xcoords.update( {BoxID: xindices}) #add box coordinates to the dictionary
    
    #1A) FIND THE TOP LEFT COORDINATES (min x and min y)
    xy = xindices*yindices
    min_xy_i = np.where(xy == np.min(xy))[0][0]  #Find the x and y pair corresponding to that lowest xy
    if BoxID == '001':
        topleft = [6, 26]
    else:
         topleft = [xindices[min_xy_i], yindices[min_xy_i]]
    topleft_coords.update(  {BoxID: topleft}  )     #Add to dictionary of topleft coordinates
    print("Top left", topleft)  
    
    #2B) FIND THE BOTTOM RIGHT COORDINATES (highest x*y)
    max_xy = np.max(xy)
    max_xy_i = np.where(xy == max_xy)[0][0]
    bottomright = [xindices[max_xy_i], yindices[max_xy_i]]
    bottomright_coords.update( {BoxID: bottomright})
    print("Bottom right", bottomright)
    
    #1B) FIND THE BOTTOM LEFT COORDINATE(highest y/x)
    y_x = yindices/xindices
    max_y_x = np.max(y_x) #Find the highest y/x value
    #Find the x and y pair corresponding to that y/x using the index
    max_y_x_i = np.where(y_x == max_y_x)[0][0]
    bottomleft = [xindices[max_y_x_i], yindices[max_y_x_i]]
    print("Bottom left", bottomleft)
    bottomleft_coords.update( {BoxID: bottomleft}  ) #Add to dictionary of bottomleft coordinates
    
    #2A) FIND THE TOP RIGHT COORDINATES (highest x/y)
    x_y = xindices/yindices
    max_x_y = np.max(x_y)  # find highest x/y value
    max_x_y_i = np.where(x_y == max_x_y)[0][0]  #Find the x, y pair correpsonding to the maximum x/y using the index
    topright = [xindices[max_x_y_i], yindices[max_x_y_i]]
    topright_coords.update( {BoxID: topright} )
    print("Top right", topright)
    
    #1C and 2C) CALCULATE THE MIDPOINTS USING MIDPOINT FUNCTION
    #Left
    midpoint_x, midpoint_y = midpoint(topleft[0], topleft[1], bottomleft[0], bottomleft[1])
    #Right
    midpoint_r_x, midpoint_r_y = midpoint(topright[0], topright[1], bottomright[0], bottomright[1])
    
    #GRAB 1/4th and 3/4ths lines (midpoints)
    mid_l025_x, mid_l025_y = midpoint(topleft[0], topleft[1], midpoint_x, midpoint_y)
    mid_r025_x, mid_r025_y = midpoint(topright[0], topright[1], midpoint_r_x, midpoint_r_y) 
    mid_l075_x, mid_l075_y = midpoint(bottomleft[0], bottomleft[1], midpoint_x, midpoint_y)
    mid_r075_x, mid_r075_y = midpoint(bottomright[0], bottomright[1], midpoint_r_x, midpoint_r_y)
    
    #3) CALCULATE CENTERLINE EQUATIONS (y_intercept = y1 - m*x1)
    #1/2
    m = (midpoint_r_y - midpoint_y)/(midpoint_r_x - midpoint_x);b = midpoint_y - (m*midpoint_x)
    #1/4
    m025 = (mid_r025_y-mid_l025_y)/(mid_r025_x-mid_l025_x); b025 = mid_l025_y - (m*mid_l025_x)
    #3/4
    m075 = (mid_r075_y-mid_l075_y)/(mid_r075_x-mid_l075_x); b075 = mid_l075_y - (m*mid_l075_x)
    
    #append BoxIDs, slopes, intercepts, midpoints, and centerlines to lists
    boxes.append(BoxID);
    midpoints_x.append(midpoint_x); midpoints_y.append(midpoint_y)
    midpoints_r_x.append(midpoint_r_x); midpoints_r_y.append(midpoint_r_y)  
    mids_l025_x.append(mid_l025_x); mids_l025_y.append(mid_l025_y); 
    mids_r025_x.append(mid_r025_x); mids_r025_y.append(mid_r025_y)
    mids_l075_x.append(mid_l075_x) ;mids_l075_y.append(mid_l075_y) ;
    mids_r075_x.append(mid_r075_x) ;mids_r075_y.append(mid_r075_y)
    slope_50.append(m); intercept_50.append(b); 
    slope_25.append(m025); intercept_25.append(b025)
    slope_75.append(m075); intercept_75.append(b075)
    
#create a dataframe
total_df = pd.DataFrame(list(zip(boxes, midpoints_x, midpoints_y, midpoints_r_x, midpoints_r_y, slope_50, 
                                 intercept_50, mids_l025_x, mids_l025_y, mids_r025_x, mids_r025_y, slope_25, 
                                 intercept_25, mids_l075_x, mids_l075_y, mids_r075_x, mids_r075_y, slope_75, 
                                intercept_75)), 
                        columns=['BoxID', 'lmid50_x', 'lmid50_y', 'rmid50_x','rmid50_y', 'm50', 'b50',
                                 'lmid25_x', 'lmid25_y','rmid25_x','rmid25_y', 'm25', 'b25',
                                 'lmid75_x', 'lmid75_y', 'rmid75_x','rmid75_y', 'm75', 'b75'])

total_df = total_df.drop_duplicates().set_index('BoxID')
total_df
# Out:
# Top left [45, 67]
# Bottom right [102, 75]
# Bottom left [58, 94]
# Top right [89, 44]
# Top left [66, 47]
# Bottom right [103, 95]
# Bottom left [55, 61]
# Top right [106, 75]
# Top left [97, 144]
# Bottom right [238, 192]
# Bottom left [145, 238]
# Top right [190, 96]
# Top left [79, 107]
# Bottom right [178, 168]
# Bottom left [87, 178]
# Top right [170, 95]
# Top left [80, 85]
# Bottom right [162, 139]
# Bottom left [81, 139]
# Top right [163, 83]
# Top left [101, 158]
# Bottom right [234, 197]
# Bottom left [121, 229]
# Top right [213, 125]
# Top left [57, 97]
# Bottom right [138, 110]
# Bottom left [57, 101]
# Top right [109, 60]
# Top left [106, 88]
# Bottom right [173, 173]
# Bottom left [86, 143]
# Top right [192, 118]
# Top left [65, 84]
# Bottom right [148, 100]
# Bottom left [78, 121]
# Top right [135, 60]
# Top left [187, 136]
# Bottom right [296, 337]
# Bottom left [145, 297]
# Top right [339, 176]
# Top left [72, 93]
# Bottom right [159, 121]
# Bottom left [84, 139]
# Top right [147, 73]
# Top left [118, 111]
# Bottom right [196, 226]
# Bottom left [88, 185]
# Top right [224, 152]
# Top left [86, 86]
# Bottom right [155, 145]
# Bottom left [77, 128]
# Top right [164, 103]
# Top left [171, 206]
# Bottom right [353, 325]
# Bottom left [186, 342]
# Top right [338, 188]
# Top left [361, 174]
# Bottom right [430, 465]
# Bottom left [315, 446]
# Top right [476, 194]
# Top left [118, 135]
# Bottom right [231, 221]
# Bottom left [115, 218]
# Top right [232, 138]
# Top left [44, 54]
# Bottom right [83, 83]
# Bottom left [66, 86]
# Top right [60, 43]
# Top left [152, 145]
# Bottom right [275, 260]
# Bottom left [139, 241]
# Top right [288, 163]
# Top left [29, 52]
# Bottom right [70, 62]
# Bottom left [32, 68]
# Top right [67, 45]
# Top left [102, 63]
# Bottom right [144, 133]
# Bottom left [80, 91]
# Top right [106, 63]
# Top left [45, 100]
# Bottom right [98, 84]
# Bottom left [45, 101]
# Top right [89, 61]
# Top left [34, 55]
# Bottom right [83, 75]
# Bottom left [41, 85]
# Top right [75, 44]
# Top left [86, 125]
# Bottom right [204, 159]
# Bottom left [121, 199]
# Top right [167, 85]
# Top left [263, 158]
# Bottom right [316, 370]
# Bottom left [165, 275]
# Top right [265, 159]
# Top left [154, 148]
# Bottom right [272, 294]
# Bottom left [131, 267]
# Top right [295, 175]
# Top left [164, 139]
# Bottom right [263, 274]
# Bottom left [161, 274]
# Top right [264, 141]
# Top left [116, 142]
# Bottom right [268, 239]
# Bottom left [147, 268]
# Top right [237, 113]
# Top left [196, 142]
# Bottom right [264, 311]
# Bottom left [153, 277]
# Top right [306, 177]
# Top left [220, 203]
# Bottom right [360, 385]
# Bottom left [218, 384]
# Top right [361, 203]
# Top left [198, 213]
# 276      360.25    339.50  0.005291  337.977915
# 281      392.75    324.00 -0.060080  347.854000
# 286      364.25    265.50 -0.244573  354.931159
# 291      244.25    239.25  0.307229  164.117000
# 296      175.25    130.00  0.043228  122.669075

# %% [markdown]
# ### Another visual check

# %%
# Choose which glacier BoxID to check:
BOI_ID = '276'

# plot the raster pixels in black
plt.scatter(boxes_xcoords[BOI_ID], boxes_ycoords[BOI_ID], c='k',marker='s')
#plot the vertices
plt.scatter(topleft_coords[BOI_ID][0], topleft_coords[BOI_ID][1], c='y')
plt.scatter(bottomleft_coords[BOI_ID][0], bottomleft_coords[BOI_ID][1], c='y')
plt.scatter(topright_coords[BOI_ID][0], topright_coords[BOI_ID][1], c='y')
plt.scatter(bottomright_coords[BOI_ID][0], bottomright_coords[BOI_ID][1], c='y')
#plot midpoints
plt.scatter(total_df.at[BOI_ID,'lmid50_x'], total_df.at[BOI_ID,'lmid50_y'], c='m'); plt.scatter(total_df.at[BOI_ID, 'rmid50_x'], total_df.at[BOI_ID, 'rmid50_y'], c='m')
plt.scatter(total_df.at[BOI_ID,'lmid25_x'], total_df.at[BOI_ID,'lmid25_y'], c='r'); plt.scatter(total_df.at[BOI_ID, 'rmid25_x'], total_df.at[BOI_ID, 'rmid25_y'], c='r')
plt.scatter(total_df.at[BOI_ID,'lmid75_x'], total_df.at[BOI_ID,'lmid75_y'], c='b'); plt.scatter(total_df.at[BOI_ID, 'rmid75_x'], total_df.at[BOI_ID, 'rmid75_y'], c='b')
# plot the centerlines in cyan
x=np.linspace(np.min(boxes_xcoords[BOI_ID]), np.max(boxes_xcoords[BOI_ID])); y50=(total_df.at[BOI_ID, 'm50'])*x + (total_df.at[BOI_ID, 'b50']); 
y25=(total_df.at[BOI_ID, 'm25'])*x + (total_df.at[BOI_ID, 'b25']); y75=(total_df.at[BOI_ID, 'm75'])*x + (total_df.at[BOI_ID, 'b75'])
plt.plot(x, y50, '--m', x, y25, '--r', x, y75, '--b')
# plot parameters      
plt.gca().invert_yaxis(); plt.axis('scaled'); plt.show()

# %% [markdown]
# ### Drop the right midpoints and write the centerline information to a csv

# %%
total_df = total_df.drop(['rmid50_y', 'rmid25_y', 'rmid75_y'], axis=1)
total_df.head(10)
# Out:
#        lmid50_x  lmid50_y  rmid50_x       m50         b50  lmid25_x  lmid25_y  \
# BoxID
# 106        51.5      80.5      95.5 -0.477273  105.079545     48.25     73.75
# 111        60.5      54.0     104.5  0.704545   11.375000     63.25     50.50
# 116       121.0     191.0     214.0 -0.505376  252.150538    109.00    167.50
# 121        83.0     142.5     174.0 -0.120879  152.532967     81.00    124.75
# 126        80.5     112.0     162.5 -0.012195  112.981707     80.25     98.50
# 131       111.0     193.5     223.5 -0.288889  225.566667    106.00    175.75
# 136        57.0      99.0     123.5 -0.210526  111.000000     57.00     98.00
# 146        96.0     115.5     182.5  0.346821   82.205202    101.00    101.75
# 151        71.5     102.5     141.5 -0.321429  125.482143     68.25     93.25
# 156       166.0     216.5     317.5  0.264026  172.671617    176.50    176.25
#
#        rmid25_x       m25         b25  lmid75_x  lmid75_y  rmid75_x       m75  \
# BoxID
# 106       92.25 -0.500000   96.778409     54.75     87.25     98.75 -0.454545
# 111      105.25  0.702381    5.937500     57.75     57.50    103.75  0.706522
# 116      202.00 -0.510753  222.586022    133.00    214.50    226.00 -0.500000
# 121      172.00 -0.126374  134.541209     85.00    160.25    176.00 -0.115385
# 126      162.75 -0.018182   99.478659     80.75    125.50    162.25 -0.006135
# 131      218.25 -0.291759  206.372222    116.00    211.25    228.75 -0.286031
# 136      116.25 -0.430380  110.000000     57.00    100.00    130.75 -0.033898
# 146      187.25  0.347826   66.721098     91.00    129.25    177.75  0.345821
# 151      138.25 -0.332143  115.187500     74.75    111.75    144.75 -0.310714
# 156      328.25  0.263591  129.649340    155.50    256.75    306.75  0.264463
#
#               b75
# BoxID
# 106    113.380682
# 111     16.812500
# 116    281.715054
# 121    170.524725
# 126    126.484756
# 131    244.761111
# 136    112.000000
# 146     97.689306
# 151    135.776786
# 156    215.693894

# %%
CLINE_NAME = 'Boxes_coords_pathrows_SE_2.csv'
total_df.to_csv(path_or_buf = basepath+CLINE_NAME, sep=',')

# %% [markdown]
# # 2) Calculate terminus position time series

# %%
# IMPORT THE FUNCTION
os.chdir('/home/jukes/automated-glacier-terminus')
from automated_terminus_functions import results_allglaciers

# %%
# first number is maximum flow speed scalar, second is number of remove dip iterations, third is remove jumps
# results_allglaciers(date_csv, centerline_csv, vel_csv, analysis_date, V, N1, N2):

results_allglaciers('Images_downloaded_SE_2.csv','imgdates_SE_2.csv', 'Boxes_coords_pathrows_SE_2.csv','Glacier_vel_measures_SE_2.csv', '2020_05_09', 3, 1, 1)
# Out:
# (690, 2)
# Box106
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 78 dips
# Dropping 85 dips
# Dropping 82 dips
# Dropping 99 jumps
# Dropping 76 jumps
# Dropping 97 jumps
# 70
# 52
# 52
# Box111
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 17 dips
# Dropping 31 dips
# Dropping 22 dips
# Dropping 51 jumps
# Dropping 37 jumps
# Dropping 63 jumps
# 35
# 28
# 28
# Box116
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 57 dips
# Dropping 28 dips
# Dropping 57 dips
# Dropping 42 jumps
# Dropping 34 jumps
# Dropping 42 jumps
# 30
# 19
# 25
# Box121
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 43 dips
# Dropping 30 dips
# Dropping 32 dips
# Dropping 38 jumps
# Dropping 21 jumps
# Dropping 40 jumps
# 38
# 38
# 47
# Box126
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 25 dips
# Dropping 21 dips
# Dropping 17 dips
# Dropping 44 jumps
# Dropping 32 jumps
# Dropping 46 jumps
# 27
# 26
# 30
# Box131
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 59 dips
# Dropping 25 dips
# Dropping 37 dips
# Dropping 46 jumps
# Dropping 23 jumps
# Dropping 31 jumps
# 20
# 22
# 26
# Box136
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 7 dips
# Dropping 0 dips
# Dropping 32 dips
# Dropping 15 jumps
# Dropping 2 jumps
# Dropping 31 jumps
# 13
# 1
# 25
# Box146
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 53 dips
# Dropping 50 dips
# Dropping 56 dips
# Dropping 55 jumps
# Dropping 34 jumps
# Dropping 43 jumps
# 36
# 26
# 30
# Box151
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 49 dips
# Dropping 32 dips
# Dropping 34 dips
# Dropping 45 jumps
# Dropping 34 jumps
# Dropping 39 jumps
# 24
# 22
# 23
# Box156
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 65 dips
# Dropping 41 dips
# Dropping 60 dips
# Dropping 33 jumps
# Dropping 18 jumps
# Dropping 30 jumps
# 26
# 21
# 28
# Box161
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 36 dips
# Dropping 28 dips
# Dropping 59 dips
# Dropping 38 jumps
# Dropping 32 jumps
# Dropping 34 jumps
# 37
# 35
# 29
# Box166
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 31 dips
# Dropping 20 dips
# Dropping 35 dips
# Dropping 66 jumps
# Dropping 45 jumps
# Dropping 39 jumps
# 29
# 28
# 22
# Box171
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 58 dips
# Dropping 26 dips
# Dropping 66 dips
# Dropping 47 jumps
# Dropping 29 jumps
# Dropping 49 jumps
# 27
# 15
# 25
# Box176
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 43 dips
# Dropping 23 dips
# Dropping 23 dips
# Dropping 20 jumps
# Dropping 10 jumps
# Dropping 20 jumps
# 20
# 13
# 13
# Box186
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 38 dips
# Dropping 4 dips
# Dropping 39 dips
# Dropping 14 jumps
# Dropping 8 jumps
# Dropping 26 jumps
# 31
# 24
# 31
# Box191
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 171 dips
# Dropping 86 dips
# Dropping 114 dips
# Dropping 78 jumps
# Dropping 50 jumps
# Dropping 69 jumps
# 67
# 53
# 60
# Box196
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 17 dips
# Dropping 4 dips
# Dropping 4 dips
# Dropping 30 jumps
# Dropping 19 jumps
# Dropping 10 jumps
# 43
# 33
# 23
# Box201
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 111 dips
# Dropping 62 dips
# Dropping 70 dips
# Dropping 39 jumps
# Dropping 32 jumps
# Dropping 46 jumps
# 26
# 24
# 28
# Box211
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 121 dips
# Dropping 93 dips
# Dropping 112 dips
# Dropping 81 jumps
# Dropping 87 jumps
# Dropping 72 jumps
# 54
# 47
# 57
# Box216
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 8 dips
# Dropping 0 dips
# Dropping 18 dips
# Dropping 29 jumps
# Dropping 10 jumps
# Dropping 31 jumps
# 20
# 9
# 27
# Box226
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 18 dips
# Dropping 15 dips
# Dropping 29 dips
# Dropping 33 jumps
# Dropping 3 jumps
# Dropping 51 jumps
# 53
# 44
# 46
# Box231
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 49 dips
# Dropping 34 dips
# Dropping 59 dips
# Dropping 68 jumps
# Dropping 89 jumps
# Dropping 52 jumps
# 48
# 37
# 46
# Box246
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 0 dips
# Dropping 1 dips
# Dropping 10 dips
# Dropping 39 jumps
# Dropping 17 jumps
# Dropping 14 jumps
# 43
# 44
# 39
# Box256
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 46 dips
# Dropping 25 dips
# Dropping 34 dips
# Dropping 22 jumps
# Dropping 23 jumps
# Dropping 31 jumps
# 19
# 17
# 23
# Box261
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 106 dips
# Dropping 75 dips
# Dropping 109 dips
# Dropping 59 jumps
# Dropping 46 jumps
# Dropping 66 jumps
# 43
# 41
# 41
# Box266
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 54 dips
# Dropping 40 dips
# Dropping 74 dips
# Dropping 50 jumps
# Dropping 41 jumps
# Dropping 51 jumps
# 32
# 31
# 38
# Box271
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 19 dips
# Dropping 8 dips
# Dropping 22 dips
# Dropping 15 jumps
# Dropping 13 jumps
# Dropping 31 jumps
# 40
# 40
# 39
# Box281
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 42 dips
# Dropping 23 dips
# Dropping 31 dips
# Dropping 61 jumps
# Dropping 35 jumps
# Dropping 42 jumps
# 45
# 49
# 30
# Box291
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 47 dips
# Dropping 56 dips
# Dropping 54 dips
# Dropping 40 jumps
# Dropping 27 jumps
# Dropping 28 jumps
# 41
# 36
# 24
# Box296
# /home/jukes/automated-glacier-terminus/automated_terminus_functions.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['changerate'] = tchange
# Dropping 78 dips
# Dropping 65 dips
# Dropping 45 dips
# Dropping 33 jumps
# Dropping 37 jumps
# Dropping 33 jumps
# 40
# 37
# 50
