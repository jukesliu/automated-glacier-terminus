# %% [markdown]
# # Automated bulk download of Landsat image subsets through AWS
#
# _Last modified 2022-05-11._
#
# This script is run to download Landsat images over the glaciers available through the AWS s3 bucket. The workflow is streamlined to analyze images for 10s to 100s of glaciers, specifically, the marine-terminating glaciers along the periphery of Greenland. Sections of code that may need to be modified are indicated as below:
#
#     ##########################################################################################
#
#     Code that must be modified.
#
#     ##########################################################################################
#
#
# ### Configure your AWS profile to access the Landsat images on the s3 bucket:
#
# Follow instructions at https://docs.aws.amazon.com/cli/latest/userguide/cli-chap-install.html to get required __aws__ command line software.
#
# Set up your AWS profile with a payment option. Then configure it to your machine following these steps:
#
#     aws configure --profile terminusmapping
#
# Enter in your credentials.
#
# ### Steps in the script:
#     1. Set-up: import packages, set paths, and enter glaciers IDs
#     2. Find all the Landsat footprints that overlap the glaciers
#     3. Download Landsat metadata (*MTL.txt) files from AWS for all overlapping scenes
#     4. Calculate cloud % over terminus box using Landsat quality band (QA_PIXEL)
#     5. Create buffer zone around terminus boxes and rasterize terminus boxes
#     6. Download non-cloudy Landsat images from AWS
#     7. Grab image acquisition dates from metadata files
#     8. Delete the *QA_PIXEL.TIF files downloaded in step (4) to save space

# %% [markdown]
# # 1) Set-up: import packages, set paths, and enter glaciers IDs

# %%
import numpy as np
import pandas as pd
import scipy
import math
import subprocess
import os
import shutil
import datetime
import cv2
from PIL import Image
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import glob

# geospatial packages
import fiona
import geopandas as gpd
from shapely.geometry import Polygon, Point, LineString
import shapely
from matplotlib.pyplot import imshow
import rasterio as rio

# Enable fiona KML file reading driver
gpd.io.file.fiona.drvsupport.supported_drivers['KML'] = 'rw'

# import necessary functions from automated-glacier-terminus.py
from automated_terminus_functions import distance

# %%
# # change display width if desired
# from IPython.display import display, HTML

# display(HTML(data="""
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>
# """))

# %% [markdown]
# ## AWS configuration:

# %%
# ! aws s3 ls --profile terminusmapping

# %%
# AWS settings
from rasterio.session import AWSSession
import pickle
import boto3
import boto3.session

cred = boto3.Session(profile_name='terminusmapping').get_credentials()
ACCESS_KEY = cred.access_key
SECRET_KEY = cred.secret_key
SESSION_TOKEN = cred.token  ## optional


s3client = boto3.client('s3', 
                        aws_access_key_id = ACCESS_KEY, 
                        aws_secret_access_key = SECRET_KEY, 
#                         aws_session_token = SESSION_TOKEN
                       )

# response = s3client.get_object(Bucket='name_of_your_bucket', Key='path/to_your/file.pkl')
# body = response['Body'].read()
# data = pickle.loads(body)
 
######################################################################################
# path to the collection on AWS usgs-landsat s3 bucket:
collectionpath = 'collection02/level-1/standard/' # collection 2 level 1 data being used
######################################################################################

# %% [markdown]
# ## Define paths, satellites, geographic projections:

# %%
######################################################################################
# ADJUST THESE VARIABLES:
basepath = '/home/jukes/Documents/Sample_glaciers/' # folder containing the all glacier shapefile(s)
downloadpath ='/media/jukes/jukes1/LS8aws/' # folder to eventually contain downloaded Landsat images

sats = ['L7','L8'] # names of landsats to download images from ('L7' for Landsat 7 or 'L8' or both)
L8_yrs = np.arange(2013,2022).astype(str) # set target years for L8: 2013-2021
L7_yrs = np.arange(1999,2004).astype(str) # set target years for L7: 1999-2003
L8_bands = [8] # panchromatic band for L8
L7_bands = [8] # panchromatic band for L7

repopath = '/home/jukes/automated-glacier-terminus/' # path to this repository
os.chdir(repopath) # change directories to this repo

source_srs = '3413' # EPSG code for the current projection of the glacier shapefiles 
# (3413 = Greenland polar stereographic)

csvext = '_test_Box009.csv' # enter a file suffix for the CSV files produced 
# that describes the analysis (e.g., glacier or group of glaciers)

RGIpath = '/media/jukes/jukes1/RGI_shps/' # path to folder with all individual RGI glacier outline shapefiles
boxespath = '/media/jukes/jukes1/Boxes_individual/' # folder with all individual glacier terminus box shapes
######################################################################################

# %%
# filenames that will be written in this script
# all with common extension
print("CSV files that will be produced:"); print()
PR_FILENAME = 'LS_pathrows'+csvext; print(PR_FILENAME) # glacier Landsat path, row, zone info
BOX_FILENAME = 'Buffdist'+csvext; print(BOX_FILENAME) # buffer distances around glacier terminus boxes
DATES_FILENAME = 'imgdates'+csvext; print(DATES_FILENAME) # acquisition dates for downloaded Landsat images
# Out:
# CSV files that will be produced:
#
# LS_pathrows_test_Box009.csv
# Buffdist_test_Box009.csv
# imgdates_test_Box009.csv

# %% [markdown]
# #### Keep a record of the csv file names generated as many of them will be used later for analysis.
#
# ##  Enter in the glacier BoxIDs:
#
# The Greenland peripheral glacier terminus boxes were referenced using their 3 digit BoxID: Box###.
# For other glaciers, replace this code with a list of IDs corresponding to the glaciers and corresponding shapefiles (e.g. BoxHelheim.shp).

# %%
######################################################################################
BoxIDs = []
boxes = list(map(str, np.arange(9, 10, 1))) #1, 642, 1
for BoxID in boxes: # convert integers to 3-digit strings with leading zeros
    BoxID = BoxID.zfill(3)
    BoxIDs.append(BoxID)
print(BoxIDs) # show the final BoxIDs
######################################################################################
# Out:
# ['009']

# %% [markdown]
# ### Create new folders corresponding to these glaciers:

# %%
# create new BoxID folders 
for BoxID in BoxIDs:
    # create folder to hold glacier shapefiles
    shapefilepath = basepath+'Box'+BoxID+'/' # path to that folder
    if os.path.exists(shapefilepath):
#         shutil.rmtree(shapefilepath) # remove the old folder
        print("Path exists already for Box", BoxID)
    else:
        os.mkdir(basepath+'Box'+BoxID)
            
    # create folder to hold glacier images (inside downloadpath)
    if os.path.exists(downloadpath+'Box'+BoxID):
        print("Path exists already in LS8aws for Box", BoxID)
    else:
        os.mkdir(downloadpath+'Box'+BoxID)
    
    # Now place terminus box shapefile and RGI glacier outline shapefile into the
    # boxespath folder. Done automatically below for the Greenland peripheral glaciers:
    ######################################################################################
    ID = int(BoxID) # make into an integer in order to grab the .shp files
    
    # if the terminus box shapefile is not in this folder, then move it
    if not os.path.exists(shapefilepath+'Box'+BoxID+'.shp'):
        for filename in os.listdir(boxespath):
            if filename.startswith('BoxID_'+str(ID)):
                shutil.copyfile(boxespath+filename, basepath+'Box'+BoxID+'/Box'+BoxID+filename[-4:])
                print("Box"+BoxID+filename[-4:], "moved")
    else:
        print("Box"+BoxID+'.shp', "already in folder")

    if not os.path.exists(shapefilepath+'RGI_Box'+BoxID+'.shp'): # if the RGI shapfile is not in this folder
        # move RGI glacier outline into the new folder
        for filename in os.listdir(RGIpath):
            if filename.startswith('BoxID_'+str(ID)):
                shutil.copyfile(RGIpath+filename, basepath+'Box'+BoxID+'/RGI_Box'+BoxID+filename[-4:])
                print("RGI_Box"+BoxID+filename[-4:], "moved")
    else:
        print("RGI_Box"+BoxID+'.shp', "already in folder")
    ######################################################################################
# Out:
# Path exists already for Box 009
# Box009.shp already in folder
# RGI_Box009.shp already in folder

# %% [markdown]
# # 2) Find all the Landsat footprints that overlap the glaciers
#
# This step requires the WRS-2_bound_world_0.kml file containing the footprints of all the Landsat scene boundaries available through the USGS (https://www.usgs.gov/land-resources/nli/landsat/landsat-shapefiles-and-kml-files). Place this file in your base directory (basepath).
#
# To check if they overlap the glacier terminus box shapefiles, the box shapefiles must be in WGS84 coordinates (ESPG: 4326). If they are not yet, we use the following GDAL command to reproject them into WGS84:
#
#         ogr2ogr -f "ESRI Shapefile" -t_srs EPSG:NEW_EPSG_NUMBER -s_srs EPSG:OLD_EPSG_NUMBER out.shp in.shp

# %%
# Reproject terminus box shapefiles to WGS84 if in a different projection
for BoxID in BoxIDs:
    boxespath = basepath+"Box"+BoxID+"/Box"+BoxID # access the BoxID folders created 
    # construct the gdal command
    rp = "ogr2ogr -f 'ESRI Shapefile' -t_srs EPSG:4326 -s_srs EPSG:"+source_srs+" "
    rp +=boxespath+"_WGS.shp "+boxespath+".shp"
    print("Command:", rp) # check command
    subprocess.run(rp, shell=True, check=True) # run the command on terminal
    
    # if an error is produced, check the error output on the terminal window that runs this notebook
# Out:
# Command: ogr2ogr -f 'ESRI Shapefile' -t_srs EPSG:4326 -s_srs EPSG:3413 /home/jukes/Documents/Sample_glaciers/Box009/Box009_WGS.shp /home/jukes/Documents/Sample_glaciers/Box009/Box009.shp

# %%
# Grab the WGS84 coordinates of the boxes
box_points = {} # dictionary of points
for BoxID in BoxIDs:
    boxpath = basepath+"Box"+BoxID+"/Box"+BoxID # path to the reprojected terminus box
    termbox = fiona.open(boxpath+'_WGS.shp') # open reprojected terminus box
    box = termbox.next(); box_coords=box['geometry']['coordinates'][0] # grab coords
    points = [] # to hold the box vertices
    
    # read coordinates and convert to a shapely object
    for coord_pair in box_coords: 
        lat = coord_pair[0]; lon = coord_pair[1]        
        point = shapely.geometry.Point(lat, lon) # create shapely point 
        points.append(point) # append to points list
        
    box_points.update({BoxID: points}) # update dictionary
    print("Box"+BoxID+" coordinates recorded.") # keep track of progress
# Out:
# Box009 coordinates recorded.
# /home/jukes/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: FionaDeprecationWarning: Collection.__next__() is buggy and will be removed in Fiona 2.0. Switch to `next(iter(collection))`.

# %%
######################################################################################
# open the kml file with the Landsat path, row footprints:
WRS = fiona.open(basepath+'WRS-2_bound_world_0.kml', driver='KML') # check the path to the world bounds file
print('Landsat footprint file opened.')
######################################################################################
# Out:
# Landsat footprint file opened.

# %%
paths = []; rows = []; boxes = [] # create lists to hold the paths and rows and BoxIDs

#loop through all Landsat scenes (path, row footprints)
for feature in WRS:
    # create shapely polygons from the Landsat footprints
    coordinates = feature['geometry']['coordinates'][0]
    coords = [xy[0:2] for xy in coordinates]
    pathrow_poly = Polygon(coords)
    
    # grab the path and row name from the WRS kml file:
    pathrowname = feature['properties']['Name']  
    path = pathrowname.split('_')[0]; row = pathrowname.split('_')[1]
#     print(path, row)
    
    # for each feature, loop through each of the vertices stored in the dictionary
    for BoxID in box_points:  
        box_points_in = 0 # counter for number of box_points in the pathrow_geom:
        points = box_points.get(BoxID) # grab the points corresponding to the ID
        for i in range(0, len(points)):
            point = points[i]
            if point.within(pathrow_poly): # if the pathrow shape contains the point
                box_points_in = box_points_in+1 # append the counter
        if box_points_in == 5: # if all box vertices are inside the footprint, save the path, row, BoxID
            paths.append('%03d' % int(path))
            rows.append('%03d' % int(row))
            boxes.append(BoxID)

# Store in dataframe
boxes_pr_df = pd.DataFrame(list(zip(boxes, paths, rows)), columns=['BoxID','Path', 'Row'])
boxes_pr_df = boxes_pr_df.sort_values(by='BoxID')
boxes_pr_df # display
# Out:
#   BoxID Path  Row
# 0   009  030  006
# 1   009  029  006
# 2   009  028  006
# 3   009  027  006
# 4   009  032  005
# 5   009  031  005

# %%
# save to file
boxes_pr_df.to_csv(path_or_buf = basepath+PR_FILENAME, sep=',') # write to csv

# %% [markdown]
# # 3) Download metadata files from AWS s3 for overlapping Landsat scenes
#
# The syntax for listing the Collection 2 Landsat image files AWS s3 bucket is as follows:
#
#     aws s3 ls --request-payer requester s3://usgs-landsat/collection02/level-2/standard/oli-tirs/yyyy/path/row/LC08_LS2R_pathrow_yyyyMMdd_yyyyMMdd_02_T1/
#
# __NOTE: Including the --request-payer requester as part of this line indicates that the referenced user will be charged for data download.__
#
# We can use the paths and rows in the dataframe to access the full Landsat scene list and the corresponding metdata files. Read https://docs.opendata.aws/landsat-pds/readme.html to learn more.
#
# The metadata files will be downloaded into folders corresponding to the Landsat footprint, identified by the Path Row numbers:
#
#     aws s3api get-object --bucket usgs-landsat --key collection02/level-2/standard/oli-tirs/yyyy/path/row/LC08_L2SP_pathrow_yyyyMMdd_yyyyMMdd_02_T1/LC08_L2SP_pathrow_yyyyMMdd_yyyyMMdd_02_T1_MTL.txt  --request-payer requester LC08_L2SP_pathrow_yyyyMMdd_yyyyMMdd_02_T1_MTL.txt

# %%
# Read in csv file from Step 2
boxes_pr_df = pd.read_csv(basepath+PR_FILENAME, dtype=str)
boxes_pr_df = boxes_pr_df.set_index('BoxID'); boxes_pr_df
# Out:
#       Unnamed: 0 Path  Row
# BoxID
# 009            0  030  006
# 009            1  029  006
# 009            2  028  006
# 009            3  027  006
# 009            4  032  005
# 009            5  031  005

# %%
# Loop through the dataframe containing overlapping path, row info:
for index, row in boxes_pr_df.iterrows():
    p = row['Path']; r = row['Row']; folder_name = 'Path'+p+'_Row'+r+'_c2' # folder name
    bp_out = downloadpath+folder_name+'/' # output path for the downloaded files
    print("Downloaded metadata files are stored in:",bp_out)
    
    # create Path_Row folders if they don't exist already
    if os.path.exists(bp_out):
        print(folder_name, " exists already, skip directory creation")
    else:
        os.mkdir(bp_out)
        print(folder_name+" directory made")
    
    for sat in sats: # for each satellite
        if sat == 'L8':
            collectionfolder = 'oli-tirs/'; years = L8_yrs; prefix='LC08' # set folder, years, file prefix
        elif sat == 'L7':
            collectionfolder = 'etm/'; years = L7_yrs; prefix='LE07' # set folder, years, file prefix
        
        # loop through years
        for year in years:
            # grab list of images in each year, path, row folder
            find_imgs = 'aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/'
            find_imgs += collectionpath+collectionfolder
            find_imgs += year+'/'+p+'/'+r+'/'
            print(find_imgs)
            if subprocess.run(find_imgs,shell=True).returncode != 0:
                print('No results found for '+collectionpath+collectionfolder+year+'/'+p+'/'+r+'/')
                results = [] # empty results
            else:
                result = subprocess.check_output(find_imgs,shell=True) # grab the avilable images
                results = result.split() # split string
            
            imagenames = []
            for line in results: # loop through strings
                line = str(line)
                if prefix in line and 'T1' in line: # find just the Tier-1 images
                    imgname = line[2:-2]; imagenames.append(imgname)

            # download the metadata (MTL.txt) file if it doesn't exist
            for imgname in imagenames:
                if not os.path.exists(bp_out+imgname+'_MTL.txt'): # check in output directory
                    command = 'aws s3api get-object --bucket usgs-landsat --key '+collectionpath+collectionfolder
                    command += year+'/'+p+'/'+r+'/'
                    command += imgname+'/'+imgname+'_MTL.txt'
                    command += ' --profile terminusmapping --request-payer requester '
                    command += bp_out+imgname+'_MTL.txt'
                    print('Downloading', imgname+'_MTL.txt')
                    subprocess.run(command,shell=True,check=True)
                else:
                    print(imgname+'_MTL.txt exists. Skip.')
# Out:
# Downloaded metadata files are stored in: /media/jukes/jukes1/LS8aws/Path030_Row006_c2/
# Path030_Row006_c2  exists already, skip directory creation
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/1999/030/006/
# LE07_L1TP_030006_19990705_20200918_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/2000/030/006/
# LE07_L1TP_030006_20000520_20200918_02_T1_MTL.txt exists. Skip.
# LE07_L1TP_030006_20000605_20200918_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/2001/030/006/
# LE07_L1TP_030006_20010405_20200917_02_T1_MTL.txt exists. Skip.
# LE07_L1TP_030006_20010811_20200917_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/2002/030/006/
# LE07_L1TP_030006_20020323_20200916_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/2003/030/006/
# LE07_L1TP_030006_20030411_20200916_02_T1_MTL.txt exists. Skip.
# LE07_L1TP_030006_20030513_20200916_02_T1_MTL.txt exists. Skip.
# LE07_L1TP_030006_20030529_20200915_02_T1_MTL.txt exists. Skip.
# LE07_L1TP_030006_20030716_20200915_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2013/030/006/
# LC08_L1TP_030006_20130516_20200913_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2014/030/006/
# LC08_L1TP_030006_20140228_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20140417_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20140519_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20140604_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20140706_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20140807_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20140823_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20140908_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20140924_20200910_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2015/030/006/
# LC08_L1TP_030006_20150319_20200909_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20150404_20200909_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20150420_20200909_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20150506_20201015_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20150522_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20150607_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20150709_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20150725_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20150810_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20150826_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20151013_20200908_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2016/030/006/
# LC08_L1TP_030006_20160321_20200907_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20160406_20200907_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20160524_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20160625_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20160711_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20160727_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20160913_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20160929_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20161015_20200905_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2017/030/006/
# LC08_L1TP_030006_20170409_20200904_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20170425_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20170511_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20170714_20201015_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20170730_20200903_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20170815_20200903_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20170916_20200903_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2018/030/006/
# LC08_L1TP_030006_20180311_20200901_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20180327_20200901_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20180412_20201015_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20180428_20200901_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20180514_20200901_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20180615_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20180701_20200831_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20180717_20200831_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20180802_20200831_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20180903_20200831_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20180919_20200830_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20181005_20200830_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2019/030/006/
# LC08_L1TP_030006_20190314_20200829_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20190415_20200829_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20190501_20200830_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20190602_20200828_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20190704_20200830_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20190805_20200828_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20190821_20200828_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20190906_20200828_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20190922_20200826_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20191008_20200825_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2020/030/006/
# LC08_L1TP_030006_20200229_20200822_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20200316_20200822_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20200401_20200822_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20200417_20200822_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20200503_20200820_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20200604_20200824_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20200620_20200823_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20200706_20200913_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20200722_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20200807_20200916_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20200908_20200919_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20200924_20201007_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20201010_20201015_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2021/030/006/
# LC08_L1TP_030006_20210404_20210409_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20210420_20210430_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20210506_20210517_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20210522_20210529_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20210607_20210615_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20210623_20210630_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20210709_20210720_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20210725_20210803_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20210911_20210916_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_030006_20210927_20210930_02_T1_MTL.txt exists. Skip.
# Downloaded metadata files are stored in: /media/jukes/jukes1/LS8aws/Path029_Row006_c2/
# Path029_Row006_c2  exists already, skip directory creation
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/1999/029/006/
# No results found for collection02/level-1/standard/etm/1999/029/006/
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/2000/029/006/
# LE07_L1TP_029006_20000427_20200918_02_T1_MTL.txt exists. Skip.
# LE07_L1TP_029006_20000513_20200918_02_T1_MTL.txt exists. Skip.
# LE07_L1TP_029006_20001004_20200917_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/2001/029/006/
# LE07_L1TP_029006_20010414_20200917_02_T1_MTL.txt exists. Skip.
# LE07_L1TP_029006_20010516_20200917_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/2002/029/006/
# LE07_L1TP_029006_20020722_20200916_02_T1_MTL.txt exists. Skip.
# LE07_L1TP_029006_20020823_20200916_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/2003/029/006/
# LE07_L1TP_029006_20030404_20200915_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2013/029/006/
# LC08_L1TP_029006_20130829_20200912_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20130914_20200912_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20130930_20200912_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2014/029/006/
# LC08_L1TP_029006_20140309_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20140410_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20140613_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20140629_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20140715_20201015_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20140731_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20140901_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20140917_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20141003_20200910_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2015/029/006/
# LC08_L1TP_029006_20150312_20200909_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20150328_20200909_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20150413_20200909_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20150429_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20150515_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20150531_20200909_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20150616_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20150718_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20150803_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20150819_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20150904_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20150920_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20151006_20200908_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2016/029/006/
# LC08_L1TP_029006_20160501_20200907_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20160602_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20160618_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20160704_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20160805_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20160922_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20161008_20200905_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2017/029/006/
# LC08_L1TP_029006_20170317_20200904_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20170402_20200904_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20170520_20200904_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20170621_20200903_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20170707_20200903_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20170723_20200903_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20170925_20200903_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20171011_20200903_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2018/029/006/
# LC08_L1TP_029006_20180304_20200902_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20180405_20200901_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20180421_20200901_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20180507_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20180523_20200901_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20180624_20200831_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20180726_20200831_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20180912_20200830_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20180928_20200830_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2019/029/006/
# LC08_L1TP_029006_20190323_20200829_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20190424_20200828_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20190510_20200829_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20190526_20200828_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20190611_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20190627_20200828_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20190713_20200830_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20190729_20200827_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20190814_20200827_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20190830_20200826_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20190915_20200826_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2020/029/006/
# LC08_L1TP_029006_20200309_20200822_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20200528_20200820_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20200613_20200823_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20200731_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20200816_20200920_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20200901_20200906_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2021/029/006/
# LC08_L1TP_029006_20210312_20210317_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20210328_20210402_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20210429_20210508_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20210616_20210622_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20210702_20210712_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20210718_20210729_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20210819_20210827_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20210920_20210925_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_029006_20211006_20211013_02_T1_MTL.txt exists. Skip.
# Downloaded metadata files are stored in: /media/jukes/jukes1/LS8aws/Path028_Row006_c2/
# Path028_Row006_c2  exists already, skip directory creation
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/1999/028/006/
# LE07_L1TP_028006_19990723_20200918_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/2000/028/006/
# LE07_L1TP_028006_20000404_20200918_02_T1_MTL.txt exists. Skip.
# LE07_L1TP_028006_20000506_20200918_02_T1_MTL.txt exists. Skip.
# LE07_L1TP_028006_20000623_20200918_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/2001/028/006/
# LE07_L1TP_028006_20010322_20200917_02_T1_MTL.txt exists. Skip.
# LE07_L1TP_028006_20010407_20200917_02_T1_MTL.txt exists. Skip.
# LE07_L1TP_028006_20010930_20200917_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/2002/028/006/
# LE07_L1TP_028006_20020325_20200916_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/2003/028/006/
# LE07_L1TP_028006_20030413_20200915_02_T1_MTL.txt exists. Skip.
# LE07_L1TP_028006_20030803_20200915_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2013/028/006/
# LC08_L1TP_028006_20130907_20200913_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20130923_20200913_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2014/028/006/
# LC08_L1TP_028006_20140302_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20140318_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20140505_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20140521_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20140708_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20140825_20200911_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2015/028/006/
# LC08_L1TP_028006_20150305_20200909_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20150321_20201015_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20150406_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20150422_20200909_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20150508_20200909_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20150524_20200909_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20150609_20201015_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20150625_20200909_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20150711_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20150727_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20150812_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20150828_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20150913_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20150929_20200908_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2016/028/006/
# LC08_L1TP_028006_20160424_20200907_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20160526_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20160611_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20160627_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20160713_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20160729_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20160814_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20160830_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20161001_20200906_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2017/028/006/
# LC08_L1TP_028006_20170310_20200904_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20170427_20201015_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20170513_20200904_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20170614_20200903_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20170630_20200903_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20170716_20200903_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20170817_20200903_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20170902_20200903_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2018/028/006/
# LC08_L1TP_028006_20180414_20200901_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20180430_20200901_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20180516_20200901_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20180601_20201015_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20180719_20200831_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20180804_20200831_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20180905_20200831_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20180921_20200830_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2019/028/006/
# LC08_L1TP_028006_20190316_20200829_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20190401_20200829_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20190417_20200829_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20190620_20200830_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20190807_20200827_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20190823_20200828_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20190908_20200828_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20191010_20200825_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2020/028/006/
# LC08_L1TP_028006_20200318_20200822_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20200403_20200822_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20200419_20200822_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20200505_20200820_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20200521_20200820_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20200606_20200825_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20200622_20200824_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20200724_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20200809_20200918_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20200910_20200919_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20200926_20201007_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2021/028/006/
# LC08_L1TP_028006_20210305_20210311_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20210321_20210401_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20210422_20210430_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20210508_20210518_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20210524_20210529_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20210609_20210615_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20210711_20210720_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20210812_20210819_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_028006_20210929_20211013_02_T1_MTL.txt exists. Skip.
# Downloaded metadata files are stored in: /media/jukes/jukes1/LS8aws/Path027_Row006_c2/
# Path027_Row006_c2  exists already, skip directory creation
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/1999/027/006/
# LE07_L1TP_027006_19990630_20200918_02_T1_MTL.txt exists. Skip.
# LE07_L1TP_027006_19990716_20200918_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/2000/027/006/
# LE07_L1TP_027006_20000531_20200918_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/2001/027/006/
# LE07_L1TP_027006_20010331_20200917_02_T1_MTL.txt exists. Skip.
# LE07_L1TP_027006_20010822_20200917_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/2002/027/006/
# LE07_L1TP_027006_20020622_20200916_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/2003/027/006/
# LE07_L1TP_027006_20030406_20200915_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2013/027/006/
# LC08_L1TP_027006_20130831_20200913_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20130916_20200913_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2014/027/006/
# LC08_L1TP_027006_20140412_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20140701_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20140802_20200911_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2015/027/006/
# LC08_L1TP_027006_20150314_20200909_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20150330_20200909_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20150415_20200909_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20150501_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20150517_20201015_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20150602_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20150618_20200909_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20150720_20200909_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20150805_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20150821_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20150906_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20150922_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20151008_20200908_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2016/027/006/
# LC08_L1TP_027006_20160229_20200907_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20160417_20200907_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20160503_20200907_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20160620_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20160706_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20160722_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20160807_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20160823_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20160908_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20160924_20200906_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2017/027/006/
# LC08_L1TP_027006_20170319_20200904_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20170404_20200904_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20170506_20200904_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20170623_20200903_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20170709_20200903_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20170725_20200903_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20170826_20200903_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20170927_20200903_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20171013_20200902_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2018/027/006/
# LC08_L1TP_027006_20180407_20200901_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20180423_20200901_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20180509_20200901_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20180626_20200831_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20180813_20200831_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20180829_20200831_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20180930_20200830_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2019/027/006/
# LC08_L1TP_027006_20190309_20200829_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20190325_20200829_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20190410_20200828_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20190426_20200829_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20190512_20200829_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20190528_20200828_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20190613_20200829_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20190629_20200830_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20190731_20200828_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20190816_20200827_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20190901_20200827_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20191003_20200825_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2020/027/006/
# LC08_L1TP_027006_20200327_20200822_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20200530_20200820_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20200615_20200823_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2021/027/006/
# LC08_L1TP_027006_20210226_20210303_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20210314_20210328_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20210602_20210608_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20210618_20210628_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20210805_20210811_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20210906_20210915_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20210922_20210930_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_027006_20211008_20211018_02_T1_MTL.txt exists. Skip.
# Downloaded metadata files are stored in: /media/jukes/jukes1/LS8aws/Path032_Row005_c2/
# Path032_Row005_c2  exists already, skip directory creation
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/1999/032/005/
# No results found for collection02/level-1/standard/etm/1999/032/005/
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/2000/032/005/
# LE07_L1TP_032005_20000603_20200918_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/2001/032/005/
# LE07_L1TP_032005_20010606_20200917_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/2002/032/005/
# LE07_L1TP_032005_20020609_20200916_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/2003/032/005/
# No results found for collection02/level-1/standard/etm/2003/032/005/
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2013/032/005/
# LC08_L1TP_032005_20130514_20200913_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20130903_20200913_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20130919_20200913_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2014/032/005/
# LC08_L1TP_032005_20140314_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20140415_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20140602_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20140704_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20140720_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20140805_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20140906_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20140922_20200910_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2015/032/005/
# LC08_L1TP_032005_20150402_20200909_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20150418_20200909_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20150504_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20150520_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20150605_20200909_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20150621_20201015_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20150707_20200909_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20150723_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20150808_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20150824_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20150909_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20150925_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20151011_20200908_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2016/032/005/
# LC08_L1TP_032005_20160303_20200907_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20160319_20200907_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20160420_20200907_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20160506_20200907_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20160522_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20160607_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20160709_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20160725_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20160810_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20160826_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20160911_20200906_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2017/032/005/
# LC08_L1TP_032005_20170322_20200904_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20170407_20200904_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20170423_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20170509_20200904_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20170610_20200903_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20170712_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20170728_20200903_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20170829_20200903_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20170914_20200903_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20170930_20200903_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2018/032/005/
# LC08_L1TP_032005_20180309_20200901_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20180325_20200901_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20180410_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20180426_20200901_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20180512_20200901_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20180528_20201015_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20180613_20200831_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20180629_20200831_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20180731_20200831_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20180816_20200831_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20180917_20200830_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20181003_20200830_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2019/032/005/
# LC08_L1TP_032005_20190312_20200829_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20190413_20200828_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20190515_20200828_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20190531_20200828_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20190616_20200830_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20190702_20200829_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20190803_20200827_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20190819_20200827_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20190904_20200826_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20190920_20200826_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20191006_20200825_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2020/032/005/
# LC08_L1TP_032005_20200314_20200822_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20200330_20200822_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20200415_20200822_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20200501_20200820_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20200517_20200820_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20200618_20200823_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20200704_20200913_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20200720_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20200805_20200916_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20200821_20200905_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20200906_20200918_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20200922_20201007_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20201008_20201015_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2021/032/005/
# LC08_L1TP_032005_20210418_20210424_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20210504_20210517_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20210520_20210528_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20210605_20210614_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20210621_20210629_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20210707_20210713_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20210723_20210729_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20210808_20210819_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20210824_20210901_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20210909_20210916_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_032005_20210925_20210930_02_T1_MTL.txt exists. Skip.
# Downloaded metadata files are stored in: /media/jukes/jukes1/LS8aws/Path031_Row005_c2/
# Path031_Row005_c2  exists already, skip directory creation
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/1999/031/005/
# No results found for collection02/level-1/standard/etm/1999/031/005/
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/2000/031/005/
# LE07_L1TP_031005_20000628_20200918_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/2001/031/005/
# LE07_L1TP_031005_20010615_20200917_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/2002/031/005/
# LE07_L1TP_031005_20020618_20200916_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/etm/2003/031/005/
# No results found for collection02/level-1/standard/etm/2003/031/005/
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2013/031/005/
# LC08_L1TP_031005_20130402_20200912_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20130523_20200913_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20130827_20200912_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20130928_20200912_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2014/031/005/
# LC08_L1TP_031005_20140323_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20140408_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20140526_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20140627_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20140713_20201015_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20140814_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20140830_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20140915_20200911_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20141001_20200910_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2015/031/005/
# LC08_L1TP_031005_20150310_20200909_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20150326_20200909_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20150411_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20150427_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20150513_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20150529_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20150614_20201015_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20150630_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20150716_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20150801_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20150817_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20150902_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20150918_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20151004_20200908_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2016/031/005/
# LC08_L1TP_031005_20160312_20200907_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20160328_20200907_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20160413_20200907_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20160429_20200907_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20160515_20200907_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20160531_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20160616_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20160702_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20160718_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20160803_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20160904_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20161006_20200906_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2017/031/005/
# LC08_L1TP_031005_20170315_20200904_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20170331_20200904_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20170416_20200904_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20170502_20200904_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20170603_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20170619_20200903_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20170705_20200903_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20170721_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20170822_20201016_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20170923_20200903_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2018/031/005/
# LC08_L1TP_031005_20180302_20200902_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20180318_20200901_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20180403_20200901_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20180419_20200901_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20180521_20200901_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20180606_20200831_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20180622_20201015_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20180708_20200831_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20180724_20200831_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20180825_20200831_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20180910_20200830_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20180926_20200830_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20181012_20200830_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2019/031/005/
# LC08_L1TP_031005_20190321_20200829_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20190422_20200828_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20190508_20200830_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20190524_20201015_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20190609_20200828_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20190625_20200829_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20190711_20200829_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20190727_20200828_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20190913_20200827_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20190929_20200825_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2020/031/005/
# LC08_L1TP_031005_20200307_20200822_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20200408_20200822_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20200424_20200822_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20200510_20200820_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20200526_20200820_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20200627_20200823_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20200713_20200912_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20200729_20200908_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20200814_20200920_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20200830_20200906_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20200915_20200919_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20201001_20201007_02_T1_MTL.txt exists. Skip.
# aws s3 ls --profile terminusmapping --request-payer requester s3://usgs-landsat/collection02/level-1/standard/oli-tirs/2021/031/005/
# LC08_L1TP_031005_20210310_20210317_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20210326_20210402_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20210513_20210524_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20210529_20210608_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20210614_20210622_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20210630_20210708_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20210716_20210729_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20210902_20210910_02_T1_MTL.txt exists. Skip.
# LC08_L1TP_031005_20210918_20210925_02_T1_MTL.txt exists. Skip.

# %% [markdown]
# # 4) Calculate cloud % over terminus box using Landsat quality band
#
# If the terminus box shapefiles were not originally in UTM projection, will need to reproject them into UTM to match the Landsat projection. The code automatically finds the UTM zones from the metadata files and fills in the following syntax to reproject:
#
#     ogr2ogr -f "ESRI Shapefile" -t_srs EPSG:326zone output.shp input.shp
#
# #### If the terminus box shapefiles are already in UTM projection, skip the following cell and rename the files to end with "\_UTM\_##.shp" where ## corresponds to the zone number (e.g., "\_UTM\_07.shp", "\_UTM\_21.shp").

# %%
zones = {} # initialize dictionary to hold UTM zone for each Landsat scene path row
zone_list = [] # list of zones

# Loop through all scenes:
for index, row in boxes_pr_df.iterrows():
    BoxID = str(index)
    p = row['Path']; r = row['Row']; folder_name = 'Path'+p+'_Row'+r+'_c2' # Landsat path and row
    pr_folderpath = downloadpath+folder_name+'/' # path to the downloaded metadata files
    pathtoshp = basepath+"Box"+BoxID+"/Box"+BoxID # path to the terminus box shapefiles (all projections)
    
    if len(os.listdir(pr_folderpath)) > 0: # if there are files in the folder
        # grab UTM Zone from the first metadata file
        mtl_scene = glob.glob(pr_folderpath+'*_MTL.txt')[0]
        mtl = open(mtl_scene, 'r')
        
        # loop through lines in the metadata file to find the UTM ZONE
        for line in mtl:  
            variable = line.split("=")[0] # grab the variable name
            if ("UTM_ZONE" in variable):
                zone = '%02d' % int(line.split("=")[1][1:-1]) # grab the 2-digit zone number
                zones.update({folder_name: zone}); zone_list.append(zone) # add to zone lists
                break
                
        # reproject shapefile(s) into UTM
        zone = zones[folder_name]
        rp_shp = 'ogr2ogr -f "ESRI Shapefile" '+pathtoshp+'_UTM_'+zone+'.shp '+pathtoshp+'_WGS.shp'
        rp_shp += ' -t_srs EPSG:326'+zone
        subprocess.run(rp_shp, shell=True,check=True)
        
    else: # if no files in folder, zone = nan, must fill in manually
        zone_list.append(np.nan)
        
boxes_pr_df['Zone'] = zone_list # add to the path row dataframe
boxes_pr_df.head()
# Out:
#       Unnamed: 0 Path  Row Zone
# BoxID
# 008            0  031  006   19
# 008            1  030  006   19
# 008            2  029  006   19
# 008            3  028  006   19
# 008            4  027  006   20

# %%
# overwrite path row csv file with UTM zone information, see above for variable PR_FILENAME
boxes_pr_df.to_csv(path_or_buf = basepath+PR_FILENAME, sep=',')

# %% [markdown]
# Use GDAL and __vsi3__ link to download subset of the quality band we will use to determine cloud cover over the terminus:
#
#     gdalwarp -cutline path_to_shp.shp -crop_to_cutline /vsi3/usgs-landsat/collection02/level-1/standard/oli-tirs/yyyy/path/row/scene/scene_QA_PIXEL.TIF path_to_subset_QA_PIXEL.TIF

# %%
# Loop through all scenes:
for index, row in boxes_pr_df.iterrows():
    p = row['Path']; r = row['Row']; zone = row['Zone'] # grab path, row, zone
    BoxID = str(index)
    folder_name = 'Path'+p+'_Row'+r+'_c2'
    pr_folderpath = downloadpath+folder_name+'/' # path to the downloaded metadata files
    pathtoshp = basepath+"Box"+BoxID+"/Box"+BoxID # path to the terminus box shapefiles (all projections)
    pathtoshp_rp = pathtoshp+'_UTM_'+zone # path to the UTM projected box shapefile

    files = os.listdir(pr_folderpath) # grab the names of the Landsat scenes
    
    # for all files in the path row folders
    for file in files:
        scene = file[:40] # slice the filename to grab the scene name

        if scene.startswith('L') and 'T1' in scene: # L1TP scenes
            scene_year = scene[17:21] # grab the year from the scene name
            
            if scene.startswith('LC08'):
                collectionfolder='oli-tirs/'
            elif scene.startswith('LE07'):
                collectionfolder='etm/'
                
            # set path to the QA pixel Landsat files
            pathtoQAPIXEL='/vsis3/usgs-landsat/'+collectionpath+collectionfolder
            pathtoQAPIXEL+=scene_year+'/'
            pathtoQAPIXEL+=p+'/'+r+'/'
            pathtoQAPIXEL+=scene+'/'+scene+"_QA_PIXEL.TIF"
            
            # set path to the subset QA pixel files inside the path row folders
            subsetout = pr_folderpath+scene+'_QA_PIXEL_Box'+BoxID+'.TIF' 
            
            # if the file hasn't already been downloaded
            if not os.path.exists(subsetout):
                print('Downloading', scene)
                # construct download command
                QAPIXEL_dwnld_cmd='gdalwarp -overwrite -cutline '+pathtoshp_rp+'.shp -crop_to_cutline '
                QAPIXEL_dwnld_cmd+= pathtoQAPIXEL+' '+subsetout
                QAPIXEL_dwnld_cmd+=' --config AWS_REQUEST_PAYER requester --config AWS_REGION us-west-2'
                QAPIXEL_dwnld_cmd+=' --config AWS_SECRET_ACCESS_KEY '+SECRET_KEY
                QAPIXEL_dwnld_cmd+=' --config AWS_ACCESS_KEY_ID '+ACCESS_KEY

                subprocess.run(QAPIXEL_dwnld_cmd, shell=True, check=True)
# Out:
# Downloading LC08_L1TP_031006_20180505_20200901_02_T1
# Downloading LC08_L1TP_031006_20200627_20200823_02_T1
# Downloading LC08_L1TP_031006_20140526_20200911_02_T1
# Downloading LC08_L1TP_031006_20150716_20200908_02_T1
# Downloading LC08_L1TP_031006_20190913_20200826_02_T1
# Downloading LC08_L1TP_031006_20190711_20200828_02_T1
# Downloading LC08_L1TP_031006_20140814_20200911_02_T1
# Downloading LC08_L1TP_031006_20150614_20200909_02_T1
# Downloading LC08_L1TP_031006_20170619_20200903_02_T1
# Downloading LC08_L1TP_031006_20180403_20200901_02_T1
# Downloading LC08_L1TP_031006_20170416_20201015_02_T1
# Downloading LC08_L1TP_031006_20140915_20200911_02_T1
# Downloading LC08_L1TP_031006_20200713_20200912_02_T1
# Downloading LC08_L1TP_031006_20160616_20201016_02_T1
# Downloading LC08_L1TP_031006_20161006_20200906_02_T1
# Downloading LC08_L1TP_031006_20190929_20200825_02_T1
# Downloading LC08_L1TP_031006_20150411_20200909_02_T1
# Downloading LC08_L1TP_031006_20140830_20200911_02_T1
# Downloading LC08_L1TP_031006_20170705_20201016_02_T1
# Downloading LC08_L1TP_031006_20141001_20200910_02_T1
# Downloading LC08_L1TP_031006_20160531_20200906_02_T1
# Downloading LC08_L1TP_031006_20150918_20200908_02_T1
# Downloading LC08_L1TP_031006_20160312_20200907_02_T1
# Downloading LC08_L1TP_031006_20210918_20210925_02_T1
# Downloading LC08_L1TP_031006_20210902_20210910_02_T1
# Downloading LC08_L1TP_031006_20170822_20200903_02_T1
# Downloading LC08_L1TP_031006_20200814_20200919_02_T1
# Downloading LC08_L1TP_031006_20150902_20200908_02_T1
# Downloading LC08_L1TP_031006_20180825_20200831_02_T1
# Downloading LE07_L1TP_031006_19990829_20200918_02_T1
# Downloading LC08_L1TP_031006_20210529_20210608_02_T1
# Downloading LC08_L1TP_031006_20150513_20201015_02_T1
# Downloading LC08_L1TP_031006_20160429_20200907_02_T1
# Downloading LC08_L1TP_031006_20140713_20201015_02_T1
# Downloading LC08_L1TP_031006_20150529_20201015_02_T1
# Downloading LC08_L1TP_031006_20190609_20200829_02_T1
# Downloading LC08_L1TP_031006_20180708_20200831_02_T1
# Downloading LC08_L1TP_031006_20180606_20201015_02_T1
# Downloading LC08_L1TP_031006_20210614_20210622_02_T1
# Downloading LC08_L1TP_031006_20170502_20200904_02_T1
# Downloading LC08_L1TP_031006_20190625_20200829_02_T1
# Downloading LC08_L1TP_031006_20200424_20200822_02_T1
# Downloading LC08_L1TP_031006_20200830_20200906_02_T1
# Downloading LC08_L1TP_031006_20180926_20200830_02_T1
# Downloading LC08_L1TP_031006_20140627_20200911_02_T1
# Downloading LC08_L1TP_031006_20180910_20200830_02_T1
# Downloading LC08_L1TP_031006_20190422_20200828_02_T1
# Downloading LC08_L1TP_031006_20130827_20200912_02_T1
# Downloading LC08_L1TP_031006_20160225_20200907_02_T1
# Downloading LC08_L1TP_031006_20170721_20200903_02_T1
# Downloading LC08_L1TP_031006_20180622_20200831_02_T1
# Downloading LC08_L1TP_031006_20150310_20200909_02_T1
# Downloading LC08_L1TP_031006_20200729_20200908_02_T1
# Downloading LC08_L1TP_031006_20160803_20200906_02_T1
# Downloading LC08_L1TP_031006_20150630_20200909_02_T1
# Downloading LC08_L1TP_031006_20190812_20200827_02_T1
# Downloading LC08_L1TP_031006_20170315_20200904_02_T1
# Downloading LC08_L1TP_031006_20170227_20200905_02_T1
# Downloading LE07_L1TP_031006_20020330_20200916_02_T1
# Downloading LC08_L1TP_031006_20150817_20200908_02_T1
# Downloading LC08_L1TP_031006_20180521_20200901_02_T1
# Downloading LC08_L1TP_031006_20210310_20210317_02_T1
# Downloading LC08_L1TP_031006_20180419_20200901_02_T1
# Downloading LC08_L1TP_031006_20200408_20200822_02_T1
# Downloading LC08_L1TP_031006_20170923_20200903_02_T1
# Downloading LC08_L1TP_031006_20130928_20200912_02_T1
# Downloading LC08_L1TP_031006_20150427_20200909_02_T1
# Downloading LC08_L1TP_031006_20200307_20200822_02_T1
# Downloading LC08_L1TP_031006_20181012_20200830_02_T1
# Downloading LC08_L1TP_031006_20210326_20210402_02_T1
# Downloading LC08_L1TP_031006_20190727_20200828_02_T1
# Downloading LC08_L1TP_031006_20190321_20200829_02_T1
# Downloading LC08_L1TP_031006_20130523_20200913_02_T1
# Downloading LC08_L1TP_031006_20150801_20200908_02_T1
# Downloading LC08_L1TP_031006_20200915_20200919_02_T1
# Downloading LC08_L1TP_031006_20180724_20200831_02_T1
# Downloading LC08_L1TP_031006_20160904_20200906_02_T1
# Downloading LC08_L1TP_031006_20160515_20200907_02_T1
# Downloading LC08_L1TP_031006_20201001_20201007_02_T1
# Downloading LC08_L1TP_031006_20180318_20200901_02_T1
# Downloading LC08_L1TP_031006_20190524_20201015_02_T1
# Downloading LC08_L1TP_031006_20170331_20200904_02_T1
# Downloading LC08_L1TP_031006_20160702_20200906_02_T1
# Downloading LC08_L1TP_031006_20140323_20200911_02_T1
# Downloading LC08_L1TP_030006_20160913_20200906_02_T1
# Downloading LC08_L1TP_030006_20140519_20200911_02_T1
# Downloading LC08_L1TP_030006_20200908_20200919_02_T1
# Downloading LE07_L1TP_030006_20010405_20200917_02_T1
# Downloading LC08_L1TP_030006_20180311_20200901_02_T1
# Downloading LC08_L1TP_030006_20200604_20200824_02_T1
# Downloading LC08_L1TP_030006_20170511_20201016_02_T1
# Downloading LC08_L1TP_030006_20180903_20200831_02_T1
# Downloading LC08_L1TP_030006_20210623_20210630_02_T1
# Downloading LC08_L1TP_030006_20150404_20200909_02_T1
# Downloading LC08_L1TP_030006_20160321_20200907_02_T1
# Downloading LE07_L1TP_030006_20000520_20200918_02_T1
# Downloading LC08_L1TP_030006_20170425_20201016_02_T1
# Downloading LC08_L1TP_030006_20140924_20200910_02_T1
# Downloading LC08_L1TP_030006_20180615_20201016_02_T1
# Downloading LE07_L1TP_030006_20030529_20200915_02_T1
# Downloading LC08_L1TP_030006_20200417_20200822_02_T1
# Downloading LC08_L1TP_030006_20160929_20200906_02_T1
# Downloading LC08_L1TP_030006_20150506_20201015_02_T1
# Downloading LC08_L1TP_030006_20190501_20200830_02_T1
# Downloading LC08_L1TP_030006_20200924_20201007_02_T1
# Downloading LC08_L1TP_030006_20190922_20200826_02_T1
# Downloading LC08_L1TP_030006_20210725_20210803_02_T1
# Downloading LC08_L1TP_030006_20140604_20200911_02_T1
# Downloading LC08_L1TP_030006_20190602_20200828_02_T1
# Downloading LC08_L1TP_030006_20170730_20200903_02_T1
# Downloading LC08_L1TP_030006_20180919_20200830_02_T1
# Downloading LC08_L1TP_030006_20210607_20210615_02_T1
# Downloading LE07_L1TP_030006_19990705_20200918_02_T1
# Downloading LC08_L1TP_030006_20161015_20200905_02_T1
# Downloading LC08_L1TP_030006_20180327_20200901_02_T1
# Downloading LC08_L1TP_030006_20150709_20200908_02_T1
# Downloading LC08_L1TP_030006_20150826_20200908_02_T1
# Downloading LE07_L1TP_030006_20000605_20200918_02_T1
# Downloading LC08_L1TP_030006_20201010_20201015_02_T1
# Downloading LE07_L1TP_030006_20010811_20200917_02_T1
# Downloading LC08_L1TP_030006_20200316_20200822_02_T1
# Downloading LC08_L1TP_030006_20160625_20200906_02_T1
# Downloading LC08_L1TP_030006_20210911_20210916_02_T1
# Downloading LC08_L1TP_030006_20150607_20201016_02_T1
# Downloading LC08_L1TP_030006_20210927_20210930_02_T1
# Downloading LC08_L1TP_030006_20170916_20200903_02_T1
# Downloading LC08_L1TP_030006_20190314_20200829_02_T1
# Downloading LC08_L1TP_030006_20210709_20210720_02_T1
# Downloading LC08_L1TP_030006_20150319_20200909_02_T1
# Downloading LC08_L1TP_030006_20180701_20200831_02_T1
# Downloading LC08_L1TP_030006_20151013_20200908_02_T1
# Downloading LC08_L1TP_030006_20150810_20200908_02_T1
# Downloading LC08_L1TP_030006_20190821_20200828_02_T1
# Downloading LC08_L1TP_030006_20181005_20200830_02_T1
# Downloading LC08_L1TP_030006_20180428_20200901_02_T1
# Downloading LC08_L1TP_030006_20160711_20200906_02_T1
# Downloading LC08_L1TP_030006_20130516_20200913_02_T1
# Downloading LC08_L1TP_030006_20190415_20200829_02_T1
# Downloading LC08_L1TP_030006_20140228_20200911_02_T1
# Downloading LC08_L1TP_030006_20190704_20200830_02_T1
# Downloading LC08_L1TP_030006_20190805_20200828_02_T1
# Downloading LC08_L1TP_030006_20200401_20200822_02_T1
# Downloading LC08_L1TP_030006_20180412_20201015_02_T1
# Downloading LE07_L1TP_030006_20030716_20200915_02_T1
# Downloading LC08_L1TP_030006_20150725_20200908_02_T1
# Downloading LC08_L1TP_030006_20160524_20200906_02_T1
# Downloading LC08_L1TP_030006_20180514_20200901_02_T1
# Downloading LE07_L1TP_030006_20020323_20200916_02_T1
# Downloading LE07_L1TP_030006_20030411_20200916_02_T1
# Downloading LC08_L1TP_030006_20200722_20200911_02_T1
# Downloading LC08_L1TP_030006_20140807_20200911_02_T1
# Downloading LC08_L1TP_030006_20150522_20201016_02_T1
# Downloading LC08_L1TP_030006_20170815_20200903_02_T1
# Downloading LC08_L1TP_030006_20191008_20200825_02_T1
# Downloading LC08_L1TP_030006_20150420_20200909_02_T1
# Downloading LC08_L1TP_030006_20140706_20200911_02_T1
# Downloading LC08_L1TP_030006_20200807_20200916_02_T1
# Downloading LC08_L1TP_030006_20140908_20200911_02_T1
# Downloading LC08_L1TP_030006_20190906_20200828_02_T1
# Downloading LC08_L1TP_030006_20210506_20210517_02_T1
# Downloading LC08_L1TP_030006_20210420_20210430_02_T1
# Downloading LC08_L1TP_030006_20140823_20200911_02_T1
# Downloading LC08_L1TP_030006_20160406_20200907_02_T1
# Downloading LC08_L1TP_030006_20200503_20200820_02_T1
# Downloading LC08_L1TP_030006_20210404_20210409_02_T1
# Downloading LE07_L1TP_030006_20030513_20200916_02_T1
# Downloading LC08_L1TP_030006_20140417_20200911_02_T1
# Downloading LC08_L1TP_030006_20180717_20200831_02_T1
# Downloading LC08_L1TP_030006_20180802_20200831_02_T1
# Downloading LC08_L1TP_030006_20210522_20210529_02_T1
# Downloading LC08_L1TP_030006_20200706_20200913_02_T1
# Downloading LC08_L1TP_030006_20200229_20200822_02_T1
# Downloading LC08_L1TP_030006_20160727_20200906_02_T1
# Downloading LC08_L1TP_030006_20170714_20201015_02_T1
# Downloading LC08_L1TP_030006_20170409_20200904_02_T1
# Downloading LC08_L1TP_030006_20200620_20200823_02_T1
# Downloading LE07_L1TP_029006_20001004_20200917_02_T1
# Downloading LC08_L1TP_029006_20130914_20200912_02_T1
# Downloading LC08_L1TP_029006_20180405_20200901_02_T1
# Downloading LC08_L1TP_029006_20200528_20200820_02_T1
# Downloading LC08_L1TP_029006_20180523_20200901_02_T1
# Downloading LC08_L1TP_029006_20211006_20211013_02_T1
# Downloading LC08_L1TP_029006_20170402_20200904_02_T1
# Downloading LC08_L1TP_029006_20150616_20201016_02_T1
# Downloading LC08_L1TP_029006_20140410_20200911_02_T1
# Downloading LC08_L1TP_029006_20171011_20200903_02_T1
# Downloading LC08_L1TP_029006_20190611_20201016_02_T1
# Downloading LC08_L1TP_029006_20170520_20200904_02_T1
# Downloading LC08_L1TP_029006_20140309_20200911_02_T1
# Downloading LE07_L1TP_029006_20000427_20200918_02_T1
# Downloading LC08_L1TP_029006_20210328_20210402_02_T1
# Downloading LC08_L1TP_029006_20190627_20200828_02_T1
# Downloading LC08_L1TP_029006_20140901_20200911_02_T1
# Downloading LC08_L1TP_029006_20150718_20201016_02_T1
# Downloading LC08_L1TP_029006_20140917_20200911_02_T1
# Downloading LC08_L1TP_029006_20150328_20200909_02_T1
# Downloading LC08_L1TP_029006_20150803_20200908_02_T1
# Downloading LC08_L1TP_029006_20200901_20200906_02_T1
# Downloading LE07_L1TP_029006_20010414_20200917_02_T1
# Downloading LC08_L1TP_029006_20190814_20200827_02_T1
# Downloading LC08_L1TP_029006_20170621_20200903_02_T1
# Downloading LC08_L1TP_029006_20200613_20200823_02_T1
# Downloading LC08_L1TP_029006_20210702_20210712_02_T1
# Downloading LC08_L1TP_029006_20210312_20210317_02_T1
# Downloading LC08_L1TP_029006_20190830_20200826_02_T1
# Downloading LC08_L1TP_029006_20190526_20200828_02_T1
# Downloading LC08_L1TP_029006_20170925_20200903_02_T1
# Downloading LC08_L1TP_029006_20160501_20200907_02_T1
# Downloading LC08_L1TP_029006_20130829_20200912_02_T1
# Downloading LE07_L1TP_029006_20020722_20200916_02_T1
# Downloading LC08_L1TP_029006_20210429_20210508_02_T1
# Downloading LE07_L1TP_029006_20020823_20200916_02_T1
# Downloading LC08_L1TP_029006_20180624_20200831_02_T1
# Downloading LC08_L1TP_029006_20210718_20210729_02_T1
# Downloading LC08_L1TP_029006_20130930_20200912_02_T1
# Downloading LC08_L1TP_029006_20161008_20200905_02_T1
# Downloading LC08_L1TP_029006_20160602_20200906_02_T1
# Downloading LC08_L1TP_029006_20150429_20201016_02_T1
# Downloading LC08_L1TP_029006_20160618_20200906_02_T1
# Downloading LC08_L1TP_029006_20210616_20210622_02_T1
# Downloading LC08_L1TP_029006_20180421_20200901_02_T1
# Downloading LC08_L1TP_029006_20140731_20200911_02_T1
# Downloading LC08_L1TP_029006_20150904_20200908_02_T1
# Downloading LC08_L1TP_029006_20210920_20210925_02_T1
# Downloading LC08_L1TP_029006_20170707_20200903_02_T1
# Downloading LC08_L1TP_029006_20210819_20210827_02_T1
# Downloading LC08_L1TP_029006_20200731_20200908_02_T1
# Downloading LC08_L1TP_029006_20170723_20200903_02_T1
# Downloading LC08_L1TP_029006_20150920_20200908_02_T1
# Downloading LC08_L1TP_029006_20160922_20200906_02_T1
# Downloading LC08_L1TP_029006_20160704_20200906_02_T1
# Downloading LC08_L1TP_029006_20180912_20200830_02_T1
# Downloading LC08_L1TP_029006_20170317_20200904_02_T1
# Downloading LC08_L1TP_029006_20190729_20200827_02_T1
# Downloading LC08_L1TP_029006_20150515_20201016_02_T1
# Downloading LC08_L1TP_029006_20190323_20200829_02_T1
# Downloading LC08_L1TP_029006_20190713_20200830_02_T1
# Downloading LE07_L1TP_029006_20010516_20200917_02_T1
# Downloading LC08_L1TP_029006_20180304_20200902_02_T1
# Downloading LC08_L1TP_029006_20141003_20200910_02_T1
# Downloading LC08_L1TP_029006_20150531_20200909_02_T1
# Downloading LE07_L1TP_029006_20000513_20200918_02_T1
# Downloading LC08_L1TP_029006_20190424_20200828_02_T1
# Downloading LC08_L1TP_029006_20150413_20200909_02_T1
# Downloading LC08_L1TP_029006_20200309_20200822_02_T1
# Downloading LC08_L1TP_029006_20150312_20200909_02_T1
# Downloading LE07_L1TP_029006_20030404_20200915_02_T1
# Downloading LC08_L1TP_029006_20151006_20200908_02_T1
# Downloading LC08_L1TP_029006_20190510_20200829_02_T1
# Downloading LC08_L1TP_029006_20140629_20200911_02_T1
# Downloading LC08_L1TP_029006_20140613_20200911_02_T1
# Downloading LC08_L1TP_029006_20180726_20200831_02_T1
# Downloading LC08_L1TP_029006_20180928_20200830_02_T1
# Downloading LC08_L1TP_029006_20180507_20201016_02_T1
# Downloading LC08_L1TP_029006_20160805_20200906_02_T1
# Downloading LC08_L1TP_029006_20190915_20200826_02_T1
# Downloading LC08_L1TP_029006_20200816_20200920_02_T1
# Downloading LC08_L1TP_029006_20150819_20200908_02_T1
# Downloading LC08_L1TP_029006_20140715_20201015_02_T1
# Downloading LC08_L1TP_028006_20150828_20200908_02_T1
# Downloading LC08_L1TP_028006_20180430_20200901_02_T1
# Downloading LC08_L1TP_028006_20210305_20210311_02_T1
# Downloading LC08_L1TP_028006_20210524_20210529_02_T1
# Downloading LC08_L1TP_028006_20210711_20210720_02_T1
# Downloading LC08_L1TP_028006_20150609_20201015_02_T1
# Downloading LC08_L1TP_028006_20150422_20200909_02_T1
# Downloading LC08_L1TP_028006_20150913_20200908_02_T1
# Downloading LE07_L1TP_028006_20010322_20200917_02_T1
# Downloading LC08_L1TP_028006_20210508_20210518_02_T1
# Downloading LC08_L1TP_028006_20170513_20200904_02_T1
# Downloading LC08_L1TP_028006_20200926_20201007_02_T1
# Downloading LC08_L1TP_028006_20140708_20200911_02_T1
# Downloading LC08_L1TP_028006_20200318_20200822_02_T1
# Downloading LC08_L1TP_028006_20170716_20200903_02_T1
# Downloading LC08_L1TP_028006_20150711_20200908_02_T1
# Downloading LC08_L1TP_028006_20190316_20200829_02_T1
# Downloading LC08_L1TP_028006_20200403_20200822_02_T1
# Downloading LC08_L1TP_028006_20210422_20210430_02_T1
# Downloading LC08_L1TP_028006_20190908_20200828_02_T1
# Downloading LC08_L1TP_028006_20140505_20200911_02_T1
# Downloading LC08_L1TP_028006_20160526_20200906_02_T1
# Downloading LC08_L1TP_028006_20130907_20200913_02_T1
# Downloading LC08_L1TP_028006_20140825_20200911_02_T1
# Downloading LE07_L1TP_028006_20010930_20200917_02_T1
# Downloading LC08_L1TP_028006_20170902_20200903_02_T1
# Downloading LC08_L1TP_028006_20150305_20200909_02_T1
# Downloading LC08_L1TP_028006_20130923_20200913_02_T1
# Downloading LC08_L1TP_028006_20210321_20210401_02_T1
# Downloading LC08_L1TP_028006_20150508_20200909_02_T1
# Downloading LC08_L1TP_028006_20160611_20200906_02_T1
# Downloading LC08_L1TP_028006_20150929_20200908_02_T1
# Downloading LC08_L1TP_028006_20170630_20200903_02_T1
# Downloading LC08_L1TP_028006_20150812_20201016_02_T1
# Downloading LE07_L1TP_028006_20000623_20200918_02_T1
# Downloading LE07_L1TP_028006_20000506_20200918_02_T1
# Downloading LE07_L1TP_028006_20030803_20200915_02_T1
# Downloading LC08_L1TP_028006_20180601_20201015_02_T1
# Downloading LC08_L1TP_028006_20180516_20200901_02_T1
# Downloading LC08_L1TP_028006_20170817_20200903_02_T1
# Downloading LC08_L1TP_028006_20210609_20210615_02_T1
# Downloading LE07_L1TP_028006_20000404_20200918_02_T1
# Downloading LC08_L1TP_028006_20200809_20200918_02_T1
# Downloading LE07_L1TP_028006_19990723_20200918_02_T1
# Downloading LC08_L1TP_028006_20160814_20200906_02_T1
# Downloading LC08_L1TP_028006_20150321_20201015_02_T1
# Downloading LC08_L1TP_028006_20200419_20200822_02_T1
# Downloading LC08_L1TP_028006_20150625_20200909_02_T1
# Downloading LC08_L1TP_028006_20190620_20200830_02_T1
# Downloading LE07_L1TP_028006_20030413_20200915_02_T1
# Downloading LC08_L1TP_028006_20160627_20200906_02_T1
# Downloading LC08_L1TP_028006_20180905_20200831_02_T1
# Downloading LC08_L1TP_028006_20190823_20200828_02_T1
# Downloading LC08_L1TP_028006_20200910_20200919_02_T1
# Downloading LC08_L1TP_028006_20190807_20200827_02_T1
# Downloading LC08_L1TP_028006_20170427_20201015_02_T1
# Downloading LC08_L1TP_028006_20191010_20200825_02_T1
# Downloading LC08_L1TP_028006_20140318_20200911_02_T1
# Downloading LC08_L1TP_028006_20180719_20200831_02_T1
# Downloading LC08_L1TP_028006_20190417_20200829_02_T1
# Downloading LC08_L1TP_028006_20150727_20200908_02_T1
# Downloading LC08_L1TP_028006_20161001_20200906_02_T1
# Downloading LC08_L1TP_028006_20210812_20210819_02_T1
# Downloading LC08_L1TP_028006_20200521_20200820_02_T1
# Downloading LC08_L1TP_028006_20210929_20211013_02_T1
# Downloading LC08_L1TP_028006_20160713_20200906_02_T1
# Downloading LC08_L1TP_028006_20140521_20200911_02_T1
# Downloading LC08_L1TP_028006_20180804_20200831_02_T1
# Downloading LE07_L1TP_028006_20020325_20200916_02_T1
# Downloading LC08_L1TP_028006_20190401_20200829_02_T1
# Downloading LC08_L1TP_028006_20170614_20200903_02_T1
# Downloading LC08_L1TP_028006_20170310_20200904_02_T1
# Downloading LC08_L1TP_028006_20150406_20201016_02_T1
# Downloading LC08_L1TP_028006_20200606_20200825_02_T1
# Downloading LC08_L1TP_028006_20160729_20200906_02_T1
# Downloading LE07_L1TP_028006_20010407_20200917_02_T1
# Downloading LC08_L1TP_028006_20160830_20200906_02_T1
# Downloading LC08_L1TP_028006_20200622_20200824_02_T1
# Downloading LC08_L1TP_028006_20160424_20200907_02_T1
# Downloading LC08_L1TP_028006_20140302_20200911_02_T1
# Downloading LC08_L1TP_028006_20180921_20200830_02_T1
# Downloading LC08_L1TP_028006_20200724_20200911_02_T1
# Downloading LC08_L1TP_028006_20200505_20200820_02_T1
# Downloading LC08_L1TP_028006_20150524_20200909_02_T1
# Downloading LC08_L1TP_028006_20180414_20200901_02_T1
# Downloading LE07_L1TP_027006_20010331_20200917_02_T1
# Downloading LC08_L1TP_027006_20170506_20200904_02_T1
# Downloading LC08_L1TP_027006_20190410_20200828_02_T1
# Downloading LC08_L1TP_027006_20160924_20200906_02_T1
# Downloading LC08_L1TP_027006_20210618_20210628_02_T1
# Downloading LC08_L1TP_027006_20150805_20200908_02_T1
# Downloading LC08_L1TP_027006_20200615_20200823_02_T1
# Downloading LC08_L1TP_027006_20160823_20200906_02_T1
# Downloading LC08_L1TP_027006_20150906_20200908_02_T1
# Downloading LE07_L1TP_027006_20010822_20200917_02_T1
# Downloading LC08_L1TP_027006_20180813_20200831_02_T1
# Downloading LC08_L1TP_027006_20170709_20200903_02_T1
# Downloading LC08_L1TP_027006_20210226_20210303_02_T1
# Downloading LC08_L1TP_027006_20190325_20200829_02_T1
# Downloading LC08_L1TP_027006_20190512_20200829_02_T1
# Downloading LE07_L1TP_027006_20000531_20200918_02_T1
# Downloading LC08_L1TP_027006_20160722_20200906_02_T1
# Downloading LC08_L1TP_027006_20190629_20200830_02_T1
# Downloading LE07_L1TP_027006_20030406_20200915_02_T1
# Downloading LC08_L1TP_027006_20180829_20200831_02_T1
# Downloading LC08_L1TP_027006_20210805_20210811_02_T1
# Downloading LC08_L1TP_027006_20150602_20201016_02_T1
# Downloading LC08_L1TP_027006_20150330_20200909_02_T1
# Downloading LC08_L1TP_027006_20150517_20201015_02_T1
# Downloading LC08_L1TP_027006_20170319_20200904_02_T1
# Downloading LC08_L1TP_027006_20160417_20200907_02_T1
# Downloading LC08_L1TP_027006_20190731_20200828_02_T1
# Downloading LC08_L1TP_027006_20180930_20200830_02_T1
# Downloading LC08_L1TP_027006_20190816_20200827_02_T1
# Downloading LC08_L1TP_027006_20151008_20200908_02_T1
# Downloading LC08_L1TP_027006_20170927_20200903_02_T1
# Downloading LC08_L1TP_027006_20190901_20200827_02_T1
# Downloading LC08_L1TP_027006_20150314_20200909_02_T1
# Downloading LC08_L1TP_027006_20210922_20210930_02_T1
# Downloading LC08_L1TP_027006_20190528_20200828_02_T1
# Downloading LC08_L1TP_027006_20150922_20200908_02_T1
# Downloading LC08_L1TP_027006_20140802_20200911_02_T1
# Downloading LC08_L1TP_027006_20180407_20200901_02_T1
# Downloading LC08_L1TP_027006_20211008_20211018_02_T1
# Downloading LC08_L1TP_027006_20170623_20200903_02_T1
# Downloading LC08_L1TP_027006_20171013_20200902_02_T1
# Downloading LC08_L1TP_027006_20180423_20200901_02_T1
# Downloading LC08_L1TP_027006_20190426_20200829_02_T1
# Downloading LC08_L1TP_027006_20140412_20200911_02_T1
# Downloading LC08_L1TP_027006_20200327_20200822_02_T1
# Downloading LC08_L1TP_027006_20191003_20200825_02_T1
# Downloading LC08_L1TP_027006_20160620_20201016_02_T1
# Downloading LC08_L1TP_027006_20160908_20200906_02_T1
# Downloading LC08_L1TP_027006_20140701_20200911_02_T1
# Downloading LC08_L1TP_027006_20200530_20200820_02_T1
# Downloading LE07_L1TP_027006_19990630_20200918_02_T1
# Downloading LC08_L1TP_027006_20150821_20200908_02_T1
# Downloading LC08_L1TP_027006_20160503_20200907_02_T1
# Downloading LC08_L1TP_027006_20160229_20200907_02_T1
# Downloading LC08_L1TP_027006_20170404_20200904_02_T1
# Downloading LC08_L1TP_027006_20180509_20200901_02_T1
# Downloading LC08_L1TP_027006_20180626_20200831_02_T1
# Downloading LE07_L1TP_027006_19990716_20200918_02_T1
# Downloading LE07_L1TP_027006_20020622_20200916_02_T1
# Downloading LC08_L1TP_027006_20170725_20200903_02_T1
# Downloading LC08_L1TP_027006_20170826_20200903_02_T1
# Downloading LC08_L1TP_027006_20150720_20200909_02_T1
# Downloading LC08_L1TP_027006_20160807_20201016_02_T1
# Downloading LC08_L1TP_027006_20150501_20201016_02_T1
# Downloading LC08_L1TP_027006_20150618_20200909_02_T1
# Downloading LC08_L1TP_027006_20130831_20200913_02_T1
# Downloading LC08_L1TP_027006_20190309_20200829_02_T1
# Downloading LC08_L1TP_027006_20210906_20210915_02_T1
# Downloading LC08_L1TP_027006_20150415_20200909_02_T1
# Downloading LC08_L1TP_027006_20190613_20200829_02_T1
# Downloading LC08_L1TP_027006_20210602_20210608_02_T1
# Downloading LC08_L1TP_027006_20210314_20210328_02_T1
# Downloading LC08_L1TP_027006_20130916_20200913_02_T1
# Downloading LC08_L1TP_027006_20160706_20200906_02_T1
# Downloading LC08_L1TP_032005_20150504_20201016_02_T1
# Downloading LC08_L1TP_032005_20181003_20200830_02_T1
# Downloading LC08_L1TP_032005_20190819_20200827_02_T1
# Downloading LC08_L1TP_032005_20170610_20200903_02_T1
# Downloading LC08_L1TP_032005_20170407_20200904_02_T1
# Downloading LC08_L1TP_032005_20150707_20200909_02_T1
# Downloading LC08_L1TP_032005_20170728_20200903_02_T1
# Downloading LC08_L1TP_032005_20160607_20200906_02_T1
# Downloading LC08_L1TP_032005_20210925_20210930_02_T1
# Downloading LC08_L1TP_032005_20200922_20201007_02_T1
# Downloading LC08_L1TP_032005_20190616_20200830_02_T1
# Downloading LC08_L1TP_032005_20160522_20201016_02_T1
# Downloading LC08_L1TP_032005_20180613_20200831_02_T1
# Downloading LC08_L1TP_032005_20160319_20200907_02_T1
# Downloading LC08_L1TP_032005_20210824_20210901_02_T1
# Downloading LC08_L1TP_032005_20150723_20201016_02_T1
# Downloading LC08_L1TP_032005_20180629_20200831_02_T1
# Downloading LC08_L1TP_032005_20200704_20200913_02_T1
# Downloading LC08_L1TP_032005_20140314_20200911_02_T1
# Downloading LC08_L1TP_032005_20200821_20200905_02_T1
# Downloading LC08_L1TP_032005_20170423_20201016_02_T1
# Downloading LC08_L1TP_032005_20130514_20200913_02_T1
# Downloading LC08_L1TP_032005_20200314_20200822_02_T1
# Downloading LC08_L1TP_032005_20160810_20200906_02_T1
# Downloading LC08_L1TP_032005_20170712_20201016_02_T1
# Downloading LC08_L1TP_032005_20201008_20201015_02_T1
# Downloading LC08_L1TP_032005_20180731_20200831_02_T1
# Downloading LC08_L1TP_032005_20210520_20210528_02_T1
# Downloading LC08_L1TP_032005_20130919_20200913_02_T1
# Downloading LC08_L1TP_032005_20200501_20200820_02_T1
# Downloading LC08_L1TP_032005_20160725_20200906_02_T1
# Downloading LC08_L1TP_032005_20160420_20200907_02_T1
# Downloading LC08_L1TP_032005_20210418_20210424_02_T1
# Downloading LC08_L1TP_032005_20180426_20200901_02_T1
# Downloading LC08_L1TP_032005_20210723_20210729_02_T1
# Downloading LC08_L1TP_032005_20150402_20200909_02_T1
# Downloading LC08_L1TP_032005_20200906_20200918_02_T1
# Downloading LC08_L1TP_032005_20150520_20201016_02_T1
# Downloading LC08_L1TP_032005_20140415_20200911_02_T1
# Downloading LC08_L1TP_032005_20150925_20200908_02_T1
# Downloading LC08_L1TP_032005_20210504_20210517_02_T1
# Downloading LC08_L1TP_032005_20190515_20200828_02_T1
# Downloading LC08_L1TP_032005_20180917_20200830_02_T1
# Downloading LC08_L1TP_032005_20170829_20200903_02_T1
# Downloading LC08_L1TP_032005_20210707_20210713_02_T1
# Downloading LC08_L1TP_032005_20191006_20200825_02_T1
# Downloading LC08_L1TP_032005_20200330_20200822_02_T1
# Downloading LE07_L1TP_032005_20020609_20200916_02_T1
# Downloading LC08_L1TP_032005_20180309_20200901_02_T1
# Downloading LC08_L1TP_032005_20150621_20201015_02_T1
# Downloading LC08_L1TP_032005_20210808_20210819_02_T1
# Downloading LC08_L1TP_032005_20180528_20201015_02_T1
# Downloading LC08_L1TP_032005_20160911_20200906_02_T1
# Downloading LC08_L1TP_032005_20210605_20210614_02_T1
# Downloading LE07_L1TP_032005_20010606_20200917_02_T1
# Downloading LC08_L1TP_032005_20190920_20200826_02_T1
# Downloading LC08_L1TP_032005_20150418_20200909_02_T1
# Downloading LC08_L1TP_032005_20190413_20200828_02_T1
# Downloading LC08_L1TP_032005_20150808_20200908_02_T1
# Downloading LC08_L1TP_032005_20210621_20210629_02_T1
# Downloading LC08_L1TP_032005_20210909_20210916_02_T1
# Downloading LC08_L1TP_032005_20180816_20200831_02_T1
# Downloading LC08_L1TP_032005_20170322_20200904_02_T1
# Downloading LC08_L1TP_032005_20190904_20200826_02_T1
# Downloading LC08_L1TP_032005_20180410_20201016_02_T1
# Downloading LC08_L1TP_032005_20170914_20200903_02_T1
# Downloading LC08_L1TP_032005_20170509_20200904_02_T1
# Downloading LC08_L1TP_032005_20160506_20200907_02_T1
# Downloading LC08_L1TP_032005_20151011_20200908_02_T1
# Downloading LC08_L1TP_032005_20170930_20200903_02_T1
# Downloading LC08_L1TP_032005_20190702_20200829_02_T1
# Downloading LC08_L1TP_032005_20200415_20200822_02_T1
# Downloading LC08_L1TP_032005_20200720_20200911_02_T1
# Downloading LC08_L1TP_032005_20140720_20200911_02_T1
# Downloading LC08_L1TP_032005_20150824_20200908_02_T1
# Downloading LC08_L1TP_032005_20160303_20200907_02_T1
# Downloading LC08_L1TP_032005_20150605_20200909_02_T1
# Downloading LC08_L1TP_032005_20190531_20200828_02_T1
# Downloading LC08_L1TP_032005_20150909_20200908_02_T1
# Downloading LC08_L1TP_032005_20180512_20200901_02_T1
# Downloading LC08_L1TP_032005_20130903_20200913_02_T1
# Downloading LC08_L1TP_032005_20140805_20200911_02_T1
# Downloading LC08_L1TP_032005_20160709_20200906_02_T1
# Downloading LC08_L1TP_032005_20160826_20200906_02_T1
# Downloading LC08_L1TP_032005_20180325_20200901_02_T1
# Downloading LC08_L1TP_032005_20200517_20200820_02_T1
# Downloading LC08_L1TP_032005_20140906_20200911_02_T1
# Downloading LC08_L1TP_032005_20140602_20200911_02_T1
# Downloading LE07_L1TP_032005_20000603_20200918_02_T1
# Downloading LC08_L1TP_032005_20190312_20200829_02_T1
# Downloading LC08_L1TP_032005_20200618_20200823_02_T1
# Downloading LC08_L1TP_032005_20140704_20200911_02_T1
# Downloading LC08_L1TP_032005_20190803_20200827_02_T1
# Downloading LC08_L1TP_032005_20140922_20200910_02_T1
# Downloading LC08_L1TP_032005_20200805_20200916_02_T1
# Downloading LE07_L1TP_031005_20000628_20200918_02_T1
# Downloading LC08_L1TP_031005_20180910_20200830_02_T1
# Downloading LC08_L1TP_031005_20160413_20200907_02_T1
# Downloading LC08_L1TP_031005_20170603_20201016_02_T1
# Downloading LC08_L1TP_031005_20150614_20201015_02_T1
# Downloading LC08_L1TP_031005_20151004_20200908_02_T1
# Downloading LC08_L1TP_031005_20150801_20200908_02_T1
# Downloading LC08_L1TP_031005_20150310_20200909_02_T1
# Downloading LC08_L1TP_031005_20130827_20200912_02_T1
# Downloading LC08_L1TP_031005_20190711_20200829_02_T1
# Downloading LC08_L1TP_031005_20170705_20200903_02_T1
# Downloading LC08_L1TP_031005_20161006_20200906_02_T1
# Downloading LC08_L1TP_031005_20200307_20200822_02_T1
# Downloading LC08_L1TP_031005_20210902_20210910_02_T1
# Downloading LC08_L1TP_031005_20150918_20200908_02_T1
# Downloading LC08_L1TP_031005_20210326_20210402_02_T1
# Downloading LC08_L1TP_031005_20140915_20200911_02_T1
# Downloading LC08_L1TP_031005_20201001_20201007_02_T1
# Downloading LC08_L1TP_031005_20180403_20200901_02_T1
# Downloading LC08_L1TP_031005_20180419_20200901_02_T1
# Downloading LE07_L1TP_031005_20020618_20200916_02_T1
# Downloading LC08_L1TP_031005_20210630_20210708_02_T1
# Downloading LC08_L1TP_031005_20150817_20200908_02_T1
# Downloading LE07_L1TP_031005_20010615_20200917_02_T1
# Downloading LC08_L1TP_031005_20200526_20200820_02_T1
# Downloading LC08_L1TP_031005_20150529_20201016_02_T1
# Downloading LC08_L1TP_031005_20180708_20200831_02_T1
# Downloading LC08_L1TP_031005_20180318_20200901_02_T1
# Downloading LC08_L1TP_031005_20210513_20210524_02_T1
# Downloading LC08_L1TP_031005_20150716_20200908_02_T1
# Downloading LC08_L1TP_031005_20180622_20201015_02_T1
# Downloading LC08_L1TP_031005_20150326_20200909_02_T1
# Downloading LC08_L1TP_031005_20170721_20201016_02_T1
# Downloading LC08_L1TP_031005_20170331_20200904_02_T1
# Downloading LC08_L1TP_031005_20160803_20200906_02_T1
# Downloading LC08_L1TP_031005_20140830_20200911_02_T1
# Downloading LC08_L1TP_031005_20200424_20200822_02_T1
# Downloading LC08_L1TP_031005_20170923_20200903_02_T1
# Downloading LC08_L1TP_031005_20190913_20200827_02_T1
# Downloading LC08_L1TP_031005_20180302_20200902_02_T1
# Downloading LC08_L1TP_031005_20140323_20200911_02_T1
# Downloading LC08_L1TP_031005_20160702_20200906_02_T1
# Downloading LC08_L1TP_031005_20200814_20200920_02_T1
# Downloading LC08_L1TP_031005_20180724_20200831_02_T1
# Downloading LC08_L1TP_031005_20170315_20200904_02_T1
# Downloading LC08_L1TP_031005_20160616_20200906_02_T1
# Downloading LC08_L1TP_031005_20190929_20200825_02_T1
# Downloading LC08_L1TP_031005_20210918_20210925_02_T1
# Downloading LC08_L1TP_031005_20150902_20200908_02_T1
# Downloading LC08_L1TP_031005_20180606_20200831_02_T1
# Downloading LC08_L1TP_031005_20160531_20200906_02_T1
# Downloading LC08_L1TP_031005_20210310_20210317_02_T1
# Downloading LC08_L1TP_031005_20200627_20200823_02_T1
# Downloading LC08_L1TP_031005_20130402_20200912_02_T1
# Downloading LC08_L1TP_031005_20130928_20200912_02_T1
# Downloading LC08_L1TP_031005_20150427_20201016_02_T1
# Downloading LC08_L1TP_031005_20200729_20200908_02_T1
# Downloading LC08_L1TP_031005_20170416_20200904_02_T1
# Downloading LC08_L1TP_031005_20190508_20200830_02_T1
# Downloading LC08_L1TP_031005_20160328_20200907_02_T1
# Downloading LC08_L1TP_031005_20130523_20200913_02_T1
# Downloading LC08_L1TP_031005_20160904_20200906_02_T1
# Downloading LC08_L1TP_031005_20200408_20200822_02_T1
# Downloading LC08_L1TP_031005_20190727_20200828_02_T1
# Downloading LC08_L1TP_031005_20150411_20201016_02_T1
# Downloading LC08_L1TP_031005_20160429_20200907_02_T1
# Downloading LC08_L1TP_031005_20190524_20201015_02_T1
# Downloading LC08_L1TP_031005_20200510_20200820_02_T1
# Downloading LC08_L1TP_031005_20210529_20210608_02_T1
# Downloading LC08_L1TP_031005_20140713_20201015_02_T1
# Downloading LC08_L1TP_031005_20140627_20200911_02_T1
# Downloading LC08_L1TP_031005_20200713_20200912_02_T1
# Downloading LC08_L1TP_031005_20150630_20201016_02_T1
# Downloading LC08_L1TP_031005_20180521_20200901_02_T1
# Downloading LC08_L1TP_031005_20200830_20200906_02_T1
# Downloading LC08_L1TP_031005_20210614_20210622_02_T1
# Downloading LC08_L1TP_031005_20180825_20200831_02_T1
# Downloading LC08_L1TP_031005_20180926_20200830_02_T1
# Downloading LC08_L1TP_031005_20190321_20200829_02_T1
# Downloading LC08_L1TP_031005_20170822_20201016_02_T1
# Downloading LC08_L1TP_031005_20160515_20200907_02_T1
# Downloading LC08_L1TP_031005_20190625_20200829_02_T1
# Downloading LC08_L1TP_031005_20150513_20201016_02_T1
# Downloading LC08_L1TP_031005_20200915_20200919_02_T1
# Downloading LC08_L1TP_031005_20210716_20210729_02_T1
# Downloading LC08_L1TP_031005_20140526_20200911_02_T1
# Downloading LC08_L1TP_031005_20170619_20200903_02_T1
# Downloading LC08_L1TP_031005_20160718_20200906_02_T1
# Downloading LC08_L1TP_031005_20190609_20200828_02_T1
# Downloading LC08_L1TP_031005_20160312_20200907_02_T1
# Downloading LC08_L1TP_031005_20181012_20200830_02_T1
# Downloading LC08_L1TP_031005_20141001_20200910_02_T1
# Downloading LC08_L1TP_031005_20140814_20200911_02_T1
# Downloading LC08_L1TP_031005_20190422_20200828_02_T1
# Downloading LC08_L1TP_031005_20140408_20200911_02_T1
# Downloading LC08_L1TP_031005_20170502_20200904_02_T1

# %% [markdown]
# # 5) Create buffer around terminus boxes
#
# First, we need to grab the buffer distance which we set equal to the maximum dimension of the image (in meters).

# %%
buffers = []
# Calculate a buffer distance around the terminus box:
for BoxID in BoxIDs:
    for file in os.listdir(basepath+'Box'+BoxID+'/'):
        if 'UTM' in file and '.shp' in file and "Box" in file: # identify UTM projected box
            boxpath = basepath+"Box"+BoxID+"/"+file  
            termbox = fiona.open(boxpath)
            
    # grab the box coordinates:
    box = termbox.next(); box_geom= box.get('geometry'); box_coords = box_geom.get('coordinates')[0]
    points = []
    for coord_pair in box_coords:
        lat = coord_pair[0]; lon = coord_pair[1]; points.append([lat, lon])
    # Calculate distance between coord 1 and 2 and between 2 and 3
    coord1 = points[0]; coord2 = points[1]; coord3 = points[2]   
    dist1 = distance(coord1[0], coord1[1], coord2[0], coord2[1]);
    dist2 = distance(coord2[0], coord2[1], coord3[0], coord3[1]) 
    buff_dist = int(np.max([dist1, dist2])) # pick the longer one as the buffer distance
    buffers.append(buff_dist)

# store as dataframe:
buff_df = pd.DataFrame(list(zip(BoxIDs, buffers)), columns=['BoxID', 'Buff_dist_m'])
buff_df
# Out:
# /home/jukes/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: FionaDeprecationWarning: Collection.__next__() is buggy and will be removed in Fiona 2.0. Switch to `next(iter(collection))`.
#   # Remove the CWD from sys.path while we load stuff.
#   BoxID  Buff_dist_m
# 0   008         9438

# %%
# write to csv
buff_df.to_csv(basepath+BOX_FILENAME)

# %% [markdown]
# Then, we create the buffer zone shapefile and reproject it to UTM using GDAL.
#
# To create the buffer zone shapefile, we use the GDAL command **ogr2ogr** with the following syntax:
#
#     ogr2ogr Buffer###.shp path_to_terminusbox###.shp  -dialect sqlite -sql "SELECT ST_Buffer(geometry, buffer_distance) AS geometry,*FROM 'Box###'" -f "ESRI Shapefile"
#
# Then to reproject the the buffer shapefiles to UTM using **gdalwarp**.

# %%
# loop through the buffer distance dataframe:
for index, row in buff_df.iterrows():
    BoxID = row['BoxID']
    zones = boxes_pr_df.loc[BoxID, 'Zone'] # grab zone matching BoxID from other dataframe
    buff_dist = str(row['Buff_dist_m'])
    
    # paths
    terminusbox_path = basepath+"Box"+BoxID+"/Box"+BoxID+".shp" # path to box shapefile
    outputbuffer_path = basepath+"Box"+BoxID+"/Buffer"+BoxID+".shp" # path and name of new buffer file
    
    # Set buffer creation command
    buffer_cmd = 'ogr2ogr '+outputbuffer_path+" "+terminusbox_path
    buffer_cmd +=' -dialect sqlite -sql "SELECT ST_Buffer(geometry, '+buff_dist+") AS geometry,*FROM 'Box"
    buffer_cmd +=BoxID+"'"+'" -f "ESRI Shapefile"'
    print("Command:", buffer_cmd)
    
    subprocess.run(buffer_cmd, shell=True, check=True) # run on terminal
    
    # Reprojection needs to happen for each zone
    for zone in zones:
        rp_shp = 'ogr2ogr -f "ESRI Shapefile" -t_srs EPSG:326'+zone+' -s_srs EPSG:'+source_srs+' '
        rp_shp += outputbuffer_path[:-4]+"_UTM_"+zone+".shp "+outputbuffer_path[:-4]+'.shp'
        subprocess.run(rp_shp, shell=True, check=True) # reproject
# Out:
# Command: ogr2ogr /home/jukes/Documents/Sample_glaciers/Box008/Buffer008.shp /home/jukes/Documents/Sample_glaciers/Box008/Box008.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 9438) AS geometry,*FROM 'Box008'" -f "ESRI Shapefile"

# %% [markdown]
# # 6) Download non-cloudy Landsat images from AWS
#
# To remove cloudy images, we will find the number of pixels in our terminus box that exceed a threshold value in the QA_PIXEL band corresponding to cloud likelihood. If the fraction of cloudy pixels with values is above the threshold, we won't download the image.
#
# Additionally, we remove images that are primarily black (fill value of 0 or 1 in QA_PIXEL band). This ensures that the scenes that cut off halfway across the glacier are not included in further analysis. The fill percent threshold may need to be adjusted.

# %%
######################################################################################
# These are the recommended values. Adjust thresholds here:
QAPIXEL_thresh = 22280.0 # QA pixel value threshold to be considered cloud
cpercent_thresh = 50.0 # maximum cloud cover % in terminus box
fpercent_thresh = 60.0 # maximum fill % in terminus box
######################################################################################

# %%
# Download images that pass these thresholds:
for index, row in boxes_pr_df.iterrows():
    # grab paths
    p = row['Path']; zone = row['Zone']; r = row['Row']; BoxID = index; 
    folder_name = 'Path'+p+'_Row'+r+'_c2'
    pr_folderpath = downloadpath+folder_name+'/'
    bp_out = downloadpath+'Box'+BoxID+'/' # folder name for downloaded images
    if os.path.exists(bp_out): # create folder if it does not exist
        print("Box"+BoxID, " exists already. Skip creation of directory.")
    else:
        os.mkdir(bp_out)
        print("Box"+BoxID+" directory made.")
    
    # path to the shapefile covering the region that will be downloaded
    pathtobuffer = basepath+'Box'+BoxID+'/Buffer'+BoxID+'_UTM_'+zone+'.shp'  # buffer around box - recommended
#     pathtobox = basepath+'Box'+BoxID+'/Box'+BoxID+'_UTM_'+zone+'.shp' # just the box
    
    for scene in os.listdir(pr_folderpath):
        if scene.startswith('L') and scene.endswith(".TIF") and 'T1' in scene: # For Tier-1 images
            scene = scene[:40] # scene name
            year = scene[17:21] # grab acquisition year
            
            if scene.startswith("LC08"): # Landsat 8
                collectionfolder = 'oli-tirs/'; bands = L8_bands
            elif scene.startswith("LE07"): # Landsat 7
                collectionfolder = 'etm/'; bands = L7_bands
 
            QApixelpath = pr_folderpath+scene+'_QA_PIXEL_Box'+BoxID+'.TIF' # path to QA_PIXEL file
            subsetQApixel = mpimg.imread(QApixelpath) # read in as numpy array
            
            # calculate percentages of cloud and fill bixels
            totalpixels = subsetQApixel.shape[0]*subsetQApixel.shape[1] # total number of pixels
            cloudQApixel = subsetQApixel[subsetQApixel > QAPIXEL_thresh] # cloudy pixels (value > QAPIXEL_thresh)
            fillQApixel = subsetQApixel[subsetQApixel < 2.0] # fill pixels (value = 0 or 1)
            cloudpixels = len(cloudQApixel); fillpixels = len(fillQApixel) # count the cloudy and fill pixels
            cloudpercent = int(float(cloudpixels)/float(totalpixels)*100) # calculate percent cloudy
            fillpercent = int(float(fillpixels)/float(totalpixels)*100) # calculate percent fill
            print(scene, 'Cloud % ', cloudpercent, 'Fill %', fillpercent) # check values
            
            # evaluate thresholds
            if cloudpercent <= cpercent_thresh and fillpercent <= fpercent_thresh:
                # download the bands for that scene into your scene folders:
                for band in bands:
                        band = str(band) # string format
                        
                        # input path to your bands in AWS:
                        pathin = '/vsis3/usgs-landsat/'+collectionpath+collectionfolder+year+'/'+p+"/"+r+"/"+scene+"/"+scene+"_B"+band+".TIF"
                        
                        outfilename = scene+"_B"+band+'_Buffer'+BoxID+'.TIF' # output file name
                        pathout = downloadpath+'Box'+BoxID+'/'+outfilename # full output file path
                        
                        # if the file hasn't already been downloaded
                        if not os.path.exists(pathout):
                            # download
                            download_cmd = 'gdalwarp -overwrite -cutline '+pathtobuffer+' -crop_to_cutline '+pathin+' '+pathout
                            download_cmd+=' --config AWS_REQUEST_PAYER requester --config AWS_REGION us-west-2'
                            download_cmd+=' --config AWS_SECRET_ACCESS_KEY '+SECRET_KEY
                            download_cmd+=' --config AWS_ACCESS_KEY_ID '+ACCESS_KEY   
                            print('Downloading:', outfilename)
                            subprocess.run(download_cmd, shell=True, check=True)
                        else:
                            print(outfilename, 'exists')
            else:
                print(scene, 'failed cloud & fill thresholds')
# Out:
# Box008  exists already. Skip creation of directory.
# LC08_L1TP_031006_20181012_20200830_02_T1 Cloud %  59 Fill % 39
# LC08_L1TP_031006_20181012_20200830_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20140627_20200911_02_T1 Cloud %  46 Fill % 39
# LC08_L1TP_031006_20140627_20200911_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20180403_20200901_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20180403_20200901_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20160616_20201016_02_T1 Cloud %  17 Fill % 39
# LC08_L1TP_031006_20160616_20201016_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20170416_20201015_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20170416_20201015_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20190625_20200829_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20190625_20200829_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20180724_20200831_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20180724_20200831_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20140323_20200911_02_T1 Cloud %  26 Fill % 39
# LC08_L1TP_031006_20140323_20200911_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20190524_20201015_02_T1 Cloud %  47 Fill % 39
# LC08_L1TP_031006_20190524_20201015_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20190929_20200825_02_T1 Cloud %  57 Fill % 39
# LC08_L1TP_031006_20190929_20200825_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20150716_20200908_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20150716_20200908_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20160702_20200906_02_T1 Cloud %  50 Fill % 39
# LC08_L1TP_031006_20160702_20200906_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20190321_20200829_02_T1 Cloud %  48 Fill % 39
# LC08_L1TP_031006_20190321_20200829_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20180825_20200831_02_T1 Cloud %  20 Fill % 39
# LC08_L1TP_031006_20180825_20200831_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20160904_20200906_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20160904_20200906_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20160803_20200906_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20160803_20200906_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20190913_20200826_02_T1 Cloud %  12 Fill % 39
# LC08_L1TP_031006_20190913_20200826_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20200814_20200919_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_031006_20200814_20200919_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20180419_20200901_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20180419_20200901_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20190609_20200829_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20190609_20200829_02_T1 failed cloud & fill thresholds
# LE07_L1TP_031006_20020330_20200916_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_031006_20020330_20200916_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20170705_20201016_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20170705_20201016_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20150817_20200908_02_T1 Cloud %  18 Fill % 39
# LC08_L1TP_031006_20150817_20200908_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20210529_20210608_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20210529_20210608_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20150529_20201015_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20150529_20201015_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20190711_20200828_02_T1 Cloud %  4 Fill % 39
# LC08_L1TP_031006_20190711_20200828_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20170502_20200904_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20170502_20200904_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20160225_20200907_02_T1 Cloud %  41 Fill % 39
# LC08_L1TP_031006_20160225_20200907_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20150918_20200908_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_031006_20150918_20200908_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20160515_20200907_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20160515_20200907_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20180926_20200830_02_T1 Cloud %  59 Fill % 39
# LC08_L1TP_031006_20180926_20200830_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20180606_20201015_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20180606_20201015_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20140915_20200911_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20140915_20200911_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20140830_20200911_02_T1 Cloud %  21 Fill % 39
# LC08_L1TP_031006_20140830_20200911_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20180318_20200901_02_T1 Cloud %  34 Fill % 39
# LC08_L1TP_031006_20180318_20200901_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20140713_20201015_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20140713_20201015_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20180521_20200901_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_031006_20180521_20200901_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20200627_20200823_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20200627_20200823_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20210902_20210910_02_T1 Cloud %  33 Fill % 39
# LC08_L1TP_031006_20210902_20210910_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20200729_20200908_02_T1 Cloud %  59 Fill % 39
# LC08_L1TP_031006_20200729_20200908_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20170315_20200904_02_T1 Cloud %  20 Fill % 39
# LC08_L1TP_031006_20170315_20200904_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20200408_20200822_02_T1 Cloud %  55 Fill % 39
# LC08_L1TP_031006_20200408_20200822_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20210326_20210402_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20210326_20210402_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20170822_20200903_02_T1 Cloud %  19 Fill % 39
# LC08_L1TP_031006_20170822_20200903_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20150630_20200909_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20150630_20200909_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20200915_20200919_02_T1 Cloud %  17 Fill % 39
# LC08_L1TP_031006_20200915_20200919_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20170227_20200905_02_T1 Cloud %  57 Fill % 39
# LC08_L1TP_031006_20170227_20200905_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20160312_20200907_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_031006_20160312_20200907_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20180910_20200830_02_T1 Cloud %  20 Fill % 39
# LC08_L1TP_031006_20180910_20200830_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20201001_20201007_02_T1 Cloud %  22 Fill % 39
# LC08_L1TP_031006_20201001_20201007_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20130928_20200912_02_T1 Cloud %  15 Fill % 39
# LC08_L1TP_031006_20130928_20200912_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20170721_20200903_02_T1 Cloud %  1 Fill % 39
# LC08_L1TP_031006_20170721_20200903_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20130523_20200913_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20130523_20200913_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20150427_20200909_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20150427_20200909_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20150411_20200909_02_T1 Cloud %  23 Fill % 39
# LC08_L1TP_031006_20150411_20200909_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20150513_20201015_02_T1 Cloud %  15 Fill % 39
# LC08_L1TP_031006_20150513_20201015_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20170619_20200903_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20170619_20200903_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20170923_20200903_02_T1 Cloud %  17 Fill % 39
# LC08_L1TP_031006_20170923_20200903_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20210310_20210317_02_T1 Cloud %  31 Fill % 39
# LC08_L1TP_031006_20210310_20210317_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20200307_20200822_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20200307_20200822_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20160429_20200907_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20160429_20200907_02_T1 failed cloud & fill thresholds
# LE07_L1TP_031006_19990829_20200918_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_031006_19990829_20200918_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20200424_20200822_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20200424_20200822_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20200830_20200906_02_T1 Cloud %  18 Fill % 39
# LC08_L1TP_031006_20200830_20200906_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20140814_20200911_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20140814_20200911_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20180505_20200901_02_T1 Cloud %  49 Fill % 39
# LC08_L1TP_031006_20180505_20200901_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20160531_20200906_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_031006_20160531_20200906_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20150310_20200909_02_T1 Cloud %  39 Fill % 39
# LC08_L1TP_031006_20150310_20200909_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20210918_20210925_02_T1 Cloud %  3 Fill % 39
# LC08_L1TP_031006_20210918_20210925_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20141001_20200910_02_T1 Cloud %  16 Fill % 39
# LC08_L1TP_031006_20141001_20200910_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20190422_20200828_02_T1 Cloud %  59 Fill % 39
# LC08_L1TP_031006_20190422_20200828_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20150902_20200908_02_T1 Cloud %  14 Fill % 39
# LC08_L1TP_031006_20150902_20200908_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20150614_20200909_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20150614_20200909_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20180708_20200831_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20180708_20200831_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20170331_20200904_02_T1 Cloud %  33 Fill % 39
# LC08_L1TP_031006_20170331_20200904_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20161006_20200906_02_T1 Cloud %  18 Fill % 39
# LC08_L1TP_031006_20161006_20200906_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20190727_20200828_02_T1 Cloud %  13 Fill % 39
# LC08_L1TP_031006_20190727_20200828_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20190812_20200827_02_T1 Cloud %  22 Fill % 39
# LC08_L1TP_031006_20190812_20200827_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20130827_20200912_02_T1 Cloud %  39 Fill % 39
# LC08_L1TP_031006_20130827_20200912_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20150801_20200908_02_T1 Cloud %  44 Fill % 39
# LC08_L1TP_031006_20150801_20200908_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20140526_20200911_02_T1 Cloud %  22 Fill % 39
# LC08_L1TP_031006_20140526_20200911_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20200713_20200912_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_031006_20200713_20200912_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031006_20210614_20210622_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031006_20210614_20210622_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031006_20180622_20200831_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_031006_20180622_20200831_02_T1_B8_Buffer008.TIF exists
# Box008  exists already. Skip creation of directory.
# LC08_L1TP_030006_20200316_20200822_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20200316_20200822_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20210911_20210916_02_T1 Cloud %  48 Fill % 39
# LC08_L1TP_030006_20210911_20210916_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20160727_20200906_02_T1 Cloud %  29 Fill % 39
# LC08_L1TP_030006_20160727_20200906_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20200503_20200820_02_T1 Cloud %  54 Fill % 39
# LC08_L1TP_030006_20200503_20200820_02_T1 failed cloud & fill thresholds
# LE07_L1TP_030006_20030411_20200916_02_T1 Cloud %  0 Fill % 39
# Downloading: LE07_L1TP_030006_20030411_20200916_02_T1_B8_Buffer008.TIF
# LE07_L1TP_030006_20030716_20200915_02_T1 Cloud %  0 Fill % 46
# Downloading: LE07_L1TP_030006_20030716_20200915_02_T1_B8_Buffer008.TIF
# LC08_L1TP_030006_20190922_20200826_02_T1 Cloud %  12 Fill % 39
# LC08_L1TP_030006_20190922_20200826_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20150826_20200908_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_030006_20150826_20200908_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20180514_20200901_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20180514_20200901_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20210709_20210720_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20210709_20210720_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20150725_20200908_02_T1 Cloud %  56 Fill % 39
# LC08_L1TP_030006_20150725_20200908_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20210927_20210930_02_T1 Cloud %  49 Fill % 39
# LC08_L1TP_030006_20210927_20210930_02_T1_B8_Buffer008.TIF exists
# LE07_L1TP_030006_20030513_20200916_02_T1 Cloud %  0 Fill % 39
# Downloading: LE07_L1TP_030006_20030513_20200916_02_T1_B8_Buffer008.TIF
# LC08_L1TP_030006_20180717_20200831_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20180717_20200831_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20180311_20200901_02_T1 Cloud %  20 Fill % 39
# LC08_L1TP_030006_20180311_20200901_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20210607_20210615_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20210607_20210615_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20150506_20201015_02_T1 Cloud %  32 Fill % 39
# LC08_L1TP_030006_20150506_20201015_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20160913_20200906_02_T1 Cloud %  13 Fill % 39
# LC08_L1TP_030006_20160913_20200906_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20170916_20200903_02_T1 Cloud %  59 Fill % 39
# LC08_L1TP_030006_20170916_20200903_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20140417_20200911_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20140417_20200911_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20130516_20200913_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20130516_20200913_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20200417_20200822_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20200417_20200822_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20180919_20200830_02_T1 Cloud %  21 Fill % 39
# LC08_L1TP_030006_20180919_20200830_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20140604_20200911_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_030006_20140604_20200911_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20210420_20210430_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20210420_20210430_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20190415_20200829_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20190415_20200829_02_T1 failed cloud & fill thresholds
# LE07_L1TP_030006_20010405_20200917_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_030006_20010405_20200917_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20190821_20200828_02_T1 Cloud %  26 Fill % 39
# LC08_L1TP_030006_20190821_20200828_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20190704_20200830_02_T1 Cloud %  5 Fill % 39
# LC08_L1TP_030006_20190704_20200830_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20140908_20200911_02_T1 Cloud %  19 Fill % 39
# LC08_L1TP_030006_20140908_20200911_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20170714_20201015_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20170714_20201015_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20170511_20201016_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20170511_20201016_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20150607_20201016_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_030006_20150607_20201016_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20210404_20210409_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20210404_20210409_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20200706_20200913_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20200706_20200913_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20190906_20200828_02_T1 Cloud %  20 Fill % 39
# LC08_L1TP_030006_20190906_20200828_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20190501_20200830_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20190501_20200830_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20140823_20200911_02_T1 Cloud %  42 Fill % 39
# LC08_L1TP_030006_20140823_20200911_02_T1_B8_Buffer008.TIF exists
# LE07_L1TP_030006_20020323_20200916_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_030006_20020323_20200916_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20200401_20200822_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20200401_20200822_02_T1 failed cloud & fill thresholds
# LE07_L1TP_030006_19990705_20200918_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_030006_19990705_20200918_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20160711_20200906_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20160711_20200906_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20190314_20200829_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20190314_20200829_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20170425_20201016_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20170425_20201016_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20160524_20200906_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20160524_20200906_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20210522_20210529_02_T1 Cloud %  55 Fill % 39
# LC08_L1TP_030006_20210522_20210529_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20160321_20200907_02_T1 Cloud %  52 Fill % 39
# LC08_L1TP_030006_20160321_20200907_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20160406_20200907_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20160406_20200907_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20200924_20201007_02_T1 Cloud %  26 Fill % 39
# LC08_L1TP_030006_20200924_20201007_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20150709_20200908_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20150709_20200908_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20200722_20200911_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20200722_20200911_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20210506_20210517_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20210506_20210517_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20170730_20200903_02_T1 Cloud %  41 Fill % 39
# LC08_L1TP_030006_20170730_20200903_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20151013_20200908_02_T1 Cloud %  21 Fill % 39
# LC08_L1TP_030006_20151013_20200908_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20140706_20200911_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20140706_20200911_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20180327_20200901_02_T1 Cloud %  57 Fill % 39
# LC08_L1TP_030006_20180327_20200901_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20170409_20200904_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20170409_20200904_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20140924_20200910_02_T1 Cloud %  38 Fill % 39
# LC08_L1TP_030006_20140924_20200910_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20200620_20200823_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20200620_20200823_02_T1 failed cloud & fill thresholds
# LE07_L1TP_030006_20000520_20200918_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_030006_20000520_20200918_02_T1_B8_Buffer008.TIF exists
# LE07_L1TP_030006_20010811_20200917_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_030006_20010811_20200917_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20200604_20200824_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20200604_20200824_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20190805_20200828_02_T1 Cloud %  13 Fill % 39
# LC08_L1TP_030006_20190805_20200828_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20150810_20200908_02_T1 Cloud %  23 Fill % 39
# LC08_L1TP_030006_20150810_20200908_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20180903_20200831_02_T1 Cloud %  45 Fill % 39
# LC08_L1TP_030006_20180903_20200831_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20140807_20200911_02_T1 Cloud %  7 Fill % 39
# LC08_L1TP_030006_20140807_20200911_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20181005_20200830_02_T1 Cloud %  53 Fill % 39
# LC08_L1TP_030006_20181005_20200830_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20140228_20200911_02_T1 Cloud %  59 Fill % 39
# LC08_L1TP_030006_20140228_20200911_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20170815_20200903_02_T1 Cloud %  45 Fill % 39
# LC08_L1TP_030006_20170815_20200903_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20150404_20200909_02_T1 Cloud %  56 Fill % 39
# LC08_L1TP_030006_20150404_20200909_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20180428_20200901_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20180428_20200901_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20180412_20201015_02_T1 Cloud %  6 Fill % 39
# LC08_L1TP_030006_20180412_20201015_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20150319_20200909_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20150319_20200909_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20150522_20201016_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20150522_20201016_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20180802_20200831_02_T1 Cloud %  56 Fill % 39
# LC08_L1TP_030006_20180802_20200831_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20200229_20200822_02_T1 Cloud %  30 Fill % 39
# LC08_L1TP_030006_20200229_20200822_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20200807_20200916_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_030006_20200807_20200916_02_T1_B8_Buffer008.TIF exists
# LE07_L1TP_030006_20030529_20200915_02_T1 Cloud %  0 Fill % 39
# Downloading: LE07_L1TP_030006_20030529_20200915_02_T1_B8_Buffer008.TIF
# LC08_L1TP_030006_20200908_20200919_02_T1 Cloud %  3 Fill % 39
# LC08_L1TP_030006_20200908_20200919_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20190602_20200828_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_030006_20190602_20200828_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20201010_20201015_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20201010_20201015_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20180701_20200831_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_030006_20180701_20200831_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20160625_20200906_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_030006_20160625_20200906_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20161015_20200905_02_T1 Cloud %  34 Fill % 39
# LC08_L1TP_030006_20161015_20200905_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20180615_20201016_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20180615_20201016_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20210725_20210803_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_030006_20210725_20210803_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20191008_20200825_02_T1 Cloud %  42 Fill % 39
# LC08_L1TP_030006_20191008_20200825_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20150420_20200909_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20150420_20200909_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20140519_20200911_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20140519_20200911_02_T1 failed cloud & fill thresholds
# LC08_L1TP_030006_20210623_20210630_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_030006_20210623_20210630_02_T1 failed cloud & fill thresholds
# LE07_L1TP_030006_20000605_20200918_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_030006_20000605_20200918_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_030006_20160929_20200906_02_T1 Cloud %  23 Fill % 39
# LC08_L1TP_030006_20160929_20200906_02_T1_B8_Buffer008.TIF exists
# Box008  exists already. Skip creation of directory.
# LC08_L1TP_029006_20210312_20210317_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20210312_20210317_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20150328_20200909_02_T1 Cloud %  11 Fill % 39
# LC08_L1TP_029006_20150328_20200909_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20150515_20201016_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20150515_20201016_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20210718_20210729_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_029006_20210718_20210729_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20180912_20200830_02_T1 Cloud %  55 Fill % 39
# LC08_L1TP_029006_20180912_20200830_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20130930_20200912_02_T1 Cloud %  16 Fill % 39
# LC08_L1TP_029006_20130930_20200912_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20150819_20200908_02_T1 Cloud %  14 Fill % 39
# LC08_L1TP_029006_20150819_20200908_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20160501_20200907_02_T1 Cloud %  56 Fill % 39
# LC08_L1TP_029006_20160501_20200907_02_T1 failed cloud & fill thresholds
# LE07_L1TP_029006_20020722_20200916_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_029006_20020722_20200916_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20180507_20201016_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20180507_20201016_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20180405_20200901_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20180405_20200901_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20200731_20200908_02_T1 Cloud %  52 Fill % 39
# LC08_L1TP_029006_20200731_20200908_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20140613_20200911_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20140613_20200911_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20180523_20200901_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20180523_20200901_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20160602_20200906_02_T1 Cloud %  59 Fill % 39
# LC08_L1TP_029006_20160602_20200906_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20150312_20200909_02_T1 Cloud %  14 Fill % 39
# LC08_L1TP_029006_20150312_20200909_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20190915_20200826_02_T1 Cloud %  12 Fill % 39
# LC08_L1TP_029006_20190915_20200826_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20151006_20200908_02_T1 Cloud %  7 Fill % 39
# LC08_L1TP_029006_20151006_20200908_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20190729_20200827_02_T1 Cloud %  13 Fill % 39
# LC08_L1TP_029006_20190729_20200827_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20200901_20200906_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_029006_20200901_20200906_02_T1_B8_Buffer008.TIF exists
# LE07_L1TP_029006_20010414_20200917_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_029006_20010414_20200917_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20200613_20200823_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20200613_20200823_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20170707_20200903_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20170707_20200903_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20200816_20200920_02_T1 Cloud %  15 Fill % 39
# LC08_L1TP_029006_20200816_20200920_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20180304_20200902_02_T1 Cloud %  29 Fill % 39
# LC08_L1TP_029006_20180304_20200902_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20140309_20200911_02_T1 Cloud %  27 Fill % 39
# LC08_L1TP_029006_20140309_20200911_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20190830_20200826_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20190830_20200826_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20150904_20200908_02_T1 Cloud %  26 Fill % 39
# LC08_L1TP_029006_20150904_20200908_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20190713_20200830_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20190713_20200830_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20150803_20200908_02_T1 Cloud %  37 Fill % 39
# LC08_L1TP_029006_20150803_20200908_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20171011_20200903_02_T1 Cloud %  46 Fill % 39
# LC08_L1TP_029006_20171011_20200903_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20140917_20200911_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_029006_20140917_20200911_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20150531_20200909_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20150531_20200909_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20190814_20200827_02_T1 Cloud %  14 Fill % 39
# LC08_L1TP_029006_20190814_20200827_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20190510_20200829_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20190510_20200829_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20211006_20211013_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20211006_20211013_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20150920_20200908_02_T1 Cloud %  24 Fill % 39
# LC08_L1TP_029006_20150920_20200908_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20190611_20201016_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20190611_20201016_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20140901_20200911_02_T1 Cloud %  21 Fill % 39
# LC08_L1TP_029006_20140901_20200911_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20180421_20200901_02_T1 Cloud %  15 Fill % 39
# LC08_L1TP_029006_20180421_20200901_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20210702_20210712_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20210702_20210712_02_T1 failed cloud & fill thresholds
# LE07_L1TP_029006_20020823_20200916_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_029006_20020823_20200916_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20210429_20210508_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20210429_20210508_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20160704_20200906_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20160704_20200906_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20160618_20200906_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20160618_20200906_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20170317_20200904_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20170317_20200904_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20210819_20210827_02_T1 Cloud %  57 Fill % 39
# LC08_L1TP_029006_20210819_20210827_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20190424_20200828_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20190424_20200828_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20170723_20200903_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20170723_20200903_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20140410_20200911_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20140410_20200911_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20190526_20200828_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20190526_20200828_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20210920_20210925_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20210920_20210925_02_T1 failed cloud & fill thresholds
# LE07_L1TP_029006_20001004_20200917_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_029006_20001004_20200917_02_T1_B8_Buffer008.TIF exists
# LE07_L1TP_029006_20030404_20200915_02_T1 Cloud %  0 Fill % 39
# Downloading: LE07_L1TP_029006_20030404_20200915_02_T1_B8_Buffer008.TIF
# LE07_L1TP_029006_20000513_20200918_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_029006_20000513_20200918_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20170402_20200904_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20170402_20200904_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20150616_20201016_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20150616_20201016_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20130914_20200912_02_T1 Cloud %  56 Fill % 39
# LC08_L1TP_029006_20130914_20200912_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20190627_20200828_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20190627_20200828_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20170520_20200904_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20170520_20200904_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20160922_20200906_02_T1 Cloud %  35 Fill % 39
# LC08_L1TP_029006_20160922_20200906_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20180726_20200831_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20180726_20200831_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20150413_20200909_02_T1 Cloud %  58 Fill % 39
# LC08_L1TP_029006_20150413_20200909_02_T1 failed cloud & fill thresholds
# LE07_L1TP_029006_20000427_20200918_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_029006_20000427_20200918_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20160805_20200906_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_029006_20160805_20200906_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20190323_20200829_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20190323_20200829_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20200309_20200822_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20200309_20200822_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20180624_20200831_02_T1 Cloud %  21 Fill % 39
# LC08_L1TP_029006_20180624_20200831_02_T1_B8_Buffer008.TIF exists
# LE07_L1TP_029006_20010516_20200917_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_029006_20010516_20200917_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20170621_20200903_02_T1 Cloud %  4 Fill % 39
# LC08_L1TP_029006_20170621_20200903_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20150429_20201016_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20150429_20201016_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20140731_20200911_02_T1 Cloud %  59 Fill % 39
# LC08_L1TP_029006_20140731_20200911_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20170925_20200903_02_T1 Cloud %  14 Fill % 39
# LC08_L1TP_029006_20170925_20200903_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20140629_20200911_02_T1 Cloud %  14 Fill % 39
# LC08_L1TP_029006_20140629_20200911_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20210328_20210402_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20210328_20210402_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20161008_20200905_02_T1 Cloud %  13 Fill % 39
# LC08_L1TP_029006_20161008_20200905_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20130829_20200912_02_T1 Cloud %  3 Fill % 39
# LC08_L1TP_029006_20130829_20200912_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20180928_20200830_02_T1 Cloud %  55 Fill % 39
# LC08_L1TP_029006_20180928_20200830_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20210616_20210622_02_T1 Cloud %  49 Fill % 39
# LC08_L1TP_029006_20210616_20210622_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20150718_20201016_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20150718_20201016_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20200528_20200820_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20200528_20200820_02_T1 failed cloud & fill thresholds
# LC08_L1TP_029006_20141003_20200910_02_T1 Cloud %  14 Fill % 39
# LC08_L1TP_029006_20141003_20200910_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_029006_20140715_20201015_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_029006_20140715_20201015_02_T1 failed cloud & fill thresholds
# Box008  exists already. Skip creation of directory.
# LC08_L1TP_028006_20200318_20200822_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20200318_20200822_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20200926_20201007_02_T1 Cloud %  36 Fill % 39
# LC08_L1TP_028006_20200926_20201007_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20190823_20200828_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20190823_20200828_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20180905_20200831_02_T1 Cloud %  55 Fill % 39
# LC08_L1TP_028006_20180905_20200831_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20150913_20200908_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20150913_20200908_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20200724_20200911_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20200724_20200911_02_T1 failed cloud & fill thresholds
# LE07_L1TP_028006_20000623_20200918_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_028006_20000623_20200918_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20180601_20201015_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20180601_20201015_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20180719_20200831_02_T1 Cloud %  5 Fill % 39
# LC08_L1TP_028006_20180719_20200831_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20150321_20201015_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20150321_20201015_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20150524_20200909_02_T1 Cloud %  2 Fill % 39
# LC08_L1TP_028006_20150524_20200909_02_T1_B8_Buffer008.TIF exists
# LE07_L1TP_028006_20000506_20200918_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_028006_20000506_20200918_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20210508_20210518_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_028006_20210508_20210518_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20160713_20200906_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20160713_20200906_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20160611_20200906_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20160611_20200906_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20150828_20200908_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20150828_20200908_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20210609_20210615_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20210609_20210615_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20200622_20200824_02_T1 Cloud %  10 Fill % 39
# LC08_L1TP_028006_20200622_20200824_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20170817_20200903_02_T1 Cloud %  36 Fill % 39
# LC08_L1TP_028006_20170817_20200903_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20170614_20200903_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20170614_20200903_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20140302_20200911_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20140302_20200911_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20170513_20200904_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20170513_20200904_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20161001_20200906_02_T1 Cloud %  59 Fill % 39
# LC08_L1TP_028006_20161001_20200906_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20200809_20200918_02_T1 Cloud %  33 Fill % 39
# LC08_L1TP_028006_20200809_20200918_02_T1_B8_Buffer008.TIF exists
# LE07_L1TP_028006_20010322_20200917_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_028006_20010322_20200917_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20170902_20200903_02_T1 Cloud %  20 Fill % 39
# LC08_L1TP_028006_20170902_20200903_02_T1_B8_Buffer008.TIF exists
# LE07_L1TP_028006_20030413_20200915_02_T1 Cloud %  0 Fill % 39
# Downloading: LE07_L1TP_028006_20030413_20200915_02_T1_B8_Buffer008.TIF
# LC08_L1TP_028006_20140521_20200911_02_T1 Cloud %  59 Fill % 39
# LC08_L1TP_028006_20140521_20200911_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20190620_20200830_02_T1 Cloud %  34 Fill % 39
# LC08_L1TP_028006_20190620_20200830_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20190316_20200829_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20190316_20200829_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20150508_20200909_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20150508_20200909_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20180516_20200901_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20180516_20200901_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20150929_20200908_02_T1 Cloud %  18 Fill % 39
# LC08_L1TP_028006_20150929_20200908_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20140708_20200911_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20140708_20200911_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20200606_20200825_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20200606_20200825_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20130907_20200913_02_T1 Cloud %  52 Fill % 39
# LC08_L1TP_028006_20130907_20200913_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20210524_20210529_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20210524_20210529_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20160729_20200906_02_T1 Cloud %  48 Fill % 39
# LC08_L1TP_028006_20160729_20200906_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20210305_20210311_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20210305_20210311_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20210422_20210430_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20210422_20210430_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20160627_20200906_02_T1 Cloud %  59 Fill % 39
# LC08_L1TP_028006_20160627_20200906_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20210711_20210720_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20210711_20210720_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20190807_20200827_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20190807_20200827_02_T1 failed cloud & fill thresholds
# LE07_L1TP_028006_19990723_20200918_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_028006_19990723_20200918_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20150625_20200909_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_028006_20150625_20200909_02_T1_B8_Buffer008.TIF exists
# LE07_L1TP_028006_20010930_20200917_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_028006_20010930_20200917_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20150727_20200908_02_T1 Cloud %  45 Fill % 39
# LC08_L1TP_028006_20150727_20200908_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20190908_20200828_02_T1 Cloud %  29 Fill % 39
# LC08_L1TP_028006_20190908_20200828_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20190417_20200829_02_T1 Cloud %  42 Fill % 39
# LC08_L1TP_028006_20190417_20200829_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20150406_20201016_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20150406_20201016_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20160814_20200906_02_T1 Cloud %  14 Fill % 39
# LC08_L1TP_028006_20160814_20200906_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20150422_20200909_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20150422_20200909_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20210929_20211013_02_T1 Cloud %  48 Fill % 39
# LC08_L1TP_028006_20210929_20211013_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20130923_20200913_02_T1 Cloud %  41 Fill % 39
# LC08_L1TP_028006_20130923_20200913_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20180804_20200831_02_T1 Cloud %  7 Fill % 39
# LC08_L1TP_028006_20180804_20200831_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20150305_20200909_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20150305_20200909_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20160830_20200906_02_T1 Cloud %  13 Fill % 39
# LC08_L1TP_028006_20160830_20200906_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20150711_20200908_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20150711_20200908_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20210812_20210819_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_028006_20210812_20210819_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20200505_20200820_02_T1 Cloud %  41 Fill % 39
# LC08_L1TP_028006_20200505_20200820_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20170310_20200904_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20170310_20200904_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20150609_20201015_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_028006_20150609_20201015_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20191010_20200825_02_T1 Cloud %  44 Fill % 39
# LC08_L1TP_028006_20191010_20200825_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20140825_20200911_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20140825_20200911_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20190401_20200829_02_T1 Cloud %  26 Fill % 39
# LC08_L1TP_028006_20190401_20200829_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20180430_20200901_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20180430_20200901_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20160424_20200907_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20160424_20200907_02_T1 failed cloud & fill thresholds
# LE07_L1TP_028006_20000404_20200918_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_028006_20000404_20200918_02_T1_B8_Buffer008.TIF exists
# LE07_L1TP_028006_20030803_20200915_02_T1 Cloud %  0 Fill % 53
# Downloading: LE07_L1TP_028006_20030803_20200915_02_T1_B8_Buffer008.TIF
# LC08_L1TP_028006_20140505_20200911_02_T1 Cloud %  3 Fill % 39
# LC08_L1TP_028006_20140505_20200911_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20160526_20200906_02_T1 Cloud %  26 Fill % 39
# LC08_L1TP_028006_20160526_20200906_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20170427_20201015_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20170427_20201015_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20180414_20200901_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20180414_20200901_02_T1 failed cloud & fill thresholds
# LE07_L1TP_028006_20010407_20200917_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_028006_20010407_20200917_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20210321_20210401_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20210321_20210401_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20200910_20200919_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20200910_20200919_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20170716_20200903_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20170716_20200903_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20200403_20200822_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20200403_20200822_02_T1 failed cloud & fill thresholds
# LE07_L1TP_028006_20020325_20200916_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_028006_20020325_20200916_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20180921_20200830_02_T1 Cloud %  26 Fill % 39
# LC08_L1TP_028006_20180921_20200830_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_028006_20200521_20200820_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20200521_20200820_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20140318_20200911_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20140318_20200911_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20170630_20200903_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20170630_20200903_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20150812_20201016_02_T1 Cloud %  52 Fill % 39
# LC08_L1TP_028006_20150812_20201016_02_T1 failed cloud & fill thresholds
# LC08_L1TP_028006_20200419_20200822_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_028006_20200419_20200822_02_T1 failed cloud & fill thresholds
# Box008  exists already. Skip creation of directory.
# LC08_L1TP_027006_20180626_20200831_02_T1 Cloud %  44 Fill % 46
# LC08_L1TP_027006_20180626_20200831_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_027006_20170319_20200904_02_T1 Cloud %  21 Fill % 46
# LC08_L1TP_027006_20170319_20200904_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_027006_20160722_20200906_02_T1 Cloud %  53 Fill % 46
# LC08_L1TP_027006_20160722_20200906_02_T1 failed cloud & fill thresholds
# LC08_L1TP_027006_20210602_20210608_02_T1 Cloud %  9 Fill % 46
# LC08_L1TP_027006_20210602_20210608_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_027006_20190426_20200829_02_T1 Cloud %  53 Fill % 46
# LC08_L1TP_027006_20190426_20200829_02_T1 failed cloud & fill thresholds
# LC08_L1TP_027006_20170826_20200903_02_T1 Cloud %  4 Fill % 46
# LC08_L1TP_027006_20170826_20200903_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_027006_20140701_20200911_02_T1 Cloud %  53 Fill % 46
# LC08_L1TP_027006_20140701_20200911_02_T1 failed cloud & fill thresholds
# LC08_L1TP_027006_20170927_20200903_02_T1 Cloud %  36 Fill % 46
# LC08_L1TP_027006_20170927_20200903_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_027006_20140412_20200911_02_T1 Cloud %  53 Fill % 46
# LC08_L1TP_027006_20140412_20200911_02_T1 failed cloud & fill thresholds
# LC08_L1TP_027006_20190629_20200830_02_T1 Cloud %  53 Fill % 46
# LC08_L1TP_027006_20190629_20200830_02_T1 failed cloud & fill thresholds
# LC08_L1TP_027006_20170725_20200903_02_T1 Cloud %  53 Fill % 46
# LC08_L1TP_027006_20170725_20200903_02_T1 failed cloud & fill thresholds
# LC08_L1TP_027006_20150922_20200908_02_T1 Cloud %  12 Fill % 46
# LC08_L1TP_027006_20150922_20200908_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_027006_20210805_20210811_02_T1 Cloud %  49 Fill % 46
# LC08_L1TP_027006_20210805_20210811_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_027006_20170709_20200903_02_T1 Cloud %  4 Fill % 46
# LC08_L1TP_027006_20170709_20200903_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_027006_20150314_20200909_02_T1 Cloud %  53 Fill % 46
# LC08_L1TP_027006_20150314_20200909_02_T1 failed cloud & fill thresholds
# LC08_L1TP_027006_20190512_20200829_02_T1 Cloud %  53 Fill % 46
# LC08_L1TP_027006_20190512_20200829_02_T1 failed cloud & fill thresholds
# LC08_L1TP_027006_20180829_20200831_02_T1 Cloud %  26 Fill % 46
# LC08_L1TP_027006_20180829_20200831_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_027006_20140802_20200911_02_T1 Cloud %  31 Fill % 46
# LC08_L1TP_027006_20140802_20200911_02_T1_B8_Buffer008.TIF exists
# LE07_L1TP_027006_20010331_20200917_02_T1 Cloud %  0 Fill % 46
# LE07_L1TP_027006_20010331_20200917_02_T1_B8_Buffer008.TIF exists
# ...
# LC08_L1TP_032005_20150418_20200909_02_T1 failed cloud & fill thresholds
# LC08_L1TP_032005_20150808_20200908_02_T1 Cloud %  37 Fill % 39
# LC08_L1TP_032005_20150808_20200908_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_032005_20160826_20200906_02_T1 Cloud %  58 Fill % 39
# LC08_L1TP_032005_20160826_20200906_02_T1 failed cloud & fill thresholds
# LC08_L1TP_032005_20200330_20200822_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_032005_20200330_20200822_02_T1 failed cloud & fill thresholds
# LC08_L1TP_032005_20180816_20200831_02_T1 Cloud %  2 Fill % 39
# LC08_L1TP_032005_20180816_20200831_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_032005_20210925_20210930_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_032005_20210925_20210930_02_T1 failed cloud & fill thresholds
# LC08_L1TP_032005_20180512_20200901_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_032005_20180512_20200901_02_T1 failed cloud & fill thresholds
# LC08_L1TP_032005_20150925_20200908_02_T1 Cloud %  13 Fill % 39
# LC08_L1TP_032005_20150925_20200908_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_032005_20200517_20200820_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_032005_20200517_20200820_02_T1 failed cloud & fill thresholds
# LC08_L1TP_032005_20200704_20200913_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_032005_20200704_20200913_02_T1 failed cloud & fill thresholds
# LC08_L1TP_032005_20210418_20210424_02_T1 Cloud %  8 Fill % 39
# LC08_L1TP_032005_20210418_20210424_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_032005_20210909_20210916_02_T1 Cloud %  48 Fill % 39
# LC08_L1TP_032005_20210909_20210916_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_032005_20150402_20200909_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_032005_20150402_20200909_02_T1 failed cloud & fill thresholds
# LC08_L1TP_032005_20180325_20200901_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_032005_20180325_20200901_02_T1 failed cloud & fill thresholds
# LE07_L1TP_032005_20010606_20200917_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_032005_20010606_20200917_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_032005_20150707_20200909_02_T1 Cloud %  59 Fill % 39
# LC08_L1TP_032005_20150707_20200909_02_T1 failed cloud & fill thresholds
# LC08_L1TP_032005_20160709_20200906_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_032005_20160709_20200906_02_T1 failed cloud & fill thresholds
# LC08_L1TP_032005_20200618_20200823_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_032005_20200618_20200823_02_T1 failed cloud & fill thresholds
# LC08_L1TP_032005_20191006_20200825_02_T1 Cloud %  38 Fill % 39
# LC08_L1TP_032005_20191006_20200825_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_032005_20160303_20200907_02_T1 Cloud %  31 Fill % 39
# LC08_L1TP_032005_20160303_20200907_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_032005_20201008_20201015_02_T1 Cloud %  58 Fill % 39
# LC08_L1TP_032005_20201008_20201015_02_T1 failed cloud & fill thresholds
# LC08_L1TP_032005_20190531_20200828_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_032005_20190531_20200828_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_032005_20180629_20200831_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_032005_20180629_20200831_02_T1 failed cloud & fill thresholds
# LC08_L1TP_032005_20180731_20200831_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_032005_20180731_20200831_02_T1 failed cloud & fill thresholds
# LC08_L1TP_032005_20160420_20200907_02_T1 Cloud %  5 Fill % 39
# LC08_L1TP_032005_20160420_20200907_02_T1_B8_Buffer008.TIF exists
# Box008  exists already. Skip creation of directory.
# LC08_L1TP_031005_20190524_20201015_02_T1 Cloud %  50 Fill % 39
# LC08_L1TP_031005_20190524_20201015_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20180403_20200901_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20180403_20200901_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20180606_20200831_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20180606_20200831_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20140713_20201015_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20140713_20201015_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20150918_20200908_02_T1 Cloud %  21 Fill % 39
# LC08_L1TP_031005_20150918_20200908_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20141001_20200910_02_T1 Cloud %  17 Fill % 39
# LC08_L1TP_031005_20141001_20200910_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20140627_20200911_02_T1 Cloud %  45 Fill % 39
# LC08_L1TP_031005_20140627_20200911_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20200830_20200906_02_T1 Cloud %  19 Fill % 39
# LC08_L1TP_031005_20200830_20200906_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20200307_20200822_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20200307_20200822_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20150817_20200908_02_T1 Cloud %  17 Fill % 39
# LC08_L1TP_031005_20150817_20200908_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20180302_20200902_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20180302_20200902_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20210918_20210925_02_T1 Cloud %  22 Fill % 39
# LC08_L1TP_031005_20210918_20210925_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20180419_20200901_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20180419_20200901_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20210630_20210708_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_031005_20210630_20210708_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20160429_20200907_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20160429_20200907_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20150513_20201016_02_T1 Cloud %  38 Fill % 39
# LC08_L1TP_031005_20150513_20201016_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20170315_20200904_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20170315_20200904_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20190913_20200827_02_T1 Cloud %  12 Fill % 39
# LC08_L1TP_031005_20190913_20200827_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20140526_20200911_02_T1 Cloud %  28 Fill % 39
# LC08_L1TP_031005_20140526_20200911_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20150310_20200909_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20150310_20200909_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20210614_20210622_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20210614_20210622_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20160616_20200906_02_T1 Cloud %  37 Fill % 39
# LC08_L1TP_031005_20160616_20200906_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20210902_20210910_02_T1 Cloud %  35 Fill % 39
# LC08_L1TP_031005_20210902_20210910_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20170416_20200904_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20170416_20200904_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20140814_20200911_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20140814_20200911_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20160328_20200907_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20160328_20200907_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20170603_20201016_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20170603_20201016_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20150630_20201016_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20150630_20201016_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20160413_20200907_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20160413_20200907_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20160312_20200907_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20160312_20200907_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20181012_20200830_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20181012_20200830_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20150902_20200908_02_T1 Cloud %  14 Fill % 39
# LC08_L1TP_031005_20150902_20200908_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20150326_20200909_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20150326_20200909_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20140915_20200911_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20140915_20200911_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20210310_20210317_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20210310_20210317_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20161006_20200906_02_T1 Cloud %  19 Fill % 39
# LC08_L1TP_031005_20161006_20200906_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20200408_20200822_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20200408_20200822_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20180318_20200901_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20180318_20200901_02_T1 failed cloud & fill thresholds
# LE07_L1TP_031005_20010615_20200917_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_031005_20010615_20200917_02_T1_B8_Buffer008.TIF exists
# LE07_L1TP_031005_20000628_20200918_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_031005_20000628_20200918_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20210529_20210608_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20210529_20210608_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20200424_20200822_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20200424_20200822_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20160531_20200906_02_T1 Cloud %  34 Fill % 39
# LC08_L1TP_031005_20160531_20200906_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20180926_20200830_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20180926_20200830_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20150801_20200908_02_T1 Cloud %  44 Fill % 39
# LC08_L1TP_031005_20150801_20200908_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20140830_20200911_02_T1 Cloud %  22 Fill % 39
# LC08_L1TP_031005_20140830_20200911_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20150716_20200908_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20150716_20200908_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20190422_20200828_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20190422_20200828_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20130523_20200913_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20130523_20200913_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20190321_20200829_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20190321_20200829_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20150427_20201016_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20150427_20201016_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20190609_20200828_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20190609_20200828_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20170502_20200904_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20170502_20200904_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20150529_20201016_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20150529_20201016_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20130827_20200912_02_T1 Cloud %  40 Fill % 39
# LC08_L1TP_031005_20130827_20200912_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20190929_20200825_02_T1 Cloud %  58 Fill % 39
# LC08_L1TP_031005_20190929_20200825_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20180708_20200831_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20180708_20200831_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20160718_20200906_02_T1 Cloud %  2 Fill % 39
# LC08_L1TP_031005_20160718_20200906_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20170923_20200903_02_T1 Cloud %  19 Fill % 39
# LC08_L1TP_031005_20170923_20200903_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20150411_20201016_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20150411_20201016_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20180724_20200831_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20180724_20200831_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20160904_20200906_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20160904_20200906_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20200915_20200919_02_T1 Cloud %  17 Fill % 39
# LC08_L1TP_031005_20200915_20200919_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20151004_20200908_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20151004_20200908_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20210326_20210402_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20210326_20210402_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20200713_20200912_02_T1 Cloud %  3 Fill % 39
# LC08_L1TP_031005_20200713_20200912_02_T1_B8_Buffer008.TIF exists
# LE07_L1TP_031005_20020618_20200916_02_T1 Cloud %  0 Fill % 39
# LE07_L1TP_031005_20020618_20200916_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20180910_20200830_02_T1 Cloud %  26 Fill % 39
# LC08_L1TP_031005_20180910_20200830_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20160803_20200906_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20160803_20200906_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20150614_20201015_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20150614_20201015_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20210513_20210524_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20210513_20210524_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20190508_20200830_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20190508_20200830_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20170619_20200903_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20170619_20200903_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20200627_20200823_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20200627_20200823_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20140323_20200911_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20140323_20200911_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20180622_20201015_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_031005_20180622_20201015_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20200814_20200920_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_031005_20200814_20200920_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20180521_20200901_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_031005_20180521_20200901_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20170721_20201016_02_T1 Cloud %  13 Fill % 39
# LC08_L1TP_031005_20170721_20201016_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20170705_20200903_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20170705_20200903_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20130928_20200912_02_T1 Cloud %  16 Fill % 39
# LC08_L1TP_031005_20130928_20200912_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20160702_20200906_02_T1 Cloud %  59 Fill % 39
# LC08_L1TP_031005_20160702_20200906_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20200510_20200820_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20200510_20200820_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20190727_20200828_02_T1 Cloud %  13 Fill % 39
# LC08_L1TP_031005_20190727_20200828_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20140408_20200911_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20140408_20200911_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20180825_20200831_02_T1 Cloud %  21 Fill % 39
# LC08_L1TP_031005_20180825_20200831_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20210716_20210729_02_T1 Cloud %  44 Fill % 39
# LC08_L1TP_031005_20210716_20210729_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20190625_20200829_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20190625_20200829_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20190711_20200829_02_T1 Cloud %  2 Fill % 39
# LC08_L1TP_031005_20190711_20200829_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20160515_20200907_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20160515_20200907_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20130402_20200912_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20130402_20200912_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20170822_20201016_02_T1 Cloud %  20 Fill % 39
# LC08_L1TP_031005_20170822_20201016_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20201001_20201007_02_T1 Cloud %  30 Fill % 39
# LC08_L1TP_031005_20201001_20201007_02_T1_B8_Buffer008.TIF exists
# LC08_L1TP_031005_20170331_20200904_02_T1 Cloud %  60 Fill % 39
# LC08_L1TP_031005_20170331_20200904_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20200729_20200908_02_T1 Cloud %  59 Fill % 39
# LC08_L1TP_031005_20200729_20200908_02_T1 failed cloud & fill thresholds
# LC08_L1TP_031005_20200526_20200820_02_T1 Cloud %  0 Fill % 39
# LC08_L1TP_031005_20200526_20200820_02_T1_B8_Buffer008.TIF exists

# %% [markdown]
# # 7) Automatically grab the image acquisition dates from the metadata files

# %%
datetimes = [] # list of scene datetimes
scenes_dated = [] # list of scenes

for BoxID in BoxIDs:
    bp_out = downloadpath+'Box'+BoxID+'/' # path to downloaded images for that glacier
    
    # Grab all path row folder names from boxes_pr_df:
    paths = boxes_pr_df.loc[BoxID,'Path']
    rows = boxes_pr_df.loc[BoxID,'Row']
    
    # Grab the downloaded scenes
    downloaded_scenes = os.listdir(bp_out)
    for scene in downloaded_scenes:
        if scene.startswith('L') and 'T1' in scene and scene.endswith('.TIF'):
            scenename = scene[:40]
            
            # Search for metadata file in each path, row folder:
            found = False # not found yet
            for a in range(0, len(paths)): # look in each path row folder
                folder_name = 'Path'+paths[a]+'_Row'+rows[a]+'_c2'
                folderpath = downloadpath+folder_name+'/'
                
                # if not there
                if not os.path.exists(folderpath+scenename+'_MTL.txt'):
                    continue # skip to the next folder
                else: # if there
                    # open the file
                    mdata = open(folderpath+scenename+"_MTL.txt", "r")
                    # find the acquisition date in the file
                    for line in mdata:
                        variable = line.split("=")[0]
                        if ("DATE_ACQUIRED" in variable):
                            date = line.split("=")[1][1:-1] # find acquisition date
                    # save scenename and date
                    dates = datetime.datetime.strptime(date, '%Y-%m-%d') # save as datetime object
                    print(scenename, dates)
                    datetimes.append(dates); scenes_dated.append(scenename) # store in lists
                    
                    found = True # found the file
                    break # stop search
            
            if found == False: # if the file was not found at all
                # grab acquisition date from the filename
                date = scene[17:25]
                dates = datetime.datetime.strptime(date, '%Y%m%d') # save as datetime object
                print(scenename, 'missing metadata file. Guessing from filename instead:', dates)

# Store in a dataframe
datetime_df = pd.DataFrame(list(zip(scenes_dated, datetimes)), columns=['Scene', 'datetime'])
datetime_df = datetime_df.sort_values(by='datetime', ascending=True); datetime_df = datetime_df.drop_duplicates()
datetime_df
# Out:
# LC08_L1TP_030006_20150810_20200908_02_T1 2015-08-10 00:00:00
# LC08_L1TP_032005_20181003_20200830_02_T1 2018-10-03 00:00:00
# LC08_L1TP_031006_20141001_20200910_02_T1 2014-10-01 00:00:00
# LC08_L1TP_028006_20170902_20200903_02_T1 2017-09-02 00:00:00
# LC08_L1TP_031006_20190321_20200829_02_T1 2019-03-21 00:00:00
# LC08_L1TP_030006_20210911_20210916_02_T1 2021-09-11 00:00:00
# LC08_L1TP_029006_20130930_20200912_02_T1 2013-09-30 00:00:00
# LC08_L1TP_031006_20160616_20201016_02_T1 2016-06-16 00:00:00
# LC08_L1TP_028006_20200622_20200824_02_T1 2020-06-22 00:00:00
# LC08_L1TP_031006_20180505_20200901_02_T1 2018-05-05 00:00:00
# LC08_L1TP_031006_20200713_20200912_02_T1 2020-07-13 00:00:00
# LC08_L1TP_031005_20210630_20210708_02_T1 2021-06-30 00:00:00
# LC08_L1TP_030006_20190704_20200830_02_T1 2019-07-04 00:00:00
# LC08_L1TP_028006_20190620_20200830_02_T1 2019-06-20 00:00:00
# LC08_L1TP_029006_20130829_20200912_02_T1 2013-08-29 00:00:00
# LC08_L1TP_031006_20210918_20210925_02_T1 2021-09-18 00:00:00
# LC08_L1TP_031006_20200830_20200906_02_T1 2020-08-30 00:00:00
# LC08_L1TP_031006_20130928_20200912_02_T1 2013-09-28 00:00:00
# LE07_L1TP_029006_20000513_20200918_02_T1 2000-05-13 00:00:00
# LC08_L1TP_029006_20180421_20200901_02_T1 2018-04-21 00:00:00
# LC08_L1TP_031005_20180910_20200830_02_T1 2018-09-10 00:00:00
# LC08_L1TP_029006_20140629_20200911_02_T1 2014-06-29 00:00:00
# LC08_L1TP_028006_20150727_20200908_02_T1 2015-07-27 00:00:00
# LC08_L1TP_030006_20140908_20200911_02_T1 2014-09-08 00:00:00
# LC08_L1TP_029006_20200816_20200920_02_T1 2020-08-16 00:00:00
# LC08_L1TP_030006_20210927_20210930_02_T1 2021-09-27 00:00:00
# LC08_L1TP_027006_20150922_20200908_02_T1 2015-09-22 00:00:00
# LC08_L1TP_027006_20130916_20200913_02_T1 2013-09-16 00:00:00
# LC08_L1TP_029006_20180624_20200831_02_T1 2018-06-24 00:00:00
# LC08_L1TP_030006_20200807_20200916_02_T1 2020-08-07 00:00:00
# LC08_L1TP_029006_20150803_20200908_02_T1 2015-08-03 00:00:00
# LC08_L1TP_031006_20150513_20201015_02_T1 2015-05-13 00:00:00
# LC08_L1TP_028006_20190417_20200829_02_T1 2019-04-17 00:00:00
# LC08_L1TP_032005_20130919_20200913_02_T1 2013-09-19 00:00:00
# LC08_L1TP_032005_20200906_20200918_02_T1 2020-09-06 00:00:00
# LC08_L1TP_030006_20140604_20200911_02_T1 2014-06-04 00:00:00
# LC08_L1TP_027006_20170927_20200903_02_T1 2017-09-27 00:00:00
# LC08_L1TP_032005_20160810_20200906_02_T1 2016-08-10 00:00:00
# LC08_L1TP_027006_20160924_20200906_02_T1 2016-09-24 00:00:00
# LC08_L1TP_031006_20170923_20200903_02_T1 2017-09-23 00:00:00
# LC08_L1TP_032005_20210520_20210528_02_T1 2021-05-20 00:00:00
# LC08_L1TP_027006_20180423_20200901_02_T1 2018-04-23 00:00:00
# LC08_L1TP_032005_20200415_20200822_02_T1 2020-04-15 00:00:00
# LC08_L1TP_031006_20170315_20200904_02_T1 2017-03-15 00:00:00
# LC08_L1TP_031005_20140830_20200911_02_T1 2014-08-30 00:00:00
# LC08_L1TP_031005_20170923_20200903_02_T1 2017-09-23 00:00:00
# LC08_L1TP_031005_20161006_20200906_02_T1 2016-10-06 00:00:00
# LC08_L1TP_031006_20130827_20200912_02_T1 2013-08-27 00:00:00
# LC08_L1TP_030006_20200924_20201007_02_T1 2020-09-24 00:00:00
# LE07_L1TP_030006_20000605_20200918_02_T1 2000-06-05 00:00:00
# LC08_L1TP_030006_20190805_20200828_02_T1 2019-08-05 00:00:00
# LE07_L1TP_030006_19990705_20200918_02_T1 1999-07-05 00:00:00
# LC08_L1TP_031005_20210902_20210910_02_T1 2021-09-02 00:00:00
# LC08_L1TP_027006_20170623_20200903_02_T1 2017-06-23 00:00:00
# LC08_L1TP_031006_20200814_20200919_02_T1 2020-08-14 00:00:00
# LC08_L1TP_027006_20210314_20210328_02_T1 2021-03-14 00:00:00
# LC08_L1TP_031005_20190727_20200828_02_T1 2019-07-27 00:00:00
# LC08_L1TP_031005_20190711_20200829_02_T1 2019-07-11 00:00:00
# LC08_L1TP_032005_20140906_20200911_02_T1 2014-09-06 00:00:00
# LC08_L1TP_032005_20150808_20200908_02_T1 2015-08-08 00:00:00
# LC08_L1TP_031006_20160531_20200906_02_T1 2016-05-31 00:00:00
# LC08_L1TP_030006_20161015_20200905_02_T1 2016-10-15 00:00:00
# LC08_L1TP_029006_20141003_20200910_02_T1 2014-10-03 00:00:00
# LC08_L1TP_031006_20140526_20200911_02_T1 2014-05-26 00:00:00
# LC08_L1TP_031006_20180521_20200901_02_T1 2018-05-21 00:00:00
# LC08_L1TP_032005_20150925_20200908_02_T1 2015-09-25 00:00:00
# LC08_L1TP_029006_20160922_20200906_02_T1 2016-09-22 00:00:00
# LC08_L1TP_028006_20150609_20201015_02_T1 2015-06-09 00:00:00
# LC08_L1TP_031005_20140627_20200911_02_T1 2014-06-27 00:00:00
# LC08_L1TP_028006_20200505_20200820_02_T1 2020-05-05 00:00:00
# LC08_L1TP_031005_20130827_20200912_02_T1 2013-08-27 00:00:00
# LC08_L1TP_032005_20180309_20200901_02_T1 2018-03-09 00:00:00
# LC08_L1TP_029006_20150920_20200908_02_T1 2015-09-20 00:00:00
# LC08_L1TP_031005_20150902_20200908_02_T1 2015-09-02 00:00:00
# LC08_L1TP_029006_20170621_20200903_02_T1 2017-06-21 00:00:00
# LC08_L1TP_031005_20160616_20200906_02_T1 2016-06-16 00:00:00
# LC08_L1TP_031005_20180521_20200901_02_T1 2018-05-21 00:00:00
# LC08_L1TP_030006_20200908_20200919_02_T1 2020-09-08 00:00:00
# LC08_L1TP_031006_20140830_20200911_02_T1 2014-08-30 00:00:00
# LC08_L1TP_027006_20130831_20200913_02_T1 2013-08-31 00:00:00
# LC08_L1TP_031006_20170822_20200903_02_T1 2017-08-22 00:00:00
# LC08_L1TP_032005_20160911_20200906_02_T1 2016-09-11 00:00:00
# LC08_L1TP_028006_20160830_20200906_02_T1 2016-08-30 00:00:00
# LE07_L1TP_027006_20010331_20200917_02_T1 2001-03-31 00:00:00
# LC08_L1TP_030006_20200229_20200822_02_T1 2020-02-29 00:00:00
# LC08_L1TP_029006_20190729_20200827_02_T1 2019-07-29 00:00:00
# LC08_L1TP_027006_20190901_20200827_02_T1 2019-09-01 00:00:00
# LE07_L1TP_029006_20020722_20200916_02_T1 2002-07-22 00:00:00
# LC08_L1TP_030006_20170815_20200903_02_T1 2017-08-15 00:00:00
# LC08_L1TP_027006_20180829_20200831_02_T1 2018-08-29 00:00:00
# LC08_L1TP_028006_20210508_20210518_02_T1 2021-05-08 00:00:00
# LC08_L1TP_031006_20190913_20200826_02_T1 2019-09-13 00:00:00
# LC08_L1TP_031005_20190524_20201015_02_T1 2019-05-24 00:00:00
# LE07_L1TP_027006_19990716_20200918_02_T1 1999-07-16 00:00:00
# LC08_L1TP_027006_20140802_20200911_02_T1 2014-08-02 00:00:00
# LC08_L1TP_028006_20160526_20200906_02_T1 2016-05-26 00:00:00
# LE07_L1TP_030006_20010811_20200917_02_T1 2001-08-11 00:00:00
# LE07_L1TP_032005_20010606_20200917_02_T1 2001-06-06 00:00:00
# LC08_L1TP_027006_20180626_20200831_02_T1 2018-06-26 00:00:00
# LC08_L1TP_028006_20191010_20200825_02_T1 2019-10-10 00:00:00
# LC08_L1TP_030006_20170730_20200903_02_T1 2017-07-30 00:00:00
# LC08_L1TP_032005_20160607_20200906_02_T1 2016-06-07 00:00:00
# LC08_L1TP_031005_20210918_20210925_02_T1 2021-09-18 00:00:00
# LC08_L1TP_027006_20171013_20200902_02_T1 2017-10-13 00:00:00
# LC08_L1TP_031006_20210310_20210317_02_T1 2021-03-10 00:00:00
# LE07_L1TP_030006_20000520_20200918_02_T1 2000-05-20 00:00:00
# LC08_L1TP_029006_20161008_20200905_02_T1 2016-10-08 00:00:00
# LC08_L1TP_030006_20190922_20200826_02_T1 2019-09-22 00:00:00
# LC08_L1TP_027006_20190309_20200829_02_T1 2019-03-09 00:00:00
# LC08_L1TP_031006_20180910_20200830_02_T1 2018-09-10 00:00:00
# LC08_L1TP_031006_20161006_20200906_02_T1 2016-10-06 00:00:00
# LC08_L1TP_032005_20180816_20200831_02_T1 2018-08-16 00:00:00
# LE07_L1TP_030006_20030513_20200916_02_T1 2003-05-13 00:00:00
# LC08_L1TP_032005_20170712_20201016_02_T1 2017-07-12 00:00:00
# LC08_L1TP_029006_20170925_20200903_02_T1 2017-09-25 00:00:00
# LC08_L1TP_031005_20150918_20200908_02_T1 2015-09-18 00:00:00
# LC08_L1TP_028006_20180921_20200830_02_T1 2018-09-21 00:00:00
# LC08_L1TP_031006_20160702_20200906_02_T1 2016-07-02 00:00:00
# LC08_L1TP_030006_20160929_20200906_02_T1 2016-09-29 00:00:00
# LC08_L1TP_029006_20140901_20200911_02_T1 2014-09-01 00:00:00
# LE07_L1TP_030006_20030529_20200915_02_T1 2003-05-29 00:00:00
# LC08_L1TP_031005_20140526_20200911_02_T1 2014-05-26 00:00:00
# LC08_L1TP_031006_20201001_20201007_02_T1 2020-10-01 00:00:00
# LE07_L1TP_031005_20000628_20200918_02_T1 2000-06-28 00:00:00
# LC08_L1TP_027006_20190816_20200827_02_T1 2019-08-16 00:00:00
# LC08_L1TP_031006_20180622_20200831_02_T1 2018-06-22 00:00:00
# LC08_L1TP_029006_20190814_20200827_02_T1 2019-08-14 00:00:00
# LC08_L1TP_031006_20200915_20200919_02_T1 2020-09-15 00:00:00
# LC08_L1TP_032005_20150824_20200908_02_T1 2015-08-24 00:00:00
# LE07_L1TP_030006_20020323_20200916_02_T1 2002-03-23 00:00:00
# LC08_L1TP_031005_20130928_20200912_02_T1 2013-09-28 00:00:00
# LC08_L1TP_031005_20200526_20200820_02_T1 2020-05-26 00:00:00
# LC08_L1TP_032005_20200805_20200916_02_T1 2020-08-05 00:00:00
# LE07_L1TP_031006_19990829_20200918_02_T1 1999-08-29 00:00:00
# LC08_L1TP_032005_20191006_20200825_02_T1 2019-10-06 00:00:00
# LE07_L1TP_032005_20000603_20200918_02_T1 2000-06-03 00:00:00
# LC08_L1TP_027006_20170709_20200903_02_T1 2017-07-09 00:00:00
# LE07_L1TP_028006_20030803_20200915_02_T1 2003-08-03 00:00:00
# LC08_L1TP_031005_20200814_20200920_02_T1 2020-08-14 00:00:00
# LC08_L1TP_031005_20160718_20200906_02_T1 2016-07-18 00:00:00
# LE07_L1TP_028006_20010322_20200917_02_T1 2001-03-22 00:00:00
# LE07_L1TP_032005_20020609_20200916_02_T1 2002-06-09 00:00:00
# LC08_L1TP_031006_20180318_20200901_02_T1 2018-03-18 00:00:00
# LE07_L1TP_028006_20000404_20200918_02_T1 2000-04-04 00:00:00
# LC08_L1TP_031005_20150817_20200908_02_T1 2015-08-17 00:00:00
# LC08_L1TP_031006_20210902_20210910_02_T1 2021-09-02 00:00:00
# LC08_L1TP_030006_20150826_20200908_02_T1 2015-08-26 00:00:00
# LE07_L1TP_028006_20010407_20200917_02_T1 2001-04-07 00:00:00
# LC08_L1TP_027006_20150821_20200908_02_T1 2015-08-21 00:00:00
# LC08_L1TP_027006_20190613_20200829_02_T1 2019-06-13 00:00:00
# LC08_L1TP_027006_20191003_20200825_02_T1 2019-10-03 00:00:00
# LC08_L1TP_031006_20190812_20200827_02_T1 2019-08-12 00:00:00
# LC08_L1TP_032005_20140922_20200910_02_T1 2014-09-22 00:00:00
# LC08_L1TP_030006_20180919_20200830_02_T1 2018-09-19 00:00:00
# LC08_L1TP_029006_20200901_20200906_02_T1 2020-09-01 00:00:00
# LC08_L1TP_029006_20210718_20210729_02_T1 2021-07-18 00:00:00
# LC08_L1TP_030006_20160913_20200906_02_T1 2016-09-13 00:00:00
# LE07_L1TP_029006_20020823_20200916_02_T1 2002-08-23 00:00:00
# LE07_L1TP_029006_20000427_20200918_02_T1 2000-04-27 00:00:00
# LC08_L1TP_032005_20180426_20200901_02_T1 2018-04-26 00:00:00
# LC08_L1TP_031005_20150513_20201016_02_T1 2015-05-13 00:00:00
# LC08_L1TP_031005_20200830_20200906_02_T1 2020-08-30 00:00:00
# LC08_L1TP_028006_20170817_20200903_02_T1 2017-08-17 00:00:00
# LE07_L1TP_029006_20010414_20200917_02_T1 2001-04-14 00:00:00
# LC08_L1TP_029006_20150328_20200909_02_T1 2015-03-28 00:00:00
# LC08_L1TP_030006_20160727_20200906_02_T1 2016-07-27 00:00:00
# LC08_L1TP_030006_20140924_20200910_02_T1 2014-09-24 00:00:00
# LC08_L1TP_028006_20200809_20200918_02_T1 2020-08-09 00:00:00
# LC08_L1TP_030006_20190602_20200828_02_T1 2019-06-02 00:00:00
# LE07_L1TP_028006_20000623_20200918_02_T1 2000-06-23 00:00:00
# LC08_L1TP_027006_20210602_20210608_02_T1 2021-06-02 00:00:00
# LE07_L1TP_027006_20020622_20200916_02_T1 2002-06-22 00:00:00
# LC08_L1TP_028006_20180719_20200831_02_T1 2018-07-19 00:00:00
# LC08_L1TP_031005_20141001_20200910_02_T1 2014-10-01 00:00:00
# LE07_L1TP_031005_20010615_20200917_02_T1 2001-06-15 00:00:00
# LC08_L1TP_028006_20160814_20200906_02_T1 2016-08-14 00:00:00
# LC08_L1TP_031006_20190711_20200828_02_T1 2019-07-11 00:00:00
# LC08_L1TP_031006_20180825_20200831_02_T1 2018-08-25 00:00:00
# LE07_L1TP_027006_20000531_20200918_02_T1 2000-05-31 00:00:00
# LC08_L1TP_031006_20150801_20200908_02_T1 2015-08-01 00:00:00
# LC08_L1TP_027006_20160807_20201016_02_T1 2016-08-07 00:00:00
# LC08_L1TP_030006_20160625_20200906_02_T1 2016-06-25 00:00:00
# LC08_L1TP_032005_20190904_20200826_02_T1 2019-09-04 00:00:00
# LE07_L1TP_030006_20030716_20200915_02_T1 2003-07-16 00:00:00
# LC08_L1TP_031005_20150801_20200908_02_T1 2015-08-01 00:00:00
# LE07_L1TP_028006_20030413_20200915_02_T1 2003-04-13 00:00:00
# LC08_L1TP_031005_20201001_20201007_02_T1 2020-10-01 00:00:00
# LE07_L1TP_031006_20020330_20200916_02_T1 2002-03-30 00:00:00
# LE07_L1TP_028006_19990723_20200918_02_T1 1999-07-23 00:00:00
# LE07_L1TP_027006_19990630_20200918_02_T1 1999-06-30 00:00:00
# LC08_L1TP_031005_20180825_20200831_02_T1 2018-08-25 00:00:00
# LE07_L1TP_030006_20030411_20200916_02_T1 2003-04-11 00:00:00
# LC08_L1TP_029006_20180304_20200902_02_T1 2018-03-04 00:00:00
# LC08_L1TP_028006_20200926_20201007_02_T1 2020-09-26 00:00:00
# LC08_L1TP_031005_20180622_20201015_02_T1 2018-06-22 00:00:00
# LC08_L1TP_031006_20150902_20200908_02_T1 2015-09-02 00:00:00
# LC08_L1TP_032005_20170930_20200903_02_T1 2017-09-30 00:00:00
# LC08_L1TP_029006_20160805_20200906_02_T1 2016-08-05 00:00:00
# LC08_L1TP_029006_20140917_20200911_02_T1 2014-09-17 00:00:00
# LC08_L1TP_027006_20151008_20200908_02_T1 2015-10-08 00:00:00
# LC08_L1TP_032005_20160725_20200906_02_T1 2016-07-25 00:00:00
# LC08_L1TP_027006_20210805_20210811_02_T1 2021-08-05 00:00:00
# LC08_L1TP_032005_20190531_20200828_02_T1 2019-05-31 00:00:00
# LC08_L1TP_031005_20200713_20200912_02_T1 2020-07-13 00:00:00
# LC08_L1TP_029006_20150904_20200908_02_T1 2015-09-04 00:00:00
# LC08_L1TP_029006_20150312_20200909_02_T1 2015-03-12 00:00:00
# LC08_L1TP_031006_20170227_20200905_02_T1 2017-02-27 00:00:00
# LC08_L1TP_032005_20160420_20200907_02_T1 2016-04-20 00:00:00
# LC08_L1TP_029006_20150819_20200908_02_T1 2015-08-19 00:00:00
# LE07_L1TP_029006_20010516_20200917_02_T1 2001-05-16 00:00:00
# LC08_L1TP_031006_20160225_20200907_02_T1 2016-02-25 00:00:00
# LC08_L1TP_032005_20210418_20210424_02_T1 2021-04-18 00:00:00
# LC08_L1TP_027006_20160823_20200906_02_T1 2016-08-23 00:00:00
# LC08_L1TP_028006_20190401_20200829_02_T1 2019-04-01 00:00:00
# LC08_L1TP_028006_20190908_20200828_02_T1 2019-09-08 00:00:00
# LC08_L1TP_030006_20140823_20200911_02_T1 2014-08-23 00:00:00
# LC08_L1TP_027006_20160908_20200906_02_T1 2016-09-08 00:00:00
# LC08_L1TP_031006_20150918_20200908_02_T1 2015-09-18 00:00:00
# LC08_L1TP_028006_20150524_20200909_02_T1 2015-05-24 00:00:00
# LC08_L1TP_030006_20210725_20210803_02_T1 2021-07-25 00:00:00
# LC08_L1TP_029006_20171011_20200903_02_T1 2017-10-11 00:00:00
# LC08_L1TP_030006_20140807_20200911_02_T1 2014-08-07 00:00:00
# LC08_L1TP_030006_20191008_20200825_02_T1 2019-10-08 00:00:00
# LC08_L1TP_028006_20140505_20200911_02_T1 2014-05-05 00:00:00
# LE07_L1TP_031005_20020618_20200916_02_T1 2002-06-18 00:00:00
# LC08_L1TP_032005_20160303_20200907_02_T1 2016-03-03 00:00:00
# LE07_L1TP_029006_20030404_20200915_02_T1 2003-04-04 00:00:00
# LC08_L1TP_031006_20140627_20200911_02_T1 2014-06-27 00:00:00
# LC08_L1TP_031006_20150817_20200908_02_T1 2015-08-17 00:00:00
# LC08_L1TP_031006_20190929_20200825_02_T1 2019-09-29 00:00:00
# LC08_L1TP_030006_20151013_20200908_02_T1 2015-10-13 00:00:00
# LC08_L1TP_028006_20150929_20200908_02_T1 2015-09-29 00:00:00
# LC08_L1TP_028006_20210812_20210819_02_T1 2021-08-12 00:00:00
# LC08_L1TP_029006_20190915_20200826_02_T1 2019-09-15 00:00:00
# LC08_L1TP_029006_20140309_20200911_02_T1 2014-03-09 00:00:00
# LC08_L1TP_027006_20170826_20200903_02_T1 2017-08-26 00:00:00
# LC08_L1TP_031005_20210716_20210729_02_T1 2021-07-16 00:00:00
# LC08_L1TP_028006_20130923_20200913_02_T1 2013-09-23 00:00:00
# LC08_L1TP_028006_20180804_20200831_02_T1 2018-08-04 00:00:00
# LC08_L1TP_031006_20140323_20200911_02_T1 2014-03-23 00:00:00
# LC08_L1TP_030006_20180903_20200831_02_T1 2018-09-03 00:00:00
# LC08_L1TP_027006_20180813_20200831_02_T1 2018-08-13 00:00:00
# LC08_L1TP_031006_20170721_20200903_02_T1 2017-07-21 00:00:00
# LC08_L1TP_030006_20150506_20201015_02_T1 2015-05-06 00:00:00
# LC08_L1TP_032005_20190803_20200827_02_T1 2019-08-03 00:00:00
# LC08_L1TP_032005_20210909_20210916_02_T1 2021-09-09 00:00:00
# LC08_L1TP_028006_20210929_20211013_02_T1 2021-09-29 00:00:00
# LC08_L1TP_031005_20170721_20201016_02_T1 2017-07-21 00:00:00
# LE07_L1TP_028006_20000506_20200918_02_T1 2000-05-06 00:00:00
# LC08_L1TP_031006_20160312_20200907_02_T1 2016-03-12 00:00:00
# LE07_L1TP_029006_20001004_20200917_02_T1 2000-10-04 00:00:00
# LC08_L1TP_027006_20180930_20200830_02_T1 2018-09-30 00:00:00
# LC08_L1TP_032005_20200821_20200905_02_T1 2020-08-21 00:00:00
# LC08_L1TP_031006_20190727_20200828_02_T1 2019-07-27 00:00:00
# LC08_L1TP_029006_20151006_20200908_02_T1 2015-10-06 00:00:00
# LE07_L1TP_028006_20010930_20200917_02_T1 2001-09-30 00:00:00
# LC08_L1TP_032005_20150909_20200908_02_T1 2015-09-09 00:00:00
# LC08_L1TP_030006_20180412_20201015_02_T1 2018-04-12 00:00:00
# LE07_L1TP_030006_20010405_20200917_02_T1 2001-04-05 00:00:00
# LC08_L1TP_030006_20150607_20201016_02_T1 2015-06-07 00:00:00
# LC08_L1TP_031006_20170331_20200904_02_T1 2017-03-31 00:00:00
# LC08_L1TP_031006_20150310_20200909_02_T1 2015-03-10 00:00:00
# LC08_L1TP_032005_20170914_20200903_02_T1 2017-09-14 00:00:00
# LC08_L1TP_031005_20200915_20200919_02_T1 2020-09-15 00:00:00
# LC08_L1TP_029006_20210616_20210622_02_T1 2021-06-16 00:00:00
# LC08_L1TP_031005_20160531_20200906_02_T1 2016-05-31 00:00:00
# LC08_L1TP_031005_20190913_20200827_02_T1 2019-09-13 00:00:00
# LC08_L1TP_031006_20150411_20200909_02_T1 2015-04-11 00:00:00
# LC08_L1TP_031005_20170822_20201016_02_T1 2017-08-22 00:00:00
# LC08_L1TP_027006_20170319_20200904_02_T1 2017-03-19 00:00:00
# LE07_L1TP_028006_20020325_20200916_02_T1 2002-03-25 00:00:00
# LC08_L1TP_030006_20190906_20200828_02_T1 2019-09-06 00:00:00
# LC08_L1TP_027006_20210922_20210930_02_T1 2021-09-22 00:00:00
# LC08_L1TP_030006_20180701_20200831_02_T1 2018-07-01 00:00:00
# LE07_L1TP_027006_20010822_20200917_02_T1 2001-08-22 00:00:00
# LC08_L1TP_027006_20200615_20200823_02_T1 2020-06-15 00:00:00
# LC08_L1TP_028006_20160729_20200906_02_T1 2016-07-29 00:00:00
# LC08_L1TP_031006_20190524_20201015_02_T1 2019-05-24 00:00:00
# LC08_L1TP_028006_20150625_20200909_02_T1 2015-06-25 00:00:00
# LC08_L1TP_030006_20190821_20200828_02_T1 2019-08-21 00:00:00
# LE07_L1TP_027006_20030406_20200915_02_T1 2003-04-06 00:00:00
# LC08_L1TP_030006_20180311_20200901_02_T1 2018-03-11 00:00:00
#                                         Scene   datetime
# 189  LE07_L1TP_027006_19990630_20200918_02_T1 1999-06-30
# 51   LE07_L1TP_030006_19990705_20200918_02_T1 1999-07-05
# 93   LE07_L1TP_027006_19990716_20200918_02_T1 1999-07-16
# 188  LE07_L1TP_028006_19990723_20200918_02_T1 1999-07-23
# 133  LE07_L1TP_031006_19990829_20200918_02_T1 1999-08-29
# ..                                        ...        ...
# 102  LC08_L1TP_031005_20210918_20210925_02_T1 2021-09-18
# 15   LC08_L1TP_031006_20210918_20210925_02_T1 2021-09-18
# 272  LC08_L1TP_027006_20210922_20210930_02_T1 2021-09-22
# 25   LC08_L1TP_030006_20210927_20210930_02_T1 2021-09-27
# 246  LC08_L1TP_028006_20210929_20211013_02_T1 2021-09-29
#
# [282 rows x 2 columns]

# %%
# write dates to csv
datetime_df.to_csv(basepath+DATES_FILENAME, sep=',')

# %% [markdown]
# # 8) Delete all quality band files (*QA_PIXEL.TIF) to save space
#
# These files will not be needed after the download step, so they can be removed to save space.

# %%
for BoxID in BoxIDs:
    # Grab all path row folder names from boxes_pr_df:
    paths = boxes_pr_df.loc[BoxID,'Path']; rows = boxes_pr_df.loc[BoxID,'Row']
    
    for a in range(0, len(paths)): # look in each path row folder
        folder_name = 'Path'+paths[a]+'_Row'+rows[a]+'_c2'
        folderpath = downloadpath+folder_name+'/'
        
        # remove all files with QA_PIXEL in the name
        for file in os.listdir(folderpath):
            if 'QA_PIXEL' in file:
                os.remove(folderpath+file)
