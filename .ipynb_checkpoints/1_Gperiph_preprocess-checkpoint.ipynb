# %% [markdown]
# # Greenland peripheral glacier automated terminus detection image download and pre-processing
#
# By Jukes Liu (jukes.liu@boisestate.edu)
#
# _Last modified 05-20-2020._

# %% [markdown]
# # 1) Set-up: import necessary packages, set paths, and glaciers of interest

# %%
import numpy as np
import pandas as pd
import scipy
import math

import subprocess
import os
import shutil

import cv2
from PIL import Image
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

#geospatial packages
import fiona
import geopandas as gpd
from shapely.geometry import Polygon, Point
import shapely
import rasterio

# Enable fiona KML file reading driver
gpd.io.file.fiona.drvsupport.supported_drivers['KML'] = 'rw'

#Set base paths
basepath='/home/jukes/Documents/Sample_glaciers/' # folder containing the box shapefile and info
downloadpath = '/media/jukes/jukes1/LS8aws/' # folder to contain the downloaded images

# import necessary functions from automated-glacier-terminus.py
os.chdir('/home/jukes/automated-glacier-terminus') #import necessary functions:
from automated_terminus_functions import distance, resize_pngs

# %%
import sys
# !{sys.executable} -m pip install --upgrade imutils
# Out:
# Collecting imutils
#   Downloading imutils-0.5.3.tar.gz (17 kB)
# Building wheels for collected packages: imutils
#   Building wheel for imutils (setup.py) ... done
#   Created wheel for imutils: filename=imutils-0.5.3-py3-none-any.whl size=25850 sha256=65cdf17c62ac467474b456c979dc8ca3cee3e14c2c80c0a37e745c9b1551e6c2
#   Stored in directory: /home/jukes/.cache/pip/wheels/fc/9c/6d/1826267c72afa51b564c9c6e0f66abc806879338bc593a2270
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.3

# %% [markdown]
# #### Enter glaciers of interest by their 3-digit BoxIDs

# %%
BoxIDs = ['001', '002', '004', '033', '120', '174', '235', '259', '277', '531']# BoxIDs = np.arange(101, 301, 5)
# # BoxIDs = np.arange(100, 300, 5)
# BoxIDs = list(map(str, BoxIDs))
# BoxIDs.remove('141');
print(BoxIDs)
# Out:
# ['001', '002', '004', '033', '120', '174', '235', '259', '277', '531']

# %% [markdown]
# #### Create new folders corresponding to these glaciers

# %%
# create new BoxID folders 
for BoxID in BoxIDs:
    # create folder in Sample_glaciers
    if os.path.exists(basepath+'Box'+BoxID)==True:
#         shutil.rmtree(basepath+'Box'+BoxID)
        print("Path exists already in Sample_glaciers for Box", BoxID)
    else:
        os.mkdir(basepath+'Box'+BoxID)
        
    # move terminus box shapefile into the new folder
    ID = int(BoxID) # make into an integer in order to grab the .shp files from Boxes_individual
    boxespath = '/media/jukes/jukes1/Boxes_individual/'
    for file in os.listdir(boxespath):
        if file.startswith(str(ID)):
            if len(file) == len(str(ID))+4:
#             if file.endswith('.dbf') or file.endswith('.prj') or file.endswith('.qpj') or file.endswith('.shx') or file.endswith('.shp'):
                shutil.copyfile(boxespath+file, basepath+'Box'+BoxID+'/Box'+BoxID+file[-4:])

    # move RGI glacier outline into the new folder
    RGIpath = '/media/jukes/jukes1/RGI_shps/'
    for file in os.listdir(RGIpath):
        if file.startswith('BoxID_'+str(ID)):
            shutil.copyfile(RGIpath+file, basepath+'Box'+BoxID+'/RGI_Box'+BoxID+file[-4:])
            
    # make new download path folder
    if os.path.exists(downloadpath+'/Box'+BoxID)==True:
        print("Path exists already in LS8aws for Box", BoxID)
    else:
        os.mkdir(downloadpath+'/Box'+BoxID)
# Out:
# Path exists already in Sample_glaciers for Box 001
# Path exists already in LS8aws for Box 001
# Path exists already in Sample_glaciers for Box 002
# Path exists already in LS8aws for Box 002
# Path exists already in Sample_glaciers for Box 004
# Path exists already in LS8aws for Box 004
# Path exists already in Sample_glaciers for Box 033
# Path exists already in LS8aws for Box 033
# Path exists already in Sample_glaciers for Box 120
# Path exists already in LS8aws for Box 120
# Path exists already in Sample_glaciers for Box 174
# Path exists already in LS8aws for Box 174
# Path exists already in Sample_glaciers for Box 235
# Path exists already in LS8aws for Box 235
# Path exists already in Sample_glaciers for Box 259
# Path exists already in LS8aws for Box 259
# Path exists already in Sample_glaciers for Box 277
# Path exists already in LS8aws for Box 277
# Path exists already in Sample_glaciers for Box 531
# Path exists already in LS8aws for Box 531

# %% [markdown]
# # 2) Find all the Landsat Path Row identifiers that overlap the glaciers
#
# This step requires the WRS-2_bound_world.kml file containing the footprints of all the Landsat scene boundaries available through the USGS (https://www.usgs.gov/land-resources/nli/landsat/landsat-shapefiles-and-kml-files). To check if they overlap the glacier terminus box shapefiles, the box shapefiles must be reprojected into WRS84 coordinates (ESPG: 4326) using GDAL command line command:
#
#     ogr2ogr -f "ESRI Shapefile" -t_srs EPSG:NEW_EPSG_NUMBER -s_srs EPSG:OLD_EPSG_NUMBER output.shp input.shp

# %%
# reproject
for BoxID in BoxIDs:
    boxpath = basepath+"Box"+BoxID+"/Box"+BoxID
            
    rp = "ogr2ogr --config GDAL_DATA /usr/share/gdal/ -f 'ESRI Shapefile' -t_srs EPSG:4326 -s_srs EPSG:3413 "+boxpath+"_WRS.shp "+boxpath+".shp"
    subprocess.call(rp, shell=True)
    print(BoxID)
# Out:
# 001
# 002
# 004
# 033
# 120
# 174
# 235
# 259
# 277
# 531

# %%
# Grab the boxes' WRS84 coordinates
box_points = {}
for BoxID in BoxIDs:
    boxpath = basepath+"Box"+BoxID+"/Box"+BoxID; termbox = fiona.open(boxpath+'_WRS.shp')
    box = termbox.next()
    box_geom= box.get('geometry'); box_coords = box_geom.get('coordinates')[0]  
    points = [] # to hold the vertices
    for coord_pair in box_coords:
        lat = coord_pair[0]; lon = coord_pair[1]
        #create shapely pyoints and append to points list
        point = shapely.geometry.Point(lat, lon)
#         print(point)
        points.append(point)
    box_points.update({BoxID: points}); print("Box"+BoxID)
# Out:
# Box001
# Box002
# Box004
# Box033
# Box120
# Box174
# Box235
# Box259
# Box277
# Box531
# /home/jukes/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: FionaDeprecationWarning: Collection.__next__() is buggy and will be removed in Fiona 2.0. Switch to `next(iter(collection))`.
#   """

# %%
#open the kml file with the pathrow bounds as WRS
WRS = fiona.open(basepath+'WRS-2_bound_world.kml', driver='KML')

# %% [markdown]
# ### Loop through all the scene footprints and stores those that overlap ALL of your shapefile vertices:

# %%
#create lists to hold the paths and rows and BoxIDs
paths = []; rows = []; boxes = []

#loop through all features in the WRS .kml:
for feature in WRS:
    #create shapely polygons with the pathrow bounds
    coordinates = feature['geometry']['coordinates'][0]
    coords = [xy[0:2] for xy in coordinates]
#     print(coords)
    pathrow_poly = Polygon(coords)
    #grab the path and row name
    pathrowname = feature['properties']['Name']  
    path = pathrowname.split('_')[0]; row = pathrowname.split('_')[1]
#     print(path, row)
    
    #for each feature, loop through each of the box_points
    for BoxID in box_points:
        #create a counter for number of box_points in the pathrow_geom:
        box_points_in = 0
        
        points = box_points.get(BoxID)
        for i in range(0, len(points)):
            point = points[i]
            #if the pathrow shape contains the point
            if point.within(pathrow_poly):
#                 print("Found")
                #append the counter
                box_points_in = box_points_in+1
#         print(box_points_in)
        if box_points_in == 5:
            #save that path row and boxID
            paths.append('%03d' % int(path)); rows.append('%03d' % int(row))
            boxes.append(BoxID)

boxes_pr_df = pd.DataFrame(list(zip(boxes, paths, rows)), columns=['BoxID','Path', 'Row'])
boxes_pr_df = boxes_pr_df.sort_values(by='BoxID')
boxes_pr_df
# Out:
#    BoxID Path  Row
# 37   001  036  004
# 36   001  037  004
# 20   001  035  005
# 25   001  033  005
# 22   001  034  005
# 31   001  031  005
# 28   001  032  005
# 26   002  033  005
# 21   002  035  005
# 23   002  034  005
# 32   002  031  005
# 34   002  030  005
# 29   002  032  005
# 30   004  032  005
# 33   004  031  005
# 24   004  034  005
# 18   004  029  006
# 19   004  028  006
# 35   004  030  005
# 27   004  033  005
# 13   033  009  014
# 14   033  008  014
# 15   033  007  014
# 17   033  009  013
# 0    120  232  018
# 1    120  233  017
# 3    120  232  017
# 4    174  232  017
# 2    174  233  017
# 10   235  232  015
# 7    235  233  015
# 5    235  001  015
# 11   259  232  015
# 8    259  233  015
# 6    259  001  015
# 16   277  001  014
# 12   277  232  015
# 9    277  233  015
# 51   531  017  001
# 52   531  016  001
# 50   531  119  001
# 49   531  120  001
# 48   531  121  001
# 47   531  007  002
# 46   531  008  002
# 39   531  006  003
# 44   531  010  002
# 43   531  011  002
# 42   531  012  002
# 41   531  013  002
# 40   531  115  002
# 38   531  007  003
# 53   531  015  001
# 45   531  009  002
# 54   531  014  001

# %% [markdown]
# #### Write it to a csv file:

# %%
PR_FILENAME = 'LS_pathrows_sample10.csv'
# boxes_pr_df.to_csv(path_or_buf = basepath+PR_FILENAME, sep=',')

# %% [markdown]
# # 3) Download metadata (MTL.txt) files for all available images over glaciers
#
# Bulk download Landsat-8 images and metadata stored on the Amazon Web Services cloud (s3 bucket) over a region of interest using the Amazon Web Services command line interface. Follow instructions at https://docs.aws.amazon.com/cli/latest/userguide/cli-chap-install.html to get aws commands onto your command terminal. The syntax for grabbing an individual metadata file is as follows:
#
#      aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/path/row/LC08_XXXX_pathrow_yyyyMMdd_01_T1/LC08_XXXX_pathrow_yyyyMMdd_01_T1_MTL.txt /path_to/output/
#
# Access https://docs.opendata.aws/landsat-pds/readme.html to learn more.
#
# #### Download the metadatafiles into Path_Row folders created using:
#
#     aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/031/005/ Output/path/LS8aws/Path031_Row005/ --recursive --exclude "*" --include "*MTL.txt"

# %%
boxes_pr_df = pd.read_csv(basepath+PR_FILENAME, usecols=[0,1,2,3,4], dtype=str)
boxes_pr_df = boxes_pr_df.set_index('BoxID'); boxes_pr_df
# Out:
#       Unnamed: 0 Path  Row Zone
# BoxID
# 001           37  036  004   19
# 001           36  037  004   19
# 001           20  035  005   18
# 001           25  033  005   19
# 001           22  034  005   19
# 001           31  031  005   19
# 001           28  032  005   19
# 002           26  033  005   19
# 002           21  035  005   18
# 002           23  034  005   19
# 002           32  031  005   19
# 002           34  030  005   20
# 002           29  032  005   19
# 004           30  032  005   19
# 004           33  031  005   19
# 004           24  034  005   19
# 004           18  029  006   19
# 004           19  028  006   19
# 004           35  030  005   20
# 004           27  033  005   19
# 033           13  009  014   22
# 033           14  008  014   22
# 033           15  007  014   22
# 033           17  009  013   22
# 120            0  232  018   23
# 120            1  233  017   23
# 120            3  232  017   24
# 174            4  232  017   24
# 174            2  233  017   23
# 235           10  232  015   24
# 235            7  233  015   24
# 235            5  001  015   23
# 259           11  232  015   24
# 259            8  233  015   24
# 259            6  001  015   23
# 277           16  001  014   24
# 277           12  232  015   24
# 277            9  233  015   24
# 531           51  017  001   27
# 531           52  016  001   27
# 531           50  119  001  NaN
# 531           49  120  001  NaN
# 531           48  121  001  NaN
# 531           47  007  002   28
# 531           46  008  002   28
# 531           39  006  003   27
# 531           44  010  002   27
# 531           43  011  002   27
# 531           42  012  002   27
# 531           41  013  002   27
# 531           40  115  002  NaN
# 531           38  007  003   27
# 531           53  015  001   27
# 531           45  009  002   28
# 531           54  014  001   28

# %%
#Loop through the dataframe with your path row combinations:
for index, row in boxes_pr_df.iterrows():
    #grab the path row names and set the folder name
    path = row['Path']; row = row['Row']; folder_name = 'Path'+path+'_Row'+row+'_c1'

    #set path to access the image on the amazon cloud:
    bp_in = 's3://landsat-pds/c1/L8/'; totalp_in = bp_in+path+'/'+row+'/'
    #set output path for the downloaded files:
    bp_out = downloadpath+folder_name+'/'; print(bp_out)
    
    #create Path_Row folders and do the download if they don't exist already to hold the metadata
    if os.path.exists(bp_out):
        print(folder_name, " EXISTS ALREADY. SKIP.")
    else:
        os.mkdir(bp_out)
        print(folder_name+" directory made")

        command = 'aws --no-sign-request s3 cp '+totalp_in+' '+bp_out+' --recursive --exclude "*" --include "*MTL.txt"'
        print(command)

        #call the command line that downloads the metadata files using aws
        subprocess.call(command, shell=True)
# Out:
# /media/jukes/jukes1/LS8aws/Path036_Row004_c1/
# Path036_Row004_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/036/004/ /media/jukes/jukes1/LS8aws/Path036_Row004_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path037_Row004_c1/
# Path037_Row004_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/037/004/ /media/jukes/jukes1/LS8aws/Path037_Row004_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path035_Row005_c1/
# Path035_Row005_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/035/005/ /media/jukes/jukes1/LS8aws/Path035_Row005_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path033_Row005_c1/
# Path033_Row005_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/033/005/ /media/jukes/jukes1/LS8aws/Path033_Row005_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path034_Row005_c1/
# Path034_Row005_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/034/005/ /media/jukes/jukes1/LS8aws/Path034_Row005_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path031_Row005_c1/
# Path031_Row005_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/031/005/ /media/jukes/jukes1/LS8aws/Path031_Row005_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path032_Row005_c1/
# Path032_Row005_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/032/005/ /media/jukes/jukes1/LS8aws/Path032_Row005_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path033_Row005_c1/
# Path033_Row005_c1  EXISTS ALREADY. SKIP.
# /media/jukes/jukes1/LS8aws/Path035_Row005_c1/
# Path035_Row005_c1  EXISTS ALREADY. SKIP.
# /media/jukes/jukes1/LS8aws/Path034_Row005_c1/
# Path034_Row005_c1  EXISTS ALREADY. SKIP.
# /media/jukes/jukes1/LS8aws/Path031_Row005_c1/
# Path031_Row005_c1  EXISTS ALREADY. SKIP.
# /media/jukes/jukes1/LS8aws/Path030_Row005_c1/
# Path030_Row005_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/030/005/ /media/jukes/jukes1/LS8aws/Path030_Row005_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path032_Row005_c1/
# Path032_Row005_c1  EXISTS ALREADY. SKIP.
# /media/jukes/jukes1/LS8aws/Path032_Row005_c1/
# Path032_Row005_c1  EXISTS ALREADY. SKIP.
# /media/jukes/jukes1/LS8aws/Path031_Row005_c1/
# Path031_Row005_c1  EXISTS ALREADY. SKIP.
# /media/jukes/jukes1/LS8aws/Path034_Row005_c1/
# Path034_Row005_c1  EXISTS ALREADY. SKIP.
# /media/jukes/jukes1/LS8aws/Path029_Row006_c1/
# Path029_Row006_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/029/006/ /media/jukes/jukes1/LS8aws/Path029_Row006_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path028_Row006_c1/
# Path028_Row006_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/028/006/ /media/jukes/jukes1/LS8aws/Path028_Row006_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path030_Row005_c1/
# Path030_Row005_c1  EXISTS ALREADY. SKIP.
# /media/jukes/jukes1/LS8aws/Path033_Row005_c1/
# Path033_Row005_c1  EXISTS ALREADY. SKIP.
# /media/jukes/jukes1/LS8aws/Path009_Row014_c1/
# Path009_Row014_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/009/014/ /media/jukes/jukes1/LS8aws/Path009_Row014_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path008_Row014_c1/
# Path008_Row014_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/008/014/ /media/jukes/jukes1/LS8aws/Path008_Row014_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path007_Row014_c1/
# Path007_Row014_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/007/014/ /media/jukes/jukes1/LS8aws/Path007_Row014_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path009_Row013_c1/
# Path009_Row013_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/009/013/ /media/jukes/jukes1/LS8aws/Path009_Row013_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path232_Row018_c1/
# Path232_Row018_c1  EXISTS ALREADY. SKIP.
# /media/jukes/jukes1/LS8aws/Path233_Row017_c1/
# Path233_Row017_c1  EXISTS ALREADY. SKIP.
# /media/jukes/jukes1/LS8aws/Path232_Row017_c1/
# Path232_Row017_c1  EXISTS ALREADY. SKIP.
# /media/jukes/jukes1/LS8aws/Path232_Row017_c1/
# Path232_Row017_c1  EXISTS ALREADY. SKIP.
# /media/jukes/jukes1/LS8aws/Path233_Row017_c1/
# Path233_Row017_c1  EXISTS ALREADY. SKIP.
# /media/jukes/jukes1/LS8aws/Path232_Row015_c1/
# Path232_Row015_c1  EXISTS ALREADY. SKIP.
# /media/jukes/jukes1/LS8aws/Path233_Row015_c1/
# Path233_Row015_c1  EXISTS ALREADY. SKIP.
# /media/jukes/jukes1/LS8aws/Path001_Row015_c1/
# Path001_Row015_c1  EXISTS ALREADY. SKIP.
# /media/jukes/jukes1/LS8aws/Path232_Row015_c1/
# Path232_Row015_c1  EXISTS ALREADY. SKIP.
# /media/jukes/jukes1/LS8aws/Path233_Row015_c1/
# Path233_Row015_c1  EXISTS ALREADY. SKIP.
# /media/jukes/jukes1/LS8aws/Path001_Row015_c1/
# Path001_Row015_c1  EXISTS ALREADY. SKIP.
# /media/jukes/jukes1/LS8aws/Path001_Row014_c1/
# Path001_Row014_c1  EXISTS ALREADY. SKIP.
# /media/jukes/jukes1/LS8aws/Path232_Row015_c1/
# Path232_Row015_c1  EXISTS ALREADY. SKIP.
# /media/jukes/jukes1/LS8aws/Path233_Row015_c1/
# Path233_Row015_c1  EXISTS ALREADY. SKIP.
# /media/jukes/jukes1/LS8aws/Path017_Row001_c1/
# Path017_Row001_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/017/001/ /media/jukes/jukes1/LS8aws/Path017_Row001_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path016_Row001_c1/
# Path016_Row001_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/016/001/ /media/jukes/jukes1/LS8aws/Path016_Row001_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path119_Row001_c1/
# Path119_Row001_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/119/001/ /media/jukes/jukes1/LS8aws/Path119_Row001_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path120_Row001_c1/
# Path120_Row001_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/120/001/ /media/jukes/jukes1/LS8aws/Path120_Row001_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path121_Row001_c1/
# Path121_Row001_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/121/001/ /media/jukes/jukes1/LS8aws/Path121_Row001_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path007_Row002_c1/
# Path007_Row002_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/007/002/ /media/jukes/jukes1/LS8aws/Path007_Row002_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path008_Row002_c1/
# Path008_Row002_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/008/002/ /media/jukes/jukes1/LS8aws/Path008_Row002_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path006_Row003_c1/
# Path006_Row003_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/006/003/ /media/jukes/jukes1/LS8aws/Path006_Row003_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path010_Row002_c1/
# Path010_Row002_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/010/002/ /media/jukes/jukes1/LS8aws/Path010_Row002_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path011_Row002_c1/
# Path011_Row002_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/011/002/ /media/jukes/jukes1/LS8aws/Path011_Row002_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path012_Row002_c1/
# Path012_Row002_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/012/002/ /media/jukes/jukes1/LS8aws/Path012_Row002_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path013_Row002_c1/
# Path013_Row002_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/013/002/ /media/jukes/jukes1/LS8aws/Path013_Row002_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path115_Row002_c1/
# Path115_Row002_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/115/002/ /media/jukes/jukes1/LS8aws/Path115_Row002_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path007_Row003_c1/
# Path007_Row003_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/007/003/ /media/jukes/jukes1/LS8aws/Path007_Row003_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path015_Row001_c1/
# Path015_Row001_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/015/001/ /media/jukes/jukes1/LS8aws/Path015_Row001_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path009_Row002_c1/
# Path009_Row002_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/009/002/ /media/jukes/jukes1/LS8aws/Path009_Row002_c1/ --recursive --exclude "*" --include "*MTL.txt"
# /media/jukes/jukes1/LS8aws/Path014_Row001_c1/
# Path014_Row001_c1 directory made
# aws --no-sign-request s3 cp s3://landsat-pds/c1/L8/014/001/ /media/jukes/jukes1/LS8aws/Path014_Row001_c1/ --recursive --exclude "*" --include "*MTL.txt"

# %% [markdown]
# # 4) Determine how cloudy the images are using the LS quality band files subset to terminus box
#
# Use gdalwarp commands and the __vsicurl__ link to download subset of the quality band we will use to determine cloud cover:
#
#     gdalwarp -cutline path_to_shp.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/031/005/imagename/imagename_BQA.TIF path_to_subsetBQA.TIF
#
# These will need to go into the newly created BoxID folders because the subset of the same image for different boxes will be different. We will need to reproject the shapefiles into UTM to match the LS8 bands. We must grab the UTM zones from the metadata files downloaded and fill in the following syntax:
#
#     ogr2ogr -f "ESRI Shapefile" -t_srs EPSG:326zone -s_srs EPSG:3413 output.shp input.shp

# %%
zones = {}; zone_df = []

#Loop through the dataframe with your path row combinations:
for index, row in boxes_pr_df.iterrows():
    path = row['Path']; row = row['Row']; BoxID = str(index); folder_name = 'Path'+path+'_Row'+row+'_c1'
    
    #set path to path row folders to grab scenes from and output path according to each of the BoxIDs
    pr_folderpath = downloadpath+folder_name+'/'
    
    #set shapefile path for each BoxID
    pathtoshp = basepath+"Box"+BoxID+"/Box"+BoxID
    
    #if there are files in the folder:
    if len(os.listdir(pr_folderpath)) > 0:
        #grab UTM Zone from the first metadata file in the pr_folderpath
        mtl_scene = os.listdir(pr_folderpath)[0]
        mtl = open(pr_folderpath+mtl_scene+'/'+mtl_scene+'_MTL.txt', 'r')
        
        #loop through each line in metadata to find the UTM ZONE
        for line in mtl:
            variable = line.split("=")[0]
            if ("UTM_ZONE" in variable): 
                #save it:
                zone = '%02d' % int(line.split("=")[1][1:-1])
                zones.update({folder_name: zone}); zone_df.append(zone)
                
        #reproject shapefile(s) into UTM
        zone = zones[folder_name]
        rp_shp = 'ogr2ogr -f "ESRI Shapefile" -t_srs EPSG:326'+zone+' -s_srs EPSG:4326 '+pathtoshp+"_UTM_"+zone+".shp "+pathtoshp+"_WRS.shp"
        subprocess.call(rp_shp, shell=True)
    #if not, append nan to zone and do nothing
    else:
        zone_df.append(np.nan)
        
    #grab the names of the LS8 scenes from the downloaded metadatafiles using os.listdir() in the Path_Row folders
    scenes = os.listdir(pr_folderpath)

    for scene in scenes:
        #if the file grabbed does correspond to a Landsat scene (starts with LC08):
        if len(scenes) > 0 and scene.startswith("LC08"):            
            #set path to reprojected box shp
            pathtoshp_rp = pathtoshp+'_UTM_'+zones[folder_name]
            
            #set path to the quality band (BQA.TIF) in the cloud using the scenename
            pathtoBQA = '/vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/'+path+'/'+row+'/'+scene+"/"+scene+"_BQA.TIF"
            subsetout = pr_folderpath+scene+"/"+scene+'_BQA_Box'+BoxID+'.TIF'

            #Check download command syntax
            BQA_dwnld_cmd = 'gdalwarp -cutline '+pathtoshp_rp+'.shp -crop_to_cutline '+pathtoBQA+' '+subsetout

            #When you've checked everything, uncomment the following to run:
            subprocess.call(BQA_dwnld_cmd, shell=True)
            print(scene+'_BQA_Box'+BoxID+'.TIF subset downloaded')

boxes_pr_df['Zone'] = zone_df
print("Done.")
# Out:
# LC08_L1TP_036004_20170521_20170526_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20150329_20170228_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20190916_20190925_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20160331_20170223_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20180625_20180626_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20160416_20170223_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20180913_20180913_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1GT_036004_20200326_20200326_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20180727_20180731_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20170419_20170501_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20190527_20190528_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20190308_20190324_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20170825_20170825_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20190308_20190308_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20150905_20170225_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20190730_20190731_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20200411_20200411_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20170622_20170623_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1GT_036004_20190409_20190409_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20180406_20180406_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20150617_20170226_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20180508_20180517_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20170505_20170515_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20180828_20180911_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20150313_20170412_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20160502_20170223_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20140614_20170305_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20180321_20180321_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20180711_20180717_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_036004_20180609_20180610_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1GT_036004_20190511_20190511_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20140918_20170419_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20200411_20200422_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20140411_20170307_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20200310_20200325_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20170403_20170414_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20150414_20170301_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20190628_20190628_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20150601_20170226_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20170724_20170809_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20150921_20170225_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20170809_20170824_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20190612_20190619_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20150804_20170226_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20140716_20170421_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20150430_20170301_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20151007_20170225_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20180828_20180828_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20170724_20170724_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20180913_20180928_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20190831_20190831_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20160619_20170221_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20170622_20170630_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20190324_20190403_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_036004_20180812_20180812_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20190612_20190612_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20190916_20190916_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20150703_20170226_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_036004_20180305_20180305_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20140630_20170304_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20180625_20180704_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_036004_20191002_20191002_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20170318_20170328_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20180508_20180509_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20170521_20170521_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20170708_20170709_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20190815_20190820_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20170809_20170809_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20180929_20180929_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20190714_20190714_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20160721_20170223_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20170708_20170717_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20190714_20190720_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20140902_20170303_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20190425_20190508_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20160907_20170221_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20170910_20170927_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20160806_20170221_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20190527_20190605_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20180711_20180711_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20170606_20170606_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20150820_20170225_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20180422_20180422_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20200513_20200514_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20180929_20181009_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20160518_20170223_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20190628_20190706_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20190425_20190425_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20150516_20170227_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20170825_20170913_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20170910_20170910_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20200427_20200428_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20160923_20170222_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20200310_20200311_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20190815_20190815_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20190324_20190324_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20180321_20180403_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20170606_20170616_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20180406_20180417_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_036004_20190831_20190916_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20130906_20170309_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20180819_20180820_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20150928_20170225_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20180702_20180702_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20190923_20190926_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20200504_20200509_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20160610_20170223_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20190518_20190522_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20181006_20181010_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20130517_20170504_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20190331_20190401_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20190923_20190923_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20170325_20170329_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20170917_20170929_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20190315_20190325_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20190822_20190822_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20160712_20170221_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20170309_20180125_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20150405_20170301_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20150608_20170226_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20200504_20200504_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20140605_20180130_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20180328_20180328_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20180920_20180920_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20190502_20190508_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20200402_20200403_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20170426_20170502_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20170629_20170629_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20170528_20170615_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20180312_20180312_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20170816_20170825_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20150320_20170301_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20140504_20170423_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20190603_20190618_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20170528_20170528_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20190822_20190903_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20190331_20190404_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20180803_20180814_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20180531_20180531_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20190705_20190719_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20190502_20190503_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20180515_20180604_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20180515_20180516_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20170629_20170714_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20180904_20180904_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20180429_20180502_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20190619_20190703_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_037004_20170715_20170716_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20180702_20180717_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20140621_20170304_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20160423_20170223_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20180616_20180617_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20180616_20180703_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20180429_20180429_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1GT_037004_20170731_20170801_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20160525_20170223_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20190518_20190519_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20200418_20200423_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20200418_20200418_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20170816_20170817_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20160829_20170222_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20160407_20170223_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20140824_20170303_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20170309_20170317_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20190416_20190423_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20190705_20190706_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20140520_20170307_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20150624_20170226_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20170917_20170918_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20160813_20170223_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20190721_20190801_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20180328_20180405_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20180803_20180803_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20190907_20190907_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20140723_20170304_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20180718_20180731_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20140707_20170304_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20170512_20170525_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20150421_20170227_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20180819_20180829_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20180904_20180912_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20180413_20180417_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20160509_20170223_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20140925_20170303_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_037004_20170901_20170901_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20160626_20170222_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_037004_20170613_20170613_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20160728_20170221_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20190315_20190315_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20190603_20190603_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20190416_20190416_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20140909_20170303_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20140808_20170304_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20150726_20170226_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20190619_20190619_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20150827_20170225_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20190721_20190721_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20150912_20170225_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20180718_20180718_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20180531_20180614_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20181006_20181006_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20150811_20170226_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20190907_20190917_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20190806_20190806_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20160322_20170224_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20180413_20180413_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20180920_20180928_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_037004_20171003_20171003_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20170512_20170512_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_037004_20150710_20170226_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20150626_20170226_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20200319_20200326_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20160628_20170222_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20150525_20170226_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20170919_20170920_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20170701_20170715_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20180922_20180922_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20130503_20170310_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20200420_20200508_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20180602_20180615_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20180501_20180516_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20170514_20170514_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20180415_20180501_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20150712_20170226_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20160831_20170222_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20181008_20181029_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20170919_20170930_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20150423_20170228_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20170428_20170515_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20180602_20180602_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20161002_20170220_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20140522_20170307_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_035005_20190418_20190418_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1GT_035005_20170903_20170903_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20190520_20190604_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20190909_20190917_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20140709_20170304_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20180704_20180717_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20170615_20170615_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20200404_20200405_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20150322_20170228_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20190520_20190521_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20140623_20170304_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20170530_20170530_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20180906_20180906_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20180720_20180731_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20160612_20170223_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20140826_20170303_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20190621_20190704_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20170717_20170718_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20140319_20170425_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20150829_20170225_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20180720_20180720_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20170412_20170501_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20170802_20170803_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20160730_20170222_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20180330_20180405_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20170311_20170317_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20170615_20170629_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20140810_20170304_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20190605_20190605_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20200319_20200319_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20190605_20190618_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20160714_20170221_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20200506_20200507_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20190504_20190520_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20190402_20190402_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20181008_20181008_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20190723_20190801_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20160527_20170223_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_035005_20190824_20190824_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20170717_20170727_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20190301_20190309_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20200506_20200509_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_035005_20171005_20171005_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20190402_20190421_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20180501_20180501_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20160324_20170224_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_035005_20190808_20190808_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20180821_20180829_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20190301_20190301_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20170818_20170826_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20190317_20190325_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20190504_20190505_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20190707_20190719_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20180906_20180912_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20170818_20170819_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1GT_035005_20191011_20191011_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20130908_20170309_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_035005_20180618_20180619_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20160815_20180131_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20190621_20190621_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20150813_20180130_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_035005_20190925_20190925_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20170701_20170702_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1GT_035005_20180805_20180806_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20160511_20180131_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_035005_20200303_20200303_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20180922_20180928_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20170327_20170414_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20180517_20180604_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20190707_20190707_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20180314_20180315_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20150728_20170226_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20190723_20190723_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20150509_20170301_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20180821_20180821_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20200420_20200420_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20170530_20170615_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20190317_20190317_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20180517_20180518_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20190909_20190909_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20180704_20180705_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20150610_20170226_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20180415_20180415_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20150306_20170227_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20150407_20170227_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20130823_20170309_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20140506_20170306_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20180330_20180330_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20170514_20170525_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_035005_20130924_20180130_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20140913_20170419_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20180401_20180401_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20140609_20170422_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20140929_20170418_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20170430_20170515_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20150511_20170409_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20190709_20190709_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20180807_20180815_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20170329_20170414_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20190725_20190725_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20170516_20170516_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20180401_20180416_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20160716_20170323_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20150714_20170407_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20180620_20180703_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20190810_20190810_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20170719_20170720_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1GT_033005_20180706_20180707_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1GT_033005_20180722_20180722_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20170820_20170826_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20150730_20170406_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20160529_20170324_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20180316_20180316_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20190506_20190506_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20170820_20170820_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20190927_20191001_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20170719_20170728_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20170313_20170328_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20150815_20170406_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20160513_20170324_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20140524_20170422_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20180924_20180929_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20171007_20171023_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20140625_20170304_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20180908_20180912_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20190911_20190911_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20200406_20200410_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20150831_20170404_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20160918_20170321_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20190420_20190507_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20160801_20170322_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20170617_20170629_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_033005_20190404_20190404_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20170921_20171012_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20150409_20170410_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20170703_20170703_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20150628_20170407_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20200508_20200508_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20150612_20170408_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20180604_20180615_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20170414_20170501_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20150308_20170412_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20190303_20190303_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20170905_20170905_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20180519_20180520_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20140812_20170420_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20150425_20180130_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20170905_20170917_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20181010_20181010_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1GT_033005_20180228_20180228_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1GT_033005_20170804_20170804_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20200321_20200326_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20180519_20180605_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20180620_20180621_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20190319_20190325_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20160310_20170328_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20180316_20180402_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20180503_20180516_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20170921_20170921_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20180417_20180501_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_033005_20190623_20190623_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20190607_20190607_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20180604_20180604_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20180908_20180908_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20170921_20180125_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20190506_20190521_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_033005_20180823_20180823_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20160326_20170327_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20190607_20190619_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20180807_20180808_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20200422_20200423_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20170516_20170525_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20190709_20190719_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20130505_20170310_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20171007_20171007_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20160614_20170324_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20130323_20170310_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_033005_20190826_20190826_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20190911_20190917_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20190420_20190420_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20180924_20180924_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20170703_20170715_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20190725_20190801_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20190927_20191017_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20140508_20170422_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20150324_20170411_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20200305_20200305_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20190319_20190319_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20130910_20170502_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20180503_20180503_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20130926_20170501_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20150527_20170408_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20190522_20190604_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20200321_20200321_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20140727_20170304_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20170601_20170602_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20190303_20190309_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20200305_20200314_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20170617_20170617_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20140711_20170304_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_033005_20180417_20180417_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20170928_20171013_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20190326_20190403_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20200312_20200325_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20160707_20170221_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20180814_20180814_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1GT_034005_20180729_20180729_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20140920_20170303_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20200328_20200328_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20180713_20180714_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20160808_20170221_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20140413_20170307_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20160621_20170221_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20150603_20170226_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_034005_20200429_20200429_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20170608_20170616_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20170912_20170912_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20140328_20170424_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_034005_20170710_20170710_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20160605_20170223_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20190902_20190916_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20170320_20170328_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20150923_20180130_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20160418_20170223_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20190817_20190817_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20160301_20180131_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20170608_20170609_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20180424_20180424_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20150416_20170227_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20140904_20170303_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20160402_20170223_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20180408_20180417_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20150518_20170228_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20181001_20181001_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20190326_20190326_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20180611_20180612_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20130901_20170309_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20180814_20180828_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20180323_20180323_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20190513_20190521_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20170726_20170810_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20181001_20181010_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20190529_20190529_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20180713_20180730_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_034005_20170624_20170624_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1GT_034005_20170827_20170827_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20180526_20180526_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20190630_20190706_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20170912_20170928_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20160723_20180131_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20140702_20170304_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20180408_20180409_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20180627_20180627_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20150331_20170228_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20190918_20190926_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20160824_20170221_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20180627_20180704_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20180510_20180511_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20170928_20170928_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20190411_20190411_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20200312_20200313_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20190614_20190620_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_034005_20170523_20170523_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20180323_20180403_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20180611_20180615_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20180510_20180517_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20150822_20170225_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20140515_20170306_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20170726_20170726_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20150721_20170226_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20180424_20180502_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20160504_20170223_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20190817_20190902_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20150907_20170301_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20180526_20180605_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20180830_20180830_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20190427_20190508_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20190513_20190513_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20190918_20190918_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1GT_034005_20191004_20191004_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20200413_20200413_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20190902_20190902_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20190716_20190721_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20170405_20170414_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20190411_20190422_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20150705_20170226_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20180830_20180911_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_034005_20180915_20180915_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20190310_20190310_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20150502_20180130_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20190716_20190716_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20190801_20190801_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1GT_034005_20170811_20170811_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20160317_20170224_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20190310_20190325_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20190529_20190605_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20180307_20180307_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20170421_20170501_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20190427_20190427_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20130405_20170310_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20190614_20190614_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20130917_20170309_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_034005_20200328_20200409_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20160429_20170326_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20190711_20190719_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20200408_20200408_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20150630_20170407_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20180622_20180703_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20130827_20170502_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20140915_20170419_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20150801_20170406_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20180521_20180605_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20150614_20170407_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20190508_20190521_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20161006_20170320_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20190913_20190917_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_031005_20171009_20171009_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20170923_20170923_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20190508_20190508_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20170331_20170414_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20190625_20190705_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20190321_20190321_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20180606_20180607_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20180302_20180303_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20180825_20180829_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20140526_20170422_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20180318_20180403_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20180910_20180910_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20180724_20180731_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20151004_20170403_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20150427_20170409_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20180505_20180506_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20150411_20170410_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20170416_20170501_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20170619_20170630_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20190727_20190727_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20140323_20170424_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20200307_20200307_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20180708_20180717_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20181012_20181012_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20190524_20190604_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20130928_20170502_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20180505_20180517_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20150310_20170412_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20190406_20190422_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20170721_20170728_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20190609_20190619_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20170705_20170716_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20200323_20200323_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20170518_20170519_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1GT_031005_20170806_20170806_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20150918_20170404_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20150513_20170409_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20170603_20170604_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20180926_20181009_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_031005_20180809_20180810_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20180521_20180521_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20141001_20170418_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20140830_20170420_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20190727_20190801_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20200408_20200422_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20180910_20180927_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1GT_031005_20170907_20170907_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20181012_20181030_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20180403_20180404_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20130523_20170504_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20200510_20200510_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20180419_20180419_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20170721_20170721_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20160328_20170327_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20160702_20170323_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20170822_20170912_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20160531_20170324_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20160616_20170323_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20170705_20170705_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20190929_20191001_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20160718_20170323_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20130402_20170310_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20190711_20190711_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20190422_20190422_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20180825_20180825_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20160904_20170321_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20170822_20170822_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20150529_20170408_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20200307_20200314_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20150817_20170406_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20180606_20180615_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20150716_20170407_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20180318_20180318_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20140814_20170420_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20180708_20180708_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20190422_20190507_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20200424_20200425_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1GT_031005_20190305_20190305_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20140713_20170421_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20160515_20170324_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20190406_20190406_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1GT_031005_20190828_20190829_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20180403_20180417_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20190625_20190625_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20150902_20170404_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20170923_20171013_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20140627_20170421_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20180926_20180926_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20140408_20170423_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20190609_20190609_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20170619_20170619_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20180622_20180623_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20190913_20190913_01_RT_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20170603_20170615_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20170315_20170328_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20170502_20170515_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20180419_20180502_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20160312_20170328_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_031005_20160413_20170326_01_T1_BQA_Box001.TIF subset downloaded
# LC08_L1TP_032005_20170423_20170502_01_T1_BQA_Box001.TIF subset downloaded
# ...
# LC08_L1TP_015001_20180403_20180417_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20170806_20170813_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20170603_20170615_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20170619_20170629_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20170619_20170619_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20140729_20170420_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20190406_20190406_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20170705_20170705_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20160718_20170323_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20180926_20181009_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20190524_20190604_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20150716_20170407_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1GT_015001_20180708_20180708_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20170502_20170515_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20180809_20180815_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20150801_20170406_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20140830_20180528_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20160819_20170322_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20160702_20170323_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20200510_20200510_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20170705_20170716_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20180606_20180615_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20170416_20170501_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20180926_20180926_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20180825_20180829_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20190508_20190508_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20130421_20170505_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20180910_20180910_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20190422_20190422_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_015001_20140713_20170304_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20180831_20180831_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20160926_20170320_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20180409_20180417_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20190428_20190508_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20170508_20170508_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20150417_20170409_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20180425_20180502_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20160419_20170326_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20180628_20180628_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20190311_20190311_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20200430_20200430_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20160809_20170322_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20140329_20170424_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20150316_20170412_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20200329_20200329_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20150807_20170406_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20160521_20170324_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20190717_20190717_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20150823_20170405_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20190717_20190731_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20140804_20170420_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20190412_20190412_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20170727_20170727_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1GT_009002_20200414_20200414_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20190802_20190819_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20150908_20170404_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20190903_20190917_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20170609_20170616_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20180425_20180425_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20190701_20190706_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20170609_20170609_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1GT_009002_20180916_20180916_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20170828_20170828_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20170524_20170614_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20170508_20170515_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20200329_20200409_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20180714_20180730_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20190412_20190422_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20180527_20180605_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20180527_20180527_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20190514_20190521_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20170727_20170810_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20200313_20200315_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20160606_20170324_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20150503_20170409_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20190615_20190615_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20200430_20200509_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20180730_20180814_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20160708_20170323_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20190514_20190514_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20190311_20190325_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20160910_20180130_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20180730_20180730_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20160403_20170327_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20190802_20190802_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20130427_20170505_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20140601_20170422_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20140820_20170420_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1GT_009002_20190327_20190327_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20180815_20180815_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20130401_20170505_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20150620_20170407_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20180815_20180828_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20170828_20170914_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20150924_20170403_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20170711_20170726_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20180628_20180704_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20170625_20170625_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20170625_20170713_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20150401_20170411_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20170812_20170812_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20190701_20190701_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20150519_20170408_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20160622_20170323_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20180831_20180912_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20180612_20180612_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20180714_20180714_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20190615_20190620_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20170524_20170524_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20170422_20170501_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20170406_20170414_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20170711_20170711_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20140414_20170423_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20140617_20170421_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20190903_20190903_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20160724_20170322_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20190428_20190428_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20180409_20180409_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20140719_20170421_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20170812_20170824_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_009002_20150706_20170407_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1GT_014001_20200316_20200317_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20190602_20190618_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20170730_20170731_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20140620_20170305_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20190415_20190415_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20180514_20180604_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20150319_20180130_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20180717_20180730_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20190602_20190602_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20180412_20180417_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20180327_20180404_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20160321_20170327_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20180802_20180814_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20180802_20180802_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20130820_20170502_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20160422_20170326_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20150506_20170409_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20180818_20180829_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20150404_20170411_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20150709_20170407_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20170511_20170511_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20180530_20180530_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20180428_20180502_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20150810_20170406_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20200503_20200503_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20180530_20180614_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20130921_20170502_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20180717_20180717_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20180701_20180701_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20170511_20170525_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20140604_20180130_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20190415_20190423_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20160406_20170327_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20170425_20170502_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20150420_20170409_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20150911_20170404_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20170409_20170414_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20160508_20170325_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20170916_20170917_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20140823_20170420_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20190821_20190821_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20180701_20180716_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20170628_20170714_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20170831_20170915_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20160625_20180130_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1GT_014001_20180615_20180616_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20160812_20170322_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20190330_20190404_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20140706_20170304_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20140924_20170419_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20190922_20190922_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1GT_014001_20200401_20200401_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20170527_20170527_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20160524_20170324_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20190517_20190521_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20170714_20170726_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20140908_20170419_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20180327_20180327_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20180428_20180428_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20170916_20170929_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20170730_20170811_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20140503_20170423_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1GT_014001_20200417_20200417_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20160913_20170321_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20190805_20190805_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20190501_20190508_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20150623_20170407_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20180919_20180928_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20170324_20170329_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20190501_20190501_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20180412_20180412_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20140807_20170420_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20200503_20200509_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1GT_014001_20170815_20170815_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20180818_20180818_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20190517_20190517_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20170628_20170628_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20180903_20180912_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20150927_20170403_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20130905_20170502_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20160828_20170321_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20190330_20190401_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20190922_20190926_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20160711_20170323_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20180514_20180515_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20170527_20170615_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20170714_20170714_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20160727_20170322_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20180903_20180903_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20170831_20170831_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1GT_014001_20170612_20170612_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20180919_20180919_01_RT_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20150522_20170408_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20140722_20170304_01_T1_BQA_Box531.TIF subset downloaded
# LC08_L1TP_014001_20190821_20190903_01_T1_BQA_Box531.TIF subset downloaded
# Done.

# %% [markdown]
# #### Re-save csv file with the zone information

# %%
PR_FILENAME = 'LS_pathrows_sample10.csv'
boxes_pr_df.to_csv(path_or_buf = basepath+PR_FILENAME, sep=',')

# %% [markdown]
# # 5) Create buffer zone around terminus boxes and rasterize/subset terminus boxes (used for cropping and masknig later on)

# %% [markdown]
# The following code pulls the buffer distances around the terminus boxes from an existing .csv file with the exported attributes tables for the peripheral glacier terminus boxes. These buffer distances will be used to create a buffer zone to subset the Landsat scenes.

# %%
buffers = []
#Calculate a buffer distance around the terminus box using the UTM projected boxes
for BoxID in BoxIDs:
    buff_distances = []

    for file in os.listdir(basepath+'Box'+BoxID+'/'):
        if 'UTM' in file and '.shp' in file and "Box" in file:
            print(file)
            boxpath = basepath+"Box"+BoxID+"/"+file  
            termbox = fiona.open(boxpath)
            #grab the box feature:
            box = termbox.next(); box_geom= box.get('geometry'); box_coords = box_geom.get('coordinates')[0]
            points = []
            for coord_pair in box_coords:
                lat = coord_pair[0]; lon = coord_pair[1]; points.append([lat, lon])
            
            #Calculate distance between 1 and 2 and distance between 2 and 3 and pick the longer one
            coord1 = points[0]; coord2 = points[1]; coord3 = points[2]   
            dist1 = distance(coord1[0], coord1[1], coord2[0], coord2[1]);
            dist2 = distance(coord2[0], coord2[1], coord3[0], coord3[1])  
            buff_dist = int(np.max([dist1, dist2]))
            buff_distances.append(buff_dist) 
    buffer = buff_distances[0]; buffers.append(buffer)
buff_df = pd.DataFrame(list(zip(BoxIDs, buffers)), columns=['BoxID', 'Buff_dist_m'])
buff_df
# Out:
# Box001_UTM_18.shp
# Box001_UTM_19.shp
# Box002_UTM_20.shp
# Box002_UTM_18.shp
# Box002_UTM_19.shp
# Box004_UTM_20.shp
# Box004_UTM_19.shp
# Box033_UTM_22.shp
# Box120_UTM_23.shp
# Box120_UTM_24.shp
# Box174_UTM_23.shp
# Box174_UTM_24.shp
# Box235_UTM_23.shp
# Box235_UTM_24.shp
# Box259_UTM_23.shp
# Box259_UTM_24.shp
# Box277_UTM_24.shp
# Box531_UTM_28.shp
# Box531_UTM_27.shp
# /home/jukes/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: FionaDeprecationWarning: Collection.__next__() is buggy and will be removed in Fiona 2.0. Switch to `next(iter(collection))`.
#   if sys.path[0] == '':
#   BoxID  Buff_dist_m
# 0   001         1135
# 1   002         4354
# 2   004         4597
# 3   033         3605
# 4   120         1048
# 5   174         2027
# 6   235         1643
# 7   259         2965
# 8   277         1379
# 9   531         1790

# %% [markdown]
# The next section creates a buffer zone shapefile using GDAL command **ogr2ogr** with the following syntax:
#
#     ogr2ogr Buffer###.shp path_to_terminusbox###.shp  -dialect sqlite -sql "SELECT ST_Buffer(geometry, buffer_distance) AS geometry,*FROM 'Box###'" -f "ESRI Shapefile"

# %%
for index, row in buff_df.iterrows():
    BoxID = row['BoxID']
    buff_dist = str(row['Buff_dist_m'])
    
    #SET path to the terminus box shapefiles
    terminusbox_path = basepath+"Box"+BoxID+"/Box"+BoxID+".shp"
    outputbuffer_path = basepath+"Box"+BoxID+"/Buffer"+BoxID+".shp"
    
    #SET buffer command and print to check it
    buffer_cmd = 'ogr2ogr '+outputbuffer_path+" "+terminusbox_path+' -dialect sqlite -sql "SELECT ST_Buffer(geometry, '+buff_dist+") AS geometry,*FROM 'Box"+BoxID+"'"+'" -f "ESRI Shapefile"'
    print(buffer_cmd)
    
    subprocess.call(buffer_cmd, shell=True) 
    print("Box"+BoxID)
# Out:
# ogr2ogr /home/jukes/Documents/Sample_glaciers/Box001/Buffer001.shp /home/jukes/Documents/Sample_glaciers/Box001/Box001.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 1135) AS geometry,*FROM 'Box001'" -f "ESRI Shapefile"
# Box001
# ogr2ogr /home/jukes/Documents/Sample_glaciers/Box002/Buffer002.shp /home/jukes/Documents/Sample_glaciers/Box002/Box002.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 4354) AS geometry,*FROM 'Box002'" -f "ESRI Shapefile"
# Box002
# ogr2ogr /home/jukes/Documents/Sample_glaciers/Box004/Buffer004.shp /home/jukes/Documents/Sample_glaciers/Box004/Box004.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 4597) AS geometry,*FROM 'Box004'" -f "ESRI Shapefile"
# Box004
# ogr2ogr /home/jukes/Documents/Sample_glaciers/Box033/Buffer033.shp /home/jukes/Documents/Sample_glaciers/Box033/Box033.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 3605) AS geometry,*FROM 'Box033'" -f "ESRI Shapefile"
# Box033
# ogr2ogr /home/jukes/Documents/Sample_glaciers/Box120/Buffer120.shp /home/jukes/Documents/Sample_glaciers/Box120/Box120.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 1048) AS geometry,*FROM 'Box120'" -f "ESRI Shapefile"
# Box120
# ogr2ogr /home/jukes/Documents/Sample_glaciers/Box174/Buffer174.shp /home/jukes/Documents/Sample_glaciers/Box174/Box174.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 2027) AS geometry,*FROM 'Box174'" -f "ESRI Shapefile"
# Box174
# ogr2ogr /home/jukes/Documents/Sample_glaciers/Box235/Buffer235.shp /home/jukes/Documents/Sample_glaciers/Box235/Box235.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 1643) AS geometry,*FROM 'Box235'" -f "ESRI Shapefile"
# Box235
# ogr2ogr /home/jukes/Documents/Sample_glaciers/Box259/Buffer259.shp /home/jukes/Documents/Sample_glaciers/Box259/Box259.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 2965) AS geometry,*FROM 'Box259'" -f "ESRI Shapefile"
# Box259
# ogr2ogr /home/jukes/Documents/Sample_glaciers/Box277/Buffer277.shp /home/jukes/Documents/Sample_glaciers/Box277/Box277.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 1379) AS geometry,*FROM 'Box277'" -f "ESRI Shapefile"
# Box277
# ogr2ogr /home/jukes/Documents/Sample_glaciers/Box531/Buffer531.shp /home/jukes/Documents/Sample_glaciers/Box531/Box531.shp -dialect sqlite -sql "SELECT ST_Buffer(geometry, 1790) AS geometry,*FROM 'Box531'" -f "ESRI Shapefile"
# Box531

# %% [markdown]
# The terminus box shapefiles are then rasterized (to be used as a mask during the WTMM filering) using the GDAL **gdal_rasterize** command and subset to the buffer zone using the GDAL **gdalwarp** command using the following syntax:
#
# 1) Rasterize
#
#     gdal_rasterize -burn 1.0 -tr x_resolution y_resolution -a_nodata 0.0 path_to_terminusbox.shp path_to_terminusbox_raster.TIF
#
# The x_resolution and y_resolution are set to be 15.0 (meters) to match the Landsat B8 resolution.
#
# 2) Subset
#
#     gdalwarp -cutline path_to_Buffer###.shp -crop_to_cutline path_to_terminusbox_raster.TIF path_to_subset_raster_cut.TIF

# %%
for index, row in buff_df.iterrows():
    BoxID = row['BoxID']
    #SET path to the terminus box shapefiles
    terminusbox_path = basepath+"Box"+BoxID+"/Box"+BoxID+".shp"
    buffer_path = basepath+"Box"+BoxID+"/Buffer"+BoxID+".shp"
    
    #output raster path:
    terminusraster_path = basepath+"Box"+BoxID+"/Box"+BoxID+".TIF"
    cutraster_path = basepath+"Box"+BoxID+"/Box"+BoxID+"_raster_cut.TIF"
    
    #SET commands and print to check
    rasterize_cmd = 'gdal_rasterize -burn 1.0 -tr 15.0 15.0 -a_nodata 0.0 '+terminusbox_path+' '+terminusraster_path
    subsetbuffer_cmd = 'gdalwarp -cutline '+buffer_path+' -crop_to_cutline '+terminusraster_path+" "+cutraster_path
    
    #RASTERIZE & SUBSET
    subprocess.call(rasterize_cmd, shell=True)
    subprocess.call(subsetbuffer_cmd, shell=True)
    
    print("Box"+BoxID)
# Out:
# Box001
# Box002
# Box004
# Box033
# Box120
# Box174
# Box235
# Box259
# Box277
# Box531

# %% [markdown]
# # 6) Download non-cloudy images
#
# To threshold out cloudy images, we will find the number of pixels in our shapefile region that correspond to a cumulative pixel value of > __25000__. If the number of pixels with values above this threshold is greater than our % threshold, we won't download the image.
#
# __EDITED: We'll also filter out those images along the border that cutoff through your shapefile region. These will have a designated fill value of 1.__
#
# Set cloudy and fill thresholds:

# %%
#SET cloud cover threshold
cpercent_thresh = 20.0

#SET fill percent threshold
fpercent_thresh = 60.0

#SET BQA pixel value threshold
BQA_thresh = 4096.0
# use 4096?

# %% [markdown]
# Set LS bands to download:

# %%
#SET your desired bands here
bands = [8]
# bands = [2, 3, 4]

# %% [markdown]
# ### Download the images that pass these thresholds:

# %%
#Loop through the dataframe with your path row combinations:
for index, row in boxes_pr_df.iterrows():
    #grab the path row names and set the folder name
    path = row['Path']; zone = row['Zone']; row = row['Row']; BoxID = index; 
    folder_name = 'Path'+path+'_Row'+row+'_c1'
    
    #set path to path row folders to grab BQA files from
    pr_folderpath = downloadpath+folder_name+'/'
    
    #Output BoxID folderpath and create BoxID folders
    bp_out = downloadpath+'Box'+BoxID+'/'
    
    if os.path.exists(bp_out):
        print("Box"+BoxID, " EXISTS ALREADY. SKIP.")
    else:
        os.mkdir(bp_out)
        print("Box"+BoxID+" directory made")
                      
    #set path to the buffer zones for final subsetting:
    pathtobuffer = basepath+'Box'+BoxID+'/Buffer'+BoxID
#     pathtoshp_rp = basepath+'Box'+BoxID+'/Box'+BoxID+'_UTM_'+zone+'.shp'
    
    #REPROJECT BUFFER SHAPE
    if len(os.listdir(pr_folderpath)) > 0:
#         print(zone)
        rp_shp = 'ogr2ogr -f "ESRI Shapefile" -t_srs EPSG:326'+zone+' -s_srs EPSG:3413 '+pathtobuffer+"_UTM_"+zone+".shp "+pathtobuffer+".shp"
#         print(rp_shp)
        subprocess.call(rp_shp, shell=True)

    #loop through all the BQA files in the path_row folders:
    for scene in os.listdir(pr_folderpath):
        if len(os.listdir(pr_folderpath)) > 0 and scene.startswith("LC08"):
            #grab all the BQA files to calculate the percent cloud
            BQApath = pr_folderpath+scene+"/"+scene+'_BQA_Box'+BoxID+'.TIF'
#             print(BQApath)
            
            #read in your BQA subset raster as a numpy array:
            subsetBQA = mpimg.imread(BQApath)
            
            #CALCULATE % CLOUD COVER USING YOUR BQA SUBSET
            #first, calculate the total number of pixels
            totalpixels = subsetBQA.shape[0]*subsetBQA.shape[1]
            
            #then, calculate the number of cloud pixels:
            #mask for pixels that have a value > than your threshold value
            cloudBQA = subsetBQA[subsetBQA > BQA_thresh]
            
            #calculate number of fill pixels (fill value of 1. Will be less than 2.0)
            fillBQA = subsetBQA[subsetBQA < 2.0]
            
            #and count those cloudpixels and fillpixels:
            cloudpixels = len(cloudBQA); fillpixels = len(fillBQA)
            
            #divide this by the totalpixels and multiply by 100
            cloudpercent = int(float(cloudpixels)/float(totalpixels)*100)
            fillpercent = int(float(fillpixels)/float(totalpixels)*100)
            
            #check that the values are sensible
            print(scene, 'Cloud % ', cloudpercent, 'Fill %', fillpercent)
            
            #set path to rp buffer:
            pathtobuffer_rp = pathtobuffer+"_UTM_"+zone+".shp"
            
            #IF % CLOUD COVER IS LESS THAN OR EQUAL TO YOUR THRESHOLD DOWNLOAD THE BANDS FOR THAT SCENE:
            if cloudpercent <= cpercent_thresh and fillpercent <= fpercent_thresh:
                #download the bands for that scene into your scene folders:
                for band in bands:
                    #make sure the band is in string format:
                    band = str(band)
                    #set input path to your bands in AWS:
                    pathin = '/vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/'+path+"/"+row+"/"+scene+"/"+scene+"_B"+band+".TIF"
                    #set your output path to the overall BoxID folder, not the scene folders
                    pathout = downloadpath+'Box'+BoxID+'/'+scene+"_B"+band+'_Buffer'+BoxID+'.TIF'
                    
                    #set download command and check:
                    download_cmd = 'gdalwarp -cutline '+pathtobuffer_rp+' -crop_to_cutline '+pathin+' '+pathout
#                     download_cmd = 'gdalwarp -cutline '+pathtoshp_rp+' -crop_to_cutline '+pathin+' '+pathout
                    print(download_cmd)
                    
                    #When you're ready, comment out the above print command and
                    #uncomment the following to commence the download:                   
                    subprocess.call(download_cmd, shell=True)
                    print(scene+"_B"+band+'_Buffer'+BoxID+".TIF downloaded")
# Out:
# Box001  EXISTS ALREADY. SKIP.
# LC08_L1TP_036004_20170521_20170526_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20170521_20170526_01_T1/LC08_L1TP_036004_20170521_20170526_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20170521_20170526_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20170521_20170526_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20150329_20170228_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20150329_20170228_01_T1/LC08_L1TP_036004_20150329_20170228_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20150329_20170228_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20150329_20170228_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20190916_20190925_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20190916_20190925_01_T1/LC08_L1TP_036004_20190916_20190925_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20190916_20190925_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20190916_20190925_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20160331_20170223_01_T1 Cloud %  95 Fill % 4
# LC08_L1TP_036004_20180625_20180626_01_RT Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20180625_20180626_01_RT/LC08_L1TP_036004_20180625_20180626_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20180625_20180626_01_RT_B8_Buffer001.TIF
# LC08_L1TP_036004_20180625_20180626_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20160416_20170223_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20160416_20170223_01_T1/LC08_L1TP_036004_20160416_20170223_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20160416_20170223_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20160416_20170223_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20180913_20180913_01_RT Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20180913_20180913_01_RT/LC08_L1TP_036004_20180913_20180913_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20180913_20180913_01_RT_B8_Buffer001.TIF
# LC08_L1TP_036004_20180913_20180913_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1GT_036004_20200326_20200326_01_RT Cloud %  95 Fill % 4
# LC08_L1TP_036004_20180727_20180731_01_T1 Cloud %  92 Fill % 4
# LC08_L1TP_036004_20170419_20170501_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20170419_20170501_01_T1/LC08_L1TP_036004_20170419_20170501_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20170419_20170501_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20170419_20170501_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20190527_20190528_01_RT Cloud %  95 Fill % 4
# LC08_L1TP_036004_20190308_20190324_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20190308_20190324_01_T1/LC08_L1TP_036004_20190308_20190324_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20190308_20190324_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20190308_20190324_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20170825_20170825_01_RT Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20170825_20170825_01_RT/LC08_L1TP_036004_20170825_20170825_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20170825_20170825_01_RT_B8_Buffer001.TIF
# LC08_L1TP_036004_20170825_20170825_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20190308_20190308_01_RT Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20190308_20190308_01_RT/LC08_L1TP_036004_20190308_20190308_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20190308_20190308_01_RT_B8_Buffer001.TIF
# LC08_L1TP_036004_20190308_20190308_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20150905_20170225_01_T1 Cloud %  95 Fill % 4
# LC08_L1TP_036004_20190730_20190731_01_RT Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20190730_20190731_01_RT/LC08_L1TP_036004_20190730_20190731_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20190730_20190731_01_RT_B8_Buffer001.TIF
# LC08_L1TP_036004_20190730_20190731_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20200411_20200411_01_RT Cloud %  43 Fill % 4
# LC08_L1TP_036004_20170622_20170623_01_RT Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20170622_20170623_01_RT/LC08_L1TP_036004_20170622_20170623_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20170622_20170623_01_RT_B8_Buffer001.TIF
# LC08_L1TP_036004_20170622_20170623_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1GT_036004_20190409_20190409_01_RT Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1GT_036004_20190409_20190409_01_RT/LC08_L1GT_036004_20190409_20190409_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1GT_036004_20190409_20190409_01_RT_B8_Buffer001.TIF
# LC08_L1GT_036004_20190409_20190409_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20180406_20180406_01_RT Cloud %  90 Fill % 4
# LC08_L1TP_036004_20150617_20170226_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20150617_20170226_01_T1/LC08_L1TP_036004_20150617_20170226_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20150617_20170226_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20150617_20170226_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20180508_20180517_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20180508_20180517_01_T1/LC08_L1TP_036004_20180508_20180517_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20180508_20180517_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20180508_20180517_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20170505_20170515_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20170505_20170515_01_T1/LC08_L1TP_036004_20170505_20170515_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20170505_20170515_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20170505_20170515_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20180828_20180911_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20180828_20180911_01_T1/LC08_L1TP_036004_20180828_20180911_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20180828_20180911_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20180828_20180911_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20150313_20170412_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20150313_20170412_01_T1/LC08_L1TP_036004_20150313_20170412_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20150313_20170412_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20150313_20170412_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20160502_20170223_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20160502_20170223_01_T1/LC08_L1TP_036004_20160502_20170223_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20160502_20170223_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20160502_20170223_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20140614_20170305_01_T1 Cloud %  95 Fill % 4
# LC08_L1TP_036004_20180321_20180321_01_RT Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20180321_20180321_01_RT/LC08_L1TP_036004_20180321_20180321_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20180321_20180321_01_RT_B8_Buffer001.TIF
# LC08_L1TP_036004_20180321_20180321_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20180711_20180717_01_T1 Cloud %  95 Fill % 4
# LC08_L1GT_036004_20180609_20180610_01_RT Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1GT_036004_20180609_20180610_01_RT/LC08_L1GT_036004_20180609_20180610_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1GT_036004_20180609_20180610_01_RT_B8_Buffer001.TIF
# LC08_L1GT_036004_20180609_20180610_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1GT_036004_20190511_20190511_01_RT Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1GT_036004_20190511_20190511_01_RT/LC08_L1GT_036004_20190511_20190511_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1GT_036004_20190511_20190511_01_RT_B8_Buffer001.TIF
# LC08_L1GT_036004_20190511_20190511_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20140918_20170419_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20140918_20170419_01_T1/LC08_L1TP_036004_20140918_20170419_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20140918_20170419_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20140918_20170419_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20200411_20200422_01_T1 Cloud %  43 Fill % 4
# LC08_L1TP_036004_20140411_20170307_01_T1 Cloud %  12 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20140411_20170307_01_T1/LC08_L1TP_036004_20140411_20170307_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20140411_20170307_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20140411_20170307_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20200310_20200325_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20200310_20200325_01_T1/LC08_L1TP_036004_20200310_20200325_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20200310_20200325_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20200310_20200325_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20170403_20170414_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20170403_20170414_01_T1/LC08_L1TP_036004_20170403_20170414_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20170403_20170414_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20170403_20170414_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20150414_20170301_01_T1 Cloud %  5 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20150414_20170301_01_T1/LC08_L1TP_036004_20150414_20170301_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20150414_20170301_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20150414_20170301_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20190628_20190628_01_RT Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20190628_20190628_01_RT/LC08_L1TP_036004_20190628_20190628_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20190628_20190628_01_RT_B8_Buffer001.TIF
# LC08_L1TP_036004_20190628_20190628_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20150601_20170226_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20150601_20170226_01_T1/LC08_L1TP_036004_20150601_20170226_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20150601_20170226_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20150601_20170226_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20170724_20170809_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20170724_20170809_01_T1/LC08_L1TP_036004_20170724_20170809_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20170724_20170809_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20170724_20170809_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20150921_20170225_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20150921_20170225_01_T1/LC08_L1TP_036004_20150921_20170225_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20150921_20170225_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20150921_20170225_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20170809_20170824_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20170809_20170824_01_T1/LC08_L1TP_036004_20170809_20170824_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20170809_20170824_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20170809_20170824_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20190612_20190619_01_T1 Cloud %  95 Fill % 4
# LC08_L1TP_036004_20150804_20170226_01_T1 Cloud %  95 Fill % 4
# LC08_L1TP_036004_20140716_20170421_01_T1 Cloud %  83 Fill % 4
# LC08_L1TP_036004_20150430_20170301_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20150430_20170301_01_T1/LC08_L1TP_036004_20150430_20170301_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20150430_20170301_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20150430_20170301_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20151007_20170225_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20151007_20170225_01_T1/LC08_L1TP_036004_20151007_20170225_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20151007_20170225_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20151007_20170225_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20180828_20180828_01_RT Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20180828_20180828_01_RT/LC08_L1TP_036004_20180828_20180828_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20180828_20180828_01_RT_B8_Buffer001.TIF
# LC08_L1TP_036004_20180828_20180828_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20170724_20170724_01_RT Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20170724_20170724_01_RT/LC08_L1TP_036004_20170724_20170724_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20170724_20170724_01_RT_B8_Buffer001.TIF
# LC08_L1TP_036004_20170724_20170724_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20180913_20180928_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20180913_20180928_01_T1/LC08_L1TP_036004_20180913_20180928_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20180913_20180928_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20180913_20180928_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20190831_20190831_01_RT Cloud %  95 Fill % 4
# LC08_L1TP_036004_20160619_20170221_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20160619_20170221_01_T1/LC08_L1TP_036004_20160619_20170221_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20160619_20170221_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20160619_20170221_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20170622_20170630_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20170622_20170630_01_T1/LC08_L1TP_036004_20170622_20170630_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20170622_20170630_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20170622_20170630_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20190324_20190403_01_T1 Cloud %  53 Fill % 4
# LC08_L1GT_036004_20180812_20180812_01_RT Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1GT_036004_20180812_20180812_01_RT/LC08_L1GT_036004_20180812_20180812_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1GT_036004_20180812_20180812_01_RT_B8_Buffer001.TIF
# LC08_L1GT_036004_20180812_20180812_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20190612_20190612_01_RT Cloud %  95 Fill % 4
# LC08_L1TP_036004_20190916_20190916_01_RT Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20190916_20190916_01_RT/LC08_L1TP_036004_20190916_20190916_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20190916_20190916_01_RT_B8_Buffer001.TIF
# LC08_L1TP_036004_20190916_20190916_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20150703_20170226_01_T1 Cloud %  95 Fill % 4
# LC08_L1GT_036004_20180305_20180305_01_RT Cloud %  95 Fill % 4
# LC08_L1TP_036004_20140630_20170304_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20140630_20170304_01_T1/LC08_L1TP_036004_20140630_20170304_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20140630_20170304_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20140630_20170304_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20180625_20180704_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20180625_20180704_01_T1/LC08_L1TP_036004_20180625_20180704_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20180625_20180704_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20180625_20180704_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1GT_036004_20191002_20191002_01_RT Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1GT_036004_20191002_20191002_01_RT/LC08_L1GT_036004_20191002_20191002_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1GT_036004_20191002_20191002_01_RT_B8_Buffer001.TIF
# LC08_L1GT_036004_20191002_20191002_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20170318_20170328_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20170318_20170328_01_T1/LC08_L1TP_036004_20170318_20170328_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20170318_20170328_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20170318_20170328_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20180508_20180509_01_RT Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20180508_20180509_01_RT/LC08_L1TP_036004_20180508_20180509_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20180508_20180509_01_RT_B8_Buffer001.TIF
# LC08_L1TP_036004_20180508_20180509_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20170521_20170521_01_RT Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20170521_20170521_01_RT/LC08_L1TP_036004_20170521_20170521_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20170521_20170521_01_RT_B8_Buffer001.TIF
# LC08_L1TP_036004_20170521_20170521_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20170708_20170709_01_RT Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20170708_20170709_01_RT/LC08_L1TP_036004_20170708_20170709_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20170708_20170709_01_RT_B8_Buffer001.TIF
# LC08_L1TP_036004_20170708_20170709_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20190815_20190820_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20190815_20190820_01_T1/LC08_L1TP_036004_20190815_20190820_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20190815_20190820_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20190815_20190820_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20170809_20170809_01_RT Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20170809_20170809_01_RT/LC08_L1TP_036004_20170809_20170809_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20170809_20170809_01_RT_B8_Buffer001.TIF
# LC08_L1TP_036004_20170809_20170809_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20180929_20180929_01_RT Cloud %  2 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20180929_20180929_01_RT/LC08_L1TP_036004_20180929_20180929_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20180929_20180929_01_RT_B8_Buffer001.TIF
# LC08_L1TP_036004_20180929_20180929_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20190714_20190714_01_RT Cloud %  13 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20190714_20190714_01_RT/LC08_L1TP_036004_20190714_20190714_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20190714_20190714_01_RT_B8_Buffer001.TIF
# LC08_L1TP_036004_20190714_20190714_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20160721_20170223_01_T1 Cloud %  55 Fill % 4
# LC08_L1TP_036004_20170708_20170717_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20170708_20170717_01_T1/LC08_L1TP_036004_20170708_20170717_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20170708_20170717_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20170708_20170717_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20190714_20190720_01_T1 Cloud %  13 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20190714_20190720_01_T1/LC08_L1TP_036004_20190714_20190720_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20190714_20190720_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20190714_20190720_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20140902_20170303_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20140902_20170303_01_T1/LC08_L1TP_036004_20140902_20170303_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20140902_20170303_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20140902_20170303_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20190425_20190508_01_T1 Cloud %  95 Fill % 4
# LC08_L1TP_036004_20160907_20170221_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20160907_20170221_01_T1/LC08_L1TP_036004_20160907_20170221_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20160907_20170221_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20160907_20170221_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20170910_20170927_01_T1 Cloud %  95 Fill % 4
# LC08_L1TP_036004_20160806_20170221_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20160806_20170221_01_T1/LC08_L1TP_036004_20160806_20170221_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20160806_20170221_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20160806_20170221_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20190527_20190605_01_T1 Cloud %  95 Fill % 4
# LC08_L1TP_036004_20180711_20180711_01_RT Cloud %  95 Fill % 4
# LC08_L1TP_036004_20170606_20170606_01_RT Cloud %  95 Fill % 4
# LC08_L1TP_036004_20150820_20170225_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20150820_20170225_01_T1/LC08_L1TP_036004_20150820_20170225_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20150820_20170225_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20150820_20170225_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20180422_20180422_01_RT Cloud %  95 Fill % 4
# LC08_L1TP_036004_20200513_20200514_01_RT Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20200513_20200514_01_RT/LC08_L1TP_036004_20200513_20200514_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20200513_20200514_01_RT_B8_Buffer001.TIF
# LC08_L1TP_036004_20200513_20200514_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20180929_20181009_01_T1 Cloud %  2 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20180929_20181009_01_T1/LC08_L1TP_036004_20180929_20181009_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20180929_20181009_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20180929_20181009_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20160518_20170223_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20160518_20170223_01_T1/LC08_L1TP_036004_20160518_20170223_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20160518_20170223_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20160518_20170223_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20190628_20190706_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20190628_20190706_01_T1/LC08_L1TP_036004_20190628_20190706_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20190628_20190706_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20190628_20190706_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20190425_20190425_01_RT Cloud %  95 Fill % 4
# LC08_L1TP_036004_20150516_20170227_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20150516_20170227_01_T1/LC08_L1TP_036004_20150516_20170227_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20150516_20170227_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20150516_20170227_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20170825_20170913_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20170825_20170913_01_T1/LC08_L1TP_036004_20170825_20170913_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20170825_20170913_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20170825_20170913_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20170910_20170910_01_RT Cloud %  95 Fill % 4
# LC08_L1TP_036004_20200427_20200428_01_RT Cloud %  95 Fill % 4
# LC08_L1TP_036004_20160923_20170222_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20160923_20170222_01_T1/LC08_L1TP_036004_20160923_20170222_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20160923_20170222_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20160923_20170222_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20200310_20200311_01_RT Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20200310_20200311_01_RT/LC08_L1TP_036004_20200310_20200311_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20200310_20200311_01_RT_B8_Buffer001.TIF
# LC08_L1TP_036004_20200310_20200311_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20190815_20190815_01_RT Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20190815_20190815_01_RT/LC08_L1TP_036004_20190815_20190815_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20190815_20190815_01_RT_B8_Buffer001.TIF
# LC08_L1TP_036004_20190815_20190815_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20190324_20190324_01_RT Cloud %  53 Fill % 4
# LC08_L1TP_036004_20180321_20180403_01_T1 Cloud %  0 Fill % 4
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_19.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/036/004/LC08_L1TP_036004_20180321_20180403_01_T1/LC08_L1TP_036004_20180321_20180403_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_036004_20180321_20180403_01_T1_B8_Buffer001.TIF
# LC08_L1TP_036004_20180321_20180403_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_036004_20170606_20170616_01_T1 Cloud %  95 Fill % 4
# LC08_L1TP_036004_20180406_20180417_01_T1 Cloud %  90 Fill % 4
# LC08_L1TP_036004_20190831_20190916_01_T1 Cloud %  95 Fill % 4
# Box001  EXISTS ALREADY. SKIP.
# LC08_L1TP_037004_20130906_20170309_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20180819_20180820_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20150928_20170225_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20180702_20180702_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20190923_20190926_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20200504_20200509_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20160610_20170223_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20190518_20190522_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20181006_20181010_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20130517_20170504_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20190331_20190401_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20190923_20190923_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20170325_20170329_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20170917_20170929_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20190315_20190325_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20190822_20190822_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20160712_20170221_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20170309_20180125_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20150405_20170301_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20150608_20170226_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20200504_20200504_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20140605_20180130_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20180328_20180328_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20180920_20180920_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20190502_20190508_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20200402_20200403_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20170426_20170502_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20170629_20170629_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20170528_20170615_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20180312_20180312_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20170816_20170825_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20150320_20170301_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20140504_20170423_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20190603_20190618_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20170528_20170528_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20190822_20190903_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20190331_20190404_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20180803_20180814_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20180531_20180531_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20190705_20190719_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20190502_20190503_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20180515_20180604_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20180515_20180516_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20170629_20170714_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20180904_20180904_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20180429_20180502_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20190619_20190703_01_T1 Cloud %  0 Fill % 100
# LC08_L1GT_037004_20170715_20170716_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20180702_20180717_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20140621_20170304_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20160423_20170223_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20180616_20180617_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20180616_20180703_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20180429_20180429_01_RT Cloud %  0 Fill % 100
# LC08_L1GT_037004_20170731_20170801_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20160525_20170223_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20190518_20190519_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20200418_20200423_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20200418_20200418_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20170816_20170817_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20160829_20170222_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20160407_20170223_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20140824_20170303_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20170309_20170317_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20190416_20190423_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20190705_20190706_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20140520_20170307_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20150624_20170226_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20170917_20170918_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20160813_20170223_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20190721_20190801_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20180328_20180405_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20180803_20180803_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20190907_20190907_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20140723_20170304_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20180718_20180731_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20140707_20170304_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20170512_20170525_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20150421_20170227_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20180819_20180829_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20180904_20180912_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20180413_20180417_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20160509_20170223_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20140925_20170303_01_T1 Cloud %  0 Fill % 100
# LC08_L1GT_037004_20170901_20170901_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20160626_20170222_01_T1 Cloud %  0 Fill % 100
# LC08_L1GT_037004_20170613_20170613_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20160728_20170221_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20190315_20190315_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20190603_20190603_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20190416_20190416_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20140909_20170303_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20140808_20170304_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20150726_20170226_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20190619_20190619_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20150827_20170225_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20190721_20190721_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20150912_20170225_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20180718_20180718_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20180531_20180614_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20181006_20181006_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20150811_20170226_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20190907_20190917_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20190806_20190806_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20160322_20170224_01_T1 Cloud %  0 Fill % 100
# LC08_L1TP_037004_20180413_20180413_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20180920_20180928_01_T1 Cloud %  0 Fill % 100
# LC08_L1GT_037004_20171003_20171003_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20170512_20170512_01_RT Cloud %  0 Fill % 100
# LC08_L1TP_037004_20150710_20170226_01_T1 Cloud %  0 Fill % 100
# Box001  EXISTS ALREADY. SKIP.
# LC08_L1TP_035005_20150626_20170226_01_T1 Cloud %  0 Fill % 3
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_18.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/035/005/LC08_L1TP_035005_20150626_20170226_01_T1/LC08_L1TP_035005_20150626_20170226_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_035005_20150626_20170226_01_T1_B8_Buffer001.TIF
# LC08_L1TP_035005_20150626_20170226_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_035005_20200319_20200326_01_T1 Cloud %  39 Fill % 3
# LC08_L1TP_035005_20160628_20170222_01_T1 Cloud %  0 Fill % 3
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_18.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/035/005/LC08_L1TP_035005_20160628_20170222_01_T1/LC08_L1TP_035005_20160628_20170222_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_035005_20160628_20170222_01_T1_B8_Buffer001.TIF
# LC08_L1TP_035005_20160628_20170222_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_035005_20150525_20170226_01_T1 Cloud %  0 Fill % 3
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_18.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/035/005/LC08_L1TP_035005_20150525_20170226_01_T1/LC08_L1TP_035005_20150525_20170226_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_035005_20150525_20170226_01_T1_B8_Buffer001.TIF
# LC08_L1TP_035005_20150525_20170226_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_035005_20170919_20170920_01_RT Cloud %  0 Fill % 3
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_18.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/035/005/LC08_L1TP_035005_20170919_20170920_01_RT/LC08_L1TP_035005_20170919_20170920_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_035005_20170919_20170920_01_RT_B8_Buffer001.TIF
# LC08_L1TP_035005_20170919_20170920_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1TP_035005_20170701_20170715_01_T1 Cloud %  0 Fill % 3
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_18.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/035/005/LC08_L1TP_035005_20170701_20170715_01_T1/LC08_L1TP_035005_20170701_20170715_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_035005_20170701_20170715_01_T1_B8_Buffer001.TIF
# LC08_L1TP_035005_20170701_20170715_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_035005_20180922_20180922_01_RT Cloud %  0 Fill % 3
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_18.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/035/005/LC08_L1TP_035005_20180922_20180922_01_RT/LC08_L1TP_035005_20180922_20180922_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_035005_20180922_20180922_01_RT_B8_Buffer001.TIF
# LC08_L1TP_035005_20180922_20180922_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1TP_035005_20130503_20170310_01_T1 Cloud %  0 Fill % 3
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_18.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/035/005/LC08_L1TP_035005_20130503_20170310_01_T1/LC08_L1TP_035005_20130503_20170310_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_035005_20130503_20170310_01_T1_B8_Buffer001.TIF
# LC08_L1TP_035005_20130503_20170310_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_035005_20200420_20200508_01_T1 Cloud %  96 Fill % 3
# LC08_L1TP_035005_20180602_20180615_01_T1 Cloud %  0 Fill % 3
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_18.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/035/005/LC08_L1TP_035005_20180602_20180615_01_T1/LC08_L1TP_035005_20180602_20180615_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_035005_20180602_20180615_01_T1_B8_Buffer001.TIF
# LC08_L1TP_035005_20180602_20180615_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_035005_20180501_20180516_01_T1 Cloud %  0 Fill % 3
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_18.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/035/005/LC08_L1TP_035005_20180501_20180516_01_T1/LC08_L1TP_035005_20180501_20180516_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_035005_20180501_20180516_01_T1_B8_Buffer001.TIF
# LC08_L1TP_035005_20180501_20180516_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_035005_20170514_20170514_01_RT Cloud %  0 Fill % 3
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_18.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/035/005/LC08_L1TP_035005_20170514_20170514_01_RT/LC08_L1TP_035005_20170514_20170514_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_035005_20170514_20170514_01_RT_B8_Buffer001.TIF
# LC08_L1TP_035005_20170514_20170514_01_RT_B8_Buffer001.TIF downloaded
# LC08_L1TP_035005_20180415_20180501_01_T1 Cloud %  0 Fill % 3
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_18.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/035/005/LC08_L1TP_035005_20180415_20180501_01_T1/LC08_L1TP_035005_20180415_20180501_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_035005_20180415_20180501_01_T1_B8_Buffer001.TIF
# LC08_L1TP_035005_20180415_20180501_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_035005_20150712_20170226_01_T1 Cloud %  0 Fill % 3
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_18.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/035/005/LC08_L1TP_035005_20150712_20170226_01_T1/LC08_L1TP_035005_20150712_20170226_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_035005_20150712_20170226_01_T1_B8_Buffer001.TIF
# LC08_L1TP_035005_20150712_20170226_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_035005_20160831_20170222_01_T1 Cloud %  31 Fill % 3
# LC08_L1TP_035005_20181008_20181029_01_T1 Cloud %  0 Fill % 3
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_18.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/035/005/LC08_L1TP_035005_20181008_20181029_01_T1/LC08_L1TP_035005_20181008_20181029_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_035005_20181008_20181029_01_T1_B8_Buffer001.TIF
# LC08_L1TP_035005_20181008_20181029_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_035005_20170919_20170930_01_T1 Cloud %  0 Fill % 3
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box001/Buffer001_UTM_18.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/035/005/LC08_L1TP_035005_20170919_20170930_01_T1/LC08_L1TP_035005_20170919_20170930_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box001/LC08_L1TP_035005_20170919_20170930_01_T1_B8_Buffer001.TIF
# LC08_L1TP_035005_20170919_20170930_01_T1_B8_Buffer001.TIF downloaded
# LC08_L1TP_035005_20150423_20170228_01_T1 Cloud %  0 Fill % 3
# ...
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20170714_20170726_01_T1/LC08_L1TP_014001_20170714_20170726_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20170714_20170726_01_T1_B8_Buffer531.TIF
# LC08_L1TP_014001_20170714_20170726_01_T1_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20140908_20170419_01_T1 Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20140908_20170419_01_T1/LC08_L1TP_014001_20140908_20170419_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20140908_20170419_01_T1_B8_Buffer531.TIF
# LC08_L1TP_014001_20140908_20170419_01_T1_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20180327_20180327_01_RT Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20180327_20180327_01_RT/LC08_L1TP_014001_20180327_20180327_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20180327_20180327_01_RT_B8_Buffer531.TIF
# LC08_L1TP_014001_20180327_20180327_01_RT_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20180428_20180428_01_RT Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20180428_20180428_01_RT/LC08_L1TP_014001_20180428_20180428_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20180428_20180428_01_RT_B8_Buffer531.TIF
# LC08_L1TP_014001_20180428_20180428_01_RT_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20170916_20170929_01_T1 Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20170916_20170929_01_T1/LC08_L1TP_014001_20170916_20170929_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20170916_20170929_01_T1_B8_Buffer531.TIF
# LC08_L1TP_014001_20170916_20170929_01_T1_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20170730_20170811_01_T1 Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20170730_20170811_01_T1/LC08_L1TP_014001_20170730_20170811_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20170730_20170811_01_T1_B8_Buffer531.TIF
# LC08_L1TP_014001_20170730_20170811_01_T1_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20140503_20170423_01_T1 Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20140503_20170423_01_T1/LC08_L1TP_014001_20140503_20170423_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20140503_20170423_01_T1_B8_Buffer531.TIF
# LC08_L1TP_014001_20140503_20170423_01_T1_B8_Buffer531.TIF downloaded
# LC08_L1GT_014001_20200417_20200417_01_RT Cloud %  49 Fill % 50
# LC08_L1TP_014001_20160913_20170321_01_T1 Cloud %  49 Fill % 50
# LC08_L1TP_014001_20190805_20190805_01_RT Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20190805_20190805_01_RT/LC08_L1TP_014001_20190805_20190805_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20190805_20190805_01_RT_B8_Buffer531.TIF
# LC08_L1TP_014001_20190805_20190805_01_RT_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20190501_20190508_01_T1 Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20190501_20190508_01_T1/LC08_L1TP_014001_20190501_20190508_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20190501_20190508_01_T1_B8_Buffer531.TIF
# LC08_L1TP_014001_20190501_20190508_01_T1_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20150623_20170407_01_T1 Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20150623_20170407_01_T1/LC08_L1TP_014001_20150623_20170407_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20150623_20170407_01_T1_B8_Buffer531.TIF
# LC08_L1TP_014001_20150623_20170407_01_T1_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20180919_20180928_01_T1 Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20180919_20180928_01_T1/LC08_L1TP_014001_20180919_20180928_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20180919_20180928_01_T1_B8_Buffer531.TIF
# LC08_L1TP_014001_20180919_20180928_01_T1_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20170324_20170329_01_T1 Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20170324_20170329_01_T1/LC08_L1TP_014001_20170324_20170329_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20170324_20170329_01_T1_B8_Buffer531.TIF
# LC08_L1TP_014001_20170324_20170329_01_T1_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20190501_20190501_01_RT Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20190501_20190501_01_RT/LC08_L1TP_014001_20190501_20190501_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20190501_20190501_01_RT_B8_Buffer531.TIF
# LC08_L1TP_014001_20190501_20190501_01_RT_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20180412_20180412_01_RT Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20180412_20180412_01_RT/LC08_L1TP_014001_20180412_20180412_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20180412_20180412_01_RT_B8_Buffer531.TIF
# LC08_L1TP_014001_20180412_20180412_01_RT_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20140807_20170420_01_T1 Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20140807_20170420_01_T1/LC08_L1TP_014001_20140807_20170420_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20140807_20170420_01_T1_B8_Buffer531.TIF
# LC08_L1TP_014001_20140807_20170420_01_T1_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20200503_20200509_01_T1 Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20200503_20200509_01_T1/LC08_L1TP_014001_20200503_20200509_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20200503_20200509_01_T1_B8_Buffer531.TIF
# LC08_L1TP_014001_20200503_20200509_01_T1_B8_Buffer531.TIF downloaded
# LC08_L1GT_014001_20170815_20170815_01_RT Cloud %  49 Fill % 50
# LC08_L1TP_014001_20180818_20180818_01_RT Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20180818_20180818_01_RT/LC08_L1TP_014001_20180818_20180818_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20180818_20180818_01_RT_B8_Buffer531.TIF
# LC08_L1TP_014001_20180818_20180818_01_RT_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20190517_20190517_01_RT Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20190517_20190517_01_RT/LC08_L1TP_014001_20190517_20190517_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20190517_20190517_01_RT_B8_Buffer531.TIF
# LC08_L1TP_014001_20190517_20190517_01_RT_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20170628_20170628_01_RT Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20170628_20170628_01_RT/LC08_L1TP_014001_20170628_20170628_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20170628_20170628_01_RT_B8_Buffer531.TIF
# LC08_L1TP_014001_20170628_20170628_01_RT_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20180903_20180912_01_T1 Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20180903_20180912_01_T1/LC08_L1TP_014001_20180903_20180912_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20180903_20180912_01_T1_B8_Buffer531.TIF
# LC08_L1TP_014001_20180903_20180912_01_T1_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20150927_20170403_01_T1 Cloud %  38 Fill % 50
# LC08_L1TP_014001_20130905_20170502_01_T1 Cloud %  1 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20130905_20170502_01_T1/LC08_L1TP_014001_20130905_20170502_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20130905_20170502_01_T1_B8_Buffer531.TIF
# LC08_L1TP_014001_20130905_20170502_01_T1_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20160828_20170321_01_T1 Cloud %  49 Fill % 50
# LC08_L1TP_014001_20190330_20190401_01_RT Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20190330_20190401_01_RT/LC08_L1TP_014001_20190330_20190401_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20190330_20190401_01_RT_B8_Buffer531.TIF
# LC08_L1TP_014001_20190330_20190401_01_RT_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20190922_20190926_01_T1 Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20190922_20190926_01_T1/LC08_L1TP_014001_20190922_20190926_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20190922_20190926_01_T1_B8_Buffer531.TIF
# LC08_L1TP_014001_20190922_20190926_01_T1_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20160711_20170323_01_T1 Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20160711_20170323_01_T1/LC08_L1TP_014001_20160711_20170323_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20160711_20170323_01_T1_B8_Buffer531.TIF
# LC08_L1TP_014001_20160711_20170323_01_T1_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20180514_20180515_01_RT Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20180514_20180515_01_RT/LC08_L1TP_014001_20180514_20180515_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20180514_20180515_01_RT_B8_Buffer531.TIF
# LC08_L1TP_014001_20180514_20180515_01_RT_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20170527_20170615_01_T1 Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20170527_20170615_01_T1/LC08_L1TP_014001_20170527_20170615_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20170527_20170615_01_T1_B8_Buffer531.TIF
# LC08_L1TP_014001_20170527_20170615_01_T1_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20170714_20170714_01_RT Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20170714_20170714_01_RT/LC08_L1TP_014001_20170714_20170714_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20170714_20170714_01_RT_B8_Buffer531.TIF
# LC08_L1TP_014001_20170714_20170714_01_RT_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20160727_20170322_01_T1 Cloud %  49 Fill % 50
# LC08_L1TP_014001_20180903_20180903_01_RT Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20180903_20180903_01_RT/LC08_L1TP_014001_20180903_20180903_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20180903_20180903_01_RT_B8_Buffer531.TIF
# LC08_L1TP_014001_20180903_20180903_01_RT_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20170831_20170831_01_RT Cloud %  24 Fill % 50
# LC08_L1GT_014001_20170612_20170612_01_RT Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1GT_014001_20170612_20170612_01_RT/LC08_L1GT_014001_20170612_20170612_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1GT_014001_20170612_20170612_01_RT_B8_Buffer531.TIF
# LC08_L1GT_014001_20170612_20170612_01_RT_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20180919_20180919_01_RT Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20180919_20180919_01_RT/LC08_L1TP_014001_20180919_20180919_01_RT_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20180919_20180919_01_RT_B8_Buffer531.TIF
# LC08_L1TP_014001_20180919_20180919_01_RT_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20150522_20170408_01_T1 Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20150522_20170408_01_T1/LC08_L1TP_014001_20150522_20170408_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20150522_20170408_01_T1_B8_Buffer531.TIF
# LC08_L1TP_014001_20150522_20170408_01_T1_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20140722_20170304_01_T1 Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20140722_20170304_01_T1/LC08_L1TP_014001_20140722_20170304_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20140722_20170304_01_T1_B8_Buffer531.TIF
# LC08_L1TP_014001_20140722_20170304_01_T1_B8_Buffer531.TIF downloaded
# LC08_L1TP_014001_20190821_20190903_01_T1 Cloud %  0 Fill % 50
# gdalwarp -cutline /home/jukes/Documents/Sample_glaciers/Box531/Buffer531_UTM_28.shp -crop_to_cutline /vsicurl/https://landsat-pds.s3.amazonaws.com/c1/L8/014/001/LC08_L1TP_014001_20190821_20190903_01_T1/LC08_L1TP_014001_20190821_20190903_01_T1_B8.TIF /media/jukes/jukes1/LS8aws/Box531/LC08_L1TP_014001_20190821_20190903_01_T1_B8_Buffer531.TIF
# LC08_L1TP_014001_20190821_20190903_01_T1_B8_Buffer531.TIF downloaded

# %% [markdown]
# ### Reproject newly downloaded images into Greenland Polar Stereo projection

# %%
#Loop through the BoxIDs in the dataframe with your path row combinations:
for BoxID in list(set(boxes_pr_df.index)):
   
    #Output BoxID path 
    bp_out = downloadpath+'Box'+BoxID+'/'
    
    #create output folder to reproject into
    if os.path.exists(bp_out+'reprojected/'):
        print("Box"+BoxID, "Reprojected EXISTS ALREADY.")
    else:
        os.mkdir(bp_out+'reprojected/')
        print("Box"+BoxID+" Reprojected directory made")
                      
    #grab all downloaded images and reproject:
    downloadedimages = os.listdir(bp_out)
    for image in downloadedimages:
        if image.startswith("LC08"):
            imagename = image[:-4]
#             os.remove(bp_out+image) # remove old images
    #         print(imagename)
            rp_cmd = "gdalwarp -t_srs '+proj=stere +lat_ts=7|0 +lat_0=90 +lon_0=-45 +y=0 +x=0 +k=1 +datum=WGS84 +units=m' "+bp_out+image+" "+bp_out+'reprojected/'+imagename+"_PS.TIF"
#             print(rp_cmd)
            subprocess.call(rp_cmd, shell=True)   
    print("Box"+BoxID+" reprojected.")
# Out:
# Box002 Reprojected directory made
# Box002 reprojected.
# Box033 Reprojected directory made
# Box033 reprojected.
# Box531 Reprojected directory made
# Box531 reprojected.
# Box277 Reprojected directory made
# Box277 reprojected.
# Box174 Reprojected directory made
# Box174 reprojected.
# Box235 Reprojected directory made
# Box235 reprojected.
# Box259 Reprojected directory made
# Box259 reprojected.
# Box001 Reprojected directory made
# Box001 reprojected.
# Box120 Reprojected directory made
# Box120 reprojected.
# Box004 Reprojected directory made
# Box004 reprojected.

# %% [markdown]
# ### Grab the image acquisition dates from the metadata files

# %%
import datetime

#create a list of datetime objects for the images:
datetimes = []; scenes_dated = []

#Loop through the dataframe with your path row combinations:
# for index, row in pr_df_multi.iterrows():
for index, row in boxes_pr_df.iterrows():
    path = row['Path']; row = row['Row']; BoxID = index; 
    folder_name = 'Path'+path+'_Row'+row+'_c1'; print(folder_name)
    
    #Output folder paths
    folderpath = downloadpath+folder_name+'/'
    bp_out = downloadpath+'Box'+BoxID+'/reprojected/'
    
    #keep track of the number of scenes:
    scenecount = 0
    
    #list of files in directory where you downloaded images
    downloaded_scenes = os.listdir(bp_out)
    for scene in downloaded_scenes:
        #if it's a downloaded image and in the folder we are working on:
        if scene.endswith('.TIF') and scene.startswith("LC08"):
            scenename = scene[:-20]
            if scenename in os.listdir(folderpath):
                #go into the folder and open the metadata file:
                scenefiles = os.listdir(folderpath+scenename+'/')
                for file in scenefiles:
                    if ("MTL.txt" in file):
                        mdata = open(folderpath+scenename+"/"+scenename+"_MTL.txt", "r")
                        #loop through each line in metadata to find the date (and time) of acquisition
                        for line in mdata:
                            variable = line.split("=")[0]
                            if ("DATE_ACQUIRED" in variable):
                                date = line.split("=")[1][1:-1]

                        #save the date as a datetime object and append to list
                        dates = datetime.datetime.strptime(date, '%Y-%m-%d')
                        datetimes.append(dates); scenes_dated.append(scenename)
                scenecount = scenecount+1

# Store in a dataframe
datetime_df = pd.DataFrame(list(zip(scenes_dated, datetimes)), columns=['Scene', 'datetime'])
datetime_df = datetime_df.sort_values(by='datetime', ascending=True); datetime_df = datetime_df.drop_duplicates()
datetime_df
# Out:
# Path036_Row004_c1
# Path037_Row004_c1
# Path035_Row005_c1
# Path033_Row005_c1
# Path034_Row005_c1
# Path031_Row005_c1
# Path032_Row005_c1
# Path033_Row005_c1
# Path035_Row005_c1
# Path034_Row005_c1
# Path031_Row005_c1
# Path030_Row005_c1
# Path032_Row005_c1
# Path032_Row005_c1
# Path031_Row005_c1
# Path034_Row005_c1
# Path029_Row006_c1
# Path028_Row006_c1
# Path030_Row005_c1
# Path033_Row005_c1
# Path009_Row014_c1
# Path008_Row014_c1
# Path007_Row014_c1
# Path009_Row013_c1
# Path232_Row018_c1
# Path233_Row017_c1
# Path232_Row017_c1
# Path232_Row017_c1
# Path233_Row017_c1
# Path232_Row015_c1
# Path233_Row015_c1
# Path001_Row015_c1
# Path232_Row015_c1
# Path233_Row015_c1
# Path001_Row015_c1
# Path001_Row014_c1
# Path232_Row015_c1
# Path233_Row015_c1
# Path017_Row001_c1
# Path016_Row001_c1
# Path119_Row001_c1
# Path120_Row001_c1
# Path121_Row001_c1
# Path007_Row002_c1
# Path008_Row002_c1
# Path006_Row003_c1
# Path010_Row002_c1
# Path011_Row002_c1
# Path012_Row002_c1
# Path013_Row002_c1
# Path115_Row002_c1
# Path007_Row003_c1
# Path015_Row001_c1
# Path009_Row002_c1
# Path014_Row001_c1
#                                          Scene   datetime
# 3223  LC08_L1TP_010002_20130327_20170505_01_T1 2013-03-27
# 3597  LC08_L1TP_015001_20130402_20170310_01_T1 2013-04-02
# 3147  LC08_L1TP_006003_20130403_20170505_01_T1 2013-04-03
# 3368  LC08_L1TP_012002_20130404_20170310_01_T1 2013-04-04
# 264   LC08_L1TP_034005_20130405_20170310_01_T1 2013-04-05
# ...                                        ...        ...
# 3631  LC08_L1TP_015001_20200510_20200510_01_RT 2020-05-10
# 3184  LC08_L1TP_006003_20200511_20200511_01_RT 2020-05-11
# 1260  LC08_L1TP_029006_20200512_20200512_01_RT 2020-05-12
# 27    LC08_L1TP_036004_20200513_20200514_01_RT 2020-05-13
# 3284  LC08_L1TP_011002_20200514_20200515_01_RT 2020-05-14
#
# [2597 rows x 2 columns]

# %% [markdown]
# #### Write image dates to a csv file:

# %%
DATES_NAME = 'imgdates_sample10.csv'
datetime_df.to_csv(path_or_buf = basepath+DATES_NAME, sep=',')

# %% [markdown]
# # 7) Remove cloudy images that slipped through BQA filtering

# %%
#convert all files in reprojected folder to png from TIF
for BoxID in BoxIDs:
    print(BoxID)
    command = 'cd '+downloadpath+'Box'+BoxID+'/reprojected/; '+'mogrify -format png *_PS.TIF'
#     print(command)
    subprocess.call(command, shell=True)
# Out:
# 001
# 002
# 004
# 033
# 120
# 174
# 235
# 259
# 277
# 531

# %%
import cv2

for BoxID in BoxIDs:
    imagepath = downloadpath+'Box'+BoxID+'/reprojected/'
    for img in os.listdir(imagepath):
        if img.endswith('Buffer'+BoxID+'_PS.png'):
            image = cv2.imread(imagepath+img,-1)
            imageplt = mpimg.imread(imagepath+img)
            image_nofill = imageplt[imageplt > 0] # don't consider the fill points
            img_std = np.std(image_nofill)
            img_range = np.max(image_nofill) - np.min(image_nofill)
            img_med = np.median(image_nofill)
#             print(img, img_std, img_range, img_med)
            
            if img_std < 0.04 and img_med > 0.15:
                os.remove(imagepath+img) # remove png mimage
                os.remove(imagepath+img[:-4]+'.TIF') # remove pgm image
#                 imgplt_trim = plt.imshow(cv2.cvtColor(imageplt, cv2.COLOR_BGR2RGB))
#                 plt.show()

# %% [markdown]
# # 7) Grab fraction of total images available that were cloudy

# %%
boxes_pr_df = pd.read_csv(basepath+'LS_pathrows_sample10.csv', dtype=str)
boxes_pr_df = boxes_pr_df.set_index('BoxID'); BoxIDs = list(set(boxes_pr_df.index))
print(BoxIDs); boxes_pr_df.head()
# Out:
# ['002', '033', '531', '277', '174', '235', '259', '001', '120', '004']
#       Unnamed: 0 Path  Row Zone
# BoxID
# 001           37  036  004   19
# 001           36  037  004   19
# 001           20  035  005   18
# 001           25  033  005   19
# 001           22  034  005   19

# %%
im_tots = []; downloaded = []; fractions = [];

for BoxID in BoxIDs:
    pathrows_BoxID = boxes_pr_df[boxes_pr_df.index == BoxID].copy() # grab path rows for that BoxID
    
    im_tot = 0 # count number of total images
    for idx, rw in pathrows_BoxID.iterrows():
        p = rw['Path']; r = rw['Row']
        ims_pr = len(os.listdir(downloadpath+'Path'+p+'_Row'+r+'_c1')) # grab number of scenes in that pathrow
        im_tot = im_tot + ims_pr
    
    counter = 0
    if im_tot == 0:
        download_frac = np.NaN
    else:
        # find number downloaded (not cloudy) from the BoxID folder
        for file in os.listdir(downloadpath+'Box'+BoxID+'/reprojected/'):
            if file.startswith('LC08') and file.endswith('.png') and 'B8' in file:
                counter = counter + 1
            
        download_frac = int(counter/im_tot*100) # grab fraction downloaded
        
    im_tots.append(im_tot); downloaded.append(counter); fractions.append(download_frac)
    
downloaded_df = pd.DataFrame(list(zip(BoxIDs, im_tots, downloaded, fractions)), columns = ['BoxID', 'Total_ims', 'Downloaded', '%'])
downloaded_df
# Out:
#   BoxID  Total_ims  Downloaded   %
# 0   002        660         423  64
# 1   033        610         386  63
# 2   531       1151         593  51
# 3   277        312         205  65
# 4   174        263         152  57
# 5   235        321         192  59
# 6   259        321         188  58
# 7   001        757         413  54
# 8   120        393         224  56
# 9   004        740         440  59

# %% [markdown]
# #### Write information on number of cloudy images to a csv file

# %%
CLOUDY_NAME = 'Images_downloaded_sample10.csv'
downloaded_df.to_csv(basepath+CLOUDY_NAME, sep=',')

# %% [markdown]
# # 8) Calculate weighted average flow direction for each glacier

# %% [markdown]
# The following code processes ice velocity rasters to determine each glacier of interest's weighted average flow direction. The rasters are subset using the terminus box shapefile using a GDAL command (**gdalwarp**) with the following syntax:
#
#     gdalwarp -cutline path_to_terminusbox.shp -crop_to_cutline path_to_input_velocity.TIF path_to_output_velocity_at_term###.TIF

# %%
for BoxID in BoxIDs:
    terminus_path = basepath+"Box"+BoxID+"/RGI_Box"+BoxID+".shp"  # set path to RGI shapefiles
    vx = 'greenland_vel_mosaic250_vx_v1.tif';vy = 'greenland_vel_mosaic250_vy_v1.tif' # names of velocity files
    
    if os.path.exists(terminus_path) == False: # if the RGI shapefile does not exist
        terminus_path = basepath+"Box"+BoxID+"/Box"+BoxID+".shp"  # set the path to the box shapefile instead       
        #SET output paths
        vx_out = basepath+"Box"+BoxID+"/Box"+BoxID+'_'+vx; vy_out = basepath+"Box"+BoxID+"/Box"+BoxID+'_'+vy; 
    else:
        #SET output paths
        vx_out = basepath+"Box"+BoxID+"/RGI_Box"+BoxID+'_'+vx; vy_out = basepath+"Box"+BoxID+"/RGI_Box"+BoxID+'_'+vy; 
        
    vx_in = basepath+vx; vy_in = basepath+vy #set input paths
        
    #SET velocity subset commands and print to check it
    v_subset1 = 'gdalwarp -cutline '+terminus_path+' -crop_to_cutline '+vx_in+" "+vx_out
    v_subset2 = 'gdalwarp -cutline '+terminus_path+' -crop_to_cutline '+vy_in+" "+vy_out
#         print(v_subset_dir_cmd); print(v_subset_mag_cmd)

    #SUBSET velocity rasters
    subprocess.call(v_subset1, shell=True)
    subprocess.call(v_subset2, shell=True)
    
    print("Box"+BoxID+' done.')
# Out:
# Box033 done.
# Box120 done.
# Box174 done.
# Box259 done.
# Box235 done.
# Box002 done.
# Box531 done.
# Box277 done.
# Box004 done.
# Box001 done.

# %% [markdown]
# Next, these subset velocity rasters are opened using the **rasterio** package and read into arrays. They are filtered for anomalous values and the velocity magnitudes are converted into weights. Then the **numpy.average()** function is used to calculated the weighted average flow directions where the flow directions of the pixels where the highest velocities are found are weighted more.
#
# The resulting average flow direction will be representative of the glacier's main flow. These directions will be used to rotate the images of the glaciers so that their flow is due right.

# %%
#CREATE list of glacier average flow directions:
boxes = []; avg_rot = []; max_mag = []; num_cells = []

for BoxID in BoxIDs:
    rot_angles = []; max_magnitudes = []
    
    #READ velocity direction and magnitude data at terminus for each glacier into an array
    vx_name = 'greenland_vel_mosaic250_vx_v1.tif';vy_name = 'greenland_vel_mosaic250_vy_v1.tif'

    rgi_exists = 0
    for file in os.listdir(basepath+"Box"+BoxID):
        if file.startswith('RGI') and "greenland_vel" in file:
            rgi_exists = 1
    if rgi_exists == 1:      
        vx = rasterio.open(basepath+"Box"+BoxID+"/RGI_Box"+BoxID+'_'+vx_name, "r") # RGI
        vy = rasterio.open(basepath+"Box"+BoxID+"/RGI_Box"+BoxID+'_'+vy_name, "r") # RGI
    else:
        vx = rasterio.open(basepath+"Box"+BoxID+"/Box"+BoxID+'_'+vx_name, "r") # box 
        vy = rasterio.open(basepath+"Box"+BoxID+"/Box"+BoxID+'_'+vy_name, "r") # box
         
    vx_array = vx.read(); vy_array = vy.read()
    #remove no data values (-2000000000.0)
    vx_masked = vx_array[vx_array != -2000000000.0]; vy_masked = vy_array[vy_array != -2000000000.0]
        
    #CALCULATE FLOW DIRECTION
    direction = np.arctan2(vy_masked, vx_masked)*180/np.pi; 
#   print(BoxID, direction.max(), direction.min())
    #transform so any negative angles are placed on 0 to 360 scale:
    if len(direction[direction < 0]) > 0:
        direction[direction < 0] = 360.0+direction[direction < 0]
        
    #CALCULATE SPEED
    magnitude = np.sqrt((vx_masked*vx_masked) + (vy_masked*vy_masked)) 
        
    if len(direction) > 0: # if there are velocity values remaining
        # IF THERE ARE DIRECTIONS THAT HAVE A REALLY LARGE RANGE > 250.0 it's probably pointing East
        dir_range = direction.max() - direction.min()
        if dir_range > 200.0 and len(direction[direction >200]): # if large range and values above 200
            direction[direction > 180] = direction[direction > 180] - 360.0 # grab those values on a negative scale
            # CALCULATE the weighted average rotation angle
            # calculate weights (0 - 1) from magnitudes
            mag_range = magnitude.max() - magnitude.min(); stretch = 1/mag_range
            weights = stretch*(magnitude - magnitude.min())
            avg_dir = np.average(direction, weights=weights)
            max_magnitude = magnitude.max()*0.00273973 # conversion to m/d?
#           print("East!", avg_dir)
            if avg_dir < 0:
                avg_dir = avg_dir + 360.0 # transform back to 0 to 360 scale
        else:
            mag_range = magnitude.max() - magnitude.min()
            stretch = 1/mag_range
            weights = stretch*(magnitude - magnitude.min())
            avg_dir = np.average(direction, weights=weights)
    #           print(avg_dir)
            max_magnitude = magnitude.max()*0.00273973 # conversion to m/d?
    else:
        avg_dir = np.NaN ; max_magnitude = np.NaN # no velocities to calculate this with

    #APPEND to lists:
    avg_rot.append(avg_dir); max_mag.append(max_magnitude); boxes.append(BoxID); num_cells.append(len(direction))
        
velocities_df = pd.DataFrame(list(zip(boxes,avg_rot, max_mag, num_cells)), columns=['BoxID','Flow_dir', 'Max_speed', 'Pixels'])
velocities_df = velocities_df.sort_values(by='BoxID')
velocities_df = velocities_df.drop_duplicates()
velocities_df
# Out:
#   BoxID    Flow_dir  Max_speed  Pixels
# 9   001   67.897476   0.180412       2
# 5   002  148.929230   3.607409      69
# 8   004   72.612289   0.335084     124
# 0   033  146.154556   1.765913      35
# 1   120  291.797958   0.641524    1122
# 2   174   23.328474   2.126953    2831
# 4   235  209.207825   0.225594     159
# 3   259   60.295387   3.506471    2847
# 7   277  307.169334   0.147524      11
# 6   531   24.826708   0.047760     408

# %% [markdown]
# #### Write glacier velocities to a csv file

# %%
VEL_NAME = 'Glacier_vel_measures_sample10.csv'
velocities_df.to_csv(path_or_buf = basepath+VEL_NAME, sep=',')

# %% [markdown]
# # 9) Rotate all images by flow direction
#
# Read in the glacier velocity file as velocities_df if not already loaded:

# %%
# velocities_df = pd.read_csv(basepath+'Glacier_vel_measures_SE.csv', sep=',', dtype=str)
velocities_df = pd.read_csv(basepath+'Glacier_vel_measures_sample10.csv', sep=',', dtype=str, usecols=[1,2,3,4])
velocities_df = velocities_df.set_index('BoxID')
# velocities_df = velocities_df.drop(['004', '033', '235', '277', '531'])
velocities_df
# Out:
#                  Flow_dir             Max_speed Pixels
# BoxID
# 001     67.89747619628906   0.18041196880882263      2
# 002    148.92922973632812    3.6074087115783695     69
# 004     72.61228942871094   0.33508397443992616    124
# 033    146.15455627441406    1.7659133388775636     35
# 120    291.79795837402344    0.6415244847628785   1122
# 174    23.328474044799805      2.12695269746521   2831
# 235    209.20782470703125   0.22559381039527893    159
# 259    60.295387268066406    3.5064711321069337   2847
# 277     307.1693344116211   0.14752424545749665     11
# 531     24.82670783996582  0.047760089468879705    408

# %%
#make directory for rotated images in BoxID folders if it doesn't already exist
for index, row in velocities_df.iterrows():
    BoxID = index
    if os.path.exists(downloadpath+"Box"+BoxID+'/rotated_c1/'):
        print("Already exists.")
#         shutil.rmtree(downloadpath+"Box"+BoxID+'/reprojected/') # DELETE ROTATED IMAGES
        #OTHERWISE, create the folder and download into it
    else:
        os.mkdir(downloadpath+"Box"+BoxID+'/rotated_c1/')
        print("Folder made for Box"+BoxID)
# Out:
# Already exists.
# Already exists.
# Already exists.
# Already exists.
# Already exists.
# Already exists.
# Already exists.
# Already exists.
# Already exists.
# Already exists.

# %%
#move rasterized terminus box into reprojected folder:
for index, row in velocities_df.iterrows():
    BoxID = index
    boxfile = 'Box'+BoxID+'_raster_cut.TIF'
    boxrasterpath = basepath+'Box'+BoxID+'/'+boxfile
    newpath = downloadpath+'Box'+BoxID+'/reprojected/'+boxfile
    shutil.copyfile(boxrasterpath, newpath)

# %%
#convert rasterized box into png
for index, row in velocities_df.iterrows():
    BoxID = index
    command = 'cd '+downloadpath+'Box'+BoxID+'/reprojected/; '+'mogrify -format png *raster_cut.TIF'
#     print(command)
    subprocess.call(command, shell=True)

# %%
#ROTATE THE IMAGES IF VELOCITIES ARE GOOD
for index, row in velocities_df.iterrows():
    BoxID = index
    print(BoxID)
    #for each file in the reprojected folder:
    for file in os.listdir(downloadpath+"Box"+BoxID+'/reprojected/'):
        if file.endswith('.png') and file.startswith("LC08"):
            img  = Image.open(downloadpath+"Box"+BoxID+'/reprojected/'+file)
            rotated = img.rotate(-float(row['Flow_dir']))
            rotated.save(downloadpath+"Box"+BoxID+'/rotated_c1/R_'+file)
# Out:
# 001
# 002
# 004
# 033
# 120
# 174
# 235
# 259
# 277
# 531

# %% [markdown]
# # 10) Resize all images to the same size (the minimum image size)
#
# Uses the function resize_pngs which resizes all png files within a folder to the minimum image dimensions found. Centers images when cropping around the edges.

# %%
for index, row in velocities_df.iterrows():
    BoxID = index
    print(BoxID)
    resizepath = downloadpath+"Box"+BoxID+'/rotated_c1/'
    resize_pngs(resizepath)
# Out:
# 001
# 002
# 004
# Something is funky with the image dimesions for this Box
# 033
# 120
# 174
# 235
# 259
# 277
# 531

# %% [markdown]
# #### Convert these any png images to pgm for Xsmurf analysis:

# %%
#convert all final files to pgm
for index, row in velocities_df.iterrows():
    BoxID = index
    command = 'cd '+downloadpath+'Box'+BoxID+'/rotated_c1/; '+'mogrify -depth 16 -format pgm *.png'
    subprocess.call(command, shell=True)

# %%
# # rename the rasterized terminus box files if necessary
# for index, row in velocities_df.iterrows():
#     BoxID = index
#     files = os.listdir(downloadpath+'Box'+BoxID+'/rotated_c1/')
#     for file in files:
#         if file.startswith('R_Box'+BoxID+'_cut'):
#             rpath = downloadpath+'Box'+BoxID+'/rotated_c1/'
#             os.rename(rpath+file, rpath+'R_Box'+BoxID+'_raster_cut'+file[-4:])
