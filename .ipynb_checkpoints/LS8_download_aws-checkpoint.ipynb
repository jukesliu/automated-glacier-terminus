# %% [markdown]
# # Code to download LS8 images for Greenland peripheral glaciers using Amazon Web Services (aws)
#
# ### Jukes Liu
#
# The following code automatically downloads Landsat 8 scenes available through Amazon Web Services that have less than a threshold % of cloud cover. The Landsat 8 scenes over each glacier are identified using their pre-determined path and row, stored in a .csv file. The scenes are filtered for cloud cover using their metadata files.

# %% [markdown]
# ## 1) Set up:

# %% [markdown]
# #### Install AWS using pip or pip3
#
# Must have Amazon Web Services installed on your terminal. Follow instructions at https://docs.aws.amazon.com/cli/latest/userguide/install-linux-al2017.html to get aws commands onto your shell terminal.

# %% [markdown]
# #### Import packages

# %%
import pandas as pd
import numpy as np
import os
import subprocess

# %% [markdown]
# #### Read in LS path and row for each peripheral glacier by BoxID into a DataFrame

# %% [markdown]
# The LS Path and Row information for each peripheral glacier is stored in a .csv file.
#
# Note: Many glaciers exist in the same Landsat scene, so some Paths and Rows are repeated. Therefore, the subsequent code will not repeat download for a path and row combination that already exists in the output directory.

# %%
#set basepath
basepath = '/home/jukes/Documents/Sample_glaciers/'
#basepath = '/home/automated-glacier-terminus/'
outputpath = '/media/jukes/jukes1/'

#read the path row csv file into a dataframe
pathrows_df = pd.read_csv(basepath+'LS_pathrows.csv', sep=',', usecols =[0,1,2], dtype=str, nrows =10)
pathrows_df = pathrows_df.set_index('BoxID')
pathrows_df
# Out:
#       Path  Row
# BoxID
# 001    034  005
# 002    031  005
# 004    031  005
# 033    008  014
# 120    232  017
# 174    232  017
# 235    232  015
# 259    232  015
# 277    232  015
# 531    011  002

# %%
#check the df dimensions
pathrows_df.shape
# Out:
# (10, 2)

# %% [markdown]
# #### Create output directory: LS8aws

# %%
#create LS8aws folder
if os.path.exists(outputpath+'LS8aws')==True:
    print("Path exists already")
else:
    os.mkdir(outputpath+'LS8aws')
    print("LS8aws directory made")
# Out:
# Path exists already

# %% [markdown]
# ## 2) Download B8 (panchromatic band) and MTL.txt (metadata) files for all available images over the path/row of the glaciers

# %% [markdown]
# The Landsat8 scenes stored in AWS can be accessed using the landsat-pds bucket and the path and row information. Each of the bands and a metadata file can be accessed separately.
#
# We are interested in the panchromatic band (B8.TIF) and the metadata file to filter for cloud cover (MTL.txt). The download commands will use the following syntax:
#
#
#     aws --no-sign-request s3 cp s3://landsat-pds/L8/path/row/LC8pathrowyear001LGN00/LC8pathrowyear001LGN00_MTL.txt /path_to/output/
#
#     aws --no-sign-request s3 cp s3://landsat-pds/L8/path/row/LC8pathrowyear001LGN00/LC8pathrowyear001LGN00_B8.TIF /path_to/output/
#
# Access https://docs.opendata.aws/landsat-pds/readme.html to learn more.

# %% [markdown]
# ### 2A) Option 1: For one BoxID (one glacier) at a time

# %%
#choose a glacier: Box002
boxid = pathrows_df.index[1]
path = pathrows_df['Path'][1]
row = pathrows_df['Row'][1] 
print('BoxID ', boxid, 'path', path, 'row', row)

#set path row folder name
folder_name = 'Path'+path+'_Row'+row
print(folder_name)

#set input path
bp_in = 's3://landsat-pds/L8/'
totalp_in = bp_in+path+'/'+row+'/'
print(totalp_in)

#set output path
bp_out = outputpath+'LS8aws/'+folder_name+'/'
print(bp_out)
# Out:
# BoxID  002 path 031 row 005
# Path031_Row005
# s3://landsat-pds/L8/031/005/
# /media/jukes/jukes1/LS8aws/Path031_Row005/

# %% [markdown]
# #### Create the Path_Row folder

# %%
#create Path_row folder and write path names to txt files
if os.path.exists(bp_out):
    print(folder_name, " EXISTS ALREADY. SKIP.")
else:
    os.mkdir(bp_out)
    print(folder_name+" directory made")
# Out:
# Path031_Row005  EXISTS ALREADY. SKIP.

# %% [markdown]
# #### Download all the metadata text files using os.system aws commands

# %% [markdown]
# Use the following syntax:
#
#     aws --no-sign-request s3 cp s3://landsat-pds/L8/031/005/ Output/path/LS8aws/Path031_Row005/ --recursive --exclude "*" --include "*.txt"

# %%
#Check command syntax:
command = 'aws --no-sign-request s3 cp '+totalp_in+' '+bp_out+' --recursive --exclude "*" --include "*.txt"'
print(command)
# Out:
# aws --no-sign-request s3 cp s3://landsat-pds/L8/031/005/ /media/jukes/jukes1/LS8aws/Path031_Row005/ --recursive --exclude "*" --include "*.txt"

# %%
#call the command line that downloads the metadata files using aws
subprocess.call(command, shell=True)
# Out:
# 0

# %% [markdown]
# #### Filter for cloud cover
#
# If the metadata files indicate land cloud cover is less than the threshold, then download the B8, otherwise, delete the folder. Not all metadata files contain the land cloud cover, some only contain the overall cloud cover. If land cloud cover is not found, use the cloud cover value to determine whether the image should be downloaded .Use the following metadata attributes:
#
#   GROUP = IMAGE_ATTRIBUTES
#
#     CLOUD_COVER = 23.58
#     CLOUD_COVER_LAND = 20.41

# %%
#set cloud cover % thresholds
ccland_thresh = 30.0
cc_thresh = 50.0

#set paths:
#set path row folder name
folder_name = 'Path'+path+'_Row'+row
print(folder_name)

#set input path
bp_in = 's3://landsat-pds/L8/'
totalp_in = bp_in+path+'/'+row+'/'
print(totalp_in)

#set output path
bp_out = outputpath+'LS8aws/'+folder_name+'/'
print(bp_out)
# Out:
# Path011_Row002
# s3://landsat-pds/L8/011/002/
# /media/jukes/jukes1/LS8aws/Path011_Row002/

# %%
#loop through all the metadata files in the path_row folder:
for image in os.listdir(bp_out):
    if image.startswith("LC"):
        #list the name of the image folder
        print(image)
        
        #open the metadata file within that folder
        mdata = open(bp_out+image+"/"+image+"_MTL.txt", "r")
        
        #set a detection variable for whether or not the metadata contains land cloud cover
        ccl_detected = False
        
        #loop through each line in metadata to find Land Cloud Cover
        for line in mdata:
            cc_variable = line.split("=")[0]
            
            #if there is land cloud cover:
            if ("CLOUD_COVER_LAND" in cc_variable):
                #save it:
                ccl = np.float(line.split("=")[1])
                         
                #switch the ccl_detected variable to True!
                ccl_detected = True
                    
                #if the ccl is less than the threshold, delete the file
                if ccl > ccland_thresh:
                    #remove the image directory
                    subprocess.call('rm -r '+bp_out+image, shell=True)
                    print(ccl, ' > ', ccland_thresh, ", ", image, "removed")
                #otherwise: 
                else:
                    #DOWNLOAD THE B8 FILE
                    subprocess.call('source activate aws; aws --no-sign-request s3 cp '+totalp_in+' '+bp_out+' --recursive --exclude "*" --include "*B8.TIF"', shell=True)
                    print(image, "B8 downloaded -ccl ")
        
        #Was the ccl detected?
        print("CCL detected = ", ccl_detected)
                        
        #if False,use the overall cloud cover:
        if ccl_detected == False:   
            print("CCL not detected, use CC.")
            
            #open the metadata file again
            mdata = open(bp_out+image+"/"+image+"_MTL.txt", "r")
            for line in mdata:
                variable = line.split("=")[0]
                
                #now there should only be one line starting with cloud_cover
                if ("CLOUD_COVER" in variable):       
                    #save the cloud cover:
                    cc = np.float(line.split("=")[1])

                    #if the cc is less than the threshold, delete the file:
                    if cc > cc_thresh:
                        #remove the image directory
                        subprocess.call('rm -r '+bp_out+image, shell=True)
                        print(cc, ' > ', cc_thresh, ", ", image, "removed")

                    #otherwise: 
                    else:
                        #DOWNLOAD THE B8 FILE
                        subprocess.call('source activate aws; aws --no-sign-request s3 cp '+totalp_in+' '+bp_out+' --recursive --exclude "*" --include "*B8.TIF"', shell=True)
                        print(image, "B8 downloaded -cc")
print('Done.')
# Out:
# LC80110022014214LGN00
# LC80110022014214LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80110022016140LGN00
# LC80110022016140LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80110022015153LGN00
# LC80110022015153LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80110022016268LGN00
# LC80110022016268LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80110022014230LGN00
# LC80110022014230LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80110022017094LGN00
# LC80110022017094LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80110022017110LGN00
# LC80110022017110LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80110022017078LGN00
# LC80110022017078LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80110022016204LGN00
# LC80110022016204LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80110022014246LGN00
# 93.23  >  30.0 ,  LC80110022014246LGN00 removed
# CCL detected =  True
# LC80110022016092LGN00
# LC80110022016092LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80110022013243LGN00
# LC80110022013243LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80110022016188LGN00
# 65.15  >  30.0 ,  LC80110022016188LGN00 removed
# CCL detected =  True
# LC80110022015217LGN00
# LC80110022015217LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80110022013115LGN01
# LC80110022013115LGN01 B8 downloaded -ccl
# CCL detected =  True
# LC80110022015201LGN00
# LC80110022015201LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80110022016220LGN00
# 73.05  >  30.0 ,  LC80110022016220LGN00 removed
# CCL detected =  True
# LC80110022015105LGN00
# CCL detected =  False
# CCL not detected, use CC.
# 63.21  >  50.0 ,  LC80110022015105LGN00 removed
# LC80110022014182LGN00
# 76.39  >  30.0 ,  LC80110022014182LGN00 removed
# CCL detected =  True
# LC80110022016252LGN00
# LC80110022016252LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80110022015089LGN00
# CCL detected =  False
# CCL not detected, use CC.
# LC80110022015089LGN00 B8 downloaded -cc
# LC80110022016108LGN00
# LC80110022016108LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80110022016124LGN00
# 72.28  >  30.0 ,  LC80110022016124LGN00 removed
# CCL detected =  True
# LC80110022015185LGN00
# LC80110022015185LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80110022013275LGN00
# LC80110022013275LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80110022016236LGN00
# 56.98  >  30.0 ,  LC80110022016236LGN00 removed
# CCL detected =  True
# LC80110022016076LGN00
# LC80110022016076LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80110022015249LGN00
# 87.35  >  30.0 ,  LC80110022015249LGN00 removed
# CCL detected =  True
# LC80110022015233LGN00
# 50.15  >  30.0 ,  LC80110022015233LGN00 removed
# CCL detected =  True
# LC80110022015121LGN00
# LC80110022015121LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80110022014150LGN00
# 31.51  >  30.0 ,  LC80110022014150LGN00 removed
# CCL detected =  True
# LC80110022013259LGN00
# LC80110022013259LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80110022015137LGN00
# LC80110022015137LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80110022014262LGN00
# CCL detected =  False
# CCL not detected, use CC.
# LC80110022014262LGN00 B8 downloaded -cc
# LC80110022014198LGN00
# 88.39  >  30.0 ,  LC80110022014198LGN00 removed
# CCL detected =  True
# LC80110022015169LGN00
# LC80110022015169LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80110022015073LGN00
# CCL detected =  False
# CCL not detected, use CC.
# LC80110022015073LGN00 B8 downloaded -cc
# LC80110022013147LGN00
# LC80110022013147LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80110022016156LGN00
# 63.56  >  30.0 ,  LC80110022016156LGN00 removed
# CCL detected =  True
# LC80110022014166LGN00
# LC80110022014166LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80110022016172LGN00
# 51.59  >  30.0 ,  LC80110022016172LGN00 removed
# CCL detected =  True

# %% [markdown]
# ### 2B) Option 2: For all glaciers, loop through the DataFrame and perform all the Option 1 steps

# %%
#SET cloud cover thresholds for filtering
ccland_thresh = 30.0
cc_thresh = 50.0



#LOOP through each of the glaciers in the DataFrame and download for each path and row
for i in range(0, len(pathrows_df.index)):
    #SET path and row variables to the LS path and rows of the box
    path = pathrows_df['Path'][i]
    row = pathrows_df['Row'][i]
    #print(path, row)
    
    #1) CREATE path and row folders to download into and set input output paths
    #SET path row folder name
    folder_name = 'Path'+path+'_Row'+row
    print(folder_name)
    
    #SET input path
    bp_in = 's3://landsat-pds/L8/'
    totalp_in = bp_in+path+'/'+row+'/'
    #print(totalp_in)

    #SET output path
    bp_out = outputpath+'LS8aws/'+folder_name+'/'
    
    
    
    #IF the folder exists, it's already been downloaded, do not attempt download.
    if os.path.exists(bp_out):
        print(folder_name, " EXISTS ALREADY. SKIP.")
    #2) OTHERWISE, create the folder and download into it
    else:
        os.mkdir(bp_out)
        print(folder_name+" directory made")

        
        #3) DOWNLOAD metadata files into the new path-row folder
        #CHECK COMMAND SYNTAX
        command = 'source activate aws; aws --no-sign-request s3 cp '+totalp_in+' '+bp_out+' --recursive --exclude "*" --include "*.txt"'
        #print(command)
        subprocess.call(command, shell=True)
        
        
        
        #4) LOOP through all the files in the path_row folder to download based on cloud cover
        # in the metadata files
        for image in os.listdir(bp_out):
            if image.startswith("LC"):
                #list the name of the image folder
                print(image)

                #open the metadata file within that folder
                mdata = open(bp_out+image+"/"+image+"_MTL.txt", "r")

                #set a detection variable for whether or not the metadata contains land cloud cover
                ccl_detected = False

                #loop through each line in metadata to find the land cloud cover
                for line in mdata:
                    cc_variable = line.split("=")[0]

                    #if there is land cloud cover:
                    if ("CLOUD_COVER_LAND" in cc_variable):
                        #save it:
                        ccl = np.float(line.split("=")[1])

                        #switch the ccl detected variable to True
                        ccl_detected = True

                        #if the ccl is less than the threshold, delete the file
                        if ccl > ccland_thresh:
                            #remove the image directory
                            #subprocess.call('rm -r '+bp_out+image, shell=True)
                            print(ccl, ' > ', ccland_thresh, ", ", image, "removed")
                        #otherwise: 
                        else:
                            #download the B8 file
                            subprocess.call('source activate aws; aws --no-sign-request s3 cp '+totalp_in+' '+bp_out+' --recursive --exclude "*" --include "*B8.TIF"', shell=True)
                            print(image, "B8 downloaded -ccl ")

                print("CCL detected = ", ccl_detected)

                #if False,use the overall cloud cover:
                if ccl_detected == False:   
                    print("CCL not detected, use CC.")

                    #open the metadata file again
                    mdata = open(bp_out+image+"/"+image+"_MTL.txt", "r")
                    for line in mdata:
                        variable = line.split("=")[0]

                        #now there should only be one line starting with cloud_cover
                        if ("CLOUD_COVER" in variable):       
                            #save the cloud cover:
                            cc = np.float(line.split("=")[1])

                            #if the cc is less than the threshold, delete the file:
                            if cc > cc_thresh:
                                #remove the image directory
                                #subprocess.call('rm -r '+bp_out+image, shell=True)
                                print(cc, ' > ', cc_thresh, ", ", image, "removed")

                            #otherwise: 
                            else:
                                #DOWNLOAD THE B8 FILE
                                subprocess.call('source activate aws; aws --no-sign-request s3 cp '+totalp_in+' '+bp_out+' --recursive --exclude "*" --include "*B8.TIF"', shell=True)
                                print(image, "B8 downloaded -cc")
# Out:
# Path034_Row005
# Path034_Row005 directory made
# LC80340052014215LGN00
# 84.84  >  30.0 ,  LC80340052014215LGN00 removed
# CCL detected =  True
# LC80340052013148LGN00
# LC80340052013148LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80340052016125LGN00
# LC80340052016125LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80340052014183LGN00
# 33.55  >  30.0 ,  LC80340052014183LGN00 removed
# CCL detected =  True
# LC80340052014135LGN00
# 52.56  >  30.0 ,  LC80340052014135LGN00 removed
# CCL detected =  True
# LC80340052016157LGN00
# LC80340052016157LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80340052015106LGN00
# CCL detected =  False
# CCL not detected, use CC.
# 52.51  >  50.0 ,  LC80340052015106LGN00 removed
# LC80340052016093LGN00
# LC80340052016093LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80340052015170LGN00
# 67.3  >  30.0 ,  LC80340052015170LGN00 removed
# CCL detected =  True
# LC80340052014247LGN00
# CCL detected =  False
# CCL not detected, use CC.
# LC80340052014247LGN00 B8 downloaded -cc
# LC80340052015202LGN00
# LC80340052015202LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80340052015266LGN00
# LC80340052015266LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80340052017079LGN00
# LC80340052017079LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80340052014087LGN00
# LC80340052014087LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80340052017095LGN00
# LC80340052017095LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80340052014231LGN00
# 73.26  >  30.0 ,  LC80340052014231LGN00 removed
# CCL detected =  True
# LC80340052014151LGN00
# 75.11  >  30.0 ,  LC80340052014151LGN00 removed
# CCL detected =  True
# LC80340052016141LGN00
# 45.85  >  30.0 ,  LC80340052016141LGN00 removed
# CCL detected =  True
# LC80340052016205LGN00
# LC80340052016205LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80340052014263LGN00
# CCL detected =  False
# CCL not detected, use CC.
# 60.95  >  50.0 ,  LC80340052014263LGN00 removed
# LC80340052016189LGN00
# LC80340052016189LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80340052015122LGN00
# LC80340052015122LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80340052014167LGN00
# 82.44  >  30.0 ,  LC80340052014167LGN00 removed
# CCL detected =  True
# LC80340052015090LGN00
# CCL detected =  False
# CCL not detected, use CC.
# LC80340052015090LGN00 B8 downloaded -cc
# LC80340052016237LGN00
# 30.53  >  30.0 ,  LC80340052016237LGN00 removed
# CCL detected =  True
# LC80340052016221LGN00
# LC80340052016221LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80340052015250LGN00
# 47.86  >  30.0 ,  LC80340052015250LGN00 removed
# CCL detected =  True
# LC80340052016061LGN00
# LC80340052016061LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80340052015234LGN00
# 57.86  >  30.0 ,  LC80340052015234LGN00 removed
# CCL detected =  True
# LC80340052016077LGN00
# LC80340052016077LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80340052015218LGN00
# 83.64  >  30.0 ,  LC80340052015218LGN00 removed
# CCL detected =  True
# LC80340052014103LGN00
# LC80340052014103LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80340052015282LGN00
# LC80340052015282LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80340052015138LGN00
# LC80340052015138LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80340052016285LGN00
# LC80340052016285LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80340052013260LGN00
# LC80340052013260LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80340052016253LGN00
# 72.53  >  30.0 ,  LC80340052016253LGN00 removed
# CCL detected =  True
# LC80340052016109LGN00
# LC80340052016109LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80340052013244LGN00
# 73.91  >  30.0 ,  LC80340052013244LGN00 removed
# CCL detected =  True
# LC80340052017111LGN00
# LC80340052017111LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80340052015154LGN00
# LC80340052015154LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80340052015074LGN00
# CCL detected =  False
# CCL not detected, use CC.
# LC80340052015074LGN00 B8 downloaded -cc
# LC80340052015186LGN00
# LC80340052015186LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80340052017063LGN00
# LC80340052017063LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80340052016173LGN00
# 64.06  >  30.0 ,  LC80340052016173LGN00 removed
# CCL detected =  True
# Path031_Row005
# Path031_Row005  EXISTS ALREADY. SKIP.
# Path031_Row005
# Path031_Row005  EXISTS ALREADY. SKIP.
# Path008_Row014
# Path008_Row014 directory made
# LC80080142016311LGN00
# LC80080142016311LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80080142014177LGN00
# 76.32  >  30.0 ,  LC80080142014177LGN00 removed
# CCL detected =  True
# LC80080142015132LGN00
# LC80080142015132LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80080142015292LGN00
# 46.74  >  30.0 ,  LC80080142015292LGN00 removed
# CCL detected =  True
# LC80080142015148LGN00
# 35.86  >  30.0 ,  LC80080142015148LGN00 removed
# CCL detected =  True
# LC80080142016103LGN00
# 77.91  >  30.0 ,  LC80080142016103LGN00 removed
# CCL detected =  True
# LC80080142016183LGN00
# LC80080142016183LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80080142016247LGN00
# LC80080142016247LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80080142016039LGN00
# LC80080142016039LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80080142016199LGN00
# 80.08  >  30.0 ,  LC80080142016199LGN00 removed
# CCL detected =  True
# LC80080142014049LGN00
# LC80080142014049LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80080142015180LGN00
# LC80080142015180LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80080142014225LGN00
# 95.9  >  30.0 ,  LC80080142014225LGN00 removed
# CCL detected =  True
# LC80080142014065LGN00
# 85.37  >  30.0 ,  LC80080142014065LGN00 removed
# CCL detected =  True
# LC80080142013110LGN01
# 31.3  >  30.0 ,  LC80080142013110LGN01 removed
# CCL detected =  True
# LC80080142014033LGN00
# LC80080142014033LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80080142016151LGN00
# 62.63  >  30.0 ,  LC80080142016151LGN00 removed
# CCL detected =  True
# LC80080142014241LGN00
# 94.23  >  30.0 ,  LC80080142014241LGN00 removed
# CCL detected =  True
# LC80080142015276LGN00
# LC80080142015276LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80080142017073LGN00
# LC80080142017073LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80080142014081LGN00
# LC80080142014081LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80080142014273LGN00
# 62.82  >  30.0 ,  LC80080142014273LGN00 removed
# CCL detected =  True
# LC80080142015100LGN00
# CCL detected =  False
# CCL not detected, use CC.
# 74.97  >  50.0 ,  LC80080142015100LGN00 removed
# LC80080142015228LGN00
# 80.05  >  30.0 ,  LC80080142015228LGN00 removed
# CCL detected =  True
# LC80080142014289LGN00
# CCL detected =  False
# CCL not detected, use CC.
# 86.15  >  50.0 ,  LC80080142014289LGN00 removed
# LC80080142016071LGN00
# 78.29  >  30.0 ,  LC80080142016071LGN00 removed
# CCL detected =  True
# LC80080142014097LGN00
# LC80080142014097LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80080142014209LGN00
# 79.79  >  30.0 ,  LC80080142014209LGN00 removed
# CCL detected =  True
# LC80080142016119LGN00
# LC80080142016119LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80080142014193LGN01
# CCL detected =  False
# CCL not detected, use CC.
# LC80080142014193LGN01 B8 downloaded -cc
# LC80080142014113LGN00
# LC80080142014113LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80080142015212LGN00
# LC80080142015212LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80080142016087LGN00
# 84.26  >  30.0 ,  LC80080142016087LGN00 removed
# CCL detected =  True
# LC80080142017025LGN00
# 35.28  >  30.0 ,  LC80080142017025LGN00 removed
# CCL detected =  True
# LC80080142014257LGN00
# 62.52  >  30.0 ,  LC80080142014257LGN00 removed
# CCL detected =  True
# LC80080142016295LGN00
# LC80080142016295LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80080142014161LGN00
# CCL detected =  False
# CCL not detected, use CC.
# LC80080142014161LGN00 B8 downloaded -cc
# LC80080142014305LGN00
# CCL detected =  False
# CCL not detected, use CC.
# LC80080142014305LGN00 B8 downloaded -cc
# LC80080142016135LGN00
# LC80080142016135LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80080142016215LGN00
# 45.36  >  30.0 ,  LC80080142016215LGN00 removed
# CCL detected =  True
# LC80080142016231LGN00
# LC80080142016231LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80080142014321LGN00
# CCL detected =  False
# CCL not detected, use CC.
# LC80080142014321LGN00 B8 downloaded -cc
# LC80080142015308LGN00
# LC80080142015308LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80080142013238LGN00
# 62.43  >  30.0 ,  LC80080142013238LGN00 removed
# CCL detected =  True
# LC80080142013302LGN00
# LC80080142013302LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80080142015196LGN00
# LC80080142015196LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80080142017105LGN00
# LC80080142017105LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80080142015244LGN00
# 76.35  >  30.0 ,  LC80080142015244LGN00 removed
# CCL detected =  True
# LC80080142015116LGN00
# LC80080142015116LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80080142015068LGN00
# 96.07  >  30.0 ,  LC80080142015068LGN00 removed
# CCL detected =  True
# LC80080142017089LGN00
# 36.21  >  30.0 ,  LC80080142017089LGN00 removed
# CCL detected =  True
# LC80080142015260LGN00
# 86.37  >  30.0 ,  LC80080142015260LGN00 removed
# CCL detected =  True
# LC80080142016263LGN00
# 35.76  >  30.0 ,  LC80080142016263LGN00 removed
# CCL detected =  True
# LC80080142017057LGN00
# LC80080142017057LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80080142013270LGN00
# 56.65  >  30.0 ,  LC80080142013270LGN00 removed
# CCL detected =  True
# LC80080142015164LGN00
# LC80080142015164LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80080142016167LGN00
# LC80080142016167LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC80080142016279LGN00
# 53.64  >  30.0 ,  LC80080142016279LGN00 removed
# CCL detected =  True
# LC80080142014145LGN00
# 42.02  >  30.0 ,  LC80080142014145LGN00 removed
# CCL detected =  True
# LC80080142014129LGN00
# CCL detected =  False
# CCL not detected, use CC.
# LC80080142014129LGN00 B8 downloaded -cc
# Path232_Row017
# Path232_Row017 directory made
# LC82320172014066LGN00
# LC82320172014066LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172013111LGN01
# LC82320172013111LGN01 B8 downloaded -ccl
# CCL detected =  True
# LC82320172016024LGN00
# LC82320172016024LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172016248LGN00
# 66.07  >  30.0 ,  LC82320172016248LGN00 removed
# CCL detected =  True
# LC82320172013319LGN00
# LC82320172013319LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172013255LGN00
# 47.36  >  30.0 ,  LC82320172013255LGN00 removed
# CCL detected =  True
# LC82320172016008LGN00
# LC82320172016008LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172015117LGN00
# 55.26  >  30.0 ,  LC82320172015117LGN00 removed
# CCL detected =  True
# LC82320172013271LGN00
# LC82320172013271LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172016136LGN00
# 74.11  >  30.0 ,  LC82320172016136LGN00 removed
# CCL detected =  True
# LC82320172016280LGN00
# 33.75  >  30.0 ,  LC82320172016280LGN00 removed
# CCL detected =  True
# LC82320172015309LGN00
# 34.48  >  30.0 ,  LC82320172015309LGN00 removed
# CCL detected =  True
# LC82320172016040LGN00
# LC82320172016040LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172015261LGN00
# 67.34  >  30.0 ,  LC82320172015261LGN00 removed
# CCL detected =  True
# LC82320172015213LGN00
# LC82320172015213LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172015053LGN00
# CCL detected =  False
# CCL not detected, use CC.
# LC82320172015053LGN00 B8 downloaded -cc
# LC82320172017074LGN00
# LC82320172017074LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172014258LGN00
# CCL detected =  False
# CCL not detected, use CC.
# LC82320172014258LGN00 B8 downloaded -cc
# LC82320172014098LGN00
# LC82320172014098LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172014338LGN00
# CCL detected =  False
# CCL not detected, use CC.
# LC82320172014338LGN00 B8 downloaded -cc
# LC82320172014226LGN00
# 83.66  >  30.0 ,  LC82320172014226LGN00 removed
# CCL detected =  True
# LC82320172014178LGN00
# LC82320172014178LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172017058LGN00
# 94.38  >  30.0 ,  LC82320172017058LGN00 removed
# CCL detected =  True
# LC82320172014274LGN00
# CCL detected =  False
# CCL not detected, use CC.
# LC82320172014274LGN00 B8 downloaded -cc
# LC82320172017026LGN00
# LC82320172017026LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172014194LGN00
# LC82320172014194LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172015181LGN00
# LC82320172015181LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172015165LGN00
# LC82320172015165LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172014002LGN00
# LC82320172014002LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172016296LGN00
# LC82320172016296LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172016200LGN00
# LC82320172016200LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172015037LGN00
# CCL detected =  False
# CCL not detected, use CC.
# LC82320172015037LGN00 B8 downloaded -cc
# LC82320172016088LGN00
# LC82320172016088LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172016120LGN00
# 38.21  >  30.0 ,  LC82320172016120LGN00 removed
# CCL detected =  True
# LC82320172017042LGN00
# 63.68  >  30.0 ,  LC82320172017042LGN00 removed
# CCL detected =  True
# LC82320172014242LGN00
# 77.39  >  30.0 ,  LC82320172014242LGN00 removed
# CCL detected =  True
# LC82320172015069LGN00
# LC82320172015069LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172016184LGN00
# LC82320172016184LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172014018LGN00
# LC82320172014018LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172014290LGN00
# CCL detected =  False
# CCL not detected, use CC.
# 64.48  >  50.0 ,  LC82320172014290LGN00 removed
# LC82320172015325LGN00
# LC82320172015325LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172016232LGN00
# 78.76  >  30.0 ,  LC82320172016232LGN00 removed
# CCL detected =  True
# LC82320172017010LGN00
# LC82320172017010LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172016344LGN00
# LC82320172016344LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172015197LGN00
# LC82320172015197LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172015277LGN00
# LC82320172015277LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172016104LGN00
# LC82320172016104LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172016168LGN00
# 38.45  >  30.0 ,  LC82320172016168LGN00 removed
# CCL detected =  True
# LC82320172015149LGN00
# 38.02  >  30.0 ,  LC82320172015149LGN00 removed
# CCL detected =  True
# LC82320172016328LGN00
# LC82320172016328LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172015085LGN00
# CCL detected =  False
# CCL not detected, use CC.
# LC82320172015085LGN00 B8 downloaded -cc
# LC82320172014130LGN00
# LC82320172014130LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172016056LGN00
# 82.26  >  30.0 ,  LC82320172016056LGN00 removed
# CCL detected =  True
# LC82320172016312LGN00
# LC82320172016312LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172016072LGN00
# LC82320172016072LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172015293LGN00
# 38.51  >  30.0 ,  LC82320172015293LGN00 removed
# CCL detected =  True
# LC82320172015245LGN00
# 48.0  >  30.0 ,  LC82320172015245LGN00 removed
# CCL detected =  True
# LC82320172016264LGN00
# LC82320172016264LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172014306LGN00
# CCL detected =  False
# CCL not detected, use CC.
# LC82320172014306LGN00 B8 downloaded -cc
# LC82320172014114LGN00
# 88.83  >  30.0 ,  LC82320172014114LGN00 removed
# CCL detected =  True
# LC82320172016216LGN00
# 45.58  >  30.0 ,  LC82320172016216LGN00 removed
# CCL detected =  True
# LC82320172015341LGN00
# LC82320172015341LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172014322LGN00
# CCL detected =  False
# CCL not detected, use CC.
# LC82320172014322LGN00 B8 downloaded -cc
# LC82320172015229LGN00
# 45.08  >  30.0 ,  LC82320172015229LGN00 removed
# CCL detected =  True
# LC82320172014210LGN00
# LC82320172014210LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172015005LGN00
# CCL detected =  False
# CCL not detected, use CC.
# LC82320172015005LGN00 B8 downloaded -cc
# LC82320172014162LGN00
# 95.57  >  30.0 ,  LC82320172014162LGN00 removed
# CCL detected =  True
# LC82320172016152LGN00
# 64.9  >  30.0 ,  LC82320172016152LGN00 removed
# CCL detected =  True
# LC82320172014146LGN00
# LC82320172014146LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172015101LGN00
# CCL detected =  False
# CCL not detected, use CC.
# 55.4  >  50.0 ,  LC82320172015101LGN00 removed
# LC82320172015021LGN00
# CCL detected =  False
# CCL not detected, use CC.
# LC82320172015021LGN00 B8 downloaded -cc
# LC82320172017090LGN00
# LC82320172017090LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320172013143LGN01
# 40.02  >  30.0 ,  LC82320172013143LGN01 removed
# CCL detected =  True
# LC82320172015133LGN00
# LC82320172015133LGN00 B8 downloaded -ccl
# CCL detected =  True
# Path232_Row017
# Path232_Row017  EXISTS ALREADY. SKIP.
# Path232_Row015
# Path232_Row015 directory made
# LC82320152013111LGN01
# LC82320152013111LGN01 B8 downloaded -ccl
# CCL detected =  True
# LC82320152016056LGN00
# 73.7  >  30.0 ,  LC82320152016056LGN00 removed
# CCL detected =  True
# LC82320152015309LGN00
# LC82320152015309LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320152015181LGN00
# LC82320152015181LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320152015325LGN00
# LC82320152015325LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320152017074LGN00
# LC82320152017074LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320152016264LGN00
# 71.21  >  30.0 ,  LC82320152016264LGN00 removed
# CCL detected =  True
# LC82320152015085LGN00
# CCL detected =  False
# CCL not detected, use CC.
# 62.8  >  50.0 ,  LC82320152015085LGN00 removed
# LC82320152016136LGN00
# LC82320152016136LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320152017058LGN00
# 99.85  >  30.0 ,  LC82320152017058LGN00 removed
# CCL detected =  True
# LC82320152013255LGN00
# LC82320152013255LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320152016296LGN00
# 57.98  >  30.0 ,  LC82320152016296LGN00 removed
# CCL detected =  True
# LC82320152016168LGN00
# LC82320152016168LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320152016216LGN00
# LC82320152016216LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320152016280LGN00
# 73.16  >  30.0 ,  LC82320152016280LGN00 removed
# CCL detected =  True
# LC82320152015037LGN00
# CCL detected =  False
# CCL not detected, use CC.
# LC82320152015037LGN00 B8 downloaded -cc
# LC82320152014290LGN00
# CCL detected =  False
# CCL not detected, use CC.
# 85.51  >  50.0 ,  LC82320152014290LGN00 removed
# LC82320152014066LGN00
# LC82320152014066LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320152015245LGN00
# 31.15  >  30.0 ,  LC82320152015245LGN00 removed
# CCL detected =  True
# LC82320152014162LGN00
# 36.08  >  30.0 ,  LC82320152014162LGN00 removed
# CCL detected =  True
# LC82320152016184LGN00
# LC82320152016184LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320152016312LGN00
# LC82320152016312LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320152017026LGN00
# LC82320152017026LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320152015229LGN00
# LC82320152015229LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320152014258LGN00
# CCL detected =  False
# CCL not detected, use CC.
# LC82320152014258LGN00 B8 downloaded -cc
# LC82320152015277LGN00
# LC82320152015277LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320152015197LGN00
# LC82320152015197LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320152014098LGN00
# LC82320152014098LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320152015021LGN00
# CCL detected =  False
# CCL not detected, use CC.
# LC82320152015021LGN00 B8 downloaded -cc
# LC82320152016072LGN00
# 75.43  >  30.0 ,  LC82320152016072LGN00 removed
# CCL detected =  True
# LC82320152015117LGN00
# LC82320152015117LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320152014274LGN00
# CCL detected =  False
# CCL not detected, use CC.
# 66.01  >  50.0 ,  LC82320152014274LGN00 removed
# LC82320152015293LGN00
# 54.91  >  30.0 ,  LC82320152015293LGN00 removed
# CCL detected =  True
# LC82320152014306LGN00
# CCL detected =  False
# CCL not detected, use CC.
# LC82320152014306LGN00 B8 downloaded -cc
# LC82320152015101LGN00
# CCL detected =  False
# CCL not detected, use CC.
# LC82320152015101LGN00 B8 downloaded -cc
# LC82320152015261LGN00
# 60.93  >  30.0 ,  LC82320152015261LGN00 removed
# CCL detected =  True
# LC82320152015053LGN00
# CCL detected =  False
# CCL not detected, use CC.
# LC82320152015053LGN00 B8 downloaded -cc
# LC82320152016120LGN00
# LC82320152016120LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320152014146LGN00
# LC82320152014146LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320152015165LGN00
# LC82320152015165LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320152015213LGN00
# LC82320152015213LGN00 B8 downloaded -ccl
# CCL detected =  True
# LC82320152014210LGN00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-db5d543f5c26> in <module>
#      77                         else:
#      78                             #download the B8 file
# ---> 79                             subprocess.call('source activate aws; aws --no-sign-request s3 cp '+totalp_in+' '+bp_out+' --recursive --exclude "*" --include "*B8.TIF"', shell=True)
#      80                             print(image, "B8 downloaded -ccl ")
#      81
#
# ~/anaconda3/lib/python3.7/subprocess.py in call(timeout, *popenargs, **kwargs)
#     323     with Popen(*popenargs, **kwargs) as p:
#     324         try:
# --> 325             return p.wait(timeout=timeout)
#     326         except:  # Including KeyboardInterrupt, wait handled that.
#     327             p.kill()
#
# ~/anaconda3/lib/python3.7/subprocess.py in wait(self, timeout)
#     988             endtime = _time() + timeout
#     989         try:
# --> 990             return self._wait(timeout=timeout)
#     991         except KeyboardInterrupt:
#     992             # https://bugs.python.org/issue25942
#
# ~/anaconda3/lib/python3.7/subprocess.py in _wait(self, timeout)
#    1622                         if self.returncode is not None:
#    1623                             break  # Another thread waited.
# -> 1624                         (pid, sts) = self._try_wait(0)
#    1625                         # Check the pid and loop as waitpid has been known to
#    1626                         # return 0 even without WNOHANG in odd situations.
#
# ~/anaconda3/lib/python3.7/subprocess.py in _try_wait(self, wait_flags)
#    1580             """All callers to this function MUST hold self._waitpid_lock."""
#    1581             try:
# -> 1582                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1583             except ChildProcessError:
#    1584                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %% [markdown]
# ## 3) Grab image dates from the metadata

# %%
import datetime

#create dictionary of datetime objects for the images:
datetime_objs = {}

scenecount = 0

#LOOP through each of the glaciers in the DataFrame and download for each path and row
for i in range(0, len(pathrows_df.index)):
    #SET path and row variables to the LS path and rows of the box
    path = pathrows_df['Path'][i]
    row = pathrows_df['Row'][i]
    #print(path, row)
    
    #SET path row folder name
    folder_name = 'Path'+path+'_Row'+row
#     print(folder_name)
    
    #SET output path
    bp_out = outputpath+'LS8aws/'+folder_name+'/'
        
        
    # LOOP through all the metadata files in the path_row folder to grab the image dates
    # in the metadata files
    for scene in os.listdir(bp_out):
        if scene.startswith("LC"):
            #list the name of the image folder
#             print(scene)
            scenetag = scene[9:19]
#             print(scenetag)
            scenecount = scenecount+1

            #open the metadata file within that folder
            for file in os.listdir(bp_out+scene+"/"):
#                 #if no metadata file is there, skip it
#                 datetime_objs.update( {scene: "Nan"})
                
                if ("MTL.txt" in file):
                    
                    mdata = open(bp_out+scene+"/"+scene+"_MTL.txt", "r")

                    #loop through each line in metadata to find the date and time of acquisition
                    for line in mdata:
                        variable = line.split("=")[0]

                        if ("DATE_ACQUIRED" in variable):
                            #save it:
                            date = line.split("=")[1][1:-1]
#                             print(date)

                        #if ("SCENE_CENTER_TIME" in variable): 
                            #save it:
                            #time = line.split("=")[1][2:-2]
                            #print(time)
                
                    #combine them into a datetime object
                    datetime_obj = datetime.datetime.strptime(date, '%Y-%m-%d')
                    datetime_objs.update( {scene[4:-5]: datetime_obj} )
                         

datetime_df = pd.DataFrame.from_dict(datetime_objs, orient='index')
datetime_df
# Out:
#                       0
# 340052014215 2014-08-03
# 340052013148 2013-05-28
# 340052016125 2016-05-04
# 340052014183 2014-07-02
# 340052014135 2014-05-15
# 340052016157 2016-06-05
# 340052015106 2015-04-16
# 340052016093 2016-04-02
# 340052015170 2015-06-19
# 340052014247 2014-09-04
# 340052015202 2015-07-21
# 340052015266 2015-09-23
# 340052017079 2017-03-20
# 340052014087 2014-03-28
# 340052017095 2017-04-05
# 340052014231 2014-08-19
# 340052014151 2014-05-31
# 340052016141 2016-05-20
# 340052016205 2016-07-23
# 340052014263 2014-09-20
# 340052016189 2016-07-07
# 340052015122 2015-05-02
# 340052014167 2014-06-16
# 340052015090 2015-03-31
# 340052016237 2016-08-24
# 340052016221 2016-08-08
# 340052015250 2015-09-07
# 340052016061 2016-03-01
# 340052015234 2015-08-22
# 340052016077 2016-03-17
# ...                 ...
# 110022016092 2016-04-01
# 110022013243 2013-08-31
# 110022016188 2016-07-06
# 110022015217 2015-08-05
# 110022013115 2013-04-25
# 110022015201 2015-07-20
# 110022016220 2016-08-07
# 110022015105 2015-04-15
# 110022014182 2014-07-01
# 110022016252 2016-09-08
# 110022015089 2015-03-30
# 110022016108 2016-04-17
# 110022016124 2016-05-03
# 110022015185 2015-07-04
# 110022013275 2013-10-02
# 110022016236 2016-08-23
# 110022016076 2016-03-16
# 110022015249 2015-09-06
# 110022015233 2015-08-21
# 110022015121 2015-05-01
# 110022014150 2014-05-30
# 110022013259 2013-09-16
# 110022015137 2015-05-17
# 110022014262 2014-09-19
# 110022014198 2014-07-17
# 110022015169 2015-06-18
# 110022015073 2015-03-14
# 110022013147 2013-05-27
# 110022016156 2016-06-04
# 110022014166 2014-06-15
#
# [331 rows x 1 columns]

# %% [markdown]
# Export image dates to .csv

# %%
datetime_df.to_csv(path_or_buf = basepath+'datetags.csv', sep=',')

# %% [markdown]
# ## For download using Google instead, follow these instructions:

# %% [markdown]
# Use gsutil: https://krstn.eu/landsat-batch-download-from-google/
#
# To access a scene for Path 124, Row 053, use this syntax:
#
# gsutil cp -n gs://earthengine-public/landsat/L8/124/053/LC81240532013107LGN01.tar.bz /landsat/
